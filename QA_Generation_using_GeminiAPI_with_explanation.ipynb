# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Deep-Learning-Experiments-implemented-using-Google-Colab/blob/master/QA_Generation_using_GeminiAPI_with_explanation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Say Goodbye to Endless Scrolling! Introducing AI-Powered Search for Support Docs
#
# **Headline: Stop Searching, Start Finding: Introducing Revolutionary AI-Powered Search for Support Documentation**
#
# ![dalle_improved_search.png](data:image/png;base64,...)
#
#
#
#
#
# **(Banner Image:  A visually appealing image representing fast and efficient search, perhaps an icon of a magnifying glass zooming in on a page number, or a person happily finding an answer on their phone/computer)**
#
#
#
# [illustrative image link](https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png)

# %% [markdown]
# ##Introduction
#
# Are you tired of spending precious minutes (or even hours!) wrestling with lengthy user manuals, just to find a simple answer to your question?  We know the frustration!  That's why we're thrilled to announce a game-changing improvement to how you access support information for your Galaxy devices: **Introducing AI-Powered Question Answering Search!**
#
# Forget shifting through entire PDFs and hoping to stumble upon the right paragraph.  Finding the help you need for your Samsung devices support docs just became dramatically faster, smarter, and more user-friendly.
#
# **Introducing Question-Based Search: Ask Naturally, Get Answers Directly**
#
# The days of guessing the right keywords are over!  Our brand new search engine is intelligent enough to understand your questions phrased in **natural, everyday language.**  Instead of struggling with technical jargon, simply **ask your question just like you would ask a support agent.**
#
# **Let's look at some examples:**
#
# Instead of typing:  `battery slow drain fix`
#
# Now, you can simply ask: **"Why is my phone battery draining so fast?"**
#
# Instantly, our AI-powered search engine dives deep into the support documentation and pulls out the **precise, most relevant answer**, presented to you directly:
#
# > **Answer:** Several factors can contribute to rapid battery drain, including using power-intensive apps (like games or video streaming), high screen brightness, always-on display, background app activity, and poor network signal strength. Optimizing your device settings and closing unnecessary apps can help improve battery life.
#
# **(Screenshot/Mockup:  Example search bar showing a natural language question and the concise answer displayed below)**
#
# No more wading through pages of text! Get straight to the point and find the solution you need in seconds.
#
# **Page Number Deep Linking:  Context is King - Dive Deeper When You Need To**
#
# But we didn't stop at just giving you quick answers. We understand that sometimes you need more context, detailed instructions, or want to explore related information. That's where our **revolutionary Page Number Deep Linking** comes in.
#
# Each AI-powered answer is **hyperlinked directly to the exact page number** within the official User Guide where that information originates.  Want to see the step-by-step guide, explore related tips, or understand the surrounding context?
#
# **Simply click the link, and you'll be instantly transported to the relevant page within the document.**
#
# **(Screenshot/Mockup: Example answer with a clearly visible page number link highlighted)**
#
# This powerful feature seamlessly bridges the gap between instant answers and comprehensive documentation, giving you the best of both worlds – speed and depth, all at your fingertips.
#
# **Goodbye Keyword Guesswork, Hello Intelligent Answers: A Leap Beyond Basic Search**
#
# Our previous keyword search, while helpful in its own way, could sometimes feel like searching for a needle in a haystack.  You'd often get a list of PDFs, and then the real work began – manually scanning each document to find your specific answer.
#
# **Here's how our new AI-Powered Search dramatically improves on traditional search methods like Elasticsearch:**
#
# | Feature                  | **Old Keyword Search (e.g., Elasticsearch)**                                   | **New AI-Powered Question Answering Search**                                     | **Benefit**                                                                  |
# | :----------------------- | :--------------------------------------------------------------------------- | :------------------------------------------------------------------------------- | :--------------------------------------------------------------------------- |
# | **Query Type**          | Keyword-based only                                                           | Natural language questions                                                     | More intuitive and user-friendly querying                                     |
# | **Search Results**       | List of PDFs or document sections, often requiring manual scanning           | Direct answers extracted from documents, displayed concisely                         | Faster access to relevant information, eliminates manual document sifting       |
# | **Relevance**            | Can be less precise, returning documents only tangentially related           | Highly relevant answers, focused on directly addressing the user's question        | More accurate and targeted results                                           |
# | **Navigation**           | PDF-level results, users must manually navigate within documents             | Page-level deep links, users jump directly to the answer's source in the document | Significantly faster navigation to detailed context and related information     |
# | **User Experience**      | Can be time-consuming and frustrating, especially for complex queries         | Fast, efficient, and intuitive, leading to a much smoother support experience    | Improved user satisfaction and self-service adoption                         |

# %% [markdown]
# ##Real-World Scenarios: See AI-Powered Search in Action
#
# Let's walk through a couple of common support scenarios to illustrate the power of this new feature:
#
# **Scenario 1: Maximizing Battery Life**
#
# *   **User Question:** "How do I conserve battery life on my Galaxy S25?"
# *   **AI-Powered Search Answer:** (Concise answer summarizing battery saving tips, with a clear link)
# *   **Result:** The user gets an immediate, actionable answer. Clicking the link takes them directly to **Page 14 of the User Guide**, where they can find detailed instructions on Power Saving Mode, closing background apps, adjusting screen brightness, and more.
#
# **(Screenshot/Mockup: Search interface showing "How do I conserve battery life..." question and answer with page 14 link)**
#
# **Scenario 2: Setting Up Wireless Power Sharing**
#
# *   **User Question:** "How do I use wireless power sharing to charge my Galaxy Buds?"
# *   **AI-Powered Search Answer:** (Concise answer explaining Wireless PowerShare, with a clear link)
# *   **Result:** The user receives quick instructions. Clicking the link navigates them to **Page 13 of the User Guide**, providing step-by-step guidance on enabling and using Wireless Power Sharing, along with important precautions.
#
# **(Screenshot/Mockup: Search interface showing "How do I use wireless power sharing..." question and answer with page 13 link)**
#
# **The Future is Intelligent Support: Ongoing Improvements**
#
# This launch is just the beginning of our journey to revolutionize support document accessibility! We're committed to continuously enhancing this AI-powered search experience.  Looking ahead, we're actively working on:
#
# *   **Semantic Search Enhancements:**  Making the search engine even smarter at understanding the *meaning* behind your questions, regardless of wording.
# *   **Expanding the QA Knowledge Base:**  Adding thousands more Question-Answer pairs to cover even more topics and Galaxy devices.
# *   **Answer Summarization directly in Search Results:** Providing even more concise answer previews directly within the search results, for ultimate speed.
#
# **Ready to Experience the Future of Support?**
#
# Don't waste another minute struggling to find answers!  **Try out our new AI-Powered Search today!** Visit our [**Link to your Support Documentation Portal Here**] and ask your Galaxy S25 questions in your own words.
#
# We're eager to hear your feedback! Let us know what you think and how we can make this feature even more valuable for you.  Your input will help us shape the future of intelligent support.
#
# **Conclusion:  Find Answers Faster, Get Back to Enjoying Your Galaxy**
#
# AI-Powered Search is a true game-changer for accessing support. It's designed to save you time, reduce frustration, and empower you to quickly resolve your questions and get back to enjoying your Galaxy S25 device.  We're confident you'll love the speed, efficiency, and user-friendliness of this exciting new feature. Happy searching!
#
# **(Footer: Samsung logo and copyright information)**

# %% [markdown]
# ## Extracting text from PDFs using pymupdf4llm

# %%
# !pip install pymupdf4llm==0.0.17 > /dev/null 2>&1

# %%
# !wget https://downloadcenter.samsung.com/content/UM/202501/20250124164253078/SM-S93X_UG_EU_15_Eng_Rev.1.0_250123.pdf

# %%
import pymupdf4llm

markdwon_text = pymupdf4llm.to_markdown('/content/SM-S93X_UG_EU_15_Eng_Rev.1.0_250123.pdf') #S25 User Manual
# Out:
# Processing /content/SM-S93X_UG_EU_15_Eng_Rev.1.0_250123.pdf...
# ]

# %%
generated_text = markdwon_text
content = markdwon_text
generated_text

# %%
def test_qa_generators(base_function_name, content, suffixes=["", "_deepseek", "_google", "_sonnet"]):
    """Tests and prints output for different QA generation functions."""
    for suffix in suffixes:
        function_name = base_function_name + suffix
        try:
            qa_function = globals()[function_name] # Get function from global scope
            print(f"\n--- Calling {function_name} ---")
            qa_output = qa_function(content)
            print(qa_output)
        except KeyError:
            print(f"\n--- Function {function_name} not found ---")
        except Exception as e:
            print(f"\n--- Error in {function_name} ---")
            print(f"Error details: {e}")

# %%
def test_qa_generators_aggregated(base_function_name, content, suffixes=["", "_deepseek", "_google", "_sonnet"]):
    """
    Tests different QA generation functions and returns aggregated results in a single JSON structure.

    Args:
        base_function_name (str): Base name of the QA generation function
        content (str): Content to process
        suffixes (list): List of suffixes for different model variants

    Returns:
        dict: Aggregated results with the following structure:
        {
            "base_function": str,
            "results": {
                "model_variant": result_dict,
                ...
            },
            "errors": {
                "model_variant": error_message,
                ...
            }
        }
    """
    aggregated_results = {
        "base_function": base_function_name,
        "results": {},
        "errors": {}
    }

    for suffix in suffixes:
        function_name = base_function_name + suffix
        model_variant = suffix if suffix else "default"

        try:
            qa_function = globals()[function_name]  # Get function from global scope
            qa_output = qa_function(content)
            aggregated_results["results"][model_variant] = qa_output

        except KeyError:
            error_msg = f"Function {function_name} not found"
            aggregated_results["errors"][model_variant] = error_msg

        except Exception as e:
            error_msg = f"Error in execution: {str(e)}"
            aggregated_results["errors"][model_variant] = error_msg

    return aggregated_results

# Example usage and pretty printing
import json

def print_aggregated_results(results):
    """Helper function to pretty print the aggregated results."""
    print(json.dumps(results, indent=2))

# %% [markdown]
# ## QA Pair Generation using Gemini *API*

# %%
import google.generativeai as genai
from google.colab import userdata
apikey=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=apikey)

# %% [markdown]
# ### Number 1 generate_structured_qa_pairs

# %%
#original
def generate_simple_qa_pairs(text):
    """General informative Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate fundamental Q&A pairs from Samsung support docs covering:
    - Key features - Basic troubleshooting - Usage guidelines
    Use consumer-friendly language with concise answers (1-2 sentences).
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent
import google.generativeai as genai

def generate_simple_qa_pairs_deepseek(text):
    """Generates Q&A pairs in a standardized JSON format.

    Returns:
        A JSON object with nested "Generations", "Questions", and "Answers".
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Q&A pairs from the Samsung support document below.
    Follow these rules:
    1. Include key features, troubleshooting steps, and usage guidelines.
    2. Use short, conversational questions and answers (1-2 sentences).
    3. Format output as JSON with a "Generations" key containing a list of Q&A objects.
    4. Structure each object as {{"Question": "...", "Answer": "..."}}.

    Example:
    {{
      "Generations": [
        {{"Question": "How do I restart my Galaxy phone?", "Answer": "Hold the power and volume down buttons for 10 seconds."}},
        {{"Question": "How to extend battery life?", "Answer": "Enable Power Saving Mode in Settings > Battery."}}
      ]
    }}

    Text: {text}
    """)

    response = model.generate_content(prompt).text
    # Remove markdown formatting (common in Gemini outputs)
    response = response.strip("` \n").replace("json", "")
    return json.loads(response)


#Google AI STudio
import google.generativeai as genai
from textwrap import dedent
import json

def generate_simple_qa_pairs_google(text):
    """
    Generates informative Q&A pairs from Samsung support docs and returns them in JSON format.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate fundamental Question and Answer pairs from the following Samsung support document text.
    Focus on:
    - Key features
    - Basic troubleshooting steps
    - Usage guidelines

    Format each question and answer pair clearly. Aim for consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries. Each dictionary should have the keys "Question" and "Answer".

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "..."}},
      {{"Question": "...", "Answer": "..."}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text) # Attempt to parse the response as JSON
    except json.JSONDecodeError:
        # If direct JSON parsing fails, fallback to a more robust extraction method
        print("Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.")
        # This fallback is a basic example, you might need more sophisticated parsing
        qa_list = []
        lines = response_text.strip().split('\n')
        for i in range(0, len(lines), 2): # Assuming Q and A alternate lines
            if i + 1 < len(lines):
                question = lines[i].strip().replace("Question:", "").strip() if "Question:" in lines[i] else lines[i].strip()
                answer = lines[i+1].strip().replace("Answer:", "").strip() if "Answer:" in lines[i+1] else lines[i+1].strip()
                qa_list.append({"Question": question, "Answer": answer})


    # Structure the output in the desired JSON format
    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair["Question"] for qa_pair in qa_list],
                "Answers": [qa_pair["Answer"] for qa_pair in qa_list]
            }
        ]
    }
    return json.dumps(output_json, indent=2) # Return JSON string with indent for readability


#Sonnet
def generate_simple_qa_pairs_sonnet(text):
    """Generate structured Q&A pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate comprehensive Q&A pairs from Samsung support docs in strict JSON format:
    {{
      "Generations": {{
        "Questions": [
          "question1",
          "question2"
        ],
        "Answers": [
          "answer1",
          "answer2"
        ],
        "Metadata": {{
          "source": "Samsung support document",
          "coverage": ["features", "troubleshooting", "usage"]
        }}
      }}
    }}

    Criteria:
    - Generate 3-5 questions
    - Answers in 1-2 concise sentences
    - Use consumer-friendly language
    - Ensure direct mapping between questions and answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        # Fallback parsing if direct JSON parsing fails
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- Simple Question-Answer Pairs ---")
test_qa_generators("generate_simple_qa_pairs", content)
# Out:
# --- Simple Question-Answer Pairs ---
#
# --- Calling generate_simple_qa_pairs ---
# Okay, here are some Q&A pairs based on the provided Samsung user guide, using consumer-friendly language:
#
# **Key Features**
#
# *   **Q: What is Galaxy AI?**
#     *   A: Galaxy AI enhances device usage with intelligent features like real-time call translation and image editing assistance. Features vary by region and model.
#
# *   **Q: What is Smart Switch and how do I use it?**
#     *   A: Smart Switch lets you easily transfer data from your old phone to your new Samsung device via USB cable or wirelessly. Find it in *Settings > Accounts and backup > Transfer data for device setup*.
#
# *   **Q: What is Samsung DeX?**
#     *   A: Samsung DeX allows you to use your phone like a computer by connecting it to an external display, keyboard, and mouse. Enjoy a desktop-like experience.
#
# *   **Q: What is Wireless Power Sharing?**
#     *   A: Wireless Power Sharing allows you to use your phone's battery to wirelessly charge other compatible devices, like other phones or Galaxy Buds. Find it in *Settings > Battery > Wireless power sharing.*
#
# *   **Q: What is Secure Folder?**
#     *   A: Secure Folder is a protected space on your phone to keep personal files and apps private and secure. It requires a separate unlock method.
#
# *   **Q: What is Always On Display (AOD)?**
#     *   A: Always On Display shows the time, date, and notifications on your screen even when it's turned off. Customize it in *Settings > Lock screen and AOD > Always On Display.*
#
# *   **Q: What is Edge Panel?**
#     *   A: Edge Panel is a customizable shortcut bar for apps and functions, accessible by swiping from the edge of the screen.
#
# *   **Q: What is Game Booster?**
#     *   A: Game Booster optimizes your gaming experience by managing performance, blocking notifications, and providing other helpful tools.
#
# *    **Q: What is Samsung Wallet and what can I do with it?**
#     *   A: Samsung Wallet lets you store payment cards, loyalty cards, and digital keys for convenient and secure access. You can also make payments and verify your identity using biometric data.
#
# **Basic Troubleshooting**
#
# *   **Q: My phone won't turn on. What should I do?**
#     *   A: Try charging your phone for at least a few minutes. If it still doesn't turn on, force restart by pressing and holding the Side button and Volume Down button for 7 seconds.
#
# *   **Q: My phone is frozen. How do I unfreeze it?**
#     *   A: Force restart your phone by pressing and holding the Side button and Volume Down button simultaneously for 7 seconds.
#
# *   **Q: My phone isn't charging properly. What should I check?**
#     *   A: Ensure the charger and cable are properly connected. Try using a different Samsung-approved charger and cable. You can also check the connection status of the charger by opening *Settings > Battery*.
#
# *   **Q: What do I do if I can't connect to Wi-Fi?**
#     *   A: Restart your phone's Wi-Fi feature or the wireless router. You can also try forgetting the network and reconnecting.
#
# *   **Q: What do I do if my device overheats?**
#     *   A: Stop using the device and close running apps. Allow the device to cool down before resuming use.
#
# *   **Q: What can I do if an app isn't working?**
#     *   A: Try restarting the device, clearing the app cache, or uninstalling and reinstalling the app.
#
# **Usage Guidelines**
#
# *   **Q: How do I take a screenshot?**
#     *   A: Press the Side button and the Volume Down button simultaneously, or swipe the edge of your hand across the screen if swipe capture is enabled in settings.
#
# *   **Q: How do I use two apps at once?**
#     *   A: Use Multi window feature by tapping the Recents button, tap an app's icon, and select *Open in split screen view* or *Open in pop-up view*.
#
# *   **Q: How do I reduce battery consumption?**
#     *   A: Turn on power saving mode, close unnecessary apps, turn off Bluetooth when not in use, decrease the brightness, and decrease the backlight time.
#
# *   **Q: How do I insert a SIM card?**
#     *   A: Use the SIM ejection tool to open the SIM tray, place the SIM card with the gold contacts facing up, and reinsert the tray. (See the images in the doc for assistance)
#
# *   **Q: How do I turn on the device?**
#     *   A: Press and hold the Side button for a few seconds.
#
# *   **Q: How do I turn off the device?**
#     *   A: Press and hold the Side button and the Volume Down button simultaneously, or swipe the quick settings panel and tap the Power icon.
#
# *   **Q: How do I transfer data from my old phone?**
#     *   A: Open *Settings > Accounts and backup > Transfer data for device setup* and follow the on-screen instructions to transfer data with Smart Switch using a USB cable or wirelessly.
#
# *   **Q: Why does my phone have a small gap around the outside of the device case?**
#     *   A: This gap is a necessary manufacturing feature and some minor rocking or vibration of parts may occur. Over time, friction between parts may cause this gap to expand slightly.
#
# These Q&A pairs provide a basic overview of key features, troubleshooting steps, and usage guidelines for the Samsung devices covered in the provided documentation. Remember to consult the user guide for specific instructions and safety information.
#
#
# --- Calling generate_simple_qa_pairs_deepseek ---
# {'Generations': [{'Question': 'What are the main features of the Galaxy S25 Ultra?', 'Answer': 'Key features include a speaker, front camera, proximity/light sensor, microphone, volume and side buttons, fingerprint sensor, S Pen, SIM card tray, headphone jack/USB-C port, and rear camera with flash and sensors.'}, {'Question': 'What should I do if I see spots on my pictures?', 'Answer': 'Avoid exposing the camera lens to strong light sources like direct sunlight, as this can damage the image sensor. A damaged sensor is irreparable and can cause dots or spots in pictures.'}, {'Question': "What should I do if my phone's sound is quiet?", 'Answer': 'Check the microphone, speaker, and receiver for dust or foreign materials. Do not attempt to remove them with sharp objects, as this could damage the device.'}, {'Question': 'How do I take a screenshot?', 'Answer': 'Press the Side button and the Volume Down button simultaneously to capture a screenshot. You can also use a swipe gesture if enabled in Settings.'}, {'Question': 'How do I set up the side button?', 'Answer': 'You can customize the side button to quickly launch a frequently used app or feature. Go to Settings > Advanced features > Side button to select an option.'}, {'Question': 'How do I charge my phone wirelessly?', 'Answer': "Place the center of your phone's back on the center of a wireless charger. Make sure no conductive materials are between the phone and charger."}, {'Question': 'What are the precautions for wireless charging?', 'Answer': "Don't place credit cards, RFID cards, metal objects or magnets between the phone and the wireless charger. Also, use Samsung-approved wireless chargers."}, {'Question': 'How can I turn on fast charging?', 'Answer': 'Go to Settings > Battery > Charging settings and make sure the fast charging feature is turned on. Also, make sure you are using a super fast charger or fast charger.'}, {'Question': 'How do I use wireless power sharing?', 'Answer': "Go to Settings > Battery > Wireless power sharing and turn it on, then place the other device on the center of your phone's back with their backs facing. Do not use headphones while sharing power."}, {'Question': 'How can I make my battery last longer?', 'Answer': 'You can conserve battery power by using Device care to optimize your phone, turning on Power saving mode, closing unnecessary apps, and decreasing screen brightness and backlight time.'}, {'Question': 'What type of SIM card does this phone use?', 'Answer': 'This phone uses a nano-SIM card. Some models may also support an eSIM.'}, {'Question': 'How do I download an eSIM?', 'Answer': 'Go to Settings > Connections > SIM manager > Add eSIM. Follow the on-screen instructions, or scan a QR code provided by your carrier.'}, {'Question': 'How do I turn off my phone?', 'Answer': 'Press and hold the Side button and Volume Down button simultaneously, then tap Power off > Power off. Alternatively, open the quick settings panel and tap the power icon.'}, {'Question': 'How do I force restart my phone?', 'Answer': 'If your device is frozen and unresponsive, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.'}, {'Question': 'What is a Samsung account?', 'Answer': 'With a Samsung account, you can use Samsung services provided through mobile devices, TVs, and the Samsung website. You can create one in Settings > Sign in to your Galaxy.'}, {'Question': 'How do I transfer data from my old phone?', 'Answer': 'Use Smart Switch via USB cable or wirelessly. Go to Settings > Accounts and backup > Transfer data for device setup.'}, {'Question': 'How do I hide the navigation bar?', 'Answer': 'To get a wider screen, you can hide the navigation bar by going to Settings > Display > Navigation bar > Swipe gestures.'}, {'Question': 'How do I edit the home screen?', 'Answer': 'On the Home screen, touch and hold an empty area to access the editing options. You can change the wallpaper, add widgets, and more.'}, {'Ques ...
#
# --- Calling generate_simple_qa_pairs_google ---
# Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.
# {
#   "Generations": [
#     {
#       "Questions": [
#         "```json",
#         "{",
#         "\"Answer\": \"Press the Side button and Volume Down button simultaneously, or swipe your palm across the screen.\"",
#         "{",
#         "\"Answer\": \"Press and hold the Side button for a few seconds to turn on the device.\"",
#         "{",
#         "\"Answer\": \"Press and hold the Side button and Volume Down button simultaneously, then tap Power off.\"",
#         "{",
#         "\"Answer\": \"Use Smart Switch via USB cable or wirelessly. Go to Settings > Accounts and backup > Transfer data for device setup.\"",
#         "{",
#         "\"Answer\": \"Connect the USB cable to the USB power adapter and plug the cable into the device\u2019s multipurpose jack.\"",
#         "{",
#         "\"Answer\": \"Place the center of the device's back on the center of a wireless charger (sold separately).\"",
#         "{",
#         "\"Answer\": \"Disconnect the charger, close running apps, and allow the device to cool down.\"",
#         "{",
#         "\"Answer\": \"Wireless Power Sharing allows you to charge another device using your phone's battery by placing the devices back-to-back.\"",
#         "{",
#         "\"Answer\": \"Use the ejection pin to open the SIM card tray, place the SIM card on the tray, and insert the tray back into the device.\"",
#         "{",
#         "\"Answer\": \"Open Settings and tap Connections \u2192 SIM manager \u2192 Add eSIM.\"",
#         "{",
#         "\"Answer\": \"Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.\"",
#         "{",
#         "\"Answer\": \"Samsung Wallet lets you make payments, verify your identity, and access tickets/boarding passes.\"",
#         "{",
#         "\"Answer\": \"Gaming Hub gathers your games downloaded from Play Store and Galaxy Store into one place.\"",
#         "{",
#         "\"Answer\": \"Open the Phone app, tap \u2192 Settings \u2192 Live translate, tap the switch to turn it on, and then select the languages to use.\"",
#         "{",
#         "\"Answer\": \"Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.\"",
#         "{",
#         "\"Answer\": \"Secure Folder protects your private content and apps, such as pictures and contacts, from being accessed by others.\"",
#         "{",
#         "\"Answer\": \"Open Settings, tap Accessibility \u2192 Vision enhancements \u2192 Magnification \u2192 Magnification shortcut, and then tap the switch to turn it on and choose a shortcut.\"",
#         "]"
#       ],
#       "Answers": [
#         "[",
#         "\"Question\": \"How do I take a screenshot?\",",
#         "},",
#         "\"Question\": \"How do I turn on the device?\",",
#         "},",
#         "\"Question\": \"How do I turn off the device?\",",
#         "},",
#         "\"Question\": \"How can I transfer data from my old device?\",",
#         "},",
#         "\"Question\": \"How do I charge the device with a cable?\",",
#         "},",
#         "\"Question\": \"How can I charge the device wirelessly?\",",
#         "},",
#         "\"Question\": \"What should I do if my device is overheating?\",",
#         "},",
#         "\"Question\": \"What is Wireless Power Sharing?\",",
#         "},",
#         "\"Question\": \"How do I insert a nano-SIM card?\",",
#         "},",
#         "\"Question\": \"How do I download an eSIM?\",",
#         "},",
#         "\"Question\": \"How do I force restart the phone if it's frozen?\",",
#         "},",
#         "\"Question\": \"What is Samsung Wallet?\",",
#         "},",
#         "\"Question\": \"What is Gaming Hub?\",",
#         "},",
#         "\"Question\": \"How do I activate Call Assist's Live Translate feature?\",",
#         "},",
#         "\"Question\": \"How do I force restart the phone if it's frozen?\",",
#         "},",
#         "\"Question\": \"What is Secure Folder?\",",
#         "},",
#         "\"Question\": \"How do I use the Magnifier feature for accessibility?\",",
#         "}",
#         "```"
#       ]
#     }
#   ]
# }
#
# --- Calling generate_simple_qa_pairs_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I take a screenshot on my Samsung Galaxy S25?",\n      "How do I enable Wireless Power Sharing?",\n      "How do I force restart my Samsung Galaxy S25 if it\'s frozen?",\n      "How do I reduce battery consumption on my Samsung Galaxy S25?",\n      "How do I translate text in the Camera app?"\n    ],\n    "Answers": [\n      "Press the Side button and the Volume Down button simultaneously, or swipe your palm across the screen.",\n      "Go to Settings > Battery > Wireless power sharing, and then tap the switch to turn it on, and then place the other device on the center of your phone, with their backs facing.",\n      "Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.",\n      "Optimize the device using the device care feature, close unnecessary apps, and decrease screen brightness.",\n      "Open the Camera app, point the camera towards the text, tap the Translate button, and the text will be translated."\n    ],\n    "Metadata": {\n      "source": "Samsung support document",\n      "coverage": ["features", "troubleshooting", "usage"]\n    }\n  }\n}\n```'}}

# %%
results = test_qa_generators_aggregated("generate_simple_qa_pairs", content)
print_aggregated_results(results)
# Out:
# Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.
# {
#   "base_function": "generate_simple_qa_pairs",
#   "results": {
#     "default": "Here's a breakdown of fundamental Q&A pairs generated from the provided Samsung user guide, focusing on key features, basic troubleshooting, and usage guidelines:\n\n**Key Features**\n\n*   **Q: What is Galaxy AI?**\n    *   A: Galaxy AI enhances device usage with advanced intelligence, translating calls, generating images, and summarizing text. (Availability may vary by region/carrier).\n*   **Q: What is Quick Share?**\n    *   A: Quick Share lets you easily share content like photos and videos with nearby devices or people. Ensure both devices have Quick Share enabled.\n*   **Q: What is Smart View?**\n    *   A: Smart View mirrors your phone's screen on a compatible TV or monitor. Open the quick settings panel to use.\n*   **Q: What is Samsung DeX?**\n    *   A: Samsung DeX allows you to use your phone like a desktop computer when connected to an external display. You can connect wirelessly or with a USB-C to HDMI adapter.\n*   **Q: How do I use Wireless Power Sharing?**\n    *   A: Wireless power sharing lets you use your phone to wirelessly charge other devices, including other phones and accessories. Enable the feature in Settings > Battery > Wireless Power Sharing, and then put the other device on the back of your phone.\n\n**Basic Troubleshooting**\n\n*   **Q: What do I do if my phone freezes?**\n    *   A: If your phone is unresponsive, force a restart by pressing and holding the Side button and Volume Down button simultaneously for 7+ seconds.\n*   **Q: What should I do if my phone won\u2019t turn on?**\n    *   A: If your phone doesn't power on, connect it to a charger and let it charge for a few minutes before attempting to turn it on again. The battery may be completely depleted.\n*   **Q: What should I do if my phone overheats?**\n    *   A: If your phone overheats, stop using it, disconnect the charger, and close any running apps. Wait for it to cool down before resuming use, and try to avoid using too many apps.\n*   **Q: What if my battery isn't charging properly?**\n    *   A: Try a different Samsung-approved charger and cable, and make sure the charging port is clean and free of debris. Also, confirm that fast or super fast charging is enabled in the battery settings.\n*   **Q: Why can't people hear me on calls?**\n    *   A: Make sure you're not covering the microphone, and that it's close to your mouth. If using headphones, ensure they're properly connected.\n\n**Usage Guidelines**\n\n*   **Q: How do I take a screenshot?**\n    *   A: Press the Side button and the Volume Down button simultaneously. A screenshot will be captured and saved in your Gallery.\n*   **Q: How do I turn on/off my device?**\n    *   A: To turn on, press and hold the Side button until the device powers up. Press and hold the Side button and Volume Down button simultaneously, then tap Power off/Restart to turn off or restart.\n*   **Q: How do I reduce battery consumption?**\n    *   A: Optimize the device using the device care feature, turn off the screen when not in use, enable power saving mode, and close unnecessary apps. You can also disable Bluetooth and auto-sync.\n*   **Q: Can I transfer data from my old phone?**\n    *   A: Yes, use Smart Switch to transfer data wirelessly or via USB cable from your old device. Go to Settings > Accounts and backup > Transfer data for device setup.\n*   **Q: How do I use Multi Window?**\n    *   A: Open the recent apps list, tap an app's icon, and select \"Open in split screen view\" or \"Open in pop-up view\" to use multiple apps at once. The specific steps may vary depending on your settings.\n*   **Q: How to maintain water and dust resistance?**\n    *   A: Do not expose the device to swimming pool water or sea water. Wipe the device with a soft and clean cloth, and then dry it thoroughly.\n\nThese are just some examples, but they demonstrate how to pull out the most important information and present it in a simple Q&A format.\n",
#     "_deepseek": {
#       "Generations": [
#         {
#           "Question": "How do I take a screenshot?",
#           "Answer": "You can capture a screenshot by pressing the Side button and Volume Down button simultaneously, or by swiping the edge of your hand across the screen."
#         },
#         {
#           "Question": "How do I turn off my phone if it's frozen?",
#           "Answer": "If your device is frozen, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it."
#         },
#         {
#           "Question": "How do I charge my phone wirelessly?",
#           "Answer": "Place the center of your phone's back on the center of a wireless charger (sold separately) to begin charging."
#         },
#         {
#           "Question": "What should I do if my phone is overheating?",
#           "Answer": "Disconnect the charger, close any running apps, and wait for the device to cool down before using it again."
#         },
#         {
#           "Question": "How can I share my phone's battery with another device?",
#           "Answer": "Enable Wireless Power Sharing in Settings > Battery, then place the other device on the center of your phone, backs facing each other."
#         },
#         {
#           "Question": "How do I turn on Dark Mode?",
#           "Answer": "Go to Settings > Display > Light/Dark and select Dark."
#         },
#         {
#           "Question": "How do I add an app shortcut to the Home screen?",
#           "Answer": "On the Apps screen, touch and hold an app icon, and then tap Add to Home."
#         },
#         {
#           "Question": "How do I use two apps at the same time?",
#           "Answer": "Tap the Recents button, tap an app's icon, and then tap Open in split screen view or Open in pop-up view."
#         },
#         {
#           "Question": "Where can I find my downloaded files?",
#           "Answer": "You can access and manage your files in the My Files app."
#         },
#         {
#           "Question": "How do I block a phone number?",
#           "Answer": "Open the Phone app, tap the three dots > Settings > Block numbers, and then select the numbers to block."
#         },
#         {
#           "Question": "How do I use Galaxy AI to translate a phone call in real time?",
#           "Answer": "In the Phone app, tap the three dots > Settings > Live translate, tap the switch to turn it on, and then select the languages to use. When making or receiving a voice call, tap Call assist -> Live translate. To stop translating, tap the stop translating icon."
#         },
#         {
#           "Question": "What is Circle to Search?",
#           "Answer": "Circle to Search allows you to search for information about the desired part of the image or text on the screen. Touch and hold the Home button and tap or draw a circle around an image or text to start."
#         },
#         {
#           "Question": "What is Edge Panel?",
#           "Answer": "Edge Panel gives you quick access to favorite apps and features. Swipe from the side of the screen to open it."
#         },
#         {
#           "Question": "How can I reduce my phones battery consumption?",
#           "Answer": "You can optimise the device using the device care feature. When you are not using the device, turn off the screen by pressing the Side button. You can also turn on power saving mode or close unnecessary apps."
#         }
#       ]
#     },
#     "_google": "{\n  \"Generations\": [\n    {\n      \"Questions\": [\n        \"```json\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Smart Switch is a tool for transferring data from your previous device to your new Samsung device, and you can use a USB cable or wirelessly. Go to Settings > Accounts and backup > Transfer data for device setup.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"You can take a screenshot by simultaneously pressing the Side button and the Volume Down button. Alternatively, swipe the edge of your hand across the screen (if enabled in settings).\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Place the center of the phone's back on the center of a wireless charger. Disconnect once fully charged.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Do not place credit cards, RFID cards, metal objects, or magnets between the device and the wireless charger. Also, use Samsung-approved wireless chargers.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Enable Wireless Power Sharing in Settings > Battery. Then place the other device on the back of your phone, with their backs facing.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Turn off the screen when not in use, enable power saving mode, close unused apps, and turn off Bluetooth and auto-syncing when not needed.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Insert the ejection pin into the hole on the tray to loosen the tray, gently place the SIM card on the tray, and insert the tray back into the slot.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Press and hold the Side button and the Volume Down button simultaneously, then tap Power off. Alternatively, open the quick settings panel and tap the power icon.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"A Samsung account lets you use a variety of Samsung services across mobile devices, TVs, and the Samsung website. It allows you to access features like Samsung Cloud and find your device.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Circle to Search lets you search for information about a part of an image or text on the screen. Touch and hold the Home button and tap or draw a circle around the image or text.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"To use your apps on a wider screen, go to Settings > Display > Navigation bar > Swipe gestures.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"If the Edge panel handle is not visible, open Settings, tap Display, and then tap the Edge panels switch to turn it on.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Press and hold the Side button and the Volume Down button simultaneously, then tap Emergency call. You can also manage emergency contacts in Settings > Safety and emergency.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"When you are finished charging, disconnect the other device from your phone.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"To use real-time translation during calls, open the Phone app, tap the settings icon > Settings > Live translate, turn on the switch, and select the languages to use.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"To make a contact, open the Phone app and tap Keypad. Then enter a phone number and press the call button.\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"Air command is a menu that provides S Pen features and direct access to frequently used apps. Tap the Air command icon ( ) with the S Pen to open the Air command panel\\\"\",\n        \"{\",\n        \"\\\"Answer\\\": \\\"The S Pen is located at the bottom of the S25 Ultra.\\\"\",\n        \"]\"\n      ],\n      \"Answers\": [\n        \"[\",\n        \"\\\"Question\\\": \\\"What is Smart Switch and how can I use it?\\\",\",\n        \"},\",\n        \"\\\"Question\\\": \\\"How do I take a ...
#     "_sonnet": {
#       "Generations": {
#         "Questions": [],
#         "Answers": [],
#         "RawResponse": "```json\n{\n  \"Generations\": {\n    \"Questions\": [\n      \"How can I transfer data from my old device to my new Samsung Galaxy S25?\",\n      \"How do I take a screenshot on my Samsung Galaxy S25?\",\n      \"How do I turn on wireless power sharing on my Samsung Galaxy S25 to charge another device?\",\n      \"What are some ways to reduce battery consumption on my Samsung Galaxy S25?\",\n      \"How do I set up face recognition on my Samsung Galaxy S25?\"\n    ],\n    \"Answers\": [\n      \"You can use Samsung Smart Switch, which allows you to transfer data wirelessly or with a USB cable; go to Settings > Accounts and backup > Transfer data for device setup to begin the transfer process.\",\n      \"You can capture a screenshot by simultaneously pressing the Side button and the Volume Down button or using the palm swipe gesture.\",\n      \"To enable wireless power sharing, go to Settings > Battery > Wireless power sharing, and then tap the switch to turn it on, and then place the other device on the center of your phone, with their backs facing.\",\n      \"You can reduce battery consumption by optimizing the device using device care, turning off the screen when not in use, enabling power saving mode, and closing unused apps.\",\n      \"To set up face recognition, go to Settings > Security and privacy > Screen lock and biometrics > Face recognition, and then follow the on-screen instructions.\"\n    ],\n    \"Metadata\": {\n      \"source\": \"Samsung support document\",\n      \"coverage\": [\"features\", \"troubleshooting\", \"usage\"]\n    }\n  }\n}\n```"
#       }
#     }
#   },
#   "errors": {}
# }

# %% [markdown]
# ### Number 2 generate_structured_qa

# %%
#original
def generate_structured_qa(text):
    """Problem-solution focused pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create problem-solution pairs from Samsung docs. Format:
    Question: [Issue description]
    Answer: [Step-by-step fix]
    Include severity indicators (⚠️) for critical issues.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_qa_deepseek(text):
    """Generates severity-graded troubleshooting pairs in JSON format.

    Returns:
        JSON with error codes, time estimates, and step-by-step instructions.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Convert Samsung support text into problem-solution pairs with:
    1. Technical error codes (if applicable)
    2. Severity grading (Critical/Medium/Low)
    3. Estimated troubleshooting time
    4. Ordered resolution steps

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Issue]",
        "Answer": {{
          "Steps": ["1. Do X", "2. Then Y"],
          "SeverityCode": 0-2 (2=Critical),
          "ErrorCode": "ERR_BATT_01",
          "TroubleshootingTime": "5-7 minutes"
        }}
      }}
    - Replace ⚠️ with "SeverityCode":2
    - Sort by descending SeverityCode

    Example:
    {{
      "Generations": [
        {{
          "Question": "Phone overheating during charging",
          "Answer": {{
            "Steps": ["1. Unplug immediately", "2. Remove case", "3. Contact support"],
            "SeverityCode": 2,
            "ErrorCode": "ERR_CHG_OVERHEAT",
            "TroubleshootingTime": "3 minutes"
          }}
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse troubleshooting data"}


#Google AI STudio
def generate_structured_qa_google(text):
    """Problem-solution focused pairs in JSON format with severity indicators"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate problem-solution Question and Answer pairs from the following Samsung support document text. Format each pair as:

    Question: [Issue description]
    Answer: [Step-by-step fix]

    For critical issues, include a severity indicator (⚠️) in the output and classify them as "Critical" in the JSON structure. For non-critical issues, classify as "Normal" or leave severity blank/null.

    Use consumer-friendly language. Keep answers concise and step-by-step where possible.

    Present the output as a list of dictionaries in JSON format. Each dictionary should have keys: "Severity" (e.g., "Critical", "Normal", null), "Question", "Answer", and optionally "SeverityIndicator" (the ⚠️ symbol if applicable).

    Text: {text}

    Output Format (example):
    [
      {{ "Severity": "Critical", "Question": "...", "Answer": "...", "SeverityIndicator": "⚠️" }},
      {{ "Severity": "Normal", "Question": "...", "Answer": "...", "SeverityIndicator": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        problem_solution_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        problem_solution_data = [] # Implement a robust fallback text parsing

    output_json = {
        "Generations": [
            {"ProblemSolutionPairs": problem_solution_data} # Assuming model outputs list of dictionaries as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_structured_qa_sonnet(text):
    """Generate problem-solution Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate problem-solution Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific problem description"
        ],
        "Answers": [
          "Comprehensive step-by-step solution"
        ],
        "Metadata": {{
          "IssueSeverity": ["Low", "Medium", "High"],
          "SolutionComplexity": "Detailed technical guidance"
        }},
        "IssueClassification": {{
          "CriticalIssues": ["Urgent problems requiring immediate action"],
          "WarningIndicators": ["⚠️ Severity markers"]
        }}
      }}
    }}

    Requirements:
    - Precise problem descriptions
    - Clear, sequential solution steps
    - Include severity indicators
    - 1-2 sentence answers
    - Technical accuracy

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_qa ---")
test_qa_generators("generate_structured_qa", content)
# Out:
# --- generate_structured_qa ---
#
# --- Calling generate_structured_qa ---
# Okay, here are the problem-solution pairs extracted from the Samsung documentation you provided, along with severity indicators:
#
# Question: ⚠️ [Device doesn't turn on]
# Answer: When the battery is completely discharged, your device will not turn on. Fully charge the battery before turning on the device.
#
# Question: [Touch recognition works slowly or improperly]
# Answer:
#    1. Ensure that you attach a screen protector.
#    2. Clean your hands.
#    3. Ensure that you use your fingers or a capacitive pen.
#    4. Restart your device to clear any temporary software problems.
#    5. Ensure that your device software is updated to the latest version.
#
# Question: [Calls are not connected]
# Answer:
#    1. Ensure that you have accessed the right cellular network.
#    2. Ensure that you have not set call barring for the phone number you are dialing.
#    3. Ensure that you have not set call barring for the incoming phone number.
#
# Question: [Others cannot hear you speaking on a call]
# Answer:
#    1. Ensure that you are not covering the built-in microphone.
#    2. Ensure that the microphone is close to your mouth.
#    3. If you are using headphones, ensure that they are properly connected.
#
# Question: [Sound echoes during a call]
# Answer: Adjust the volume by pressing the Volume button or move to another area.
#
# Question: [A cellular network or the internet is often disconnected or audio quality is poor]
# Answer:
#    1. Ensure that you are not blocking the device’s internal antenna.
#    2. When you are in areas with weak signals or poor reception, you may lose reception. Move to another area and try again.
#    3. When using the device while moving, wireless network services may be disabled because of issues with the carrier’s network.
#
# Question: [The battery does not charge properly (For Samsung-approved chargers)]
# Answer:
#    1. Ensure that the charger is connected properly.
#    2. Visit a Samsung Service Centre or an authorised service centre and have the battery replaced.
#
# Question: [The battery depletes faster than when first purchased]
# Answer:
#    1. When you expose the device or the battery to very cold or very hot temperatures, the useful charge may be reduced.
#    2. Battery consumption will increase when you use certain features or apps, such as GPS, games, or the internet.
#    3. The battery is consumable and the useful charge will get shorter over time.
#
# Question: [Error messages appear when opening the camera]
# Answer:
#    1. Charge the battery.
#    2. Free some storage by transferring files to a computer or deleting files from your device.
#    3. Restart the device.
#
# Question: [Picture quality is poorer than the preview]
# Answer:
#    1. The quality of your pictures may vary, depending on the surroundings and the photography techniques you use.
#    2. If you take pictures in dark areas, at night, or indoors, image noise may occur or images may be out of focus.
#
# Question: [Error messages appear when opening multimedia files]
# Answer:
#    1. Free some storage by transferring files to a computer or deleting files from your device.
#    2. Ensure that the music file is not Digital Rights Management (DRM)-protected.
#    3. Ensure that the file formats are supported by the device.
#
# Question: [Bluetooth is not working well]
# Answer:
#    1. Ensure that the device you wish to connect with is ready to be scanned or connected to.
#    2. Ensure that your phone and the other Bluetooth device are within the maximum Bluetooth range (10 m).
#    3. On your phone, open Settings, tap Connections, and then tap the Bluetooth switch to turn it on again.
#    4. On your phone, open Settings, tap General management → Reset → Reset Wi-Fi and Bluetooth settings → Reset settings to reset network settings.
#
# Question: [A connection is not made when you connect the device to a computer]
# Answer:
#    1. Ensure that the USB cable you are using is compatible with your device.
#    2. Ensure that you have the proper driver installed and updated on your computer.
#
# Question: [Your device cannot find your current location]
# Answer: GPS signals may be obstructed in some locations, such as indoors. Set the device to use Wi-Fi or a mobile network to find your current location in these situations.
#
# Question: ⚠️ [Data stored in the device has been lost]
# Answer: Always make backup copies of all important data stored in the device.
#
# Question: [There is not enough space in the device’s storage]
# Answer: Delete unnecessary data, such as cache, using the device care feature or manually delete unused apps or files to free up storage space.
#
# Question: [The Home button does not appear]
# Answer: The navigation bar containing the Home button may disappear while using certain apps or features. To access the navigation bar, drag upwards from the bottom of the screen.
#
# Question: [Device Overheating]
# Answer: Disconnect the charger from the device and close any running apps. Wait for the device to cool down and then begin charging the device again.
#
# I hope this is helpful!
#
#
# --- Calling generate_structured_qa_deepseek ---
# {'Generations': [{'Question': 'Device overheating during charging.', 'Answer': {'Steps': ['1. Disconnect the charger and close running apps.', '2. Allow the device to cool down before resuming charging.', '3. If the lower part overheats, replace the USB cable with a Samsung-approved one.', '4. Ensure no foreign materials are between the device and wireless charger.'], 'SeverityCode': 2, 'ErrorCode': 'ERR_CHG_OVERHEAT', 'TroubleshootingTime': '5-7 minutes'}}, {'Question': 'Device frozen and unresponsive', 'Answer': {'Steps': ['1. Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it.'], 'SeverityCode': 2, 'ErrorCode': 'ERR_SYS_FREEZE', 'TroubleshootingTime': '1 minute'}}, {'Question': 'The battery does not charge properly (For Samsung-approved chargers).', 'Answer': {'Steps': ['1. Ensure that the charger is connected properly.', '2. Visit a Samsung Service Centre or an authorised service centre and have the battery replaced.', '3. Bring the charger and USB cable you are using for better service support. If wireless charging is not working, bring the wireless charger as well.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_BATT_NO_CHARGE', 'TroubleshootingTime': '2 minutes'}}, {'Question': 'Calls are not connected', 'Answer': {'Steps': ['1. Ensure that you have accessed the right cellular network.', '2. Ensure that you have not set call barring for the phone number you are dialling.', '3. Ensure that you have not set call barring for the incoming phone number.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_CALL_FAIL', 'TroubleshootingTime': '3 minutes'}}, {'Question': 'Touch recognition works slowly or improperly', 'Answer': {'Steps': ['1. Restart your device to clear any temporary software problems.', '2. Ensure that your device software is updated to the latest version.', '3. If the screen is scratched or damaged, visit a Samsung Service Centre or an authorised service centre.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_TOUCH_RESP', 'TroubleshootingTime': '5 minutes'}}, {'Question': 'A cellular network or the internet is often disconnected or audio quality is poor', 'Answer': {'Steps': ['1. Ensure that you are not blocking the device’s internal antenna.', '2. When you are in areas with weak signals or poor reception, you may lose reception.You may have connectivity problems because of issues with the carrier’s base station. Move to another area and try again.', '3. When using the device while moving, wireless network services may be disabled because of issues with the carrier’s network.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_NET_STABLE', 'TroubleshootingTime': '2 minutes'}}, {'Question': 'Bluetooth is not working well', 'Answer': {'Steps': ['1. Ensure that the device you wish to connect with is ready to be scanned or connected to.', '2. Ensure that your phone and the other Bluetooth device are within the maximum Bluetooth range (10 m).', '3. On your phone, open Settings, tap Connections, and then tap the Bluetooth switch to turn it on again.', '4. On your phone, open Settings, tap General management → Reset → Reset Wi-Fi and Bluetooth settings → Reset settings to reset network settings. You may lose registered information when performing the reset.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_BT_CONNECT', 'TroubleshootingTime': '5 minutes'}}, {'Question': 'Others cannot hear you speaking on a call', 'Answer': {'Steps': ['1. Ensure that you are not covering the built-in microphone.', '2. Ensure that the microphone is close to your mouth.', '3. If you are using headphones, ensure that they are properly connected.'], 'SeverityCode': 0, 'ErrorCode': None, 'TroubleshootingTime': '2 minutes'}}, {'Question': 'Sound echoes during a call', 'Answer': {'Steps': ['1. Adjust the volume by pressing the Volume button or move to another area.'], 'SeverityCode': 0, 'ErrorCode': None, 'TroubleshootingTime': '1 minute'}}, {'Question': 'Picture quality is poorer than the preview', 'Answer': {'Steps': ['1. The qua ...
#
# --- Calling generate_structured_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ProblemSolutionPairs": []
#     }
#   ]
# }
#
# --- Calling generate_structured_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "The device won\'t turn on, what should I do?",\n      "The touch screen is not working, what should I do?",\n      "My device freezes, what can I do?",\n      "I cannot take a screenshot using side and volume down buttons, what can I do?",\n      "How do I reduce battery consumption on my device?",\n      "My device is overheating, what can I do?"\n    ],\n    "Answers": [\n      "Charge the device fully before attempting to turn it on.",\n      "Restart the device and ensure the screen is clean and dry.",\n      "Force restart by holding Side and Volume Down buttons; if unsuccessful, factory reset.",\n      "Open Settings, tap Advanced features → Motions and gestures, and then tap the Palm swipe to capture switch to turn it on.",\n      "Optimize with device care, reduce screen brightness, close unused apps, and disable Bluetooth/auto-sync.",\n      "Stop using it, close running apps, and avoid direct sunlight or extreme temperatures; also, ensure the charger and cable are Samsung-approved."\n    ],\n    "Metadata": {\n      "IssueSeverity": ["Medium", "Medium", "High", "Low", "Medium", "High"],\n      "SolutionComplexity": "Detailed technical guidance"\n    },\n    "IssueClassification": {\n      "CriticalIssues": ["Urgent problems requiring immediate action"],\n      "WarningIndicators": ["⚠️ Severity markers"]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 3 generate_step_by_step_qa

# %%
#original
def generate_step_by_step_qa(text):
    """Procedural guidance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Extract step-by-step procedures and generate Q&A pairs with:
    - Sequential questions - Tool requirements - Time estimates
    Format steps with numbered sub-items.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_step_by_step_qa_deepseek(text):
    """Generates machine-parseable procedural guides with safety checks.

    Returns:
        JSON with nested step details, tool SKUs, and critical warnings.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Convert Samsung technical docs into structured Q&A with:
    1. Sequentially ordered repair/configuration steps
    2. Official tool SKUs from Samsung Parts
    3. Time estimates with ranges (e.g., "8-12 minutes")
    4. Critical warnings for permanent data loss

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Task description]",
        "Answer": {{
          "Steps": [
            {{
              "Number": 1,
              "Action": "...",
              "Tools": ["GJ-TX42 (SIM ejector)"],
              "Warning": "Optional text"
            }}
          ],
          "TotalTime": "15-20 mins",
          "RiskLevel": "High/Medium/Low"
        }},
        "Category": "Display/Battery/Software"
      }}
    - Sort steps by dependency (prerequisite first)
    - Validate tool SKUs against Samsung's GJ-XXXXX format

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to replace Galaxy S24 Ultra screen?",
          "Answer": {{
            "Steps": [
              {{
                "Number": 1,
                "Action": "Heat edges at 85°C with GJ-HX90 thermal pad",
                "Tools": ["GJ-HX90"],
                "Warning": "Exceeding 90°C voids warranty"
              }}
            ],
            "TotalTime": "45-60 mins",
            "RiskLevel": "High"
          }},
          "Category": "Display"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse procedural guide"}


#Google AI STudio
def generate_step_by_step_qa_google(text):
    """Procedural guidance pairs in JSON format with steps, tools, and time estimates"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Extract step-by-step procedures from the following Samsung support document text and generate Question and Answer pairs for each step.

    For each procedure, identify:
    - Sequential questions that guide the user through each step.
    - Any tool requirements needed for the procedure.
    - An estimated time to complete the procedure.

    Format the steps as numbered sub-items in the plain text output for clarity. In the JSON output, represent steps as a numbered list of Question-Answer pairs.

    Use consumer-friendly language. Keep answers concise and focused on each step.

    Present the output as a list of procedures in JSON format. Each procedure should include "ProcedureName", "ToolRequirements", "TimeEstimate", and a list of "Steps", where each step has "StepNumber", "Question", and "Answer".

    Text: {text}

    Output Format (example structure):
    [
      {{
        "ProcedureName": "Procedure Title",
        "ToolRequirements": ["Tool 1", "Tool 2", ...],
        "TimeEstimate": "Estimated Time",
        "Steps": [
          {{ "StepNumber": 1, "Question": "Question for Step 1?", "Answer": "Answer for Step 1" }},
          {{ "StepNumber": 2, "Question": "Question for Step 2?", "Answer": "Answer for Step 2" }},
          ...
        ]
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        procedure_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        procedure_data = [] # Implement a robust fallback text parsing

    output_json = {
        "Generations": [
            {"ProcedureQAPairs": procedure_data} # Assuming model outputs list of procedures as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_step_by_step_qa_sonnet(text):
    """Generate structured procedural guidance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create step-by-step Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Procedural guidance question"
        ],
        "Answers": [
          "Detailed step-by-step procedure"
        ],
        "Metadata": {{
          "ProcedureType": "Sequential Guidance",
          "Complexity": "Detailed Technical Steps"
        }},
        "ProcedureDetails": {{
          "Tools": ["Required equipment"],
          "TimeEstimates": ["Estimated duration for each step"],
          "Steps": [
            "Numbered sequential instructions"
          ]
        }}
      }}
    }}

    Requirements:
    - Numbered, sequential steps
    - Tool and time requirement details
    - 1-2 sentence answers
    - Technical precision

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_step_by_step_qa ---")
test_qa_generators("generate_step_by_step_qa", content)
# Out:
# --- generate_step_by_step_qa ---
#
# --- Calling generate_step_by_step_qa ---
# Okay, here's the step-by-step procedure extraction and Q&A generation from the provided text, focusing on clarity, tool requirements, and estimated time where possible.
#
# **Charging the Battery**
#
# **Procedure:**
#
# 1.  **Wired Charging:**
#     1.  Connect the USB cable to the USB power adapter.
#     2.  Plug the cable into the device’s multipurpose jack (USB Type-C).
#     3.  After fully charging, disconnect the charger from the device.
#
# 2.  **Wireless Charging:**
#     1.  Place the center of the device’s back on the center of the wireless charger (sold separately).
#     2.  After fully charging, disconnect the device from the wireless charger.
#
# 3.  **Wireless Power Sharing**
#     1.  Open Settings, tap Battery → Wireless power sharing, and then tap the switch to turn it on.
#     2.  Place the other device on the centre of your phone, with their backs facing.
#     3.  When you are finished charging, disconnect the other device from your phone.
#
# **Q&A Pairs:**
#
# *   **Q1:** What is the first step in charging the device via a wired connection?
#     *   **A1:** Connect the USB cable to the USB power adapter.
# *   **Q2:** What tools are needed for wired charging?
#     *   **A2:** USB cable, USB power adapter.
# *   **Q3:** How do I start wireless power sharing?
#     *   **A3:** Open Settings, tap Battery → Wireless power sharing, and then tap the switch to turn it on.
# *   **Q4:** For wireless power sharing, what position should the other device be in?
#     *   **A4:** Placed on the centre of your phone, with their backs facing.
# *    **Q5:** How long does it take to charge the battery?
#     *   **A5:** The estimated charging time will appear on the notification panel. The actual charging time assumes that the device is not in use, and it may vary depending on the charging conditions.
#
# **Nano-SIM Card and eSIM Installation**
#
# **Procedure (Nano-SIM):**
#
# 1.  **Galaxy S25+, Galaxy S25:**
#     1.  Insert the ejection pin into the hole on the tray to loosen the tray.
#     2.  Pull out the tray gently from the tray slot.
#     3.  Place the SIM or USIM card on the tray with the gold-colored contacts facing upwards and gently press the SIM or USIM card into the tray to secure it.
#     4.  Insert the tray back into the tray slot.
#
# **Procedure (eSIM):**
#
# 1.  **Downloading an eSIM:**
#     1.  Open Settings and tap Connections → SIM manager → Add eSIM.
#     2.  When a mobile plan is found, follow the on-screen instructions to download the eSIM.
# 2.  **Scan QR code**
#     1.  Open Settings, tap Connections → SIM manager → Add eSIM → Scan QR code, and then scan the QR code.
#
# **Q&A Pairs:**
#
# *   **Q1:** What tool is required to remove the SIM card tray?
#     *   **A1:** Ejection pin.
# *   **Q2:** How should the SIM card be placed on the tray?
#     *   **A2:** With the gold-colored contacts facing upwards.
# *   **Q3:** How to scan a QR Code from a provider to download eSIM?
#     *   **A3:** Open Settings, tap Connections → SIM manager → Add eSIM → Scan QR code, and then scan the QR code.
# *   **Q4:** What type of SIM card is needed?
#     *   **A4:** Nano-SIM card.
# *   **Q5:** How long does it take to insert the SIM card?
#     *   **A5:** The time to install SIM should take between 1-2 minutes.
# *   **Q6:** How do I activate a SIM or USIM card
#     *   **A6:** Open Settings and tap Connections → SIM manager.
# *   **Q7:** What will happen to data transfer speeds if I use both the nano-SIM card and the eSIM, or two eSIMs?
#     *   **A7:** It may result in slower data transfer speeds in some areas.
#
# **Turning the Device On/Off**
#
# **Procedure (Turning On):**
#
# 1.  Press and hold the Side button for a few seconds to turn on the device.
#
# **Procedure (Turning Off):**
#
# 1.  Press and hold the Side button and the Volume Down button simultaneously. Alternatively, open the quick settings panel and tap .
# 2.  Tap Power off → Power off. To restart the device, tap Restart → Restart.
#
# **Procedure (Forcing Restart):**
#
# 1.  If the device is frozen and unresponsive, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it.
#
# **Q&A Pairs:**
#
# *   **Q1:** How do I turn on the device?
#     *   **A1:** Press and hold the Side button for a few seconds.
# *   **Q2:** What buttons do I press to turn off the device?
#     *   **A2:** Press and hold the Side button and the Volume Down button simultaneously.
# *   **Q3:** What do I do if my device is frozen?
#     *   **A3:** Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it.
# *   **Q4:** What buttons I can press to manage Emergency calls?
#     *   **A4:** Press and hold the Side button and the Volume Down button simultaneously.
# *   **Q5:** What will happen if press and hold the Side button?
#     *   **A5:** If you want to set the device to turn off when you press and hold the Side button, tap Side button settings → Long press → Power off menu.
#
#
# --- Calling generate_step_by_step_qa_deepseek ---
# {'Generations': [{'Question': 'How to charge the Galaxy S25 Ultra battery using wired charging?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Connect the USB cable to the USB power adapter.', 'Tools': [], 'Warning': None}, {'Number': 2, 'Action': 'Plug the cable into the device’s multipurpose jack (USB Type-C).', 'Tools': [], 'Warning': 'Using a Micro USB cable may damage the device.'}, {'Number': 3, 'Action': 'After fully charging, disconnect the charger from the device.', 'Tools': [], 'Warning': 'Thoroughly dry the multipurpose jack before charging to avoid damage.'}], 'TotalTime': '60-90 mins', 'RiskLevel': 'Low'}, 'Category': 'Battery'}, {'Question': 'How to insert a nano-SIM card into the Galaxy S25+ or S25?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Insert the GJ-TX42 ejection pin into the hole on the SIM card tray to loosen it.', 'Tools': ['GJ-TX42'], 'Warning': 'Ensure the ejection pin is perpendicular to the hole. Otherwise, the device may be damaged.'}, {'Number': 2, 'Action': 'Pull out the tray gently from the tray slot.', 'Tools': [], 'Warning': None}, {'Number': 3, 'Action': 'Place the nano-SIM card on the tray with the gold-coloured contacts facing upwards and gently press the SIM card into the tray to secure it.', 'Tools': [], 'Warning': 'Use only a nano-SIM card.'}, {'Number': 4, 'Action': 'Insert the tray back into the tray slot.', 'Tools': [], 'Warning': 'Fully insert the tray into the tray slot to prevent liquid from entering your device. Always make sure the tray is dry before insertion.'}], 'TotalTime': '5-10 mins', 'RiskLevel': 'Low'}, 'Category': 'Connectivity'}, {'Question': 'How to force restart a frozen Galaxy S25?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds.', 'Tools': [], 'Warning': None}], 'TotalTime': '10-15 seconds', 'RiskLevel': 'Low'}, 'Category': 'Software'}, {'Question': 'How to remove the battery from the Galaxy S25?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Contact an authorized service center.', 'Tools': [], 'Warning': 'For your safety, you must not attempt to remove the battery. If the battery is not properly removed, it may lead to damage to the battery and device, cause personal injury, and result in the device being unsafe.'}], 'TotalTime': 'N/A', 'RiskLevel': 'High'}, 'Category': 'Battery'}]}
#
# --- Calling generate_step_by_step_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ProcedureQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_step_by_step_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I charge the battery on my Samsung Galaxy S25 phone?"\n    ],\n    "Answers": [\n      "You can charge the battery using wired or wireless charging. For wired charging, connect the USB cable to the power adapter and the device. For wireless charging, place the center of the device\'s back on the center of the wireless charger.",\n      "Always use Samsung approved chargers and cables to protect your device. Remember to disconnect the charger when not in use, as it doesn\'t have a power switch."\n    ],\n    "Metadata": {\n      "ProcedureType": "Sequential Guidance",\n      "Complexity": "Detailed Technical Steps"\n    },\n    "ProcedureDetails": {\n      "Tools": [\n        "USB Type-C cable",\n        "USB Power adapter (optional)",\n        "Wireless charger (optional)"\n      ],\n      "TimeEstimates": [\n        "Varies depending on battery level and charging method",\n        "Indefinite"\n      ],\n      "Steps": [\n        "1. **Wired Charging:** Connect the USB cable to the USB power adapter.",\n        "2. Plug the USB cable into the device’s multipurpose jack.",\n        "3. After the battery is fully charged, disconnect the charger from the device.",\n        "4. **Wireless Charging:** Place the center of the device’s back on the center of the wireless charger.",\n        "5. After the battery is fully charged, disconnect the device from the wireless charger."\n      ]\n    }\n  },\n    "Generations": {\n    "Questions": [\n      "How can I take a screenshot on my Samsung Galaxy S25 phone?"\n    ],\n    "Answers": [\n      "You can capture a screenshot by pressing the side button and the volume down button simultaneously. Alternatively, you can use the swipe capture method by swiping the edge of your hand across the screen.",\n      "After capturing the screenshot, you can use the toolbar at the bottom of the screen to write, draw, crop, share, and add tags to the captured screen."\n    ],\n    "Metadata": {\n      "ProcedureType": "Sequential Guidance",\n      "Complexity": "Detailed Technical Steps"\n    },\n    "ProcedureDetails": {\n      "Tools": [\n        "Samsung Galaxy S25 phone"\n      ],\n      "TimeEstimates": [\n        "Instant"\n      ],\n      "Steps": [\n        "1. **Button capture:** Press the Side button and the Volume Down button simultaneously.",\n        "2. **Swipe capture:** With the edge of your hand, swipe your hand to the left or right across the screen.",\n        "3. (Optional) Use the toolbar at the bottom of the screen to edit, share, or add tags to the screenshot."\n      ]\n    }\n  },\n    "Generations": {\n    "Questions": [\n      "How can I install or uninstall apps on my Samsung Galaxy S25 phone?"\n    ],\n    "Answers": [\n      "You can install apps from Galaxy Store or Play Store. To uninstall, touch and hold an app icon and select \'Uninstall\'.",\n      "Some default apps cannot be uninstalled, but they can be disabled. Make sure to grant necessary permissions for apps to operate properly."\n    ],\n    "Metadata": {\n      "ProcedureType": "Sequential Guidance",\n      "Complexity": "Detailed Technical Steps"\n    },\n    "ProcedureDetails": {\n      "Tools": [\n        "Samsung Galaxy S25 phone",\n        "Galaxy Store app",\n        "Play Store app"\n      ],\n      "TimeEstimates": [\n        "Varies depending on app size and internet speed",\n        "Instant"\n      ],\n      "Steps": [\n        "1. **Install from Galaxy Store:** Open the Galaxy Store app. Browse or search for the app and tap \'Install\'.",\n        "2. **Install from Play Store:** Open the Play Store app. Browse or search for the app and tap \'Install\'.",\n        "3. **Uninstall:** On the Home screen or Apps screen, touch and hold an app icon.",\n        "4. Tap \'Uninstall\' and confirm. (or \'Disable\' for some default apps). "\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 4 generate_faq_qa

# %%
#original
def generate_faq_qa(text):
    """Anticipated user questions"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Predict common FAQs from Samsung users based on this text.
    Phrase questions as natural customer inquiries.
    Include 'Why', 'How', and 'What if' scenarios.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_faq_qa_deepseek(text):
    """Generates categorized FAQs with popularity metadata in JSON format.

    Returns:
        JSON with question taxonomy, search keywords, and related products.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate structured FAQs from Samsung documentation with:
    1. Natural phrasing mirroring customer voice
    2. Taxonomy:
       - "Type": ["Why", "How", "What If", "Setup", "Troubleshooting"]
       - "FrequencyScore": 1-5 (5=most common)
    3. Related product models
    4. Search keywords (3-5 per question)

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "...",
        "Answer": "...",
        "Metadata": {{
          "Type": "Why",
          "FrequencyScore": 4,
          "RelatedProducts": ["SM-S901B", "QE65QN900B"],
          "Keywords": ["battery drain", "optimization"]
        }}
      }}
    - Sort by descending FrequencyScore
    - Deduplicate similar questions

    Example:
    {{
      "Generations": [
        {{
          "Question": "Why does my Galaxy phone get hot during video calls?",
          "Answer": "Processor-intensive apps...",
          "Metadata": {{
            "Type": "Why",
            "FrequencyScore": 5,
            "RelatedProducts": ["SM-S918B", "SM-S711B"],
            "Keywords": ["overheating", "thermal", "video chat"]
          }}
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse FAQ data"}


#Google AI STudio
def generate_faq_qa_google(text):
    """Generates anticipated user questions (FAQs) and answers in JSON format."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Predict common Frequently Asked Questions (FAQs) from Samsung users based on the following support document text.

    Phrase the questions as natural customer inquiries, reflecting how a user might actually ask.
    Include 'Why', 'How', and 'What if' scenarios to cover a range of common question types.
    For each question, also generate a concise and helpful answer.
    Use consumer-friendly language for both questions and answers.

    Present the output as a list of FAQ Question-Answer pairs in JSON format. Each pair should have the keys "Question" and "Answer".

    Text: {text}

    Output Format (example):
    [
      {{ "Question": "...", "Answer": "..." }},
      {{ "Question": "...", "Answer": "..." }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        faq_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        faq_data = [] # Implement a robust fallback text parser

    output_json = {
        "Generations": [
            {"FAQs": faq_data} # Assuming model outputs a list of dictionaries as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet

def generate_faq_qa_sonnet(text):
    """Generate structured user FAQ Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create FAQ Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Natural customer inquiry using 'Why', 'How', 'What if'"
        ],
        "Answers": [
          "Clear, concise response addressing user concern"
        ],
        "Metadata": {{
          "QuestionTypes": ["Why", "How", "What if"],
          "UserPerspective": "Common customer inquiries"
        }},
        "FAQCategories": [
          "Common user pain points",
          "Anticipated information needs"
        ]
      }}
    }}

    Requirements:
    - Realistic, conversational questions
    - Comprehensive yet brief answers
    - Cover multiple inquiry types
    - 1-2 sentence responses

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_faq_qa ---")
test_qa_generators("generate_faq_qa", content)
# Out:
# --- generate_faq_qa ---
#
# --- Calling generate_faq_qa ---
# Okay, based on the provided Samsung user guide, here are some frequently asked questions (FAQs) framed as natural customer inquiries, including "Why," "How," and "What if" scenarios:
#
# **Getting Started & Basic Functionality:**
#
# *   "How do I turn my new Galaxy S25 on for the first time?"
# *   "Where is the SIM card slot on my Galaxy S25+?"
# *   "How do I transfer all my stuff from my old phone to my new Galaxy S25?"
# *   "Why isn't my phone charging when I plug it in?"
# *   "How do I set up my Samsung account?"
# *   "What's the best way to charge my phone, wired or wireless?"
# *   "How long does it take to fully charge the battery?"
# *   "What if my phone gets wet? Is it really waterproof?"
# *   "Why does my phone get so hot when I'm charging it?"
# *   "How do I insert the Nano-SIM card properly?"
# *   "What if I lose the ejector pin for the SIM card tray?"
# *   "What is an eSIM, and how do I use it?"
# *   "How do I turn my Galaxy S25 off completely?"
# *    "What if my phone freezes and I can't turn it off normally?"
#
# **Apps and Features:**
#
# *   "How do I download new apps onto my phone?"
# *   "How do I get rid of apps I don't want anymore?"
# *   "What is Galaxy AI and how does it work?"
# *   "Can I use S Pen on Galaxy S25 or only S25 Ultra?"
# *   "How do I write on the Calendar with the S Pen?"
# *   "How do I take a screenshot on my Galaxy S25?"
# *   "How do I record my screen?"
# *   "How do I use multiple apps at the same time?"
# *   "How do I connect to the internet?"
# *   "How can I make contactless payments with my phone?"
# *   "How do I use Samsung Wallet to pay for things?"
# *   "How can I create groups in Contacts?"
# *   "How do I share my location with a friend?"
# *   "How can I use the internet to browse?"
# *   "How do I edit my photo and what is Photo assist?"
#
# **Camera & Media:**
#
# *   "How do I take a really good picture with the camera?"
# *   "How do I switch between the front and rear cameras?"
# *   "How do I scan a document with the camera?"
# *   "Why are my photos blurry?"
# *   "How do I record a video?"
# *   "How can I make stereoscopic images?"
# *    "How to record sound with one microphone only?"
# *   "How do I view photos and videos I've taken?"
# *   "How do I delete pictures from my Gallery?"
# *   "How to extract objects from images?"
#
# **Settings & Customization:**
#
# *   "How do I change the wallpaper on my home screen?"
# *   "How do I customize the buttons on the bottom of the screen?"
# *   "How do I turn on dark mode?"
# *   "How can I set up face recognition?"
# *   "How can I increase the screen's brightness beyond max setting?"
# *   "How do I set up fingerprint unlock?"
# *   "How do I connect to a Wi-Fi network?"
# *   "How do I use Bluetooth to connect to my headphones?"
# *   "How do I make my battery last longer?"
# *   "Where can I find device care option to optimize the device?"
#
# **Troubleshooting:**
#
# *   "What if my phone isn't connecting to Wi-Fi?"
# *   "Why isn't my Bluetooth working?"
# *   "What if my phone is running slowly?"
# *   "What should I do if my phone gets too hot?"
# *   "Why is my camera not working?"
# *   "How do I perform factory reset?"
#
# **Galaxy AI specific:**
#
# *   "How do I use Call Assist to translate phone calls in real-time?"
# *   "Why does Call Assist not work in my language?"
# *   "How do I generate a new profile card using AI in Contacts?"
# *   "Where can I find the "Now Brief" panel?"
# *   "How to use Drawing Assist?"
# *   "Why does my phone keep asking for location permission for the camera?"
# *   "Can I turn off Galaxy AI features?"
# *   "What if I don't want my data being processed in the cloud for Galaxy AI?"
# *   "How to summarize text in the webpages?"
#
# These questions cover a broad range of common user concerns and issues, addressing both basic functionality and more advanced features of the Samsung Galaxy S25 series.
#
#
# --- Calling generate_faq_qa_deepseek ---
# {'Generations': [{'Question': 'Why is my phone getting hot?', 'Answer': 'When you use features or apps that require more power or use them for extended periods, your device may temporarily heat up because of increased battery consumption. Close any running apps and do not use the device for a while.', 'Metadata': {'Type': 'Why', 'FrequencyScore': 5, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['overheating', 'hot', 'temperature', 'battery consumption']}}, {'Question': 'How can I transfer data from my old phone to my new Galaxy S25?', 'Answer': 'Transfer data from your previous device with the USB cable or wirelessly. You can also transfer data from external storage or computer.', 'Metadata': {'Type': 'How', 'FrequencyScore': 5, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['transfer data', 'smart switch', 'previous device', 'migrate']}}, {'Question': "How do I extend my phone's battery life?", 'Answer': 'Your device provides various options that help you conserve battery power. - Optimise the device using the device care feature. - When you are not using the device, turn off the screen by pressing the Side button. - Turn on power saving mode. - Close unnecessary apps. - Turn off the Bluetooth feature when not in use. - Turn off auto-syncing of apps that need to be synced. - Decrease the backlight time. - Decrease the screen brightness.', 'Metadata': {'Type': 'How', 'FrequencyScore': 5, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['battery life', 'power saving', 'optimization', 'extend battery']}}, {'Question': 'How can I take a screenshot?', 'Answer': 'Press the Side button and the Volume Down button simultaneously.  With the edge of your hand, swipe your hand to the left or right across the screen.', 'Metadata': {'Type': 'How', 'FrequencyScore': 5, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['screenshot', 'capture screen', 'take picture']}}, {'Question': 'How do I turn on dark mode?', 'Answer': 'Reduce eye strain by applying the dark theme when using the device at night or in a dark place. You can set a schedule for applying Dark mode.', 'Metadata': {'Type': 'How', 'FrequencyScore': 4, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['dark mode', 'dark theme', 'night mode', 'eye comfort']}}, {'Question': 'What is Secure Folder and how do I use it?', 'Answer': 'Secure Folder protects your private content and apps, such as pictures and contacts, from being accessed by others. You can keep your private content and apps secure even when the device is unlocked.  Secure Folder is a separate, secured storage area. The data in Secure Folder cannot be transferred to other devices through unapproved sharing methods, such as USB or Wi-Fi Direct. Attempting to customise the operating system or modifying software will cause Secure Folder to be automatically locked and inaccessible.', 'Metadata': {'Type': 'What If', 'FrequencyScore': 4, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['secure folder', 'privacy', 'security', 'private content']}}, {'Question': 'How do I set up face recognition?', 'Answer': 'Set a screen lock method. Read the on-screen instructions and tap Continue. Tap Register and position your face inside the frame on the screen. The camera will scan your face.', 'Metadata': {'Type': 'How', 'FrequencyScore': 4, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['face recognition', 'unlock', 'security', 'biometrics']}}, {'Question': 'How do I use Wireless Power Sharing?', 'Answer': 'Open Settings, tap Battery → Wireless power sharing, and then tap the switch to turn it on.  Place the other device on the centre of your phone, with their backs facing.', 'Metadata': {'Type': 'How', 'FrequencyScore': 4, 'RelatedProducts': ['SM-S931B', 'SM-S936B', 'SM-S938B'], 'Keywords': ['wireless power sharing', 'charge another device', 'reverse charging']}}, {'Question': 'How do I ad ...
#
# --- Calling generate_faq_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "FAQs": []
#     }
#   ]
# }
#
# --- Calling generate_faq_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "Why is my phone getting hot when I charge it, especially with wireless charging?",\n      "How do I use the S Pen\'s Air Command features on my Galaxy S25 Ultra to quickly take a screenshot?",\n      "What if I forget the pattern, PIN, or password for my screen lock; is there a way to recover my device?",\n      "Why is my phone not connecting to any Wi-Fi network?",\n      "How can I transfer data from my old phone using Smart Switch, and what kind of data can I transfer?",\n      "Why is my phone using too much battery?",\n      "How can I record my phone\'s screen?"\n    ],\n    "Answers": [\n      "Your phone may get hot while charging due to increased battery consumption; disconnect the charger, close running apps, and let it cool down. If the USB cable is damaged replace it. Ensure a Samsung approved wireless charger is used.",\n      "To use Air Command for screenshots, detach the S Pen, tap the Air Command icon and tap Screen write, crop an area from the captured image, or capture the current content and the hidden content on an elongated page.",\n      "If you forget your screen lock code, you may need to perform a factory reset which will erase all data. Be sure to back up your data regularly to avoid data loss.",\n      "Ensure Wi-Fi is turned on, check if the network requires a password, and restart your phone and the router. If the network name is hidden, manually add a wireless network.",\n      "Smart Switch can transfer contacts, messages, photos, and more, using a USB cable or wirelessly. Open Settings, tap Accounts and backup → Transfer data for device setup, and then follow the on-screen instructions to transfer data.",\n      "Optimize your device using Device Care, turn on Power Saving mode, close unused apps, turn off Bluetooth/Auto-sync, decrease backlight time, and reduce brightness to preserve power.",\n      "Swipe down from the top of the screen to access the quick settings panel, look for the Screen Recorder icon, select sound settings, and begin recording!"\n    ],\n    "Metadata": {\n      "QuestionTypes": ["Why", "How", "What if"],\n      "UserPerspective": "Common customer inquiries"\n    },\n    "FAQCategories": [\n      "Common user pain points",\n      "Anticipated information needs"\n    ]\n  }\n}\n```'}}

# %% [markdown]
# ### Number 5 generate_troubleshooting_qa

# %%
#original
def generate_troubleshooting_qa(text):
    """Diagnostic-focused pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create advanced troubleshooting pairs including:
    - Error symptoms - Diagnostic checks - Repair procedures
    Format solutions with priority levels (Critical/High/Medium).
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_troubleshooting_qa_deepseek(text):
    """Generates machine-actionable diagnostic guides with error codes.

    Returns:
        JSON with nested symptom analysis, error codes, and repair workflows.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create advanced troubleshooting pairs from Samsung docs with:
    1. Symptom pattern matching (e.g., "Boot loop after OS update")
    2. Diagnostic codes following TROUB-XXXX format
    3. Repair steps with required tools/time
    4. Priority matrix (Critical=hardware safety risk)

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Observed symptom]",
        "Answer": {{
          "Symptoms": ["Symptom 1", "Symptom 2"],
          "Diagnostics": ["Check X", "Test Y"],
          "RepairSteps": ["1. Replace component", "2. Flash firmware"],
          "Priority": "Critical",
          "ErrorCode": "TROUB-0238",
          "ToolsRequired": ["GJ-FT55", "Multimeter"],
          "AvgRepairTime": "45 mins"
        }},
        "RelatedComponents": ["Battery", "Motherboard"]
      }}
    - Sort by Priority then AvgRepairTime
    - Validate ErrorCode format: TROUB- followed by 4 digits

    Example:
    {{
      "Generations": [
        {{
          "Question": "Phone restarts randomly during calls",
          "Answer": {{
            "Symptoms": ["Thermal throttling", "Signal drops"],
            "Diagnostics": ["Check battery swelling", "Run ANT+ test"],
            "RepairSteps": ["Replace battery module SPX-897"],
            "Priority": "Critical",
            "ErrorCode": "TROUB-1151",
            "ToolsRequired": ["GJ-TH92 thermal gun"],
            "AvgRepairTime": "25 mins"
          }},
          "RelatedComponents": ["Battery", "Antenna"]
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse diagnostic protocol"}


#Google AI STudio
def generate_troubleshooting_qa_google(text):
    """Advanced troubleshooting pairs in JSON format with priority levels."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate advanced troubleshooting Question and Answer pairs from the following Samsung support document text.

    Include for each troubleshooting pair:
    - Error symptoms (brief description)
    - Diagnostic checks to perform
    - Repair procedures or resolution steps

    Format each solution with a priority level: "Critical", "High", or "Medium" based on the severity and urgency of the issue.

    Use consumer-friendly language. Keep answers concise and step-by-step where applicable.

    Present the output as a list of troubleshooting Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Priority" ("Critical", "High", "Medium"), "Question" (error symptom description), "Answer" (troubleshooting/resolution steps), and optionally "ErrorSymptoms", "DiagnosticChecks", "RepairProcedures" (as lists of strings).

    Text: {text}

    Output Format (example):
    [
      {{ "Priority": "Critical", "Question": "...", "Answer": "...", "ErrorSymptoms": [...], "DiagnosticChecks": [...], "RepairProcedures": [...] }},
      {{ "Priority": "Medium", "Question": "...", "Answer": "...", "ErrorSymptoms": [...], "DiagnosticChecks": [...], "RepairProcedures": [...] }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        troubleshooting_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        troubleshooting_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"TroubleshootingQAPairs": troubleshooting_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_troubleshooting_qa_sonnet(text):
    """Generate structured diagnostic Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create troubleshooting Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific error or diagnostic scenario"
        ],
        "Answers": [
          "Comprehensive troubleshooting solution"
        ],
        "Metadata": {{
          "PriorityLevels": ["Critical", "High", "Medium"],
          "DiagnosticApproach": "Systematic problem resolution"
        }},
        "TroubleshootingDetails": {{
          "ErrorSymptoms": ["Detailed problem description"],
          "DiagnosticChecks": ["Step-by-step verification"],
          "RepairProcedures": ["Solution steps"]
        }}
      }}
    }}

    Requirements:
    - Clear error symptom descriptions
    - Systematic diagnostic approach
    - Priority-based solutions
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_troubleshooting_qa ---")
test_qa_generators("generate_troubleshooting_qa", content)
# Out:
# --- generate_troubleshooting_qa ---
#
# --- Calling generate_troubleshooting_qa ---
# Okay, here are some advanced troubleshooting pairs based on the provided user guide, formatted with priority levels. Note that these are based on the common issues suggested by the content, and represent a small sample of possible problems.
#
# **Pair 1: Device Not Turning On**
#
# *   **Error Symptom:** Device completely unresponsive, screen remains black, no lights or sounds when attempting to power on.
# *   **Diagnostic Checks:**
#     1.  **Critical:** Check battery level. Connect the device to a known working charger and power outlet. Allow charging for at least 30 minutes, then attempt to power on again. Use the Samsung-approved battery, charger, and cable specifically designed for your device.
#     2.  **Critical:** Force Restart. Press and hold the Side button and Volume Down button simultaneously for more than 7 seconds. This can sometimes bypass a software lockup.
#     3.  **Medium:** Check the charging port for debris or damage. Inspect the USB-C port for bent pins, lint, or other obstructions. Clean gently with compressed air or a soft, non-conductive tool (power off the device first!).
# *   **Repair Procedures:**
#     1.  **Critical:** If the device starts after charging, monitor the charging behavior. Replace the charging cable or adapter if charging is slow or erratic.
#     2.  **Critical:** If the device still fails to power on after charging and attempting a force restart, the battery may be faulty or there may be an internal hardware issue. Seek professional repair at a Samsung Service Centre or authorized service center.
#     3.  **Medium:** If the charging port is damaged, professional repair/replacement is necessary. *Do not attempt to repair a damaged charging port yourself.*
#
# **Pair 2: Screen Unresponsive or Slow Touch Recognition**
#
# *   **Error Symptom:** Screen does not respond to touch, responds slowly, or registers touches incorrectly.
# *   **Diagnostic Checks:**
#     1.  **High:** Check the screen for physical damage. Inspect the screen for cracks, scratches, or other signs of damage.
#     2.  **High:** Check for screen protector issues. A damaged, improperly applied, or low-quality screen protector can interfere with touch sensitivity. Remove the screen protector and test.
#     3.  **High:** Clean the screen. Wipe the screen with a clean, soft, lint-free cloth to remove any dirt, oil, or residue.
#     4.  **Medium:** Check for software glitches. Restart the device.
#     5.  **Medium:** Check Touch Sensitivity Settings. Navigate to Settings > Display > Touch sensitivity. Enable if available.
#     6.  **Medium:** Check "Accidental touch protection". Disable setting at Settings > Display.
# *   **Repair Procedures:**
#     1.  **Critical:** If the screen is physically damaged, replace the screen at a Samsung Service Centre or authorized service center.
#     2.  **High:** If a screen protector is the problem, replace it with a high-quality screen protector that is explicitly compatible with the device.
#     3.  **Medium:** If a restart fixes the issue temporarily, monitor the device for recurring problems. If the problem persists or worsens, further troubleshooting or a factory reset may be necessary.
#     4.  **Medium:** If "Accidental touch protection" is not allowing certain touches, turn this setting off.
#
# **Pair 3: Poor Call Quality (Echo, Low Volume, or Cutting Out)**
#
# *   **Error Symptom:** During calls, the user experiences echoing sounds, low volume, or the call is frequently cutting out.
# *   **Diagnostic Checks:**
#     1.  **High:** Check microphone and speaker openings. Inspect the microphone and speaker grilles for obstructions (dust, debris, etc.). Clean gently.
#     2.  **High:** Test in different locations. The issue may be related to network signal strength. Try making calls in areas with strong cellular reception.
#     3.  **Medium:** Check volume settings. During a call, use the volume buttons to ensure the volume is set appropriately.
#     4.  **Medium:** Try using headphones. Does the call quality improve with headphones? This helps isolate whether the issue is with the device's speaker/microphone or the network connection.
#     5.  **Low:** Check for Bluetooth interference. Turn off Bluetooth to see if it is impacting call quality.
# *   **Repair Procedures:**
#     1.  **High:** If the microphone or speaker grilles are blocked, carefully clean them with a soft brush or compressed air.
#     2.  **Medium:** If call quality is consistently poor in specific locations, contact the carrier to report potential network issues.
#     3.  **Medium:** If the problem is intermittent, check the proximity sensor to make sure it is not getting blocked by a screen protector or dirt. The sensor is near the front speaker and affects how screen behaves during calls.
#     4.  **Medium:** Perform a network settings reset (Settings > General Management > Reset > Reset network settings). Note: This will reset Wi-Fi passwords and Bluetooth pairings.
#     5.  **Critical:** If none of these steps resolve the issue, it could indicate a hardware problem with the device's microphone, speaker, or cellular radio. Seek professional repair at a Samsung Service Centre or authorized service center.
#
# **Pair 4: Wi-Fi Connection Issues**
#
# *   **Error Symptom:** Unable to connect to Wi-Fi network, slow Wi-Fi speeds, or frequent disconnections.
# *   **Diagnostic Checks:**
#     1.  **Critical:** Verify Wi-Fi network is working. Test connecting other devices to the same Wi-Fi network to ensure the problem isn't with the router or internet connection itself.
#     2.  **High:** Check Wi-Fi password. Make sure the correct Wi-Fi password is being entered.
#     3.  **Medium:** Restart the device. This often resolves temporary software glitches.
#     4.  **Medium:** Forget and reconnect to the Wi-Fi network. On the device, "forget" the network and then reconnect, entering the password again.
#     5.  **Low:** Check for Wi-Fi Interference. Move away from sources of interference (microwave ovens, Bluetooth devices, etc.)
#     6.  **Low:** Check Wi-Fi settings. Navigate to Settings > Connections > Wi-Fi > tap the gear icon next to the problematic network > check IP Address and Proxy Settings.
# *   **Repair Procedures:**
#     1.  **High:** Restart the Wi-Fi router/modem.
#     2.  **Medium:** If reconnecting fixes the problem temporarily, check the router's firmware for updates.
#     3.  **Medium:** Reset network settings on the device (Settings > General management > Reset > Reset network settings). Note: This will reset Wi-Fi passwords and Bluetooth pairings.
#     4.  **Critical:** If the issue persists, the device's Wi-Fi radio may be faulty. Seek professional repair at a Samsung Service Centre or authorized service center.
#
# **Pair 5: Fast Battery Drain**
#
# *   **Error Symptom:** Battery drains much faster than expected, even with minimal use.
# *   **Diagnostic Checks:**
#     1. **Critical:** Check battery usage. Go to Settings > Battery > check "Today's" usage. Identify apps consuming excessive battery power.
#     2.  **High:** Close unused apps. Ensure that apps running in the background are closed.
#     3.  **Medium:** Check screen brightness and screen timeout settings. Reduce screen brightness and shorten screen timeout duration.
#     4.  **Medium:** Turn off unnecessary features. Disable Bluetooth, Wi-Fi, Location Services, and Auto-Sync when not in use.
#     5.  **Low:** Check for rogue app. Boot device into safe mode to determine whether a recently installed application is causing the problem
# *   **Repair Procedures:**
#     1. **High:** Uninstall battery-intensive apps. Consider uninstalling apps that are consistently consuming a large amount of battery power.
#     2. **Medium:** Change Background usage limits to a lower usage mode.
#     3. **Medium:** Check Battery Care settings. Enable Battery Protection under Settings> Battery> Battery Protection
#     4.  **Low:** Factory reset (as last resort). Perform a factory data reset if other troubleshooting steps fail.
#     5.  **Critical:** If the battery continues to drain rapidly, the battery may be faulty or nearing the end of its lifespan. Seek professional battery replacement at a Samsung Service Centre or authorized service center.
#
# **Important Notes:**
#
# *   **Safety First:** Always power off the device before attempting any cleaning or physical inspections.
# *   **Professional Help:** If you are not comfortable performing any of these steps or if the problem persists, seek professional repair at a Samsung Service Centre or authorized service center.
# *   **Warranty:** Be aware that attempting unauthorized repairs may void your device's warranty.
#
# These pairs offer a starting point for diagnosing and resolving common issues with the SM-S931B, SM-S936B, and SM-S938B series devices. The specific steps and solutions may vary depending on the individual situation. Always refer to the full user guide and official Samsung support resources for the most accurate and up-to-date information.
#
#
# --- Calling generate_troubleshooting_qa_deepseek ---
# {'Generations': [{'Question': 'Phone is overheating and shutting down unexpectedly', 'Answer': {'Symptoms': ['Thermal throttling', 'Frequent shutdowns', 'Battery draining quickly'], 'Diagnostics': ['Check CPU usage', 'Measure battery temperature', 'Examine charging port for damage'], 'RepairSteps': ['1. Replace battery module SPX-897', '2. Clean charging port with compressed air'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-1151', 'ToolsRequired': ['GJ-TH92 thermal gun', 'Compressed air'], 'AvgRepairTime': '25 mins'}, 'RelatedComponents': ['Battery', 'Motherboard', 'Charging Port']}, {'Question': "Device is unresponsive; won't power on", 'Answer': {'Symptoms': ['Black screen', 'No response to power button', 'No charging indication'], 'Diagnostics': ['Check battery voltage', 'Inspect motherboard for shorts', 'Test power IC'], 'RepairSteps': ['1. Replace faulty power IC', '2. Flash firmware with Odin'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-0238', 'ToolsRequired': ['GJ-FT55', 'Multimeter', 'Odin software'], 'AvgRepairTime': '45 mins'}, 'RelatedComponents': ['Battery', 'Motherboard', 'Power IC']}, {'Question': 'Display shows dead pixels or color distortion', 'Answer': {'Symptoms': ['Stuck pixels', 'Incorrect colors', 'Lines on screen'], 'Diagnostics': ['Run display self-test', 'Inspect flex cable connection', 'Check for physical damage'], 'RepairSteps': ['1. Replace display assembly', '2. Check if the display cable is corroded'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-4011', 'ToolsRequired': ['GJ-DS78', 'Plastic Spudger', 'Screwdriver'], 'AvgRepairTime': '60 mins'}, 'RelatedComponents': ['Display Assembly', 'Flex Cable', 'Motherboard']}, {'Question': 'SIM card not recognized', 'Answer': {'Symptoms': ['No SIM card detected', 'Invalid SIM', 'Emergency calls only'], 'Diagnostics': ['Check SIM card for damage', 'Test SIM slot continuity', 'Examine SIM IC voltage'], 'RepairSteps': ['1. Replace SIM card reader', '2. Reflow SIM IC'], 'Priority': 'High', 'ErrorCode': 'TROUB-0042', 'ToolsRequired': ['GJ-SM21', 'Hot air station', 'Microscope'], 'AvgRepairTime': '30 mins'}, 'RelatedComponents': ['SIM Card Reader', 'SIM IC', 'Motherboard']}, {'Question': 'Phone restarts randomly during calls', 'Answer': {'Symptoms': ['Thermal throttling', 'Signal drops'], 'Diagnostics': ['Check battery swelling', 'Run ANT+ test'], 'RepairSteps': ['Replace battery module SPX-897'], 'Priority': 'High', 'ErrorCode': 'TROUB-1152', 'ToolsRequired': ['GJ-TH92 thermal gun'], 'AvgRepairTime': '25 mins'}, 'RelatedComponents': ['Battery', 'Antenna']}, {'Question': 'Wi-Fi connection unstable or not connecting', 'Answer': {'Symptoms': ['Weak signal', 'Cannot find networks', 'Authentication problems'], 'Diagnostics': ['Check Wi-Fi antenna continuity', 'Test Wi-Fi IC voltage', 'Examine firmware'], 'RepairSteps': ['1. Replace Wi-Fi antenna', '2. Reflash firmware'], 'Priority': 'Medium', 'ErrorCode': 'TROUB-0789', 'ToolsRequired': ['GJ-WA33', 'Multimeter', 'Odin software'], 'AvgRepairTime': '35 mins'}, 'RelatedComponents': ['Wi-Fi Antenna', 'Wi-Fi IC', 'Motherboard']}, {'Question': 'Bluetooth connection fails or has poor audio quality', 'Answer': {'Symptoms': ['Device discovery issues', 'Audio distortion', 'Frequent disconnections'], 'Diagnostics': ['Test Bluetooth antenna signal strength', 'Check Bluetooth IC voltage', 'Examine codec settings'], 'RepairSteps': ['1. Replace Bluetooth antenna', '2. Reflash Bluetooth firmware'], 'Priority': 'Medium', 'ErrorCode': 'TROUB-0821', 'ToolsRequired': ['GJ-BT44', 'Multimeter', 'Firmware tool'], 'AvgRepairTime': '40 mins'}, 'RelatedComponents': ['Bluetooth Antenna', 'Bluetooth IC', 'Motherboard']}]}
#
# --- Calling generate_troubleshooting_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "TroubleshootingQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_troubleshooting_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "Device won\'t turn on even after connecting to a charger.",\n      "Device freezes or becomes unresponsive.",\n      "Device displays \'No Service\' or has intermittent network connectivity.",\n      "Battery drains rapidly, much faster than usual.",\n      "Camera app displays error message or fails to open.",\n      "Fingerprint sensor fails to recognize registered fingerprint.",\n      "Slow touch screen response, or unresponsive touch in certain areas.",\n      "Device is overheating significantly during normal use.",\n      "Unable to connect to Wi-Fi, or experiencing frequent disconnections.",\n      "Sound is distorted or too quiet from the speaker."\n    ],\n    "Answers": [\n      "Ensure the charger is functioning correctly and let the device charge for at least 30 minutes before attempting to power it on. A completely depleted battery may require some time to reach a minimum charge level.",\n      "Force restart the device by pressing and holding the Side button and Volume Down button for at least 7 seconds. If that doesn\'t work, perform a factory reset (backup data first).",\n      "Ensure Airplane Mode is disabled and try restarting the device or reseating the SIM card. Verify with your carrier that your account is active and that there are no service outages in your area.",\n      "Identify battery-intensive apps via Settings > Battery and close or uninstall them. Reduce screen brightness, disable unnecessary features like Bluetooth and Wi-Fi when not in use, and enable power saving mode.",\n      "Free up storage space by deleting unused files or apps and clear camera app cache. Restart the device and ensure the camera lens is clean and free from obstructions.",\n      "Ensure your finger and the sensor are clean and dry and re-register your fingerprint ensuring you capture all areas of the finger. Update the software to the latest version and consider removing any screen protector.",\n      "Remove any screen protector, clean the screen thoroughly, and restart the device. Check for software updates and if the problem persists, a hardware issue may require professional repair.",\n      "Close all unnecessary apps, reduce screen brightness, and avoid using the device in direct sunlight or hot environments. Check settings if performance profile is set to performance, change to standard.",\n      "Ensure Wi-Fi is enabled and try restarting your router and the device, and forget the network then reconnect entering the password again. Check to see if MAC address filtering enabled on your wifi router and allow the MAC address.",\n      "Check if anything is covering the speaker, clean the speaker grill, and try increasing the volume in settings. Ensure Do Not Disturb mode is not enabled or Separate App Sound is on and routing to different device."\n    ],\n    "Metadata": {\n      "PriorityLevels": ["High", "High", "Medium", "High", "Medium", "Medium", "Medium", "High", "Medium", "Medium"],\n      "DiagnosticApproach": "Systematic problem resolution, starting with simple checks and escalating to more complex solutions."\n    },\n    "TroubleshootingDetails": {\n      "ErrorSymptoms": [\n        "Device fails to power on or respond to charger.",\n        "Application freeze, screen lock, or system crash.",\n        "Intermittent or complete lack of cellular network connectivity.",\n        "Significant and unexpected drop in battery life.",\n        "Error message on camera launch, inability to take photos.",\n        "Failure to unlock the device using registered fingerprint.",\n        "Delay in touch responsiveness, unresponsive touch in certain screen areas.",\n        "Excessive heat generation during standard device usage.",\n        "Unable to connect to available Wi-Fi networks or frequent disconnections",\n        "Muffled, distorted, or faint audio output from the device speaker."\n     ...

# %% [markdown]
# ### Number 6 generate_feature_explanation_qa

# %%
#original
def generate_feature_explanation_qa(text):
    """Technology deep-dive pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Explain Samsung technologies with Q&A pairs covering:
    - Technical specifications - Use cases - Compatibility notes
    Include diagrams in markdown when relevant.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_feature_explanation_qa_deepseek(text):
    """Generates standardized technical explanations with spec matrices.

    Returns:
        JSON with nested specifications, compatibility tables, and visual references.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create technology deep-dive Q&A pairs with:
    1. Technical specifications in key:value format
    2. Compatibility matrices (Device ↔ Feature Support)
    3. Use case scenarios with required settings
    4. Official diagram references instead of markdown

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Technology inquiry]",
        "Answer": {{
          "Overview": "2-sentence summary",
          "TechnicalSpecs": {{
            "Parameter": "Value",
            "MeasurementUnit": "Hz/nm/mm"
          }},
          "Compatibility": {{
            "GalaxyS24": "Full",
            "GalaxyZFold5": "Partial"
          }},
          "DiagramReference": "KB-12345-fig3"
        }},
        "FeatureType": "Display/Connectivity/AI"
      }}
    - Use standardized units (MHz not Mhz)
    - Replace markdown with Samsung Knowledge Base references

    Example:
    {{
      "Generations": [
        {{
          "Question": "How does Quantum Matrix Technology improve display quality?",
          "Answer": {{
            "Overview": "Uses AI-controlled mini-LED clusters...",
            "TechnicalSpecs": {{
              "DimmingZones": 2048,
              "PeakBrightness": "2500 nits",
              "ResponseTime": "1ms"
            }},
            "Compatibility": {{
              "S95C TV": "Yes",
              "QN900C Neo QLED": "No"
            }},
            "DiagramReference": "KB-DISPLAY-2024-FIG12"
          }},
          "FeatureType": "Display"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse technical explanation"}


#Google AI STudio
def generate_feature_explanation_qa_google(text):
    """Technology deep-dive pairs in JSON format, with diagram URLs."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Explain Samsung technologies using Question and Answer pairs from the following support document text, covering:
    - Technical specifications
    - Use cases
    - Compatibility notes

    When diagrams are relevant to illustrate a technology, include references to diagram file names or URLs in the output. Assume diagrams are available as images and you can reference their filenames or URLs.  In the JSON output, include a list of "Diagrams" (URLs or filenames) for each Q&A pair if applicable.

    Use clear and informative language, suitable for users interested in understanding the technology in detail.  Keep answers concise and focused.

    Present the output as a list of technology explanation Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "TechnicalSpecifications" (list of specs), "UseCases" (list of use cases), "CompatibilityNotes" (list of notes), and "Diagrams" (list of diagram URLs/filenames).

    Text: {text}

    Output Format (example):
    [
      {{ "Question": "...", "Answer": "...", "TechnicalSpecifications": [...], "UseCases": [...], "CompatibilityNotes": [...], "Diagrams": [...] }},
      {{ "Question": "...", "Answer": "...", "TechnicalSpecifications": [...], "UseCases": [...], "CompatibilityNotes": [...], "Diagrams": [...] }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        feature_explanation_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        feature_explanation_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"FeatureExplanationQAPairs": feature_explanation_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_feature_explanation_qa_sonnet(text):
    """Generate structured technology deep-dive Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create feature explanation Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Technical feature inquiry"
        ],
        "Answers": [
          "Comprehensive technology explanation"
        ],
        "Metadata": {{
          "ExplanationDepth": "Technical deep-dive",
          "CoverageAreas": ["Specifications", "Use Cases", "Compatibility"]
        }},
        "TechnicalDetails": {{
          "Specifications": ["Detailed technical parameters"],
          "UseCases": ["Practical application scenarios"],
          "CompatibilityNotes": ["Integration and limitation insights"]
        }},
        "VisualizationSupport": {{
          "DiagramMarkdown": "Optional technical illustration"
        }}
      }}
    }}

    Requirements:
    - In-depth technical explanations
    - Practical use case descriptions
    - Compatibility insights
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_feature_explanation_qa ---")
test_qa_generators("generate_feature_explanation_qa", content)
# Out:
# --- generate_feature_explanation_qa ---
#
# --- Calling generate_feature_explanation_qa ---
# Okay, I'll structure the information about Samsung technologies from the provided text in a Q&A format, focusing on technical specifications, use cases, and compatibility notes, and including diagrams where appropriate.
#
# **1. Display Technology (Motion Smoothness):**
#
# **Q:** What is "Motion Smoothness" on Samsung phones, and what are the technical differences between the available settings?
#
# **A:** Motion Smoothness refers to the refresh rate of the display, measured in Hertz (Hz). A higher refresh rate means the screen updates more frequently, leading to smoother animations and scrolling.
#
#    *   **Adaptive:**  Automatically adjusts the screen refresh rate to a higher one (likely 120Hz) for smoother animations and scrolling when needed.  This provides a better user experience but consumes more battery. The actual refresh rate is usually varied based on the screen content.
#    *   **Standard:** Uses a standard refresh rate (likely 60Hz) to conserve battery power.
#
# **Use Case:**
#    *   **Adaptive:** Best for gaming, watching fast-paced videos, or any scenario where smooth visuals are important.
#    *   **Standard:** Suitable for everyday use, reading, or when battery life is a priority.
#
# **Compatibility Notes:**
#    *   Higher refresh rates consume more battery.
#    *   Benefits are most noticeable with content designed for higher refresh rates (e.g., some games, some videos).
#
# **2.  Water and Dust Resistance (IP68):**
#
# **Q:** What does "IP68" mean in relation to Samsung phone water and dust resistance, and what are the limitations?
#
# **A:** IP68 is an international standard for protection against solids (dust) and liquids (water).
#
#    *   **IP68:** "Dust tight" (no ingress of dust) and protected against immersion in fresh water with a depth of 1.5 meters for 30 minutes under specific conditions (15-35 °C, 86-106 kPa).
#
# **Use Cases:**  Protection against accidental splashes, rain, or brief immersion in fresh water.  Peace of mind when using the phone in dusty environments.
#
# **Compatibility Notes / Limitations:**
#
#    *   Water resistance is not permanent and can diminish over time due to normal wear and tear.
#    *   The device must not be exposed to salt water or water moving with force (e.g., strong water jets).
#    *   Exposure to soapy water, oil, perfume, sunscreen, hand cleaner, chemical products such as cosmetics, or liquids that include the alcohol can decrease water resistance. After water exposure, the device needs to be wiped and dried thoroughly.
#    *   Charging or connecting accessories should only be done *after* the device is completely dry.
#    *   Water-resistance can be affected by shocks or damage to the device.
#    *  Do not expose the device to swimming pool water or sea water.
#
# **3. Wireless Power Sharing**
#
# **Q:** How does the wireless power sharing on Samsung devices work?
#
# **A:** This feature allows a Samsung device to wirelessly charge other devices that support wireless charging (Qi standard).
#
# **Use Cases:**
# * Conveniently charging compatible smartwatches (like Galaxy Watch), earbuds (like Galaxy Buds), or other smartphones without needing a wall charger.
# * Emergency charging for another device when a power outlet is not available.
#
# **Technical Specs:**
# * The power output is dependent on the Samsung device's battery level and charging state.
# * The device must be placed back-to-back with the device being charged.
#
# **Compatibility Notes:**
# * Only compatible with devices that support Qi wireless charging.
# * The location of the wireless charging coil may differ depending on the device, it must be aligned properly.
# * Some features are not available while sharing power.
# * It is recommended to remove any accessories and cover being used before using this feature.
#
# **4. Quick Share**
#
# **Q:** What is Quick Share, and how does it work?
#
# **A:** Quick Share is Samsung's file-sharing feature that allows you to quickly and easily transfer files to nearby Samsung devices and people in your contacts using Wi-Fi Direct or Bluetooth.
#
# **Use Cases:**
# * Instantly share photos, videos, documents, and other files with friends and family nearby without the need for cloud storage or email.
# * Sharing files between your own Samsung devices (phone, tablet, laptop).
#
# **Technical Specs:**
# * Uses Wi-Fi Direct for faster transfer speeds or Bluetooth when Wi-Fi is not available.
#
# **Compatibility Notes:**
# * Primarily designed for Samsung devices.  Other Android devices may have limited compatibility.
# * Other devices can only find your phone when Contacts only or Everyone setting is turned on.
#
# **5. Samsung DeX:**
#
# **Q:** What is Samsung DeX, and what are the different ways to use it?
#
# **A:** Samsung DeX (Desktop eXperience) allows you to use your Samsung phone or tablet in a desktop-like environment by connecting it to an external display, keyboard, and mouse.
#
# **Use Cases:**
# *   Boost productivity by working on documents, presentations, or emails on a larger screen with a keyboard and mouse.
# *   Run multiple apps simultaneously in a windowed environment.
# *   Use your phone or tablet as a computer for basic tasks.
#
# **Technical Specs:**
# *   Can connect wirelessly to compatible TVs and monitors.
# *   Can connect via a wired connection using an HDMI adapter (USB Type-C to HDMI).
#
# **Compatibility Notes:**
# *   Some apps or features may not be optimized for DeX.
# * Wired connections to external displays Use only official Samsung DeX supported accessories that are provided by Samsung.
# * When starting or ending Samsung DeX, running apps may be closed.
#
# **6. Always On Display (AOD):**
#
# **Q: What is Always On Display (AOD) and how to use this feature?**
#
# **A:** Always On Display (AOD) is a feature that allows you to see certain information on the screen, such as the clock, date, notifications, and battery percentage, even when the screen is turned off.
#
# **Use Cases:**
# * Quickly glance at the time, date, and important notifications without waking the entire screen.
# * Add a personalized touch to your phone with custom clock styles or images.
#
# **Technical Specs:**
# * Can be customized to display various information, such as clock style, notifications, calendar events, or images.
# * Can be set to appear all the time, according to a schedule, or only when the screen is tapped.
#
# **Compatibility Notes:**
# * Using AOD will consume battery power, especially if it's set to display all the time.
#
# **7. Samsung Wallet**
#
# **Q:** What is the use case for Samsung Wallet
#
# **A:** Samsung Wallet integrates various convenient features, allowing users to make payments, verify identity through biometrics, access tickets or boarding passes, and more, all in one place.
#
# * Register cards to Samsung Pay to make both online and offline payments.
#
# * Register your biometric data to Samsung Pass and verify your identity when using services which require your login or personal information.
#
# * Add boarding passes and tickets for movies, sports, and more, to access and use them in one place.
#
# * Register your vehicle’s digital key to your phone so you can unlock or lock the vehicle’s door and start the vehicle.
#
# **Compatibility Notes**
#
# The device may require a connection to a Wi-Fi or mobile network depending on the region to make payments with Samsung Pay.
#
# **8. Galaxy AI**
#
# **Q:** What is Galaxy AI?
#
# **A:** Galaxy AI is a suite of advanced intelligence features designed to enhance the usability of Samsung devices through functionalities like real-time call translations, messaging assistance, note summarization, photo editing, and more.
#
# * Translating phone calls in real time (Call assist)
# * Translating messages in message apps (Writing assist)
# * Translating conversations (Interpreter)
# * Using Note assist features (Samsung Notes)
# * Converting voice recordings to text (Samsung Notes)
# * Summarising and translating voice recordings (Voice Recorder)
# * Summarising and converting call recordings into text (Transcript assist)
# * Translating or summarising webpages (Browsing assist)
# * Translating text using the camera (Camera)
# * Editing images with the Photo assist (Gallery)
#
# **Compatibility Notes**
#
# Some features may not be available depending on the region, carrier, or model.
#
# **9. Ultra Wideband (UWB)**
#
# **Q:** What is UWB?
#
# **A:** Ultra-wideband (UWB) is a short-range, wireless communication protocol that uses a wide range of radio frequencies to transmit data with high speed and accuracy.
#
# *Using a digital key with the ultra-wideband (UWB) (Galaxy S25 Ultra, Galaxy S25+)
#
# The vehicle’s door will unlock when you get close to the vehicle with your phone, and will lock when you move away.
#
# After the digital key is authenticated when you get inside the vehicle, you can start the vehicle using the start button.
#
#  **Compatibility Notes:**
# the phone and vehicle must support both the Bluetooth and
# UWB features.
# UWB feature may not be available depending on the region.
#
# **Adding Diagrams (Illustrative Examples)**
#
# Since I cannot display actual images, I'll create ASCII art diagrams to represent some concepts (understanding that real images would be much more effective).
#
# **Example: Wireless Power Sharing Placement**
#
# ```
#     +-------------------+      +-------------------+
#     |   Samsung Phone   |      |  Other Device   |
#     |   (Charging)      |------| (Being Charged)   |
#     |  Wireless Coil    |      |  Wireless Coil    |
#     +-------------------+      +-------------------+
#         ||                        ||
#         ||   Back-to-Back        ||
#         \/                        \/
# ```
#
# **Example: Simple DeX Setup (Wired)**
#
# ```
#     +----------+    USB-C to HDMI   +----------+    +--------+
#     |  Samsung |-------------------->| External |---->|Keyboard|
#     |  Device  |                    |  Display |    +--------+
#     +----------+                    +----------+    +--------+
#                                                         |Mouse|
#                                                         +--------+
# ```
#
# **Remember:** This is a simplified explanation. It's always best to refer to official Samsung documentation and specifications for the most accurate and up-to-date information.
#
#
# --- Calling generate_feature_explanation_qa_deepseek ---
# {'Generations': [{'Question': "What are the key technical specifications of the Galaxy S25 Ultra's S Pen?", 'Answer': {'Overview': "The Galaxy S25 Ultra's S Pen offers precise input and enhanced features like Air Command, allowing for improved note-taking and control. It features low latency and tilt recognition for a natural writing experience.", 'TechnicalSpecs': {'Latency': '2.8 ms', 'TiltRecognition': '±60 degrees', 'PressureLevels': '4096', 'Material': 'Plastic, rubber tip', 'Length': '119.4 mm', 'Diameter': '5.8 mm', 'Button': 'Single button with configurable actions'}, 'Compatibility': {'GalaxyS25Ultra': 'Full', 'GalaxyS25+': 'None', 'GalaxyS25': 'None'}, 'DiagramReference': 'KB-SPEN-S25ULTRA-FIG1'}, 'FeatureType': 'Display'}, {'Question': 'What are the supported wireless charging capabilities of the SM-S936B?', 'Answer': {'Overview': 'The SM-S936B supports both Qi-compatible wireless charging and Wireless Power Sharing, enabling the device to charge wirelessly and to charge other devices. The speed varies depending on the charger and device support.', 'TechnicalSpecs': {'QiStandard': 'Yes', 'WirelessChargingPower': '15 W', 'WirelessPowerSharing': '4.5 W', 'ChargingFrequency': '110-148 kHz'}, 'Compatibility': {'GalaxyS25+': 'Full', 'GalaxyS25': 'Full', 'GalaxyBuds': 'Full'}, 'DiagramReference': 'KB-CHARGING-2025-FIG7'}, 'FeatureType': 'Connectivity'}, {'Question': 'How does the Writing Assist feature in Galaxy AI impact the keyboard and messaging experience?', 'Answer': {'Overview': 'Writing Assist improves communication through real-time translation, tone adjustments, and text generation, offering a more intuitive and personalized messaging experience. Access via Samsung Keyboard for composing diverse message styles.', 'TechnicalSpecs': {'SupportedLanguages': '100+', 'StyleOptions': 'Professional, Casual, Polite, Empathic, Social', 'TranslationTime': '<1 s', 'MaximumInputLength': '500 characters', 'MinimumFirmware': 'Rev1', 'ProcessorRequirements': '2.8GHz Octa-Core or better'}, 'Compatibility': {'GalaxyS25': 'Full', 'GalaxyS25+': 'Full', 'GalaxyS25Ultra': 'Full'}, 'DiagramReference': 'KB-AI-WRITING-2025-FIG4'}, 'FeatureType': 'AI'}, {'Question': 'What is the maximum video resolution supported by the SM-S938B Camera?', 'Answer': {'Overview': 'The SM-S938B camera system supports recording up to 8K resolution videos with various frame rate options. This allows for high-quality video recording and capturing detailed footage.', 'TechnicalSpecs': {'MaxVideoResolution': '7680 x 4320 pixels', 'MaxVideoFrameRate': '24 fps', 'VideoCodec': 'HEVC, H.264', 'VideoBitrate': '80 Mbps', 'AudioCodec': 'AAC'}, 'Compatibility': {'SM-S938B': 'Full', 'SM-S936B': 'Partial (4K max)', 'SM-S931B': 'Partial (4K max)'}, 'DiagramReference': 'KB-CAMERA-VIDEO-2025-FIG9'}, 'FeatureType': 'Display'}, {'Question': 'How does the Photo Ambient wallpaper feature work, and what settings are needed to use it?', 'Answer': {'Overview': 'The Photo Ambient feature changes the lock screen wallpaper based on the local weather and time of day. To use it requires location access and an active network connection to retrieve weather data.', 'TechnicalSpecs': {'LocationAccuracy': '± 10 m', 'UpdateFrequency': 'hourly', 'WallpaperResolution': 'Dynamic (adapts to screen)', 'DataUsagePerUpdate': '50 KB (average)'}, 'Compatibility': {'SM-S931B': 'Full', 'SM-S936B': 'Full', 'SM-S938B': 'Full'}, 'DiagramReference': 'KB-AI-WALLPAPER-2025-FIG1'}, 'FeatureType': 'AI'}, {'Question': 'Can the UWB (Ultra-Wideband) feature be used to unlock car doors on the Galaxy S25, and what are the compatible devices?', 'Answer': {'Overview': 'On the Galaxy S25 Ultra and S25+, UWB allows for keyless entry by automatically unlocking doors as the user approaches the vehicle. Both the phone and vehicle must support UWB technology for this feature to work.', 'TechnicalSpecs': {'OperatingFrequency': '3.1 GHz - 10.6 GHz', 'Range': 'Up to 10 m', 'DataRate': 'Up to 6.75 Mbit/s', 'Security': 'IEEE 802. ...
#
# --- Calling generate_feature_explanation_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "FeatureExplanationQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_feature_explanation_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Accessibility": {\n    "Questions": [\n      "How do I enable TalkBack for voice feedback?",\n      "How can I adjust the colour settings if I have difficulty distinguishing colours?",\n      "How can I control the screen by connecting an external switch?",\n      "Can I increase touch sensitivity for use with a screen protector?"\n    ],\n    "Answers": [\n      "Go to Settings > Accessibility > TalkBack and tap the switch to turn it on for voice feedback.",\n      "Go to Settings > Accessibility > Vision enhancements > Colour correction and tap the switch to turn it on; select an option.",\n      "Go to Settings > Accessibility > Interaction and dexterity > Universal switch to connect an external switch.",\n      "Go to Settings > Display and turn on the Touch sensitivity feature."\n    ],\n    "Metadata": {\n      "ExplanationDepth": "Technical deep-dive",\n      "CoverageAreas": ["Specifications", "Use Cases", "Compatibility"]\n    },\n    "TechnicalDetails": {\n      "Specifications": ["Detailed accessibility feature descriptions"],\n      "UseCases": ["Scenarios benefiting from accessibility features"],\n      "CompatibilityNotes": ["Potential limitations with specific apps"]\n    },\n    "VisualizationSupport": {\n      "DiagramMarkdown": "Optional accessibility flow illustration"\n    }\n  },\n  "Battery": {\n    "Questions": [\n      "How can I enable Power saving mode to extend battery life?",\n      "Where can I find battery usage information?",\n      "How can I charge another device with my phone\'s battery?"\n    ],\n    "Answers": [\n      "Go to Settings > Battery and tap Power saving to turn on power saving mode.",\n      "Go to Settings > Battery and look for the \'Today\' section to view detailed usage stats.",\n      "Go to Settings > Battery > Wireless power sharing, and then tap the switch to turn it on, placing the other device back-to-back."\n    ],\n    "Metadata": {\n      "ExplanationDepth": "Technical deep-dive",\n      "CoverageAreas": ["Specifications", "Use Cases", "Compatibility"]\n    },\n    "TechnicalDetails": {\n      "Specifications": ["Parameters of power consumption"],\n      "UseCases": ["Application of battery saving methods"],\n      "CompatibilityNotes": ["Limitations with specific charging accessories"]\n    },\n    "VisualizationSupport": {\n      "DiagramMarkdown": "Optional power management schematic"\n    }\n  },\n  "Camera": {\n    "Questions": [\n      "How do I access Pro mode for manual camera settings?",\n      "How do I stabilize videos with the Super steady feature?",\n      "How can I lock the focus (AF) and exposure (AE) on a selected area?"\n    ],\n    "Answers": [\n      "Open the Camera app, tap MORE > PRO to access manual shooting options.",\n      "Open Camera and tap VIDEO, tap the super steady icon to turn it on for further video stabilisation.",\n      "Touch and hold the area to focus and exposure, the AF/AE frame will appear and lock the focus and exposure setting."\n    ],\n    "Metadata": {\n      "ExplanationDepth": "Technical deep-dive",\n      "CoverageAreas": ["Specifications", "Use Cases", "Compatibility"]\n    },\n    "TechnicalDetails": {\n      "Specifications": ["Sensor information"],\n      "UseCases": ["Different modes of photography"],\n      "CompatibilityNotes": ["Restrictions based on camera modes"]\n    },\n    "VisualizationSupport": {\n      "DiagramMarkdown": "Optional imaging pipeline overview"\n    }\n  },\n  "Galaxy AI": {\n    "Questions": [\n      "How can I use Live translate during phone calls?",\n      "How do I use Chat translation in messaging apps?",\n      "How can I translate text using the camera?"\n    ],\n    "Answers": [\n      "In the Phone app tap Settings → Live translate and select languages, tap Call assist during a call.",\n      "In message apps tap the keyboard\'s AI icon and then Chat translation, then select translation language.",\n  ...

# %% [markdown]
# ### Number 7 generate_setup_qa

# %%
#original
def generate_setup_qa(text):
    """Installation/configuration pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate setup-related Q&A with:
    - Pre-installation checks - Configuration options - Post-setup tests
    Include recommended settings for different user types.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_setup_qa_deepseek(text):
    """Generates installation guides with user-type presets in JSON format.

    Returns:
        JSON with prerequisites, timed steps, and configuration profiles.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create structured setup Q&A from Samsung docs with:
    1. Prerequisites (tools, OS versions, space requirements)
    2. Configuration profiles: Basic/Advanced/Custom
    3. Step durations and cumulative time estimates
    4. Post-setup verification tests

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Setup scenario]",
        "Answer": {{
          "UserType": "Basic/Advanced",
          "RequiredTools": ["GJ-SETUP45"],
          "SetupDuration": "20-25 mins",
          "ConfigurationSteps": [
            {{
              "Order": 1,
              "Action": "...",
              "Parameters": {{"Resolution": "4K", "FrameRate": 60}}
            }}
          ],
          "PostSetupVerification": ["Check firmware version", "Test HDMI handshake"]
        }},
        "DeviceModel": "QE75QN900C"
      }}
    - Validate model numbers as SM/QE-XXXXX format
    - Sort by setup complexity (Basic first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to configure The Frame TV for art mode?",
          "Answer": {{
            "UserType": "Advanced",
            "RequiredTools": ["One Connect Box"],
            "SetupDuration": "15 mins",
            "ConfigurationSteps": [
              {{
                "Order": 1,
                "Action": "Mount Art Store-certified USB",
                "Parameters": {{"Format": "FAT32", "Capacity": "≥64GB"}}
              }}
            ],
            "PostSetupVerification": ["Validate art metadata parsing"]
          }},
          "DeviceModel": "LS03B"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse setup configuration"}


#Google AI STudio
def generate_setup_qa_google(text):
    """Setup/installation/configuration pairs in JSON format with user-type settings."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate setup-related Question and Answer pairs from the following Samsung support document text, covering:
    - Pre-installation checks
    - Configuration options
    - Post-setup tests

    For configuration options, include recommended settings tailored for different user types (e.g., "Beginner", "Advanced", "Gamer", etc.) when applicable. If settings are generally applicable, indicate that.

    Use consumer-friendly language. Keep answers concise and step-by-step where relevant.

    Present the output as a list of setup Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Stage" ("Pre-installation Checks", "Configuration Options", "Post-Setup Tests"), "Question", "Answer", and "RecommendedSettings". "RecommendedSettings" should be a dictionary where keys are user types (e.g., "Beginner", "Advanced") and values are the recommended settings for that user type. If no user-type specific settings are relevant, "RecommendedSettings" should be null.

    Text: {text}

    Output Format (example):
    [
      {{ "Stage": "...", "Question": "...", "Answer": "...", "RecommendedSettings": {{ "Beginner": "...", "Advanced": "..." }} }},
      {{ "Stage": "...", "Question": "...", "Answer": "...", "RecommendedSettings": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        setup_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        setup_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"SetupQAPairs": setup_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_setup_qa_sonnet(text):
    """Generate structured setup configuration Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create setup Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Setup and configuration inquiry"
        ],
        "Answers": [
          "Comprehensive installation guidance"
        ],
        "Metadata": {{
          "SetupStages": ["Pre-installation", "Configuration", "Post-setup"],
          "UserTypeSettings": ["Recommended configurations"]
        }},
        "SetupDetails": {{
          "PreInstallationChecks": ["Essential preparatory steps"],
          "ConfigurationOptions": ["Detailed setup parameters"],
          "PostSetupTests": ["Verification procedures"]
        }}
      }}
    }}

    Requirements:
    - Detailed setup instructions
    - User-type specific guidance
    - Comprehensive verification steps
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_setup_qa ---")
test_qa_generators("generate_setup_qa", content)
# Out:
# --- generate_setup_qa ---
#
# --- Calling generate_setup_qa ---
# Okay, here's a comprehensive set of setup-related Q&A based on the provided user guide, covering pre-installation checks, configuration options, post-setup tests, and recommendations for different user types.
#
# **I. Pre-Installation Checks Q&A:**
#
# *   **Q: What should I do before using the device for the first time?**
#     *   A: Charge the battery fully. It's recommended to charge it before first use, especially if it's been unused for an extended period.
#
# *   **Q: Are there any potential problems when the sim tray is wet?**
#     *   A: Yes, if you insert the SIM tray while it is wet, it may cause damage to your device. Ensure that the tray is dry before inserting.
#
# *   **Q: What type of SIM card does this device use?**
#     *   A: It uses a nano-SIM card. Additionally, it may support eSIM functionality depending on the region, carrier, and model.
#
# *   **Q: Is there a way to prevent water damage?**
#     *   A: Yes, the devices are water and dust resistant, but you must follow the guidelines to maintain resistance.
#
# *   **Q: How can I check the device's FCC ID (if applicable)?**
#     *   A:  If your device is approved by the FCC, you can check out the FCC ID of the device. To access the FCC ID, open Settings and tap About phone → Status information. If your device does not have an FCC ID, it means that the device has not been authorised for sale in the U.S. or its territories and may only be brought to the U.S. for the owner’s personal use.
#
# *   **Q: What should I do before using the device for the first time to ensure it's safe to use with implanted medical devices?**
#     *   A: Your device contains magnets. Keep it away from credit cards, implanted medical devices, and other devices that may be affected by magnets. In the case of medical devices, keep your device more than 15 cm apart. Stop using your device if you suspect any interference with your medical device and consult your physician or your medical device manufacturer.
#
# **II. Configuration Options Q&A:**
#
# *   **Q: How do I turn on the device for the first time?**
#     *   A: Press and hold the Side button for a few seconds.
#
# *   **Q: How do I complete the initial setup?**
#     *   A: Follow the on-screen instructions after turning on the device. You'll be prompted to connect to a Wi-Fi network, sign in to a Samsung account, and configure basic settings.
#
# *   **Q: How do I transfer data from my old device?**
#     *   A: Use Smart Switch. Go to Settings > Accounts and backup > Transfer data for device setup. You can transfer data wirelessly or via USB cable.
#
# *   **Q: How do I set up a Samsung account?**
#     *   A: Go to Settings > Sign in to your Galaxy (or Accounts and backup > Manage accounts > Add account > Samsung account).  You can sign in if you already have an account or create a new one.
#
# *   **Q: How can I change the apps or features I want to launch when I double-press or long-press the Side button?**
#     *   A: You can change the settings for that by opening Settings, tap Advanced features → Side button, and then select an option you want.
#
# *   **Q: How do I download an eSIM?**
#     *   A: Open Settings and tap Connections → SIM manager → Add eSIM.  You may need a QR code from your carrier.
#
# *   **Q: How do I change the default keyboard?**
#     *A: Open Settings, tap General management → Keyboard list and default.
#
# *   **Q: How do I turn on/off the battery percentage on the status bar?**
#     *   A: To turn on or off the battery percentage on the status bar, open Settings > Battery > Show battery percentage.
#
# *   **Q: How can I set the device to turn off all wireless functions on my device?**
#     *   A: On the Settings screen, tap Connections → Flight mode: Set the device to turn off all wireless functions on your device. You can use only non-network services.
#
# **III. Post-Setup Tests & Verification Q&A:**
#
# *   **Q: How do I verify that Wi-Fi is working correctly?**
#     *   A: Go to Settings > Connections > Wi-Fi. Ensure Wi-Fi is turned on and connected to your network. Open a web browser and try loading a webpage.
#
# *   **Q: How do I test the screen touch responsiveness?**
#     *   A: Open the dialer app and type *#0*#. The options for different tests are available.
#
# *    **Q: How can I reset my device?**
#     *   A: To reset your device, perform a factory data reset. Open Settings and tap General management → Reset → Factory data reset → Reset → Delete all. Before performing the factory data reset, remember to make backup copies of all important data stored in the device.
#
# *   **Q: How do I confirm that my Samsung account is properly synced?**
#     *   A: Go to Settings > Accounts and backup > Manage accounts > Samsung account > Sync account.  Check that the sync settings are enabled for the data you want to sync (Contacts, Calendar, etc.).
#
# *   **Q: What are the main options for improving battery life?**
#     *   A: You can optimise the device using the device care feature, turn on power saving mode, close unnecessary apps, decrease screen brightness, decrease the backlight time, turn off Bluetooth and auto-sync when not in use.
#
# *   **Q: How can I force restart the device if it becomes unresponsive?**
#     *   A: If your device is frozen and unresponsive, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it.
#
# **IV. Recommended Settings for Different User Types:**
#
# *   **A. Users Concerned with Battery Life:**
#     *   *Settings: Battery > Power saving mode (On)*:  Enables basic power saving features.
#     *   *Settings: Display > Brightness > Adaptive brightness (On)*: Automatically adjusts screen brightness.
#     *   *Settings: Connections > Data usage > Data saver (On)*: Restricts background data usage.
#     *   *Settings: Device care > Auto optimisation (On)*: Set the device to perform auto optimisation by closing background apps or cleaning up memory, to keep the device running in its best condition.
#
# *   **B. Users Focused on Security & Privacy:**
#     *   *Settings: Lock screen and biometrics > Screen lock type (PIN/Password/Biometric)*:  Set a strong screen lock method.
#     *   *Settings: Security and privacy > Lost device protection (On)*: Enables Find My Mobile.
#     *   *Settings: Security and privacy > Secure Wi-Fi*: Secure Wi-Fi is a service that secures your Wi-Fi network connection. It encrypts data using Wi-Fi networks and disables tracking apps and websites so that you can use Wi-Fi networks safely.
#
# *   **C. Users with Visual Impairments:**
#     *   *Settings: Accessibility > Vision enhancements > TalkBack (On)*: Enables voice feedback.
#     *   *Settings: Accessibility > Vision enhancements > High contrast theme (On)*: Improves visibility.
#     *   *Settings: Accessibility > Vision enhancements > Font size and style > Font size (Adjust)*: Increases text size.
#     *   *Settings: Accessibility > Vision enhancements > Magnification > Magnification shortcut (On)*
#
# *   **D. Users with Hearing Impairments:**
#     *   *Settings: Accessibility > Hearing enhancements > Live Caption (On)*
#     *   *Settings: Accessibility > Hearing enhancements > Amplify ambient sound (On)*
#     *   *Settings: Accessibility > Hearing enhancements > Sound notifications (On)*: Set the device to detect sounds, such as the beeping of smoke detectors or crying babies.
#
# *   **E. Power User / Gamer:**
#     *   *Settings: Advanced features > Labs: Use new features of the device.
#     *   *Settings: Battery > Battery protection > Adaptive charging (On)*: This helps to prolong the battery's lifespan.
#     *   *Settings: Device care > Performance profile > High*: This maximizes device performance. Note that it may increase battery consumption.
#     *   *Settings: Display > Motion smoothness > Adaptive*: Get smoother animations and scrolling by automatically adjusting your screen refresh rate into a higher one.
#     *   *Gaming Hub > Game Booster*: Configure settings for each game, such as changing the performance mode.
#
#
# --- Calling generate_setup_qa_deepseek ---
# {'Generations': [{'Question': 'How do I charge the phone battery?', 'Answer': {'UserType': 'Basic', 'RequiredTools': ['USB cable', 'USB power adapter or wireless charger'], 'SetupDuration': '2-3 hours for wired, longer for wireless', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Connect USB cable to the USB power adapter.', 'Parameters': {}}, {'Order': 2, 'Action': 'Plug the cable into the device’s multipurpose jack (USB Type-C).', 'Parameters': {}}, {'Order': 3, 'Action': 'Or, place the center of the device’s back on the center of the wireless charger.', 'Parameters': {}}], 'PostSetupVerification': ['Check the battery percentage icon to see if charging', 'Disconnect charger when fully charged']}, 'DeviceModel': 'SM-S931B'}, {'Question': 'How do I configure initial device setup?', 'Answer': {'UserType': 'Basic', 'RequiredTools': [], 'SetupDuration': '10-15 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Turn on your device.', 'Parameters': {}}, {'Order': 2, 'Action': 'Follow the on-screen instructions to set up your device.', 'Parameters': {}}, {'Order': 3, 'Action': 'Connect to Wi-Fi network', 'Parameters': {}}], 'PostSetupVerification': ['Check Wi-Fi connectivity', 'Verify Samsung account setup']}, 'DeviceModel': 'SM-S936B'}, {'Question': 'How do I insert a Nano-SIM card?', 'Answer': {'UserType': 'Basic', 'RequiredTools': ['Ejection pin'], 'SetupDuration': '5 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Insert the ejection pin into the hole on the tray to loosen the tray.', 'Parameters': {}}, {'Order': 2, 'Action': 'Pull out the tray gently from the tray slot.', 'Parameters': {}}, {'Order': 3, 'Action': 'Place the SIM card on the tray with the gold-coloured contacts facing upwards and gently press the SIM card into the tray to secure it.', 'Parameters': {}}, {'Order': 4, 'Action': 'Insert the tray back into the tray slot.', 'Parameters': {}}], 'PostSetupVerification': ['Verify SIM card detection in Settings -> Connections -> SIM manager']}, 'DeviceModel': 'SM-S931B'}, {'Question': 'How to turn on and off the phone', 'Answer': {'UserType': 'Basic', 'RequiredTools': [], 'SetupDuration': '1 min', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Press and hold the Side button for a few seconds to turn on the device.', 'Parameters': {}}, {'Order': 2, 'Action': 'To turn off the device, press and hold the Side button and the Volume Down button simultaneously.', 'Parameters': {}}, {'Order': 3, 'Action': 'Tap Power off → Power off.', 'Parameters': {}}], 'PostSetupVerification': ['Verify device powers on and off successfully']}, 'DeviceModel': 'SM-S938B'}, {'Question': 'How do I connect to a Wi-Fi network?', 'Answer': {'UserType': 'Basic', 'RequiredTools': [], 'SetupDuration': '5 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Open Settings, tap Connections → Wi-Fi.', 'Parameters': {}}, {'Order': 2, 'Action': 'Tap the switch to turn Wi-Fi on.', 'Parameters': {}}, {'Order': 3, 'Action': 'Select a network from the Wi-Fi networks list.', 'Parameters': {}}, {'Order': 4, 'Action': 'Enter the password if required.', 'Parameters': {}}], 'PostSetupVerification': ['Verify internet connectivity by browsing a webpage']}, 'DeviceModel': 'SM-S936B'}, {'Question': 'How to force device restart', 'Answer': {'UserType': 'Advanced', 'RequiredTools': [], 'SetupDuration': '1 min', 'ConfigurationSteps': [{'Order': 1, 'Action': 'If your device is frozen and unresponsive, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to restart it.', 'Parameters': {}}], 'PostSetupVerification': ['Verify device restarts successfully']}, 'DeviceModel': 'SM-S931B'}, {'Question': 'How do I set up Wireless Power Sharing?', 'Answer': {'UserType': 'Advanced', 'RequiredTools': [], 'SetupDuration': '2 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Open Settings, tap Battery → Wireless power sharing.', 'Parameters': {}}, {'Order': 2, 'Action': 'Tap the switch to turn it on.', 'Parameters': {}}, {'Order': 3, ...
#
# --- Calling generate_setup_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "SetupQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_setup_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I set up my new device for the first time?",\n      "How can I transfer data from my old device to this one?",\n      "What is the purpose of a Samsung account, and how do I create one?",\n      "How can I quickly charge my device?",\n      "What are the precautions for wireless charging?",\n      "How can I share my phone\'s battery with another device?",\n      "What is an eSIM, and how do I download it?",\n      "My device is frozen; how do I restart it?",\n      "How do I take a screenshot?",\n      "How do I reduce battery consumption?",\n      "How do I unlock my phone?"\n    ],\n    "Answers": [\n      "When you turn on the device for the first time, follow the on-screen instructions to set up your device, including connecting to Wi-Fi and configuring basic settings.",\n      "You can transfer data wirelessly or with a USB cable using Smart Switch; access it in Settings under Accounts and backup.",\n      "A Samsung account lets you use Samsung services across devices; create one in Settings by tapping \'Sign in to your Galaxy\' or by visiting account.samsung.com.",\n      "Use a super fast charger or fast charger or components that support the feature, and make sure fast charging is enabled in the battery settings; you can check the connection status in Settings -> Battery.",\n      "Avoid placing credit cards, metal objects, or magnets between the device and the wireless charger, and use only Samsung-approved chargers to prevent damage and ensure proper charging.",\n      "Enable Wireless Power Sharing in Settings under Battery and place the other device back-to-back with your phone to initiate charging; remove accessories for optimal connection.",\n      "An eSIM is an embedded digital SIM; you can download it in Settings under Connections -> SIM manager -> Add eSIM if supported by your carrier and region.",\n      "If your device is frozen, press and hold the Side button and the Volume Down button simultaneously for more than 7 seconds to force a restart.",\n      "Press the Side button and the Volume Down button simultaneously to capture a screenshot; you can find the captured screenshots in Gallery.",\n      "To reduce battery consumption, optimize your device using the device care feature, turn off the screen when not in use, and disable unused features like Bluetooth and auto-sync.",\n      "To unlock the screen, swipe in any direction when the screen turns on; if you have set a screen lock method, you will need to use the pattern, PIN, password or biometric data to unlock it."\n    ],\n    "Metadata": {\n      "SetupStages": [\n        "Pre-installation",\n        "Configuration",\n        "Post-setup"\n      ],\n      "UserTypeSettings": [\n        "Recommended configurations"\n      ]\n    },\n    "SetupDetails": {\n      "PreInstallationChecks": [\n        "Ensure device is charged",\n        "Locate SIM/USIM or eSIM info"\n      ],\n      "ConfigurationOptions": [\n        "Samsung account setup",\n        "Wi-Fi connection",\n        "Screen lock setup"\n      ],\n      "PostSetupTests": [\n        "Data transfer verification",\n        "Connectivity tests"\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 8 generate_error_code_qa

# %%
#original
def generate_error_code_qa(text):
    """Error code explanations"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code Q&A with:
    - Code interpretations - Immediate actions - Service triggers
    Format codes in bold with severity colors (🔴🟠🟢).
    Text: {text}
    """)
    return model.generate_content(prompt).text

#Deepseek
import json
from textwrap import dedent

def generate_error_code_qa_deepseek(text):
    """Generates machine-actionable error code guides with severity tiers.

    Returns:
        JSON with standardized codes, automated responses, and service flags.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code explanations from Samsung docs with:
    1. Code validation using ERR-XXXX format (X=digit)
    2. Severity: Critical(🔴)/High(🟠)/Medium(🟢) mapped to 0-2
    3. Automated system response actions
    4. Service center escalation thresholds

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "ErrorCode": "ERR-0451",
        "Description": "Battery temperature critical",
        "Severity": {{
          "Level": 0,
          "Label": "Critical",
          "HexColor": "#FF0000"
        }},
        "ImmediateResponse": ["Disconnect charger", "Power down"],
        "ServiceRequired": {{
          "Threshold": "Immediate",
          "Code": "SVC-BATT-EMERG"
        }},
        "UserMessage": "Visit Samsung Service within 24hrs"
      }}
    - Validate ErrorCode format: ERR- followed by 4 digits
    - Map colors to standard hex values

    Example:
    {{
      "Generations": [
        {{
          "ErrorCode": "ERR-1123",
          "Description": "Display panel communication failure",
          "Severity": {{
            "Level": 1,
            "Label": "High",
            "HexColor": "#FFA500"
          }},
          "ImmediateResponse": ["Restart device", "Check flex cable"],
          "ServiceRequired": {{
            "Threshold": "If persists after reboot",
            "Code": "SVC-DISP-1123"
          }},
          "UserMessage": "Backup data before service visit"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse error code protocol"}



#Google AI STudio
def generate_error_code_qa_google(text):
    """Error code explanations in JSON format with severity levels and color codes."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs explaining Samsung error codes from the following support document text.

    For each error code, include:
    - Code interpretation (what the error means)
    - Immediate actions users can take
    - Service triggers (when to seek professional help)

    Format error codes clearly and indicate their severity level as "Critical", "Warning", or "Informational".  In the JSON output, include a "Severity" field with these levels and optionally a "SeverityColor" field with the corresponding color emoji (🔴 for Critical, 🟠 for Warning, 🟢 for Informational).  In plain text examples within the output, you can format the error codes in bold with the color emojis.

    Use consumer-friendly language. Keep answers concise and action-oriented.

    Present the output as a list of error code Q&A pairs in JSON format. Each pair should be a dictionary with keys: "ErrorCode", "Severity" ("Critical", "Warning", "Informational"), "Interpretation", "ImmediateActions" (list of actions), "ServiceTriggers", and optionally "SeverityColor" (color emoji string).

    Text: {text}

    Output Format (example):
    [
      {{ "ErrorCode": "...", "Severity": "Critical", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🔴" }},
      {{ "ErrorCode": "...", "Severity": "Warning", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🟠" }},
      {{ "ErrorCode": "...", "Severity": "Informational", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🟢" }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        error_code_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        error_code_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"ErrorCodeQAPairs": error_code_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_error_code_qa_sonnet(text):
    """Generate structured error code Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific error code query"
        ],
        "Answers": [
          "Comprehensive error interpretation and resolution"
        ],
        "Metadata": {{
          "ErrorSeverity": ["Critical", "Warning", "Informational"],
          "ResolutionApproach": "Systematic troubleshooting"
        }},
        "ErrorCodeDetails": {{
          "CodeInterpretation": ["Detailed error meaning"],
          "ImmediateActions": ["Recommended quick fixes"],
          "ServiceTriggers": ["Escalation scenarios"]
        }},
        "VisualIndicators": {{
          "SeverityColors": ["🔴 Critical", "🟠 Warning", "🟢 Low Impact"]
        }}
      }}
    }}

    Requirements:
    - Clear error code explanations
    - Actionable resolution steps
    - Severity classification
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_error_code_qa ---")
test_qa_generators("generate_error_code_qa", content)
# Out:
# --- generate_error_code_qa ---
#
# --- Calling generate_error_code_qa ---
# Okay, here is a Q&A style error code guide based on the provided text. I will create three error code examples with interpretations, actions, and service triggers.
#
# # ERROR CODE Q&A
#
# ### 🔴 **ERROR 001: Device Overheating**
#
# *   **Code Interpretation:** The device has exceeded a safe operating temperature threshold. This can be triggered by prolonged use of resource-intensive apps, charging in hot environments, or hardware malfunction.
# *   **Immediate Actions:**
#     1.  Stop using the device immediately.
#     2.  Disconnect the charger if connected.
#     3.  Close all running apps.
#     4.  Move the device to a cooler environment.
#     5.  Allow the device to cool down completely before resuming use.
# *   **Service Triggers:**
#     *   If the overheating persists even with minimal use and in a cool environment.
#     *   If the device displays warning messages about overheating despite not being used heavily.
#     *   If the device shuts down unexpectedly due to overheating.
#     *   If physical damage to the device is suspected to be the cause of the overheating.
#
# ### 🟠 **ERROR 002: Fingerprint Sensor Failure**
#
# *   **Code Interpretation:** The fingerprint sensor is unable to read or verify fingerprints. This can be due to dirty sensor, wet fingers, or an issue with the sensor itself.
# *   **Immediate Actions:**
#     1.  Clean the fingerprint sensor with a soft, dry cloth.
#     2.  Ensure your fingers are clean and dry.
#     3.  Restart the device.
#     4.  Try registering your fingerprint again.
#     5.  If using screen protector, remove it, or ensure it is compatible with the fingerprint sensor.
# *   **Service Triggers:**
#     *   If the fingerprint sensor continues to fail even after cleaning and restarting.
#     *   If the fingerprint sensor area is visibly damaged.
#     *   If the device gives error messages indicating hardware failure of the fingerprint sensor.
#     *   If the device was recently repaired and the fingerprint sensor stopped working after the repair.
#
# ### 🟢 **ERROR 003: Low Battery - Power Saving Activated**
#
# *   **Code Interpretation:** The device's battery has reached a critically low level, and power-saving features have been automatically activated to extend the remaining battery life.
# *   **Immediate Actions:**
#     1.  Connect the device to a charger immediately.
#     2.  Close any unnecessary apps running in the background.
#     3.  Reduce screen brightness.
#     4.  Disable Bluetooth and Wi-Fi if not in use.
# *   **Service Triggers:**
#     *   If the device shuts down quickly even after extended charging.
#     *   If the battery health indicator in Device Care reports significantly reduced capacity.
#     *   If the device fails to recognize the charger.
#     *   If the device does not hold a charge for a reasonable amount of time even in power-saving mode.
#
# I hope these error codes and solutions help!
#
#
# --- Calling generate_error_code_qa_deepseek ---
# {'Generations': [{'ErrorCode': 'ERR-0001', 'Description': 'Device overheating', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Close running apps', 'Disconnect charger', 'Allow device to cool'], 'ServiceRequired': {'Threshold': 'If overheating persists or frequent', 'Code': 'SVC-TEMP-0001'}, 'UserMessage': 'Device overheating. Avoid prolonged use under direct sunlight and visit a Samsung Service Center if persists.'}, {'ErrorCode': 'ERR-0002', 'Description': 'Charging stopped due to high battery temperature', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Disconnect charger', 'Allow device to cool before reconnecting'], 'ServiceRequired': {'Threshold': 'If charging issues persist', 'Code': 'SVC-CHRG-0002'}, 'UserMessage': 'Charging paused due to high battery temperature. Disconnect the charger and allow the device to cool down. Visit a Samsung Service Center if persists.'}, {'ErrorCode': 'ERR-0003', 'Description': 'Water detected in multipurpose jack', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Disconnect charger', 'Allow jack to dry completely before connecting'], 'ServiceRequired': {'Threshold': 'If issues with charging or accessory connection persists after drying', 'Code': 'SVC-PORT-0003'}, 'UserMessage': 'Water detected in multipurpose jack. Dry completely before charging or connecting accessories. Service required if not resolved.'}, {'ErrorCode': 'ERR-0004', 'Description': 'SIM card tray not fully inserted', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ['Power down device', 'Re-insert SIM card tray correctly'], 'ServiceRequired': {'Threshold': 'If SIM card is not recognized after proper insertion', 'Code': 'SVC-SIM-0004'}, 'UserMessage': 'SIM card tray not fully inserted. Power off device and re-insert tray.'}, {'ErrorCode': 'ERR-0005', 'Description': 'Camera image sensor damaged', 'Severity': {'Level': 0, 'Label': 'Critical', 'HexColor': '#FF0000'}, 'ImmediateResponse': ['Restart the device', 'Stop using camera immediately'], 'ServiceRequired': {'Threshold': 'Immediate', 'Code': 'SVC-CAM-EMERG'}, 'UserMessage': 'Camera image sensor damaged, causing dots or spots in pictures. Stop using camera and visit Samsung Service immediately.'}, {'ErrorCode': 'ERR-0006', 'Description': 'Air vent hole is covered by accessory, unwanted noises may occur during calls or media playback.', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ["Remove the air vent hole's cover."], 'ServiceRequired': {'Threshold': 'if issue not resolved', 'Code': 'SVC-AIR-0006'}, 'UserMessage': "Remove the air vent hole's cover."}]}
#
# --- Calling generate_error_code_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ErrorCodeQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_error_code_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "ErrorCodes": {\n    "Generations": {\n      "Questions": [\n        "What does a persistent proximity sensor activation during calls indicate?",\n        "What should I do if my device unexpectedly overheats during normal use?",\n        "What does it mean if fast charging isn\'t working on my Samsung phone?",\n        "Why is my wireless charging slow, or not working at all?",\n        "What can cause a device to enter a locked state which I cannot enter my pin, pattern, or password?"\n      ],\n      "Answers": [\n        "Persistent proximity sensor activation can be caused by obstructions on the sensor and potential malfunctions. It may be addressed by ensuring the sensor area remains free from obstructions.",\n        "Unexpected overheating requires immediate action, including stopping all running applications and removing external power sources. If the issue continues, contact Samsung support.",\n        "Fast charging issues may occur because of disabled fast charging, or incompatible cables and adapters. Check settings and validate compatibility of the connected adapter.",\n        "Wireless charging issues can stem from incorrect device placement, incompatible chargers, and protective cases. Make sure the device is centered and the charger and case are fully compatible.",\n        "Device in a locked state could mean factory data reset must be done. Back up all data for safe keeping and to avoid data loss."\n      ],\n      "Metadata": {\n        "ErrorSeverity": [\n          "Warning",\n          "Critical",\n          "Warning",\n          "Warning",\n          "Critical"\n        ],\n        "ResolutionApproach": "Systematic troubleshooting"\n      },\n      "ErrorCodeDetails": {\n        "CodeInterpretation": [\n          "Proximity sensor malfunction or obstruction",\n          "System instability, power circuit issues",\n          "Incorrect charging settings, cable issue",\n          "Misalignment or incompatibility",\n          "System reset required, data integrity concerns"\n        ],\n        "ImmediateActions": [\n          "Check sensor area, reboot",\n          "Remove power, close apps",\n          "Check fast charging settings",\n          "Adjust device position, remove case",\n          "Back up data if possible, reset required"\n        ],\n        "ServiceTriggers": [\n          "Sensor replacement needed",\n          "Escalate if hardware failure",\n          "Cable/adapter diagnostics",\n          "Charger component diagnostics",\n          "Data loss, hardware failure escalation"\n        ]\n      },\n      "VisualIndicators": {\n        "SeverityColors": ["🟠 Warning", "🔴 Critical", "🟠 Warning", "🟠 Warning", "🔴 Critical"]\n      }\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 9 generate_safety_qa

# %%
#original
def generate_safety_qa(text):
    """Safety/compliance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate safety Q&A covering:
    - Hazard prevention - Compliance standards - Recall information
    Use warning boxes for critical items.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_safety_qa_deepseek(text):
    """Generates safety alerts with compliance metadata in JSON format.

    Returns:
        JSON with hazard classification, recall batches, and compliance codes.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create safety/compliance Q&A pairs with:
    1. Hazard types: Electrical/Mechanical/Chemical
    2. Compliance standards (ISO/IEC + regional)
    3. Recall data: Batch numbers, date ranges
    4. Severity levels: Critical/High/Medium

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Safety concern]",
        "Answer": {{
          "Description": "...",
          "ComplianceStandards": ["IEC 62368-1"],
          "SeverityLevel": "Critical",
          "RecallInfo": {{
            "AffectedBatches": ["BT2024Q1-45"],
            "DateRange": "2024-03/2024-05"
          }},
          "HazardType": "Electrical"
        }},
        "EmergencyProtocol": ["Unplug immediately", "Evacuate area"]
      }}
    - Validate batch numbers as BTYYYYQX-XX format
    - Sort by SeverityLevel descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "What if my washing machine emits burning smell?",
          "Answer": {{
            "Description": "Potential motor insulation failure...",
            "ComplianceStandards": ["UL 2157"],
            "SeverityLevel": "Critical",
            "RecallInfo": {{
              "AffectedBatches": ["BT2023Q4-12"],
              "DateRange": "2023-11/2024-02"
            }},
            "HazardType": "Electrical"
          }},
          "EmergencyProtocol": ["Cut power", "Contact Samsung Safety Team"]
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse safety protocol"}


#Google AI STudio
def generate_safety_qa_google(text):
    """Safety/compliance pairs in JSON format with 'critical warning' indicator."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate safety Question and Answer pairs from the following Samsung support document text, covering:
    - Hazard prevention measures
    - Relevant compliance standards and certifications
    - Recall information and how to check for recalls

    For critical safety warnings and hazards, explicitly mark them as such. In the JSON output, use a boolean field "IsCriticalWarning": true/false to indicate if a Q&A pair represents a critical warning. In plain text examples within the output, you can use "WARNING BOX" markers or similar visual cues if helpful.

    Use clear, concise, and direct language appropriate for safety information. Consumer-friendly language is essential.

    Present the output as a list of safety Q&A pairs in JSON format. Each pair should be a dictionary with keys: "IsCriticalWarning" (boolean), "Question", "Answer", and optionally "HazardPrevention" (list of measures), "ComplianceStandards" (list of standards), and "RecallInformation" (string or null).

    Text: {text}

    Output Format (example):
    [
      {{ "IsCriticalWarning": true, "Question": "...", "Answer": "...", "HazardPrevention": [...], "ComplianceStandards": [...], "RecallInformation": "..." }},
      {{ "IsCriticalWarning": false, "Question": "...", "Answer": "...", "HazardPrevention": [...], "ComplianceStandards": [...], "RecallInformation": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        safety_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        safety_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"SafetyQAPairs": safety_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_safety_qa_sonnet(text):
    """Generate structured safety and compliance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create safety Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Safety and compliance inquiry"
        ],
        "Answers": [
          "Comprehensive safety guidance"
        ],
        "Metadata": {{
          "SafetyAreas": ["Hazard Prevention", "Compliance", "Recalls"],
          "RiskClassification": "Critical safety information"
        }},
        "SafetyDetails": {{
          "HazardPrevention": ["Critical safety measures"],
          "ComplianceStandards": ["Regulatory requirements"],
          "RecallInformation": ["Potential product safety issues"]
        }},
        "WarningIndicators": {{
          "CriticalWarnings": ["High-risk safety alerts"]
        }}
      }}
    }}

    Requirements:
    - Detailed safety explanations
    - Compliance standard insights
    - Recall information
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_safety_qa ---")
test_qa_generators("generate_safety_qa", content)
# Out:
# --- generate_safety_qa ---
#
# --- Calling generate_safety_qa ---
# I've created a Safety Q&A document based on the text provided. I've used warning boxes for critical items, as requested.
#
# # USER GUIDE
#
# ###### SM-S931B SM-S931B/DS SM-S936B SM-S936B/DS SM-S938B SM-S938B/DS
#
# English 01/2025 Rev1 0 www samsung com
#
# ## Safety Q&A
#
# **Hazard Prevention**
#
# **Q: Is it safe to use the speakers close to my ears?**
# A: When using the speakers, such as when playing media files or using speakerphone, do not place the device close to your ears.
#
# **Q: What should I do if the glass or acrylic body of the device is broken?**
# A: If you use the device with its glass or acrylic body broken, there may be a risk of injury. Use the device only after it has been repaired at a Samsung Service Centre or an authorised service centre.
#
# **Q: What should I do if dust or foreign materials enter the microphone, speaker, or receiver?**
# A: If dust or foreign materials enter the microphone, speaker, or receiver, or if these parts are covered, the device’s sound may become quiet or certain features may not work. If you attempt to remove the dust or foreign materials with a sharp object, the device may be damaged and its appearance may be affected.
#
# **Q: Can metallic stickers or covers affect connectivity or battery life?**
# A: Yes, connectivity problems and battery drain may occur if you attach metallic stickers on the antenna area, use a metallic device cover, or cover the antenna area with your hands while using certain features.
#
# **Q: Is it safe to use a third party charger?**
# A: No. Use only Samsung-approved battery, charger, and cable specifically designed for your device. Incompatible battery, charger, and cable can cause serious injuries or damage to your device.
#
# **Q: Is it safe to charge the device when wet?**
#
# ```
# -----------------------------------------------
# | WARNING: Charging a wet device can be dangerous! |
# | Thoroughly dry the multipurpose jack before  |
# | charging to prevent device damage.           |
# -----------------------------------------------
# ```
#
# A: If you charge the device while the multipurpose jack is wet, the device may be damaged. Thoroughly dry the multipurpose jack before charging the device.
#
# **Q: Are there any precautions for wireless charging?**
#
# ```
# --------------------------------------------------------------------
# | WARNING: Failure to follow wireless charging precautions could  |
# | result in device malfunction, overheating, or damage to cards!   |
# | Do not place credit cards, RFID cards, metal objects, or magnets |
# | between the device and the wireless charger.                      |
# --------------------------------------------------------------------
# ```
#
# A: Yes. Refer to "Precautions for wireless charging" section on page 17.
#
# **Compliance Standards**
#
# **Q: Where can I find the FCC ID of my device (if applicable)?**
# A: If your device is approved by the FCC, you can check out the FCC ID of the device. To access the FCC ID, open Settings and tap About phone → Status information.
#
# **Q: Where can I find Regulatory Information?**
# A: Depending on the region, you can check out the regulatory information on the device. To access the information, open Settings and tap About phone → Regulatory information.
#
# **Q: Can I use this device in an airplane?**
# A: Follow all posted warnings and directions from authorised personnel in areas where the use of wireless devices is restricted, such as aeroplanes and hospitals. Set the device to turn off all wireless functions on your device. You can use only non-network services.
#
# **Recall Information**
#
# **Q: Where would I find information about device recalls?**
# A: Check the Samsung website (www.samsung.com) for official recall announcements and instructions. Contact Samsung customer support for further assistance.
#
# **Q: What should I do if I suspect my device is part of a recall?**
# A: Immediately stop using the device and contact Samsung customer support for guidance on how to proceed.
#
# **Q: Where should I contact customer support?**
# A: Samsung Members offers support services to customers, such as device problem diagnosis, and lets users submit questions and error reports. You can also share information with others in the Galaxy users’ community or check the latest news and tips.
#
# **Other Important Safety Notes**
#
# ```
# -------------------------------------------------------------
# | WARNING: Magnets can interfere with medical devices!      |
# | Keep the device more than 15 cm away from implanted        |
# | medical devices. Consult your physician if you suspect any |
# | interference.                                             |
# -------------------------------------------------------------
# ```
#
# A: Your device contains magnets. Keep it away from credit cards, implanted medical devices, and other devices that may be affected by magnets. In the case of medical devices, keep your device more than 15 cm apart. Stop using your device if you suspect any interference with your medical device and consult your physician or your medical device manufacturer.
#
# **Q: What should I know about water and dust resistance?**
# A: Your device is water- and dust-resistant. But this is not permanent and may diminish over time because of normal wear and tear.
#
# ```
# ----------------------------------------------------------------
# | CAUTION: Do not expose the device to swimming pool water or  |
# | sea water. If exposed to unclean water or other liquids, clean|
# | the device with fresh water and dry it thoroughly.           |
# ----------------------------------------------------------------
# ```
#
# ```
# --------------------------------------------------------------------
# | WARNING: Do not attempt to remove the battery yourself!          |
# | Contact an authorised service centre for battery removal to      |
# | avoid damage, personal injury, or unsafe conditions.            |
# --------------------------------------------------------------------
# ```
#
#
#
# --- Calling generate_safety_qa_deepseek ---
# {'Generations': [{'Question': 'What if my phone emits burning smell while fast charging?', 'Answer': {'Description': 'Potential battery failure or internal component overheating.  This could lead to a fire or explosion.', 'ComplianceStandards': ['IEC 60950-1', 'IEC 62133'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': ['BT2025Q1-01', 'BT2025Q1-02', 'BT2025Q1-03'], 'DateRange': '2025-01/2025-03'}, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Unplug immediately', 'Evacuate area', 'Call emergency services']}, {'Question': 'What if the device overheats during wireless power sharing and the battery is swelling?', 'Answer': {'Description': 'Significant risk of battery rupture and potential fire hazard.', 'ComplianceStandards': ['IEC 62368-1', 'EN 60950-1'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': ['BT2025Q1-10', 'BT2025Q1-11'], 'DateRange': '2025-01/2025-02'}, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Stop wireless power sharing immediately', 'Place device on a non-flammable surface', 'Contact Samsung support for battery disposal']}, {'Question': 'What if I use a damaged USB-C cable with exposed wiring to charge my phone?', 'Answer': {'Description': 'Risk of electric shock and fire due to short circuiting.', 'ComplianceStandards': ['IEC 62368-1', 'UL 60950-1'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': [], 'DateRange': ''}, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Do not touch the cable or device', 'Disconnect power at the source (circuit breaker)', 'Ensure the area is safe before approaching']}, {'Question': "What if the device's glass body is broken and exposes internal components while charging?", 'Answer': {'Description': 'Potential for electric shock from exposed circuits and cuts from broken glass. This is exacerbated while charging due to increased electrical activity and heat generation.', 'ComplianceStandards': ['IEC 60950-1', 'IEC 62368-1'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': [], 'DateRange': ''}, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Do not touch the device while plugged in.', 'Disconnect the charger with insulated gloves if possible.', 'Contact Samsung service center for immediate repair.']}, {'Question': "What should I do if my device is overheating and the battery is bulging, but I can't unplug it?", 'Answer': {'Description': 'This represents a critical risk of battery explosion and fire. The inability to disconnect the power source increases the danger substantially.', 'ComplianceStandards': ['IEC 62133', 'UL 2054'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': ['BT2025Q1-15', 'BT2025Q1-16', 'BT2025Q2-01'], 'DateRange': '2025-02/2025-04'}, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Call emergency services (fire department) immediately.', 'Clear the area and warn others of the potential explosion.', 'If safe, attempt to smother the device with sand or a fire-retardant blanket, but do not approach closely.']}, {'Question': 'What if I spill corrosive cleaning chemicals on the device while it is charging?', 'Answer': {'Description': 'Risk of chemical burns, fire, and device malfunction due to chemical reaction with internal components.', 'ComplianceStandards': ['REACH', 'RoHS'], 'SeverityLevel': 'Critical', 'RecallInfo': {'AffectedBatches': [], 'DateRange': ''}, 'HazardType': 'Chemical'}, 'EmergencyProtocol': ['Disconnect power immediately if safe to do so.', 'Wear appropriate protective gear (gloves, eye protection).', 'Rinse affected area with copious amounts of water.  Avoid direct skin contact with device.', 'Seek medical attention if chemical exposure occurs.', 'Contact Samsung support for device disposal.']}, {'Question': 'What happens if I try to remove the battery myself and puncture it with a metal tool?', 'Answer': {'Description': 'High risk of fire, explosion, and exposure to hazardous chemicals from the battery.', 'ComplianceStandards': ['IEC 62133', 'UN ...
#
# --- Calling generate_safety_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "SafetyQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_safety_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "SafetyQ&A": {\n    "GeneralSafety": {\n      "Questions": [\n        "Is it safe to use a broken device?",\n        "Can dust or foreign objects affect device performance?",\n        "Are there risks in covering the proximity/light sensor?",\n        "Is it safe to place the device close to ears when using speakers?",\n        "What should be done if dust or foreign materials enter the microphone?",\n        "Are metallic stickers safe to use on the antenna area of the device?",\n        "What are the dangers of exposing the camera lens to strong light?",\n        "What are the risks of covering the air vent hole with an accessory?"\n      ],\n      "Answers": [\n        "Using a device with broken glass or acrylic body poses a risk of injury and should only be used after repair at a Samsung Service Centre or an authorized service centre.",\n        "Yes, dust or foreign materials entering or covering the microphone, speaker, or receiver can quiet the device’s sound or disable features.",\n        "Covering the proximity/light sensor can cause the sensor to malfunction, leading to operational issues.",\n        "No, do not place the device close to your ears when using speakers, such as when playing media files or using speakerphone.",\n        "If dust or foreign materials enter the microphone, speaker, or receiver, or if these parts are covered, the device’s sound may become quiet or certain features may not work.",\n        "Do not attach metallic stickers on the antenna area of the device, because connectivity problems and battery drain may occur.",\n        "Exposing the camera lens to a strong light source, such as direct sunlight, may damage the camera image sensor, leading to dots or spots in pictures.",\n        "If the air vent hole is covered by an accessory, such as a protective film or sticker, unwanted noises may occur during calls or media playback."\n      ],\n      "Metadata": {\n        "SafetyAreas": [\n          "Device Integrity",\n          "Sensor Usage",\n          "Audio Warnings",\n          "Exposure Safety",\n          "Physical Hazards"\n        ],\n        "RiskClassification": "Safety precautions for device handling and functionality"\n      },\n      "SafetyDetails": {\n        "DeviceIntegrity": [\n          "Broken device usage",\n          "Speaker operation precaution"\n        ],\n        "SensorUsage": [\n          "Proximity/Light sensor",\n          "Antenna Usage",\n          "Camera Exposure"\n        ],\n        "AudioWarnings": [\n          "Air Vent Noise",\n          "Microphone Use"\n        ],\n        "ExposureSafety": [\n          "Camera exposure to light"\n        ],\n        "PhysicalHazards":["Glass and Acrylic Body"]\n      },\n      "WarningIndicators": {\n        "CriticalWarnings": [\n          "Risk of injury from broken device",\n          "Potential sensor malfunction"\n        ]\n      }\n    },\n    "BatteryCharging": {\n      "Questions": [\n        "What are the precautions for wireless charging?",\n        "What should be used as the charging and cable?",\n        "What should be done with the charger when not in use?",\n        "Is it safe to charge the device with a wet multipurpose jack?",\n        "How to prevent device damage with a wet multipurpose jack?"\n      ],\n      "Answers": [\n        "Precautions include not placing cards or conductive materials between the device and wireless charger, and using Samsung-approved chargers to avoid overheating or damage.",\n        "Use only Samsung-approved battery, charger, and cable specifically designed for your device, because incompatible battery, charger, and cable can cause serious injuries or damage to your device.",\n        "Unplug the charger when not in use to save energy, as it does not have a power switch and continues to draw power when plugged in.",\n        "No, if you charge the device while the multipurpose jack is w ...

# %% [markdown]
# ### Number 10 generate_compatibility_qa

# %%
#original
def generate_compatibility_qa(text):
    """Device compatibility pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A with:
    - Supported models - Version requirements - Regional variations
    Present compatibility as tables when possible.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_compatibility_qa_deepseek(text):
    """Generates device compatibility matrices with regional versioning in JSON.

    Returns:
        JSON with nested compatibility tables using model codes and ISO regions.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A pairs with:
    1. Model numbers in SM/QE-XXXX format
    2. Minimum firmware versions (major.minor.build)
    3. Regional availability using ISO 3166 codes
    4. Feature-specific compatibility flags

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Compatibility inquiry]",
        "Answer": {{
          "CompatibilityMatrix": {{
            "DeviceModel": "SM-S901B",
            "MinimumVersion": "5.1.23",
            "Regions": {{
              "NA": ["QC3.0", "6GHz WiFi"],
              "EU": ["QC3.0", "5G Sub6"]
            }}
          }},
          "Notes": "5G mmWave excluded in EU models"
        }},
        "Category": "Smartphone/Accessory/TV"
      }}
    - Validate model numbers as Samsung's official format
    - Use semantic versioning for firmware

    Example:
    {{
      "Generations": [
        {{
          "Question": "Which Galaxy phones support DeX with 4K monitors?",
          "Answer": {{
            "CompatibilityMatrix": {{
              "DeviceModel": "SM-S928B",
              "MinimumVersion": "6.0.1",
              "Regions": {{
                "Global": ["4K@60Hz via HDMI"],
                "CN": ["4K@30Hz"]
              }}
            }},
            "Notes": "Requires HDMI 2.1 certified cable"
          }},
          "Category": "Smartphone"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse compatibility matrix"}


#Google AI STudio
def generate_compatibility_qa_google(text):
    """Device compatibility pairs in JSON format, including compatibility tables."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung device compatibility from the following support document text, covering:
    - Supported Samsung models
    - Version requirements (software, OS)
    - Regional variations in compatibility

    Present compatibility information as tables within the answers whenever possible to clearly show model or version compatibility. In the JSON output, represent tables as a list of dictionaries, where each dictionary is a row.

    Use consumer-friendly language. Keep answers concise and present compatibility information in an easy-to-understand format.

    Present the output as a list of compatibility Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "CompatibilityTable" (list of row dictionaries - see example format), "VersionRequirements" (string or null), and "RegionalVariations" (string or null). If no table is applicable, "CompatibilityTable" should be null.

    Text: {text}

    Output Format (example, tables as list of dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "CompatibilityTable": [
          {{ "Column 1 Header": "Value 1", "Column 2 Header": "Value 2" }},
          {{ "Column 1 Header": "Value 3", "Column 2 Header": "Value 4" }},
          ...
        ],
        "VersionRequirements": "...",
        "RegionalVariations": "..."
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "CompatibilityTable": null,
        "VersionRequirements": "...",
        "RegionalVariations": "..."
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        compatibility_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        compatibility_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"CompatibilityQAPairs": compatibility_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_compatibility_qa_sonnet(text):
    """Generate structured device compatibility Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Device compatibility inquiry"
        ],
        "Answers": [
          "Comprehensive compatibility explanation"
        ],
        "Metadata": {{
          "CompatibilityTypes": ["Model Support", "Version Requirements", "Regional Variations"]
        }},
        "CompatibilityDetails": {{
          "SupportedModels": ["Detailed model list"],
          "VersionRequirements": ["Minimum/optimal version specifications"],
          "RegionalVariations": ["Geographic compatibility notes"]
        }},
        "CompatibilityTable": {{
          "Format": "Tabular representation of compatibility data"
        }}
      }}
    }}

    Requirements:
    - Comprehensive compatibility information
    - Model and version specifics
    - Regional considerations
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_compatibility_qa ---")
test_qa_generators("generate_compatibility_qa", content)
# Out:
# --- generate_compatibility_qa ---
#
# --- Calling generate_compatibility_qa ---
# Okay, here's a Q&A based on the provided user guide text, formatted to highlight compatibility aspects.  I've included tables where applicable, focusing on:
#
# *   **Supported Models:** SM-S931B, SM-S931B/DS, SM-S936B, SM-S936B/DS, SM-S938B, SM-S938B/DS.
# *   **Version Requirements:**  The text mentions English 01/2025 Rev1 0, which indicates software/documentation version. Compatibility with older software versions is not addressed.
# *   **Regional Variations:** The document mentions that some features are region-dependent.
#
# **Compatibility Q&A:**
#
# **General Device Support**
#
# *   **Q: Which phone models does this user guide cover?**
#     *   **A:** This user guide is applicable to the following Samsung Galaxy models:
#         *   SM-S931B
#         *   SM-S931B/DS
#         *   SM-S936B
#         *   SM-S936B/DS
#         *   SM-S938B
#         *   SM-S938B/DS
# *   **Q: Are these models compatible with each other in terms of software features?**
#     *   **A:**  The guide implies they are largely compatible in terms of core software features. However, differences may exist based on the specific model.
# *   **Q: Is the S Pen supported on all models?**
#     *   **A:** No. The S Pen functionality is exclusive to the SM-S938B and SM-S938B/DS (Galaxy S25 Ultra) models.
# *   **Q: Do all models support dual SIM functionality?**
#     *   **A:** Yes, all models ending in "/DS" support dual SIM functionality.
# *   **Q: What software/documentation version does this guide cover?**
#     *   **A:** This guide covers English version 01/2025 Rev1 0.
#
# **Software and Feature Compatibility**
#
# *   **Q: Are the "Galaxy AI" features available on all supported models?**
#     *   **A:** The guide states, "Some features may not be available depending on the region, carrier, or model."  This means that the Galaxy AI features might not be universally available across all models listed.
# *   **Q: Are there any regional restrictions on the eSIM functionality?**
#     *   **A:** Yes. The guide explicitly states, "eSIM may not be available depending on the region, carrier, or model."
# *   **Q: Does the availability of Samsung Wallet depend on the region?**
#     *   **A:** Yes, the guide states, "This app may not be available depending on the region. Some features may not be available depending on the region."
# *   **Q: What does "some features may not be available depending on the carrier or model" mean?**
#     *   **A:** This means that carriers might disable or customize certain functionalities, and/or different hardware configurations in different models may restrict feature availability.
# *   **Q: Can the models receive software updates?**
#     *   **A:** All models have the Software Update option in settings. However, the availability of software updates depends on the carrier and region.
#
# **Feature Compatibility Table**
#
# | Feature                | SM-S931B / SM-S931B/DS | SM-S936B / SM-S936B/DS | SM-S938B / SM-S938B/DS (Ultra) | Notes                                                                |
# | ---------------------- | ------------------------ | ------------------------ | ----------------------------- | -------------------------------------------------------------------- |
# | S Pen Support          | No                       | No                       | Yes                           | S Pen is exclusive to Ultra model.                                  |
# | eSIM Support           | Region/Carrier Dependant | Region/Carrier Dependant | Region/Carrier Dependant      | Availability depends on region, carrier, and model.                  |
# | Galaxy AI Features     | Region/Carrier Dependant | Region/Carrier Dependant | Region/Carrier Dependant      | Core functionality likely present, specific AI features may vary. |
# | Samsung Wallet         | Region Dependant       | Region Dependant       | Region Dependant            | App and feature availability is region-specific.                   |
# | Dual SIM (DS Models) | Yes                      | Yes                      | Yes                           | Only models ending in "/DS"                                          |
#
# **Regional Compatibility**
#
# *   **Q: Are there any features that are known to vary by region?**
#     *   **A:** Yes. The document explicitly mentions that the availability of eSIM, Samsung Wallet,  Auto-updating album, and Shared family album depends on the region or the model.
# *   **Q: How can I determine which features are available in my specific region?**
#     *   **A:** The best way to determine feature availability is to check the official Samsung website for your region, contact your local carrier, or consult the device's settings menu after inserting a SIM card.
# *   **Q: What is Ultra-wideband (UWB) (Galaxy S25 Ultra, Galaxy S25+) availability?**
#     *   **A:** The UWB feature may not be available depending on the region.
#
# **Other potential issues**
#
# *   **Q: Are there limitations with accessories?**
#     *   **A:** Yes, the guide states to "Use Samsung-approved accessories". Unapproved accessories may cause performance problems and malfunctions that are not covered by the warranty.
# *   **Q: Is it safe to use non-Samsung chargers?**
#     *   **A:** It is not recommended to use non-Samsung chargers. Incompatible battery, charger, and cable can cause serious injuries or damage to your device.
#
# **Important Considerations:**
#
# *   **"Region/Carrier Dependent" means that availability is determined by both your geographical location *and* your mobile service provider.**  This is a crucial point to emphasize.
# *   **"Model Dependent" means that the hardware and software of each model may differ slightly, causing some features to be unavailable.**
# *   This information is based SOLELY on the supplied text. Consulting official Samsung documentation and carrier details is *essential* for accurate compatibility assessment.
#
#
# --- Calling generate_compatibility_qa_deepseek ---
# {'Generations': [{'Question': 'Do all Galaxy S25 models support Wireless Power Sharing?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'SM-S931B', 'MinimumVersion': '1.0.0', 'Regions': {'Global': ['Wireless Power Sharing']}}, 'Notes': 'Wireless Power Sharing requires devices that support the feature. Check the Samsung website for compatible devices.'}, 'Category': 'Smartphone'}, {'Question': 'Which S25 models provide DeX support?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'SM-S936B', 'MinimumVersion': '1.0.0', 'Regions': {'Global': ['DeX']}}, 'Notes': 'Requires external display and compatible accessories. Some apps or features may not be available during DeX mode.'}, 'Category': 'Smartphone'}, {'Question': "What's the minimum firmware to use Live Translate on S25?", 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'SM-S938B', 'MinimumVersion': '1.1.0', 'Regions': {'Global': ['Live Translate']}}, 'Notes': 'Availability may vary by language and carrier. Check the Phone app settings for more details.'}, 'Category': 'Smartphone'}, {'Question': 'What is the firmware requirement to support 360 Audio Recording?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'SM-S938B', 'MinimumVersion': '1.2.1', 'Regions': {'Global': ['360 Audio Recording']}}, 'Notes': 'Requires Bluetooth headphones that support the 360 audio recording feature'}, 'Category': 'Smartphone/Accessory'}, {'Question': 'Which S25 models support Ultra-Wideband?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'SM-S938B', 'MinimumVersion': '1.0.0', 'Regions': {'Global': ['UWB', 'NFC'], 'EU': ['NFC']}}, 'Notes': 'UWB feature may not be available depending on the region.'}, 'Category': 'Smartphone'}]}
#
# --- Calling generate_compatibility_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "CompatibilityQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_compatibility_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "Is the Galaxy S25 compatible with my existing accessories (chargers, headphones, etc.)?",\n      "Which Galaxy S25 model (SM-S931B, SM-S936B, SM-S938B) is best suited for my region?",\n      "What are the minimum software version requirements for optimal performance of specific features on the Galaxy S25?",\n      "Does the Galaxy S25 support wireless charging, and which wireless charging standards are compatible?",\n      "Are there any regional limitations or features that are disabled in specific regions for the Galaxy S25 series?",\n      "Is the new Galaxy AI feature suite included in the S25 series devices globally, or is it region-locked?"\n    ],\n    "Answers": [\n      "The Galaxy S25 series uses a USB Type-C port for charging and audio. Compatibility with existing accessories depends on their connector type and supported standards like USB-PD for charging; older Micro-USB cables will not work and adaptors are needed. ",\n      "The optimal Galaxy S25 model for your region depends on the carrier network bands and available 5G frequencies. Check your carrier\'s specifications and compare them to supported bands of SM-S931B, SM-S936B, or SM-S938B before purchase.",\n      "Some Galaxy S25 features, especially Galaxy AI, may require the latest software updates to function correctly.  Ensure your device is running the optimal or minimum software version specified by Samsung for best performance and security.",\n      "The Galaxy S25 supports wireless charging using the Qi standard. Using Samsung-approved wireless chargers is recommended to ensure optimal and safe charging speeds and performance.",\n      "Some features or apps might be limited or unavailable in certain regions due to regulatory restrictions or carrier agreements. Check the device specifications or consult your local Samsung retailer for region-specific details.",\n      "The Galaxy AI feature suite is available in select countries and regions. Check Samsung official regional sites for availability in your current location."\n    ],\n    "Metadata": {\n      "CompatibilityTypes": [\n        "Model Support",\n        "Version Requirements",\n        "Regional Variations",\n        "Accessory Compatibility"\n      ]\n    },\n    "CompatibilityDetails": {\n      "SupportedModels": [\n        "SM-S931B",\n        "SM-S931B/DS (Dual SIM)",\n        "SM-S936B",\n        "SM-S936B/DS (Dual SIM)",\n        "SM-S938B",\n        "SM-S938B/DS (Dual SIM)"\n      ],\n      "VersionRequirements": [\n        "Android OS 15 (predicted)",\n        "One UI 7.0 (predicted)",\n        "Galaxy AI feature suite (latest available version)"\n      ],\n      "RegionalVariations": [\n        "Carrier-specific software customizations",\n        "Country-specific regulatory compliance",\n        "Feature availability (e.g., Samsung Pay, Bixby)",\n        "eSIM availability"\n      ],\n      "AccessoryCompatibility": [\n          "USB Type-C chargers with USB-PD support for fast charging",\n          "Wireless chargers supporting the Qi standard",\n          "Bluetooth 5.3 (or later) compatible devices"\n      ]\n    },\n    "CompatibilityTable": {\n      "Format": "A detailed tabular presentation of compatibility data would include rows for each model, feature, and region, with columns indicating compatibility status and any limitations."\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 11 generate_maintenance_qa

# %%
#original
def generate_maintenance_qa(text):
    """Preventive care pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate maintenance Q&A including:
    - Service intervals - Cleaning procedures - Part replacements
    Add maintenance checklists with timelines.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_maintenance_qa_deepseek(text):
    """Generates maintenance schedules with part/tool validation in JSON format.

    Returns:
        JSON with nested maintenance tiers, validated part SKUs, and interval units.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create maintenance Q&A pairs with:
    1. Maintenance types: Preventive/Predictive/Corrective
    2. Interval formats: Days/UsageHours/Cycles
    3. Samsung part numbers (SPX-XXXX format)
    4. Tool requirements with official SKUs

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Maintenance task]",
        "Answer": {{
          "MaintenanceType": "Preventive",
          "Interval": {{
            "Value": 180,
            "Unit": "Days",
            "Condition": "NormalUsage"
          }},
          "Procedures": [
            {{
              "Step": 1,
              "Action": "Clean air vents",
              "Tools": ["GJ-CLN45"],
              "PartSKU": "SPX-0987"
            }}
          ],
          "Criticality": "High"
        }},
        "LastServicedDate": "2024-03-15"
      }}
    - Validate part numbers as SPX-XXXX
    - Sort by Criticality then Interval.Value

    Example:
    {{
      "Generations": [
        {{
          "Question": "How often should I service my Bespoke refrigerator?",
          "Answer": {{
            "MaintenanceType": "Predictive",
            "Interval": {{
              "Value": 365,
              "Unit": "Days",
              "Condition": "HeavyIceUsage"
            }},
            "Procedures": [
              {{
                "Step": 1,
                "Action": "Defrost ice maker",
                "Tools": ["GJ-DEF12"],
                "PartSKU": "SPX-4567"
              }}
            ],
            "Criticality": "Medium"
          }},
          "LastServicedDate": "2023-09-01"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse maintenance protocol"}


#Google AI STudio
def generate_maintenance_qa_google(text):
    """Preventive maintenance pairs in JSON format with checklists and timelines."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate maintenance Question and Answer pairs from the following Samsung support document text, including:
    - Service intervals (how often maintenance is needed)
    - Cleaning procedures (how to clean specific parts or the device)
    - Part replacements (when and which parts need replacement)

    For key maintenance tasks, create maintenance checklists with recommended timelines for each task.  Present timelines clearly (e.g., "Monthly", "Every 6 Months", "Annually").

    Use consumer-friendly language. Keep answers concise and provide actionable maintenance advice.

    Present the output as a list of maintenance Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "ServiceInterval" (string or null), "CleaningProcedure" (string or null), "PartReplacement" (string or null), and "MaintenanceChecklist" (dictionary - see example format below, or null if no checklist is applicable).  "MaintenanceChecklist" should contain a "Timeline" (overall checklist timeline) and "Items" (list of checklist item dictionaries, each with "Task", "Timeline", and "Details").

    Text: {text}

    Output Format (example, checklists as nested dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "ServiceInterval": "...",
        "CleaningProcedure": "...",
        "PartReplacement": "...",
        "MaintenanceChecklist": {{
          "Timeline": "...",
          "Items": [
            {{ "Task": "...", "Timeline": "...", "Details": "..." }},
            {{ "Task": "...", "Timeline": "...", "Details": "..." }},
            ...
          ]
        }}
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "ServiceInterval": null,
        "CleaningProcedure": null,
        "PartReplacement": null,
        "MaintenanceChecklist": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        maintenance_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        maintenance_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"MaintenanceQAPairs": maintenance_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_maintenance_qa_sonnet(text):
    """Generate structured preventive maintenance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create maintenance Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Maintenance and care inquiry"
        ],
        "Answers": [
          "Comprehensive maintenance guidance"
        ],
        "Metadata": {{
          "MaintenanceTypes": ["Service Intervals", "Cleaning", "Part Replacement"]
        }},
        "MaintenanceDetails": {{
          "ServiceIntervals": ["Recommended maintenance schedule"],
          "CleaningProcedures": ["Detailed cleaning instructions"],
          "PartReplacements": ["Component replacement guidelines"]
        }},
        "MaintenanceChecklist": {{
          "Timeline": "Periodic maintenance schedule"
        }}
      }}
    }}

    Requirements:
    - Detailed maintenance guidance
    - Service interval specifics
    - Cleaning and replacement procedures
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_maintenance_qa ---")
test_qa_generators("generate_maintenance_qa", content)
# Out:
# --- generate_maintenance_qa ---
#
# --- Calling generate_maintenance_qa ---
# Okay, here's a comprehensive Maintenance Q&A and Checklists based on the provided User Guide for the Samsung Galaxy S25 series, covering service intervals, cleaning, and parts replacements:
#
# ## Samsung Galaxy S25 Series (SM-S931B, SM-S936B, SM-S938B) - Maintenance Q&A
#
# **Q: How often should I service my Galaxy S25 device?**
#
# *   **A:** While there are no specific "service intervals" in the traditional sense for smartphones (like with a car), it's recommended to:
#     *   Check for software updates regularly (Settings > Software update).
#     *   Monitor battery health and performance (Settings > Battery > Battery Information).
#     *   Utilize the Device Care feature to optimize performance (Settings > Device care).
#
# **Q: What's the best way to clean my Galaxy S25 device?**
#
# *   **A:**
#     1.  **Power Off:** Turn off your device before cleaning.
#     2.  **Microfiber Cloth:** Use a soft, lint-free microfiber cloth to wipe the exterior surfaces (screen, back, sides).
#     3.  **Avoid Liquids:** Do not spray liquids directly onto the device. If necessary, *lightly* dampen the microfiber cloth with distilled water or a screen cleaner specifically designed for electronics.
#     4.  **Ports and Openings:** Use a dry, soft brush (like a clean toothbrush) or compressed air to gently remove dust and debris from charging port, speaker grilles, microphone holes, and SIM tray slot. Be very gentle to avoid damage.
#     5.  **Camera Lens:** Clean the camera lens with a lens cloth designed for optics.  Avoid abrasive materials.
#     6.  **S Pen (S25 Ultra):** Clean the S Pen with a dry cloth. Ensure no debris is lodged in the S Pen slot.
#
# **Q: Can I use alcohol-based cleaners on my Galaxy S25?**
#
# *   **A:** Samsung generally recommends against using harsh chemicals, including alcohol-based cleaners, as they can damage the oleophobic coating on the screen and other surfaces. If you must use a cleaner, use a screen cleaner specifically designed for electronics.
#
# **Q: What should I do if my device gets wet?**
#
# *   **A:**
#     1.  **Power Off:** Immediately turn off the device.
#     2.  **Dry Thoroughly:** Wipe the device with a soft, clean cloth.
#     3.  **Dry Ports:** Gently shake the device to remove water from the ports. Allow the device to air dry completely. You can use a fan to speed up the drying process.
#     4.  **Avoid Heat:** Do not use a hairdryer or other heat source to dry the device, as this can cause damage.
#     5.  **Wait Before Charging:** Do not attempt to charge the device until it is completely dry (especially the charging port).
#     6.  **Monitor:** Monitor the device for proper functioning after drying. If you experience any issues (e.g., speaker distortion, charging problems), contact a Samsung Service Center.
#
# **Q: What parts of the Galaxy S25 are replaceable?**
#
# *   **A:** While some repairs can be done, it's best to consult a Samsung Service Center or authorized repair shop. Common replaceable parts (through professional service) include:
#     *   **Screen:** If cracked or damaged.
#     *   **Battery:** If it degrades significantly.
#     *   **Charging Port:** If damaged or not functioning.
#     *   **Camera Modules:** If malfunctioning.
#     *   **Back Glass:** If cracked (repair shops tend to glue it back).
#     *   **S Pen (S25 Ultra):** If lost or damaged.
#     *   **SIM Tray:** If damaged.
#
# **Q: How do I know when my battery needs replacing?**
#
# *   **A:** Signs of a degrading battery include:
#     *   Significantly reduced battery life.
#     *   Device shutting down unexpectedly even with some charge remaining.
#     *   Battery swelling (visible bulging of the back cover – *stop using immediately and contact service*).
#     *   The Battery information in the Device Care states it needs service.
#
# **Q: Where can I get genuine Samsung replacement parts?**
#
# *   **A:** It's highly recommended to obtain replacement parts and repairs from:
#     *   Samsung Service Centers
#     *   Authorized Samsung repair partners.
#
# **Q: What about third-party repair shops and parts?**
#
# *   **A:** While third-party repair options exist, using unauthorized parts or services can:
#     *   Void your warranty.
#     *   Compromise the device's water resistance.
#     *   Potentially damage the device further.
#
# **Q: How do I check if my Galaxy S25 is water resistant after it’s been opened for repair?**
#
# *   **A:** Water resistance cannot be guaranteed after the device has been opened for repair. It is very difficult to reseal it to the original factory standard. It's best to avoid water exposure after any repair.
#
# **Q: Does water or dust damage void my warranty?**
#
# *   **A:** Yes, most manufacturers will void the warranty if there is water or dust damage because water resistance is not permanent and they cannot tell how it happened.
#
# **Q: What to do if the speaker or microphone has low sound?**
#
# *   **A:** Use a dry, soft brush (like a clean toothbrush) or compressed air to gently remove dust and debris from speaker and microphone holes.
#
# ## Maintenance Checklists
#
# Here are a few maintenance checklists to help keep your Galaxy S25 series device in good working order:
#
# **Daily Checklist:**
#
# *   [ ] Wipe the screen and back with a microfiber cloth.
# *   [ ] Check for any physical damage (scratches, cracks).
# *   [ ] Ensure the charging port is clear of debris.
# *   [ ] Safely eject any water from the device.
#
# **Weekly Checklist:**
#
# *   [ ] Run Device Care optimization (Settings > Device care > Optimize now).
# *   [ ] Check for app updates in the Galaxy Store and Play Store.
# *   [ ] Delete any unnecessary files (photos, videos, documents).
# *   [ ] Clean the charging port and speaker grilles with a soft brush.
# *   [ ] Back up important data (photos, contacts, etc.) to Samsung Cloud or Google Drive.
#
# **Monthly Checklist:**
#
# *   [ ] Check battery health (Settings > Battery > Battery Information).
# *   [ ] Clear app cache (Settings > Apps > [App Name] > Storage > Clear Cache).
# *   [ ] Review app permissions (Settings > Apps > [App Name] > Permissions).
# *   [ ] Perform a security scan using the built-in app protection.
# *   [ ] Consider a restart to clear temporary files.
# *   [ ] Check your security updates are up to date (Settings > Security and privacy > Updates > Security update).
#
# **Annual Checklist:**
#
# *   [ ] Evaluate battery performance. If significantly degraded, consider battery replacement by an authorized service center.
# *   [ ] Consider if it is time for an upgrade.
#
# **Important Notes:**
#
# *   These checklists are guidelines. Adjust them based on your usage and environment.
# *   If you're not comfortable performing any of these tasks, seek professional assistance.
# *   *Always* back up your data before performing any significant maintenance or repairs.
# *   Refer to the official Samsung website and user manual for the most up-to-date information and safety guidelines.
#
#
# --- Calling generate_maintenance_qa_deepseek ---
# {'Generations': [{'Question': 'When should I clean the air vent hole on my Galaxy S25?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 30, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Use a dry, soft brush to gently remove any dust or debris from the air vent hole.', 'Tools': ['GJ-CLN45'], 'PartSKU': 'SPX-0987'}], 'Criticality': 'High'}, 'LastServicedDate': '2024-05-20'}, {'Question': 'How often should I check the charger connection status?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 7, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Open Settings, tap Battery.', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Check connection and charging percentage.', 'Tools': [], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-05-27'}, {'Question': 'What should I do if my S Pen is not working properly?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 0, 'Unit': 'Cycles', 'Condition': 'SpenFailure'}, 'Procedures': [{'Step': 1, 'Action': 'Take the S Pen to a Samsung Service Centre.', 'Tools': [], 'PartSKU': None}], 'Criticality': 'High'}, 'LastServicedDate': '2024-06-01'}, {'Question': 'What is the cycle count for battery capacity checks?', 'Answer': {'MaintenanceType': 'Predictive', 'Interval': {'Value': 500, 'Unit': 'Cycles', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Use diagnostic software to check battery health.', 'Tools': ['GJ-DIA01'], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-01-10'}, {'Question': 'How often should I replace the USB Type-C port cover to maintain water resistance?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 365, 'Unit': 'Days', 'Condition': 'WaterExposure'}, 'Procedures': [{'Step': 1, 'Action': 'Carefully remove the old USB Type-C port cover.', 'Tools': ['GJ-PRY01'], 'PartSKU': 'SPX-2345'}, {'Step': 2, 'Action': 'Install the new USB Type-C port cover.', 'Tools': ['GJ-PRY01'], 'PartSKU': 'SPX-2345'}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-03-01'}, {'Question': 'How often should I check the camera lens for scratches or damage?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 90, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Visually inspect the camera lens for any signs of scratches or damage.', 'Tools': ['GJ-LOUPE'], 'PartSKU': None}, {'Step': 2, 'Action': 'Clean the lens with a microfiber cloth.', 'Tools': ['GJ-CLN45'], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-04-01'}, {'Question': 'How often should I update my Samsung S25 software?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 30, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Open Settings', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Tap on Software update', 'Tools': [], 'PartSKU': None}, {'Step': 3, 'Action': 'Tap on Download and install if an update is available', 'Tools': [], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-05-01'}, {'Question': 'When should I replace the screen protector on my Galaxy S25?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 0, 'Unit': 'Days', 'Condition': 'DamagedScreenProtector'}, 'Procedures': [{'Step': 1, 'Action': 'Remove the damaged screen protector.', 'Tools': ['GJ-PRY01'], 'PartSKU': None}, {'Step': 2, 'Action': 'Clean the screen with a microfiber cloth.', 'Tools': ['GJ-CLN45'], 'PartSKU': None}, {'Step': 3, 'Action': 'Apply the new screen protector.', 'Tools': [], 'PartSKU': 'SPX-1234'}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-05-15'}, {'Question': 'What is the troubleshooting procedure when the device overheats?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 0, 'Unit': 'Cycles', 'Condition': 'DeviceOverheat'}, 'Procedures': [{'Step': 1, 'Action': ' ...
#
# --- Calling generate_maintenance_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "MaintenanceQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_maintenance_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I maintain and care for my Samsung Galaxy S25?"\n    ],\n    "Answers": [\n      "To maintain your Samsung Galaxy S25, it\'s important to keep the device clean, use only Samsung-approved accessories, and protect it from extreme temperatures or physical damage. Regularly check for software updates and optimize device care settings."\n    ],\n    "Metadata": {\n      "MaintenanceTypes": ["Service Intervals", "Cleaning", "Part Replacement", "Overheating Prevention"]\n    },\n    "MaintenanceDetails": {\n      "ServiceIntervals": [\n        "How often should I perform maintenance tasks on my Samsung Galaxy S25?",\n        "It is important to regularly check for software updates and optimize device care settings to prolong the lifespan and efficiency of your Samsung Galaxy S25."\n      ],\n      "CleaningProcedures": [\n        "How should I clean my Samsung Galaxy S25?",\n        "To clean your Samsung Galaxy S25, use a soft, dry cloth to wipe away any smudges, fingerprints, or dust. Avoid using excessive moisture or abrasive cleaners as they could damage the device."\n      ],\n      "PartReplacements": [\n        "When do parts need to be replaced on my Samsung Galaxy S25, and how?",\n        "Replace damaged parts such as the screen or battery only at a Samsung Service Centre or an authorized service center. Contact them as soon as broken glass or cracked casing may lead to injury."\n      ],\n      "OverheatingPrevention": [\n        "What causes my phone to overheat and what should I do to prevent it?",\n        "To prevent overheating, avoid using power-intensive apps for extended periods, keep the device out of direct sunlight, ensure the charger is Samsung-approved, and don\'t cover the air vent hole. Disconnect the charger and stop using the device immediately if it becomes uncomfortably hot, allowing it to cool down before resuming use."\n      ]\n    },\n    "MaintenanceChecklist": {\n      "Timeline": "Monthly software updates; periodic physical cleaning; immediate damage repair"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 12 generate_warranty_qa

# %%
#original
def generate_warranty_qa(text):
    """Warranty/service pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A covering:
    - Coverage details - Claim processes - Void conditions
    Include regional policy variations.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_warranty_qa_deepseek(text):
    """Generates warranty rules with policy validation in JSON format.

    Returns:
        JSON with coverage timelines, ISO regions, and machine-readable void terms.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A pairs with:
    1. Policy numbers in WR-YYYY-REG format (e.g., WR-2024-US)
    2. Coverage periods as start/end dates
    3. Void conditions as codified rules (MODIFIED_HARDWARE = void)
    4. Regional terms using ISO 3166 codes

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Warranty inquiry]",
        "Answer": {{
          "PolicyNumber": "WR-2024-EU",
          "CoveragePeriod": {{
            "Start": "2024-01-01",
            "End": "2026-12-31",
            "DurationDays": 1095
          }},
          "Regions": ["DE", "FR", "IT"],
          "VoidConditions": [
            {{
              "Code": "LIQUID_DAMAGE",
              "Description": "Water ingress signs present"
            }}
          ],
          "ClaimProcess": ["Submit form W-45", "Provide proof of purchase"]
        }},
        "ProductCategory": "Smartphone/HomeAppliance"
      }}
    - Validate PolicyNumber format
    - Sort by CoveragePeriod.DurationDays descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "Does installing third-party parts void my TV warranty?",
          "Answer": {{
            "PolicyNumber": "WR-2024-GLOBAL",
            "CoveragePeriod": {{
              "Start": "2024-03-01",
              "End": "2027-03-01",
              "DurationDays": 1096
            }},
            "Regions": ["GLOBAL"],
            "VoidConditions": [
              {{
                "Code": "UNAUTH_PARTS",
                "Description": "Non-Samsung display components detected"
              }}
            ],
            "ClaimProcess": ["Contact ASC", "Run diagnostic tool"]
          }},
          "ProductCategory": "TV"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse warranty policy"}


#Google AI STudio
def generate_warranty_qa_google(text):
    """Warranty/service pairs in JSON format, including regional policy variations."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate warranty Question and Answer pairs from the following Samsung support document text, covering:
    - Warranty coverage details (what is covered, duration)
    - Warranty claim processes (how to initiate a claim)
    - Conditions that void the warranty

    Crucially, include regional policy variations. Warranty policies often differ significantly by region.  Represent these regional differences clearly in the output. In the JSON output, structure regional variations under a "RegionalPolicyVariations" key, with regions (e.g., "USA", "Europe", "Asia") as keys and policy details as values.

    Use consumer-friendly language. Keep answers concise and provide accurate warranty information.

    Present the output as a list of warranty Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "CoverageDetails" (list of strings or null), "ClaimProcess" (string or null), "VoidConditions" (list of strings or null), and "RegionalPolicyVariations" (dictionary - see example format below, or null if no regional variations are mentioned in the Q&A pair).

    Text: {text}

    Output Format (example, regional variations as nested dictionary):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "CoverageDetails": [...],
        "ClaimProcess": "...",
        "VoidConditions": [...],
        "RegionalPolicyVariations": {{
          "Region 1 Name": {{ "Policy Detail 1": "Value 1", "Policy Detail 2": "Value 2" }},
          "Region 2 Name": {{ "Policy Detail 1": "Value 3", "Policy Detail 2": "Value 4" }},
          ...
        }}
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "CoverageDetails": null,
        "ClaimProcess": null,
        "VoidConditions": null,
        "RegionalPolicyVariations": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        warranty_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        warranty_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"WarrantyQAPairs": warranty_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_warranty_qa_sonnet(text):
    """Generate structured warranty and service Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Warranty and service inquiry"
        ],
        "Answers": [
          "Comprehensive warranty guidance"
        ],
        "Metadata": {{
          "WarrantyAreas": ["Coverage", "Claims", "Void Conditions"]
        }},
        "WarrantyDetails": {{
          "CoverageSpecifics": ["Detailed warranty terms"],
          "ClaimProcess": ["Step-by-step claim procedures"],
          "VoidConditions": ["Warranty invalidation scenarios"]
        }},
        "RegionalVariations": {{
          "PolicyDifferences": "Geographic policy variations"
        }}
      }}
    }}

    Requirements:
    - Detailed warranty information
    - Claim process insights
    - Regional policy differences
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_warranty_qa ---")
test_qa_generators("generate_warranty_qa", content)
# Out:
# --- generate_warranty_qa ---
#
# --- Calling generate_warranty_qa ---
# Okay, here's a comprehensive Warranty Q&A based on the provided text, covering coverage details, claim processes, void conditions, and incorporating regional policy variations where applicable. I've also included a disclaimer about accessories.
#
# **Disclaimer:**  *This Q&A is based solely on the provided User Guide text. It's intended for informational purposes only and should not be considered a legally binding warranty document. The actual warranty provided by Samsung may differ. Always refer to the official warranty documentation included with your device or available on the Samsung website for the most accurate and up-to-date information.*
#
# ***
#
# ## Samsung Galaxy S25 Series (SM-S931B, SM-S936B, SM-S938B) Warranty Q&A
#
# **General Information**
#
# **Q: Where can I find official warranty information?**
#
# A: Always refer to the official warranty documentation included with your device or available on the Samsung website for the most accurate and up-to-date information.
#
# **Coverage Details**
#
# **Q: What does the Samsung warranty cover?**
#
# A: The warranty typically covers defects in materials and workmanship under normal use.
#
# **Q: What is considered "normal use?"**
#
# A: "Normal use" generally means using the device as intended and described in the User Guide, following all precautions and guidelines.
#
# **Q:  Are accessories covered under warranty?**
#
# A:  Use Samsung-approved accessories. Using unapproved accessories may cause performance problems and malfunctions that are not covered by the warranty. Availability of all accessories is subject to change depending entirely on manufacturing companies. For more information about available accessories, refer to the Samsung website.
#
# **Q: Is the screen covered under warranty?**
#
# A: The warranty covers defects in materials and workmanship. Scratches, accidental damage, or misuse of the screen are generally NOT covered. Note it is recommended not to use fixed graphics on part or all of the screen for extended periods. Doing so may result in afterimages (screen burn-in) or ghosting which might not be covered.
#
# **Q: Is water or dust damage covered under warranty?**
#
# A: The device is water- and dust-resistant and meets the requirements of the IEC 60529 standard, it was tested in 15-35 °C, 86-106 kPa, 1.5 m fresh water for 30 minutes without moving.
#
# You must follow the guidelines to maintain the water- and dust-resistance of your device.
#
# Water and dust resistance is not permanent and may diminish over time because of normal wear and tear.
#
# **Q: Is the battery covered under warranty?**
#
# A: The battery is consumable and the useful charge will get shorter over time, which may not be considered a defect covered by the warranty. Improper charging and use can affect the battery's lifespan, which may void coverage.
#
# **Q: What about software issues or app compatibility?**
#
# A: Samsung is not liable for performance issues caused by apps supplied by providers other than Samsung. Samsung is not liable for performance issues or incompatibilities caused by edited registry settings or modified operating system software.
#
# **Claim Processes**
#
# **Q: How do I make a warranty claim?**
#
# A: Contact a Samsung Service Centre or an authorised service centre. Have your proof of purchase (receipt) and device information (model number, IMEI) readily available. Bring the charger and USB cable you are using for better service support. If wireless charging is not working, bring the wireless charger as well.
#
# **Q: Where can I find a Samsung Service Centre or an authorized service centre?**
#
# A: Check the Samsung website for a list of authorized service locations in your region. You can also contact Samsung customer support for assistance in locating a service center.
#
# **Q: What information or documents do I need to provide when making a claim?**
#
# A:  You will typically need to provide:
# *   Proof of Purchase (original receipt)
# *   Device Model Number
# *   Device IMEI Number
# *   Detailed description of the problem
#
# **Void Conditions**
#
# **Q: What actions will void my warranty?**
#
# A: The following actions may void your warranty:
#
# *   **Modifying the Device's Operating System:** Modifying the device's operating system or installing software from unofficial sources may result in device malfunctions and data damage or loss. These actions are violations of your Samsung licence agreement and will void your warranty.
# *   **Physical Damage:** Damage caused by accidents, misuse, abuse, neglect, improper handling, or unauthorized modifications.
# *   **Liquid Damage:** Failure to follow water resistance guidelines. Exposure to swimming pool water or sea water may damage device and void warranty.
# *   **Use of Unapproved Accessories:** Use Samsung-approved accessories. Using unapproved accessories may cause the performance problems and malfunctions that are not covered by the warranty.
# *   **Attempting to Repair the Device Yourself:** Attempting to customise the operating system may cause the device or apps to work improperly.
# *   **Improper Battery Removal:** If the battery is not properly removed, it may lead to damage to the battery and device, cause personal injury, and result in the device being unsafe.
#
# **Q: What if I accidentally break the screen?**
#
# A: Accidental damage, such as a broken screen, is not covered under the standard warranty. You may need to pay for the repair.
#
# **Regional Policy Variations**
#
# **Q: Does the warranty vary by region?**
#
# A: Yes, warranty policies can vary significantly depending on the country or region.  Always refer to the warranty documentation specific to your location.
#
# **Q: What about regulatory information and FCC ID?**
#
# A: Depending on the region or model, some devices are required to receive approval from the Federal Communications Commission (FCC).
#
# If your device is approved by the FCC, you can check out the FCC ID of the device. To access the FCC ID, open Settings and tap About phone → Status information. If your device does not have an FCC ID, it means that the device has not been authorised for sale in the U.S. or its territories and may only be brought to the U.S. for the owner’s personal use.
#
# **Q: Is there a difference in warranty for devices purchased in Germany regarding LTE TDD bands?**
#
# A: Yes, models purchased in Germany cannot receive signals in LTE TDD bands in the following countries: Belgium, Denmark, Germany, France, Luxemburg, Netherlands, Austria, Poland, Switzerland, Czech Republic.
#
# **Accessories Disclaimer**
#
# **Q: What is the responsibility of SAMSUNG with respect to accessories?**
#
# A: Connected devices’ own problems or defects are not covered by the Samsung warranty. When problems or defects occur on the connected devices, contact the device’s manufacturer.
#
# ***
#
# **Important Notes:**
#
# *   This Q&A is based on limited information and is not a substitute for the official warranty document.
# *   Always consult the official Samsung warranty documentation for your specific device and region.
# *   Keep your proof of purchase in a safe place.
# *   Contact Samsung customer support for clarification on any warranty-related questions.
#
#
# --- Calling generate_warranty_qa_deepseek ---
# {'Generations': [{'Question': 'Is the standard charger covered by warranty?', 'Answer': {'PolicyNumber': 'WR-2025-GLOBAL', 'CoveragePeriod': {'Start': '2025-01-01', 'End': '2028-01-01', 'DurationDays': 1096}, 'Regions': ['GLOBAL'], 'VoidConditions': [{'Code': 'UNAUTH_REPAIR', 'Description': 'Attempting to customize the operating system may cause the device or apps to work improperly and will void your warranty'}], 'ClaimProcess': ['Visit Samsung service center']}, 'ProductCategory': 'Smartphone'}, {'Question': "What's the European warranty length?", 'Answer': {'PolicyNumber': 'WR-2025-EU', 'CoveragePeriod': {'Start': '2025-01-01', 'End': '2027-12-31', 'DurationDays': 1095}, 'Regions': ['DE', 'FR', 'IT'], 'VoidConditions': [{'Code': 'LIQUID_DAMAGE', 'Description': 'Liquid damage will invalidate the warranty.'}], 'ClaimProcess': ['Contact Samsung customer support', 'Provide IMEI number']}, 'ProductCategory': 'Smartphone'}, {'Question': 'Is there any warranty for battery of my new home appliance?', 'Answer': {'PolicyNumber': 'WR-2025-US', 'CoveragePeriod': {'Start': '2025-01-01', 'End': '2026-12-31', 'DurationDays': 730}, 'Regions': ['US', 'CA', 'MX'], 'VoidConditions': [{'Code': 'MODIFIED_HARDWARE', 'Description': 'Modifying the device’s operating system or installing software from unofficial sources may result in device malfunctions and data damage or loss. These actions are violations of your Samsung licence agreement and will void your warranty.'}], 'ClaimProcess': ['Contact Samsung Service Centre']}, 'ProductCategory': 'HomeAppliance'}]}
#
# --- Calling generate_warranty_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "WarrantyQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_warranty_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Warranty": {\n    "Questions": [\n      "What does the warranty cover on my new Galaxy S25 device?",\n      "What is the process for filing a warranty claim?",\n      "Are there any conditions that would void my warranty?"\n    ],\n    "Answers": [\n      "The warranty covers defects in materials and workmanship under normal use. It does not cover accidental damage, misuse, or unauthorized modifications.",\n      "To file a warranty claim, contact Samsung support with proof of purchase and a detailed description of the issue. Follow their instructions for repair or replacement.",\n      "Warranty is void if the device has been tampered with, damaged by liquid or physical impact, or repaired by an unauthorized service provider."\n    ],\n    "Metadata": {\n      "WarrantyAreas": [\n        "Coverage",\n        "Claims",\n        "Void Conditions",\n        "Regional Variations"\n      ]\n    },\n    "WarrantyDetails": {\n      "CoverageSpecifics": [\n        "Covers defects in materials and workmanship for a specific period.",\n        "Doesn\'t cover damage from accidents or misuse."\n      ],\n      "ClaimProcess": [\n        "Contact Samsung support or an authorized service center to initiate a claim.",\n        "Provide proof of purchase and a description of the issue."\n      ],\n      "VoidConditions": [\n        "Unauthorized repairs or modifications void the warranty.",\n        "Damage from liquids or physical impact also voids it."\n      ],\n      "RegionalVariations": [\n        "Warranty terms may vary depending on the region of purchase.",\n        "Some regions may have extended warranty options."\n      ]\n    },\n    "RegionalVariations": {\n      "PolicyDifferences": "Warranty policies and lengths differ based on the region of purchase. Contact Samsung support in your specific region."\n    },\n    "Support": {\n        "Questions": [\n          "Where can I get additional support for my Galaxy S25 device?",\n          "How can I get my Galaxy S25 Repaired?"\n        ],\n        "Answers": [\n          "You can find support resources on the Samsung website, through the Samsung Members app, or by contacting customer support directly.",\n          "Contact Samsung support to locate authorized repair centers near you."\n        ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 13 generate_update_qa

# %%
#original
def generate_update_qa(text):
    """Software update pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create update-related Q&A including:
    - Version histories - Rollback methods - Security patches
    Add update compatibility matrices.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_update_qa_deepseek(text):
    """Generates update guides with version validation and security metadata.

    Returns:
        JSON with semantic versioning, CVE tracking, and rollback metrics.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create software update Q&A pairs with:
    1. Semantic versioning (major.minor.patch)
    2. CVE numbers for security patches
    3. Rollback success rates (%) and prerequisites
    4. Model-specific compatibility using SM-XXXX codes

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Update inquiry]",
        "Answer": {{
          "CurrentVersion": "6.1.1",
          "TargetVersion": "7.0.0",
          "SecurityPatches": [
            {{
              "CVE": "CVE-2024-1234",
              "Severity": "Critical",
              "PatchDate": "2024-03-15"
            }}
          ],
          "Compatibility": {{
            "DeviceModel": "SM-S901B",
            "MinOSVersion": "5.0.0"
          }},
          "Rollback": {{
            "Possible": true,
            "SuccessRate": 92,
            "Steps": ["Enter recovery", "Select rollback image"]
          }},
          "UpdateSize": "1.4GB"
        }},
        "ReleaseChannel": "Stable/Beta"
      }}
    - Validate versions as X.Y.Z numbers
    - Sort by TargetVersion descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to revert from One UI 6.1 to 6.0?",
          "Answer": {{
            "CurrentVersion": "6.1.0",
            "TargetVersion": "6.0.1",
            "SecurityPatches": [],
            "Compatibility": {{
              "DeviceModel": "SM-S918B",
              "MinOSVersion": "5.1.2"
            }},
            "Rollback": {{
              "Possible": true,
              "SuccessRate": 85,
              "Steps": ["Backup data", "Download rollback package"]
            }},
            "UpdateSize": "2.1GB"
          }},
          "ReleaseChannel": "Stable"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse update protocol"}


#Google AI STudio
def generate_update_qa_google(text):
    """Software update pairs in JSON format, including compatibility matrices."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung software updates from the following support document text, including:
    - Version histories and key changes in each version
    - Methods to rollback or revert to previous versions
    - Security patches included in updates

    Present update compatibility information as compatibility matrices whenever possible to clearly show which devices are compatible with which updates. In the JSON output, represent matrices as a list of dictionaries, where each dictionary is a row.

    Use consumer-friendly language. Keep answers concise and provide accurate update information.

    Present the output as a list of update Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "VersionHistories" (list of strings or null), "RollbackMethods" (list of strings or null), "SecurityPatches" (list of strings or null), and "UpdateCompatibilityMatrix" (list of row dictionaries - see example format below, or null if no matrix is applicable).

    Text: {text}

    Output Format (example, matrices as list of dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "VersionHistories": [...],
        "RollbackMethods": [...],
        "SecurityPatches": [...],
        "UpdateCompatibilityMatrix": [
          {{ "Column 1 Header": "Value 1", "Column 2 Header": "Value 2" }},
          {{ "Column 1 Header": "Value 3", "Column 2 Header": "Value 4" }},
          ...
        ]
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "VersionHistories": null,
        "RollbackMethods": null,
        "SecurityPatches": null,
        "UpdateCompatibilityMatrix": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        update_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        update_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"UpdateQAPairs": update_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_update_qa_sonnet(text):
    """Generate structured software update Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create update Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Software update inquiry"
        ],
        "Answers": [
          "Comprehensive update guidance"
        ],
        "Metadata": {{
          "UpdateTypes": ["Version History", "Rollback", "Security Patches"]
        }},
        "UpdateDetails": {{
          "VersionHistory": ["Detailed update progression"],
          "RollbackMethods": ["Reversal procedures"],
          "SecurityPatches": ["Critical security updates"]
        }},
        "CompatibilityMatrix": {{
          "DeviceModelSupport": "Update compatibility information"
        }}
      }}
    }}

    Requirements:
    - Update version details
    - Rollback process
    - Security update insights
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_update_qa ---")
test_qa_generators("generate_update_qa", content)
# Out:
# --- generate_update_qa ---
#
# --- Calling generate_update_qa ---
# Okay, here's a Q&A section focusing on software updates, based on the provided user guide content and typical Android update procedures.
#
# **Software Updates: Q&A**
#
# **Q: How do I check for software updates on my Galaxy S25 series device?**
#
# **A:** Go to Settings > Software update > Download and install. Your device will check for available updates.
#
# **Q: Where can I find information about the last software update installed on my device?**
#
# **A:** Go to Settings > Software update > Last update. This will show the date and details of the most recent update.
#
# **Q: Can I schedule software updates to install automatically?**
#
# **A:** Yes. Go to Settings > Software update > Auto download. Here, you can select when to automatically download software updates.
#
# **Q: What types of software updates will my device receive?**
#
# **A:** Your device will receive primarily two types of updates:
# *   **Security Patches:** These updates provide the latest security enhancements to protect your device from threats.
# *   **OS/Feature Updates:** These updates upgrade the operating system to a newer version (e.g., Android 16 to Android 17) and/or introduce new features and improvements.
#
# **Q: Are software updates automatic?**
#
# **A:** While you can manually check for updates in settings and begin the installation yourself. Emergency software updates related to security will be installed automatically without consent.
#
# **Version Histories**
#
# **Q: Where can I find version histories on my device?**
# **A:** Unfortunately, the user manual does not explain where to find version histories.
# However, version histories can commonly be found in the device settings, or on the Samsung Website.
#
# **Rollback Methods**
#
# **Q: Can I roll back to a previous version of the software if I don't like an update?**
#
# **A:** The User Guide does not explain how to rollback to previous versions of the software.
#
# **Security Patches**
#
# **Q: Why are security patches important?**
#
# **A:** Security patches are crucial for protecting your device and your personal data from security vulnerabilities.  They address newly discovered threats and help keep your device safe.
#
# **Q: How often will my Galaxy S25 series device receive security patches?**
#
# **A:** The frequency of security patch releases can vary. Samsung typically provides monthly or quarterly security updates for its flagship devices. Check the Samsung Mobile Security website (security.samsungmobile.com) for the most up-to-date information on your specific model.
#
# **Update Compatibility Matrix**
#
# This section outlines which models are compatible with each other and with which services.
#
# | Feature/Service         | SM-S931B | SM-S931B/DS | SM-S936B | SM-S936B/DS | SM-S938B | SM-S938B/DS | Notes                                                                                       |
# | ------------------------ | -------- | ----------- | -------- | ----------- | -------- | ----------- | ------------------------------------------------------------------------------------------- |
# | Software Updates         | Yes      | Yes         | Yes      | Yes         | Yes      | Yes         | Assumed all models in series receive updates, though timing may vary by region/carrier. |
# | All Apps                 | Yes      | Yes         | Yes      | Yes         | Yes      | Yes         | Generally, all core apps should be compatible across all models.                           |
# | Wireless Power Sharing   | Yes      | Yes         | Yes      | Yes         | Yes      | Yes         |                                                                                             |
# | Samsung DeX              | Yes      | Yes         | Yes      | Yes         | Yes      | Yes         |                                                                                             |
# | 5G Network Access        | Yes      | Yes         | Yes      | Yes         | Yes      | Yes         | But may vary based on country/carrier                                                       |
# | Dual SIM Functionality   | No       | Yes         | No       | Yes         | No       | Yes         | Indicated by "/DS" suffix.                                                                    |
#
# **Explanation of Table:**
#
# *   **Feature/Service:** Lists key features or services related to update compatibility.
# *   **Model Columns (SM-S931B etc.):** Each column represents a specific model from the Galaxy S25 series.
# *   **Yes/No:** Indicates if the feature/service is compatible/supported on that model.
# *   **Notes:** Provides additional context or clarification.
# *   **All Apps:** All the apps listed in the Table of Contents are assumed to be available on all models.
#
#
# --- Calling generate_update_qa_deepseek ---
# {'Generations': [{'Question': 'Is it possible to rollback from the latest version of the software?', 'Answer': {'CurrentVersion': '6.1.1', 'TargetVersion': '7.0.0', 'SecurityPatches': [{'CVE': 'CVE-2024-1234', 'Severity': 'Critical', 'PatchDate': '2024-03-15'}], 'Compatibility': {'DeviceModel': 'SM-S901B', 'MinOSVersion': '5.0.0'}, 'Rollback': {'Possible': True, 'SuccessRate': 92, 'Steps': ['Enter recovery', 'Select rollback image']}, 'UpdateSize': '1.4GB'}, 'ReleaseChannel': 'Stable/Beta'}, {'Question': 'How to revert from One UI 6.1 to 6.0?', 'Answer': {'CurrentVersion': '6.1.0', 'TargetVersion': '6.0.1', 'SecurityPatches': [], 'Compatibility': {'DeviceModel': 'SM-S918B', 'MinOSVersion': '5.1.2'}, 'Rollback': {'Possible': True, 'SuccessRate': 85, 'Steps': ['Backup data', 'Download rollback package']}, 'UpdateSize': '2.1GB'}, 'ReleaseChannel': 'Stable'}]}
#
# --- Calling generate_update_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "UpdateQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_update_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "Software update inquiry",\n      "How to update my phone\'s software?"\n    ],\n    "Answers": [\n      "To update your phone\'s software, go to Settings > Software update > Download and install. Your device will check for available updates and guide you through the installation process.",\n      "You can find software updates by navigating to Settings, then Software update, and selecting Download and install."\n    ],\n    "Metadata": {\n      "UpdateTypes": [\n        "Version History",\n        "Rollback",\n        "Security Patches"\n      ]\n    },\n    "UpdateDetails": {\n      "VersionHistory": [\n        "Detailed update progression",\n        "How can I see what the current version of the phone has?"\n      ],\n      "RollbackMethods": [\n        "Reversal procedures",\n        "Can I revert to a previous version?"\n      ],\n      "SecurityPatches": [\n        "Critical security updates",\n        "Why do I need the latest version?"\n      ]\n    },\n    "CompatibilityMatrix": {\n      "DeviceModelSupport": "Update compatibility information",\n      "Will my phone receive the update?"\n    },\n    "Q&A": [\n      {\n        "question": "How can I see what the current version of the phone has?",\n        "answer": "Navigate to Settings -> About phone -> Software information, this section displays your current device\'s version details."\n      },\n      {\n        "question": "Can I revert to a previous version?",\n        "answer": "Rolling back to a previous version isn\'t typically supported. It\'s best to seek assistance from a professional service center for rollback procedures."\n      },\n      {\n        "question": "Why do I need the latest version?",\n        "answer": "Latest version usually means the most security. Updating ensures critical security patches, performance improvements, and new features."\n      },\n      {\n        "question": "Will my phone receive the update?",\n        "answer": "Availability depends on the device model, region, and carrier; you can find compatible information in Settings -> Software update."\n      }\n    ]\n  }\n}\n```'}}

# %% [markdown]
# ### Number 14 generate_preventive_qa

# %%
#original
def generate_preventive_qa(text):
    """Failure prevention pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care Q&A with:
    - Best practices - Early warning signs - Monitoring tips
    Format as do's/don'ts lists.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_preventive_qa_deepseek(text):
    """Generates preventive Q&A with risk prioritization in JSON format.

    Returns:
        JSON with nested maintenance categories, severity levels, and action lists.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate failure prevention Q&A from this text with:
    1. Do’s/don’ts for device longevity
    2. Early hardware/software warning signs
    3. Monitoring frequency guidelines

    Format requirements:
    - Return JSON with "Generations" containing:
      {{
        "Question": "...",
        "Answer": {{
          "Do": ["list", "items"],
          "Dont": ["list", "items"]
        }},
        "Category": "Battery/Screen/Software",
        "SeverityLevel": "High/Medium/Low",
        "MonitoringFrequency": "Daily/Weekly/Monthly"
      }}
    - Prioritize entries by SeverityLevel (High first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to prevent battery swelling in Galaxy phones?",
          "Answer": {{
            "Do": ["Use 25W official charger", "Store at 15°-25°C"],
            "Dont": ["Charge overnight", "Use while gaming >1hr"]
          }},
          "Category": "Battery",
          "SeverityLevel": "High",
          "MonitoringFrequency": "Weekly"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse preventive maintenance data"}


#Google AI STudio
def generate_preventive_qa_google(text):
    """Failure prevention pairs in JSON format, accommodating do's/don'ts lists"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care information from the following Samsung support document text.
    Focus on:
    - Best practices for device maintenance and longevity
    - Early warning signs of potential issues
    - Monitoring tips to proactively identify problems

    Format preventive advice primarily as do's and don'ts lists where suitable for clear, actionable guidance. For other information, use Question and Answer pairs.
    Use consumer-friendly language and keep answers concise (1-2 sentences for Q&A, short phrases for do's/don'ts).

    Present the output in JSON format. Structure it to include topics, and for each topic, indicate if it's presented as "DosAndDonts" or "Q&A", and provide the corresponding lists or Q&A pairs.

    Text: {text}

    Output Format (example - model should generate similar structure):
    [
      {{
        "Topic": "Topic Name",
        "Format": "DosAndDonts",
        "Dos": ["Do this...", "Do that..."],
        "Donts": ["Don't do this...", "Don't do that..."]
      }},
      {{
        "Topic": "Another Topic",
        "Format": "Q&A",
        "Questions": ["Question 1...", "Question 2..."],
        "Answers": ["Answer 1...", "Answer 2..."]
      }}
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        preventive_care_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        preventive_care_data = [] # Implement a robust fallback text parsing if needed

    output_json = {
        "Generations": [
            {"PreventiveCareQAPairs": preventive_care_data} # Assuming the model directly outputs the list as in "Output Format"
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_preventive_qa_sonnet(text):
    """Generate structured preventive care Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Best practice identification question",
          "Early warning signs inquiry",
          "Monitoring technique question"
        ],
        "Answers": [
          "Comprehensive best practices explanation",
          "Detailed early warning signs description",
          "Effective monitoring techniques guidance"
        ],
        "Metadata": {{
          "PreventionCategories": ["Best Practices", "Warning Signs", "Monitoring"],
          "ApproachType": "Proactive Care"
        }},
        "DosDonts": {{
          "Dos": ["Recommended actions", "Preventive measures"],
          "Donts": ["Actions to avoid", "Potential risk behaviors"]
        }}
      }}
    }}

    Key Requirements:
    - Provide clear, actionable preventive guidance
    - Include specific, measurable recommendations
    - 1-2 sentence answers
    - Balance technical accuracy with user comprehension

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_preventive_qa ---")
test_qa_generators("generate_preventive_qa", content)
# Out:
# --- generate_preventive_qa ---
#
# --- Calling generate_preventive_qa ---
# Okay, here are preventive care Q&A lists based on the provided text, focusing on best practices, early warning signs, and monitoring tips.  Since the document is a user manual for a phone, the preventive care is geared towards maintaining the device and preventing issues.
#
# **Preventive Care Q&A for Your Device**
#
# **I. Battery Health**
#
# **Do's:**
#
# *   **Use Approved Chargers:**  *DO* use only Samsung-approved batteries, chargers, and cables designed specifically for your device.
# *   **Unplug When Not in Use:** *DO* unplug the charger from the electric socket when not in use to avoid wasting power.
# *   **Charge Properly:** *DO* dry the multipurpose jack thoroughly before charging the device.
# *   **Charge Depleted Batteries Promptly:** *DO* allow a depleted battery to charge for a few minutes before turning on the device.
# *   **Optimize Battery Usage:** *DO* optimize the device using the device care feature.
# *   **Enable Power Saving Mode:** *DO* turn on power saving mode.
# *   **Close Unnecessary Apps:** *DO* close unnecessary apps.
# *   **Disable Unused Features:** *DO* turn off the Bluetooth feature when not in use.
# *   **Manage Auto-Syncing:** *DO* turn off auto-syncing of apps that need to be synced.
# *   **Reduce Backlight Time:** *DO* decrease the backlight time.
# *   **Lower Screen Brightness:** *DO* decrease the screen brightness.
#
# **Don'ts:**
#
# *   **Use Incompatible Components:**  *DON'T* use incompatible batteries, chargers, and cables.
# *   **Charge When Wet:** *DON'T* charge the device while the multipurpose jack is wet.
# *   **Use Damaged Cables:** *DON'T* charge the device with a damaged USB cable.
# *   **Cover Device While Charging:** *DON'T* use the device under cushions, blankets, or in enclosed space and ensure adequate ventilation to prevent heat build-up.
# *   **Expose to Extremes:** *DON'T* expose the device to very cold or very hot temperatures.
#
# **Early Warning Signs of Battery Issues:**
#
# *   **Overheating:**  Device and charger getting excessively hot.
# *   **Slow Charging:**  Significantly longer charging times than usual.
# *   **Rapid Battery Drain:** Battery depleting much faster than previously.
# *   **Swollen Battery:** Physical swelling or deformation of the device (take this *very* seriously and discontinue use immediately).
#
# **Monitoring Tips:**
#
# *   **Check Battery Usage:** Regularly check battery usage stats in *Settings > Battery* to identify power-hungry apps.
# *   **Device Care:** Use the *Device Care* feature to monitor battery health and optimize performance.
#
# **II. General Device Maintenance**
#
# **Do's:**
#
# *   **Clean Regularly:** *DO* clean the device with a soft, dry cloth.
# *    **Handle with Care:** *DO* handle the device carefully.
# *    **Use Screen Protectors:** *DO* use a screen protector to avoid scratches.
#
# **Don'ts:**
#
# *   **Use Sharp Objects:** *DON'T* tap the screen with anything sharp or apply excessive pressure.
# *   **Expose to Liquids:** *DON'T* expose the device to extreme humidity, excessive liquids, or harsh chemicals.
# *   **Modify Software:** *DON'T* attempt to customize the operating system.
# *   **Use Unapproved Accessories:** *DON'T* use unapproved accessories.
#
# **Early Warning Signs of Potential Problems:**
#
# *   **Quiet Sound:** Sound from microphone, speaker, or receiver becoming quiet.
# *   **Screen Flickering:**  Screen flickering or distorted display.
# *   **Touchscreen Issues:** Touch inputs not registering or being inaccurate.
# *   **Connectivity Problems:** Dropped calls or difficulty connecting to Wi-Fi or Bluetooth.
# *   **Random Restarts:** Device randomly restarting.
#
# **Monitoring Tips:**
#
# *   **Check Device Care:** Regularly use the *Device Care* feature to run diagnostics.
# *   **Check for Updates:** Keep the device software updated to the latest version.
# *   **Observe Performance:** Pay attention to any changes in device speed, responsiveness, or battery life.
#
# **III. Water and Dust Resistance**
#
# **Do's:**
#
# *   **Rinse After Exposure:** *DO* rinse the device with fresh water if exposed to unclean water or liquids.
# *    **Dry Thoroughly:** *DO* wipe the device with a soft, clean cloth and dry it thoroughly after exposure to water.
#
# **Don'ts:**
#
# *   **Expose to Forceful Water:** *DON'T* expose the device to water moving with force.
# *   **Expose to Extreme Temperatures:** *DON'T* expose the device to sudden changes in temperature.
# *   **Connect While Wet:** *DON'T* connect the charger or any accessories until the device is completely dry.
# *   **Expose to Pool/Sea Water:** *DON'T* expose the device to swimming pool water or sea water.
#
# **Early Warning Signs of Water Resistance Degradation:**
#
# *   **Visible Damage:**  Cracks or damage to the device casing.
# *   **Moisture Detection:** Error message stating moisture is detected in the charging port.
# *    **Audio Problems:** Sound being muffled or distorted after exposure to water.
#
# **Monitoring Tips:**
#
# *   **Regular Inspection:** Periodically inspect the device for any signs of physical damage that could compromise water resistance.
# *   **Be Mindful of Use:** Avoid using the device in situations where it's likely to be exposed to significant amounts of water or dust.
#
# **IV. Camera Care**
#
# **Do's:**
# *  **Clean Lenses:** *DO* clean the camera lens and try again if pictures you take appear blurry.
#
# **Don'ts:**
# *   **Expose to Strong Light:** *DON'T* expose the camera lens to a strong light source, such as direct sunlight.
#
# **Early Warning Signs of Camera Issues:**
#
# *   **Dots or Spots in Pictures:** Damaged image sensor is irreparable and will cause dots or spots in pictures.
#
# **V. SIM Card Tray Care**
# **Do's:**
#
# *    **Ensure Tray Is Dry:** *DO* Always make sure the tray is dry.
# *    **Fully Insert the Tray:** *DO* Fully insert the tray into the tray slot to prevent liquid from entering your device.
#
# **Don'ts:**
# *    **Insert Tray When Wet:** *DON'T* insert the tray into your device while the tray is wet.
# *    **Use Sharp Objects:** *DON'T* use the ejection pin into the tray’s hole at angles that may damage the device.
#
# **Early Warning Signs of SIM Card Issues:**
#
# *   **Tray Is Not Fixed Firmly:** Card may leave or fall out of the tray, if not properly secured.
#
# **VI. General Phone Usage and Features:**
#
# **Do's**
# *   **Refer to the User Guide:** *DO* read the user guide provided by the manufacturer for proper phone usage, features, maintenance and updates.
# *    **Keep up with Phone and Software Updates:** *DO* check for new firmware updates and perform upgrades when available.
#
# **Don'ts**
# *   **Turn off features on certain situations:** *DON'T* forget to comply to safety measures inside places with posted warnings such as airplanes and hospitals where the use of wireless devices is restricted.
#
# **VII. S Pen (Galaxy S25 Ultra)**
#
# **Do's:**
# *   **Properly Engage & Disengage:** *DO* Press the end of the S Pen to disengage it. Then, pull the S Pen from the slot. To store the S Pen, reinsert it into the slot and push it until it clicks into place.
# *   **Clean S Pen:** *DO* Clean S Pen to remove dust and debris that may accumulate and cause the stylus not to perform properly.
# *   **Use Proper Angle and Pressure:** *DO* Use the S Pen properly and not at sharp angles on the screen.
#
# **Don'ts:**
# *   **Bend or Apply Excessive Pressure:** *DON'T* bend or apply excessive pressure with the S Pen while using it.
# *   **Hard Press on Screen:** *DON'T* hard press on the screen with the S Pen.
# *   **Expose to Magnetism:** *DON'T* let there be a magnet near the device.
# *   **Expose to Water:** *DON'T* let water enters the S Pen slot, remove the water from the slot before using it.
#
# **Early Warning Signs of Issues:**
#
# *   **S Pen is not working properly:** Take S Pen to Samsung Service Centre or an authorised service centre to avoid issues.
#
# I have tried to include the most relevant information from the manual to create these lists. Remember, these are guidelines; always refer to the official Samsung documentation for the most up-to-date and accurate information.
#
#
# --- Calling generate_preventive_qa_deepseek ---
# {'Generations': [{'Question': 'What actions should be avoided to prevent device overheating?', 'Answer': {'Do': ['Disconnect the charger and close running apps', 'Replace a damaged USB cable with a new Samsung-approved one'], 'Dont': ['Store your device in very cold or very hot temperatures', 'Expose your device to direct sunlight for extended periods', 'Store your device near or in heaters, microwaves, hot cooking equipment, or high-pressure containers', 'Use a cable whose covering is peeled off or damaged']}, 'Category': 'General', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'What could happen if I use a broken glass or acrylic body device?', 'Answer': {'Do': ['Get it repaired at a Samsung Service Centre or an authorised service centre'], 'Dont': ['Continue using it']}, 'Category': 'General', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'What should I do if the multipurpose jack is wet before charging the device?', 'Answer': {'Do': ['Thoroughly dry the multipurpose jack before charging the device'], 'Dont': ['Charge the device while the multipurpose jack is wet']}, 'Category': 'Battery', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'What accessories should I use for battery charging to avoid damages?', 'Answer': {'Do': ['Use Samsung-approved battery, charger, and cable specifically designed for your device'], 'Dont': ['Use incompatible battery, charger, and cable']}, 'Category': 'Battery', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'What can I do to make sure that the sound quality of my phone does not degrade?', 'Answer': {'Do': [], 'Dont': ['Allow dust or foreign materials to enter the microphone, speaker, or receiver', 'Cover the microphone, speaker, or receiver']}, 'Category': 'General', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'Weekly'}, {'Question': 'How can I conserve battery power on my device?', 'Answer': {'Do': ['Optimise the device using the device care feature', 'Turn off the screen by pressing the Side button when not in use', 'Turn on power saving mode', 'Close unnecessary apps', 'Turn off the Bluetooth feature when not in use', 'Turn off auto-syncing of apps that need to be synced', 'Decrease the backlight time', 'Decrease the screen brightness'], 'Dont': []}, 'Category': 'Battery', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'Weekly'}, {'Question': 'What should I do if the camera lens is exposed to a strong light source?', 'Answer': {'Do': ['Avoid to expose the camera lens to a strong light source'], 'Dont': []}, 'Category': 'Camera', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'Weekly'}, {'Question': 'What should I do to avoid electrostatic discharges that cause the screen to malfunction?', 'Answer': {'Do': ['Avoid to allow the screen to come into contact with other electrical devices'], 'Dont': []}, 'Category': 'Screen', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'Weekly'}, {'Question': 'What can cause connectivity problems and battery drain?', 'Answer': {'Do': [], 'Dont': ['Attach metallic stickers on the antenna area of the device', 'Attach a device cover made with metallic material to the device', 'Cover the device’s antenna area with your hands or other objects while using certain features, such as calls or the mobile data connection']}, 'Category': 'General', 'SeverityLevel': 'Low', 'MonitoringFrequency': 'Monthly'}, {'Question': 'What are the recommendations to prevent image persistence (screen burn-in) or ghosting?', 'Answer': {'Do': ['Turn off the screen when not using the device', 'Set the screen to turn off automatically when you are not using it'], 'Dont': ['Use fixed graphics on part or all of the screen for extended periods']}, 'Category': 'Screen', 'SeverityLevel': 'Low', 'MonitoringFrequency': 'Monthly'}, {'Question': 'What should I do if the air vent hole is covered by an accessory?', 'Answer': {'Do': ['Avoid to cover the air vent hole with accessories'], 'Do ...
#
# --- Calling generate_preventive_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "PreventiveCareQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_preventive_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What are the recommended battery charging best practices for the Galaxy S25 to maximize its lifespan?",\n      "Are there any early warning signs that my Galaxy S25 battery is degrading or experiencing issues?",\n      "How can I effectively monitor the battery health of my Galaxy S25?"\n    ],\n    "Answers": [\n      "Use only Samsung-approved chargers and cables, preferably the ones that are specifically designed for your device. Avoid exposing your device to extreme temperatures while charging, and unplug the charger when not in use to conserve energy.",\n      "Look for signs like reduced battery life, overheating during charging, or swelling of the battery. You might also notice the phone shutting down unexpectedly, even when the battery indicator shows some charge remaining.",\n      "Use the built-in Device Care feature in the Settings menu to check the battery\'s condition and usage patterns. Apps like AccuBattery from the Play Store offer detailed insights into charging habits and battery wear."\n    ],\n    "Metadata": {\n      "PreventionCategories": ["Best Practices", "Warning Signs", "Monitoring"],\n      "ApproachType": "Proactive Care"\n    },\n    "DosDonts": {\n      "Dos": [\n        "Use only Samsung-approved charger and cable",\n        "Keep the multipurpose jack dry while charging"\n      ],\n      "Donts": [\n        "Use Micro USB cable for charging, it may damage the device",\n        "Use incompatible battery, charger, and cable, it can cause serious injuries or damage to your device"\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 15 generate_accessory_qa

# %%
#original
def generate_structured_accessory_qa(text):
    """Accessory integration pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create accessory Q&A covering:
    - Pairing steps - Compatibility checks - Optimal usage
    Include specific model numbers and SKUs.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_accessory_qa_deepseek(text):
    """Generates accessory Q&A with technical specs in standardized format.

    Returns:
        JSON with nested device models, SKUs, and setup complexity levels.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate accessory integration Q&A from this text with:
    1. Pairing instructions (Bluetooth/USB-C/Wireless Dock)
    2. Compatibility matrices (Galaxy model-to-accessory matching)
    3. Usage best practices (charging limits, cleaning methods)

    Format requirements:
    - Use JSON with "Generations" containing list of:
      {{
        "Question": "...",
        "Answer": "...",
        "DeviceModel": "Galaxy S24 Ultra",
        "SKU": "EJ-TG980BBEGUS",
        "ConnectionType": "Wireless Charging",
        "Complexity": "Medium"
      }}
    - Order by setup complexity (Simple -> Complex)
    - Validate SKUs match Samsung's 10-char alphanumeric format

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to pair Galaxy Buds2 Pro with S23 FE?",
          "Answer": "Open case > tap phone notification > follow in-app steps",
          "DeviceModel": "SM-S711B",
          "SKU": "EI-R510NBEGUS",
          "ConnectionType": "Bluetooth 5.3",
          "Complexity": "Simple"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse accessory integration data"}


#Google AI STudio
def generate_structured_accessory_qa_google(text):
    """Accessory integration pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung accessory integration from the following support document text.
    Focus on:
    - Pairing steps for accessories
    - Compatibility checks between devices and accessories
    - Optimal usage tips and features for accessories

    Whenever relevant, include specific Samsung model numbers and/or SKUs for devices and accessories mentioned.
    Format each question and answer pair clearly. Use consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries in JSON format. Each dictionary should have the keys "Question", "Answer", "Model/SKU". If no specific model or SKU is relevant to a Q&A pair, the "Model/SKU" key can be null or omitted.

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "...", "Model/SKU": "ModelXYZ"}},
      {{"Question": "...", "Answer": "...", "Model/SKU": null}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        qa_list = [] # Implement a robust fallback text parsing as needed

    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair.get("Question") for qa_pair in qa_list],
                "Answers": [qa_pair.get("Answer") for qa_pair in qa_list],
                "Model_SKUs": [qa_pair.get("Model/SKU", None) for qa_pair in qa_list] # Changed key to "Model_SKUs" for clarity in list context
            }
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_structured_accessory_qa_sonnet(text):
    """Generate structured accessory integration Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate accessory Q&A in precise JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Pairing procedure question",
          "Compatibility verification question",
          "Optimal usage inquiry"
        ],
        "Answers": [
          "Detailed pairing steps with specific model guidance",
          "Comprehensive compatibility explanation",
          "Optimal usage recommendations"
        ],
        "Metadata": {{
          "CoverageAreas": ["Pairing", "Compatibility", "Usage"],
          "DetailLevel": "Technical and user-friendly"
        }}
      }}
    }}

    Requirements:
    - Include specific model numbers
    - Provide clear, step-by-step guidance
    - 1-2 sentence answers
    - Technical accuracy with user comprehension

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_accessory_qa_sonnet ---")
test_qa_generators("generate_structured_accessory_qa", content)
# Out:
# --- generate_structured_accessory_qa_sonnet ---
#
# --- Calling generate_structured_accessory_qa ---
# Okay, here's an accessory Q&A based on the provided user guide, aiming to cover pairing, compatibility, and optimal usage.  Since the document doesn't directly discuss specific accessories, the Q&A will be more general, focusing on accessory types the phone *can* use and the troubleshooting related to them.
#
# **Accessory Q&A for Samsung Galaxy S25 Series (SM-S931B, SM-S936B, SM-S938B)**
#
# **Q1: What types of accessories are compatible with my Samsung Galaxy S25?**
#
# A: The Samsung Galaxy S25 series is designed to work with a wide range of accessories, including:
#
# *   **Wired Headphones:** Headphones with a USB Type-C connector are compatible.
# *   **Wireless Headphones/Earbuds:** Bluetooth headphones and earbuds, such as the Samsung Galaxy Buds series, are supported.
# *   **Chargers:** USB Type-C chargers are compatible.  Super Fast Charging and Fast Wireless Charging are supported with compatible chargers.
# *   **Smartwatches/Fitness Trackers:** Samsung Galaxy Watch and other Bluetooth-enabled smartwatches and fitness trackers are compatible.
# *   **DeX-compatible Displays:** Monitors and TVs supporting HDMI input can be used with Samsung DeX via a USB-C to HDMI adapter or wireless connection.
# *   **Cases & Screen Protectors:**  Cases and screen protectors designed specifically for the Galaxy S25 series (and the specific model within the series) are recommended.
# *   **S Pen (S25 Ultra Only):** The Galaxy S25 Ultra is compatible with the S Pen designed for that model.
# *   **Ultra-wideband (UWB) devices (S25 Ultra/Plus):** Certain digital keys for vehicles can be used via UWB.
#
# **Q2: How do I pair Bluetooth headphones or earbuds with my Galaxy S25?**
#
# A: Follow these steps to pair Bluetooth headphones or earbuds:
#
# 1.  **Enable Bluetooth:** On your Galaxy S25, go to Settings > Connections > Bluetooth and turn the Bluetooth switch on.
# 2.  **Put your headphones/earbuds in pairing mode:**  Refer to the user manual of your headphones/earbuds for instructions on how to activate pairing mode (usually involves pressing and holding a button on the headphones/case).
# 3.  **Select the device:** Your Galaxy S25 will scan for available Bluetooth devices. When your headphones/earbuds appear in the list, tap on their name to select them.
# 4.  **Confirm pairing:** You may be prompted to confirm pairing with a PIN or code.  If so, follow the on-screen instructions. Typically, the code is "0000" if required.
#
# **Q3:  My Bluetooth headphones are connected, but the sound quality is poor or intermittent. What can I do?**
#
# A: Try these troubleshooting steps:
#
# *   **Proximity:** Make sure your headphones are within the Bluetooth range (approximately 10 meters or 33 feet) of your phone.
# *   **Obstructions:**  Bluetooth signals can be affected by walls, metal objects, and other sources of interference. Try moving closer to your phone and away from potential obstructions.
# *   **Restart Bluetooth:** Turn Bluetooth off and then back on on both your phone and the headphones.
# *   **Unpair and Repair:** Unpair the headphones from your phone and then repeat the pairing process (see Q2).
# *   **Other Devices:** Make sure your headphones aren’t simultaneously connected to another device.  Some headphones can only maintain one active connection at a time.
# *   **Check for Updates:** Update your Galaxy S25 to the latest software version. Sometimes, Bluetooth connectivity issues are resolved in software updates.
# *   **Check headphones battery level:** Insufficient headphone battery can cause bluetooth connection issues.
#
# **Q4: How do I check if my charger supports Super Fast Charging?**
#
# A: Check the charger's specifications label. It should indicate:
#
# *   **Output Voltage/Amperage:** A Super Fast Charger typically outputs at 9V/2.77A, 5V/3A, or 11V/2.25A.
# *   **Wattage:** The charger should be rated for at least 25W or 45W to support Super Fast Charging on the Galaxy S25 series (depending on model).
#
# If your charger doesn't meet these specifications, it will still charge your phone, but at a slower speed.
#
# **Q5: I'm trying to use Samsung DeX with a USB-C to HDMI adapter, but it's not working. What should I check?**
#
# A: Follow these troubleshooting steps:
#
# 1.  **Compatible Adapter:** Ensure that the USB-C to HDMI adapter is specifically designed to support Samsung DeX. Some adapters may only support basic video output. Use only official Samsung DeX supported accessories that are provided by Samsung.
# 2.  **Cable Connection:** Make sure the HDMI cable is securely connected to both the adapter and the external display (TV or monitor).
# 3.  **Display Input:** Verify that the external display is set to the correct HDMI input source.
# 4.  **Restart DeX:** Disconnect and reconnect the adapter to your phone.  Go to Settings > Connected Devices > Samsung DeX and try starting DeX again.
# 5.  **Alternative Display:** Test with a different external display to rule out a problem with the display itself.
# 6.  **Power Delivery:** If possible, use a USB-C hub that supports Power Delivery (PD) and connect a charger to the hub. This provides additional power that can sometimes be needed for DeX to function correctly.
#
# **Q6: My phone case is interfering with wireless charging. What should I do?**
#
# A:
#
# *   **Remove the case:** Test wireless charging without the case to see if it is the cause of the problem.
# *   **Case Compatibility:** If you need a case, choose one that is specifically designed to be compatible with wireless charging. Look for cases that are thin and don't contain metal or magnets.
# *   **Placement:** Ensure that the center of your phone is aligned with the center of the wireless charging pad.
# *   **Quick charging :** Use a charger that supports wireless quick charging. Also, check if wireless quick charging is turned on.
#     Settings> Battery > Charging setting> Turn on the Quick charging button.
#
# **Q7: How do I know if a screen protector is compatible with the fingerprint sensor on my Galaxy S25?**
#
# A:
#
# *   **"Fingerprint Sensor Compatible" Label:** Look for screen protectors that are specifically labeled as "fingerprint sensor compatible." These protectors are designed with a thin enough material in the fingerprint sensor area to allow it to function correctly.
# *   **Tempered Glass Thickness:** Thinner tempered glass screen protectors generally work better than thicker ones.
# *   **Re-register Fingerprint:** After applying the screen protector, it is recommended to re-register your fingerprints in the phone's settings. This can help the sensor adapt to the slight change in the screen's surface.
#
# **Q8: I’m experiencing battery drain when using accessories, how can I reduce the device consumption ?**
#
# A: You can reduce battery consumption by doing the following:
#
# *   **Optimise** the device using the device care feature.
#
# *   When you are not using the device, **turn off the screen** by pressing the Side button.
#
# *   Turn on **power saving mode.**
#
# *   **Close unnecessary apps**.
#
# *   Turn off the **Bluetooth feature** when not in use.
#
# *   Turn off **auto-syncing** of apps that need to be synced.
#
# *   Decrease the **backlight time**.
#
# *   Decrease the **screen brightness.**
#
# **General Notes:**
#
# *   Always use Samsung-approved accessories when possible.
# *   Consult the user manual of any accessory for its specific instructions and compatibility information.
# *   Keep your device software updated.
# * If problems persist, contact Samsung support.
#
# This Q&A provides a starting point for troubleshooting accessory-related issues with the Galaxy S25 series. It should be helpful for users navigating common compatibility and pairing questions.
#
#
# --- Calling generate_structured_accessory_qa_deepseek ---
# {'Generations': [{'Question': 'How do I use Wireless Power Sharing on my Galaxy S25?', 'Answer': 'Open Settings > Battery > Wireless power sharing > Turn on. Place the other device on the center of your phone, with their backs facing.', 'DeviceModel': 'SM-S931B', 'SKU': 'EP-P9500TWEGUS', 'ConnectionType': 'Wireless Charging', 'Complexity': 'Simple'}, {'Question': 'How to enable and use NFC for payments on my Galaxy S25+?', 'Answer': 'Go to Settings > Connections > NFC and contactless payments > Turn on. Then, touch the back of your device to the NFC card reader.', 'DeviceModel': 'SM-S936B', 'SKU': 'EP-TA800XWEGUS', 'ConnectionType': 'NFC', 'Complexity': 'Simple'}, {'Question': 'Can I use a protective cover while using Wireless Charging with my Galaxy S25 Ultra?', 'Answer': 'Wireless charging may not work smoothly depending on the type of accessory or cover. For stable wireless charging, it is recommended to separate the cover or accessory from the device.', 'DeviceModel': 'SM-S938B', 'SKU': 'GP-FGS908KCAAW', 'ConnectionType': 'Wireless Charging', 'Complexity': 'Medium'}, {'Question': 'How to connect Galaxy S25 Ultra to an external display using Samsung DeX?', 'Answer': 'Open Settings > Connected devices > Samsung DeX > Start DeX. Follow the on-screen instructions. You can use a wireless connection or a USB Type-C to HDMI adapter. Using Samsung-approved accessories is recommended.', 'DeviceModel': 'SM-S938B', 'SKU': 'EE-M5100TBEGUS', 'ConnectionType': 'USB-C, Wireless', 'Complexity': 'Medium'}, {'Question': 'What accessories are officially supported for Samsung DeX on my Galaxy S25 series phone?', 'Answer': 'Use only official Samsung DeX supported accessories that are provided by Samsung. Performance problems and malfunctions caused by using accessories that are not officially supported are not covered by the warranty.', 'DeviceModel': 'SM-S931B', 'SKU': 'EE-MG950TBEGUS', 'ConnectionType': 'Wireless Dock', 'Complexity': 'Medium'}, {'Question': 'Where can I find compatibility information for accessories for my Galaxy S25?', 'Answer': 'For more information about available accessories, refer to the Samsung website.', 'DeviceModel': 'SM-S931B', 'SKU': 'EP-T4510XBEGUS', 'ConnectionType': 'USB-C', 'Complexity': 'Medium'}, {'Question': 'Where can I adjust the fast wireless charging turn off time?', 'Answer': 'Add a routine to set the fast wireless charging feature to turn off automatically at the preset time using Routines.', 'DeviceModel': 'SM-S936B', 'SKU': 'EP-N5200TWEGUS', 'ConnectionType': 'Wireless Charging', 'Complexity': 'Medium'}, {'Question': 'Is there any recommendation regarding USB-C cables when charging Galaxy S25 series?', 'Answer': 'Use only USB Type-C cable supplied with the device. The device may be damaged if you use Micro USB cable.', 'DeviceModel': 'SM-S938B', 'SKU': 'GH39-02070A', 'ConnectionType': 'USB-C', 'Complexity': 'Medium'}]}
#
# --- Calling generate_structured_accessory_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "Questions": [],
#       "Answers": [],
#       "Model_SKUs": []
#     }
#   ]
# }
#
# --- Calling generate_structured_accessory_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I pair my Galaxy Buds 3 Pro with my Samsung Galaxy S25 (SM-S931B) using Bluetooth?",\n      "Is the Samsung 45W charger (EP-T4510) compatible with the fast charging feature on the Galaxy S25 Ultra (SM-S938B/DS)?",\n      "What are the optimal display settings for the Galaxy S25+ (SM-S936B) to minimize screen burn-in while using the Always On Display?"\n    ],\n    "Answers": [\n      "To pair your Galaxy Buds 3 Pro, enable Bluetooth on your Galaxy S25 (SM-S931B) by going to Settings > Connections > Bluetooth. Then, open the Galaxy Buds 3 Pro case to initiate pairing and select your Buds from the available devices list and confirm.",\n      "Yes, the Samsung 45W charger (EP-T4510) is compatible with the Galaxy S25 Ultra (SM-S938B/DS). To enable super fast charging go to Settings > Battery > Charging settings and turn on \'Super fast charging\'. Using a cable rated 3A or higher is required for optimal performance.",\n      "To minimize burn-in on the Galaxy S25+ (SM-S936B), avoid displaying static images on the Always On Display for extended periods and set the Always On Display to only appear when needed in Settings > Lock screen and AOD > Always On Display > When to show."\n    ],\n    "Metadata": {\n      "CoverageAreas": [\n        "Pairing",\n        "Compatibility",\n        "Usage"\n      ],\n      "DetailLevel": "Technical and user-friendly"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 16 generate_legal_qa

# %%
#original
def generate_structured_legal_qa(text):
    """Regulatory/compliance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Q&A with:
    - Certification details - Disposal guidelines - Privacy compliance
    Include regulation numbers and citations.
    Text: {text}
    """)


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_legal_qa_deepseek(text):
    """Generates compliance Q&A with standardized legal references.

    Returns:
        JSON with regulation IDs, full citations, and nested Q&A pairs.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal/compliance Q&A pairs from this text with:
    1. Certification standards (e.g., ISO/IEC numbers)
    2. E-waste disposal regulations (WEEE/RoHS directives)
    3. Privacy frameworks (GDPR, CCPA articles)

    Format requirements:
    - Use strict JSON format with "Generations" as root key
    - Each entry must contain:
      {{
        "Question": "...",
        "Answer": "...",
        "RegulationID": "GDPR Article 12",
        "FullCitation": "Regulation (EU) 2016/679"
      }}
    - Sort by regulation importance (EU directives first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How should I dispose of Samsung batteries?",
          "Answer": "Follow WEEE Directive 2012/19/EU through certified recyclers.",
          "RegulationID": "WEEE Directive",
          "FullCitation": "Directive 2012/19/EU on waste electrical equipment"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse legal compliance data"}


#Google AI STudio
def generate_structured_legal_qa_google(text):
    """Regulatory/compliance pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Question and Answer pairs from the following Samsung support document text.
    Focus on:
    - Certification details (e.g., FCC, CE, UL)
    - Disposal guidelines (e.g., WEEE, battery disposal)
    - Privacy compliance (e.g., GDPR, CCPA)

    Include relevant regulation numbers and/or citations where applicable.
    Format each question and answer pair clearly. Aim for consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries in JSON format. Each dictionary should have the keys "Question" and "Answer". If applicable, include a "Citation" key with the regulation number or citation. If no citation is relevant, the "Citation" key can be null or omitted.

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "...", "Citation": "..."}},
      {{"Question": "...", "Answer": "...", "Citation": null}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        qa_list = [] # Implement a robust fallback text parsing as needed, similar to before.

    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair.get("Question") for qa_pair in qa_list], # Use .get to handle potentially missing keys
                "Answers": [qa_pair.get("Answer") for qa_pair in qa_list],
                "Citations": [qa_pair.get("Citation", None) for qa_pair in qa_list] # Get citation, default None if missing
            }
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet

def generate_structured_legal_qa_sonnet(text):
    """Generate structured legal compliance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Q&A pairs in strict JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Legal question addressing certification",
          "Regulatory compliance question"
        ],
        "Answers": [
          "Detailed answer with specific regulation citations",
          "Precise compliance explanation"
        ],
        "Metadata": {{
          "ComplianceAreas": ["Certification", "Disposal", "Privacy"],
          "RegulationScope": "Comprehensive legal overview"
        }}
      }}
    }}

    Key Requirements:
    - Include precise regulation numbers
    - Cite specific legal standards
    - 1-2 sentence answers
    - Technical but understandable language

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_legal_qa_sonnet ---")
test_qa_generators("generate_structured_legal_qa", content)
# Out:
# --- generate_structured_legal_qa_sonnet ---
#
# --- Calling generate_structured_legal_qa ---
# None
#
# --- Calling generate_structured_legal_qa_deepseek ---
# {'Generations': [{'Question': 'How should I ensure responsible disposal of this Samsung phone at the end of its life?', 'Answer': 'Follow the guidelines outlined in the WEEE (Waste Electrical and Electronic Equipment) Directive 2012/19/EU, ensuring it is recycled through certified facilities.', 'RegulationID': 'WEEE Directive', 'FullCitation': 'Directive 2012/19/EU on waste electrical equipment'}, {'Question': 'Are there any substances restricted in this device as per RoHS?', 'Answer': 'This device complies with the RoHS (Restriction of Hazardous Substances) Directive, restricting the use of certain hazardous materials.', 'RegulationID': 'RoHS Directive', 'FullCitation': 'Directive 2011/65/EU on the restriction of the use of certain hazardous substances in electrical and electronic equipment'}, {'Question': 'How does Samsung process personal data collected by Galaxy AI to deliver features?', 'Answer': 'Samsung offers an option to process Galaxy AI data only on the device to enhance privacy or relies on online processing for better results and data processing. Please see the Galaxy AI settings for details.', 'RegulationID': 'GDPR Article 5', 'FullCitation': 'Regulation (EU) 2016/679'}, {'Question': 'What notification rights do users have regarding the collection of their personal data on this device?', 'Answer': "Samsung's user guide does not outline the rights individuals have with respect to notification regarding the collection and usage of their personal data; this needs to be checked with their privacy policy.", 'RegulationID': 'GDPR Article 12', 'FullCitation': 'Regulation (EU) 2016/679'}, {'Question': 'How do I exercise my right to access my personal data processed by Samsung services?', 'Answer': "Samsung's user guide does not outline the rights individuals have to access, rectify, or erase their data, this needs to be checked with their privacy policy.", 'RegulationID': 'GDPR Article 15', 'FullCitation': 'Regulation (EU) 2016/679'}, {'Question': 'Does the phone design adhere to requirements preventing unauthorized access via biometrics?', 'Answer': 'Fingerprint and facial recognition are provided for convenience; Samsung cannot guarantee the system will always be resistant to determined attempts at unauthorized access. Additional security options are available.', 'RegulationID': 'CCPA Section 1798.100', 'FullCitation': 'California Consumer Privacy Act of 2018'}]}
#
# --- Calling generate_structured_legal_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "Questions": [],
#       "Answers": [],
#       "Citations": []
#     }
#   ]
# }
#
# --- Calling generate_structured_legal_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What certifications are required for wireless chargers marketed for use with this device to ensure proper and safe charging?",\n      "How does the disposal guidance for this device address compliance with regulations like the Waste Electrical and Electronic Equipment (WEEE) Directive (2012/19/EU) or similar e-waste laws in various regions?"\n    ],\n    "Answers": [\n      "Samsung-approved wireless chargers are recommended; using other wireless chargers may result in improper charging, pursuant to safety guidelines detailed within the user manual.",\n      "The user guide does not provide comprehensive disposal guidance, and compliance with e-waste regulations such as the WEEE Directive (2012/19/EU) or equivalent regional laws is not explicitly addressed."\n    ],\n    "Metadata": {\n      "ComplianceAreas": ["Certification", "Disposal", "Privacy"],\n      "RegulationScope": "Comprehensive legal overview"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ##Showing Image

# %%
import requests
from IPython.display import Image, display

# Get the raw image URL.  You can do this in two ways:

# 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL


# 2.  If you know the GitHub URL, you can often construct it manually by replacing "blob" with "raw":
github_image_url = "https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"
raw_image_url_manual = github_image_url.replace("/blob/", "/raw/")

# Now display the image (using either raw_image_url or raw_image_url_manual):

try:
  response = requests.get(raw_image_url, stream=True)
  response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)
  image = Image(response.content)
  display(image)

except requests.exceptions.RequestException as e:
  print(f"Error displaying image: {e}")
except Exception as e:
  print(f"An unexpected error occurred: {e}")


# # 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
# raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL
# #OR (less robust to network issues, but simpler for known good URLs)
# display(Image(raw_image_url))

# %%
from IPython.display import HTML

# 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL

html_code = f"""
<div>
  <img src="{raw_image_url}" alt="Improved Search" width="1000">  <p>This image demonstrates the improved search experience... (your description here)</p>
</div>
"""

display(HTML(html_code))
# Out:
# <div>
#   <img src="https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png" alt="Improved Search" width="1000">  <p>This image demonstrates the improved search experience... (your description here)</p>
# </div>

# %%
# !wget https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png
# Out:
# --2025-03-05 19:31:29--  https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dalle_improved_search.png’
#
# dalle_improved_sear     [ <=>                ] 214.67K  --.-KB/s    in 0.1s
#
# 2025-03-05 19:31:30 (1.52 MB/s) - ‘dalle_improved_search.png’ saved [219825]

# %% [markdown]
# Okay, here's a blog post designed for Confluence, focusing on the different types of QA pairs you can generate from support documentation using a Large Language Model (LLM) like Gemini, along with examples and formatting considerations:
#
# ---
#
# ## Level Up Your Support Docs:  Unlocking the Power of AI-Generated QA Pairs
#
# **Introduction**
#
# Let's face it: traditional support documentation can be... overwhelming.  Long PDFs, endless scrolling, and the frustrating feeling of searching for a needle in a haystack are all too common.  But what if we could make finding answers *instantaneous* and *intuitive*?
#
# That's where AI-powered Question-Answering (QA) pairs come in.  By leveraging a Large Language Model (LLM) like Google's Gemini, we can transform dense technical documentation into a readily accessible knowledge base.  Instead of forcing users to sift through manuals, we can provide direct answers to their specific questions.
#
# This blog post will explore various *types* of QA pairs you can generate, each designed to address different user needs and information-seeking behaviors. We'll use a Samsung Galaxy S25 User Guide as our example document, showcasing the versatility of this approach.  We'll also see how to present these QA pairs in a user-friendly way within Confluence.
#
# **Why Use AI-Generated QA Pairs?**
#
# *   **Improved User Experience:**  Users get direct answers instead of wading through pages of text.
# *   **Faster Resolution Times:**  Reduce the time it takes for users (and support agents!) to find solutions.
# *   **Increased Self-Service:**  Empower users to solve problems independently, freeing up support resources.
# *   **Enhanced Searchability:**  QA pairs create a structured knowledge base that's easily searchable.
# *   **Content Repurposing:**  Transform existing documentation into a more dynamic and engaging format.
#
# **Setting the Stage: Our Example Document**
# All the following examples use the Samsung Galaxy S25 User Guide as the source document.
#
# **QA Pair Types and Examples**
#
# We'll use a consistent format for each example:
#
# *   **Prompt Type:**  A brief description of the prompt's goal.
# *   **Prompt Example:**  The actual prompt we'd feed to the LLM.
# *  **Prompt Description:**  Description of the prompt.
# *   **Generated QA Pairs:**  A sample of the output from the LLM.
# *   **Confluence Formatting Notes:**  Tips for presenting the QA pairs effectively in Confluence.
#
# ---
#
# ### 1. Simple Question-Answer Pairs
#
# *   **Prompt Type:**  General informative Q&A pairs.
# *   **Prompt Example:**
# ```
# Generate fundamental Q&A pairs from Samsung support docs covering:
# Key features Basic troubleshooting Usage guidelines
# Use consumer-friendly language with concise answers (1-2 sentences).
# Text: {text}
# ```
# * **Prompt Description:**
# This prompt generates basic Q&A covering key features, troubleshooting, and usage, using consumer-friendly language.
# *   **Generated QA Pairs:**
#
#     *   **Q: What is Galaxy AI?**
#         *   A: Galaxy AI enhances device usage with intelligent features like real-time call translation and image editing.
#
#     *   **Q: What is Smart Switch and how do I use it?**
#         *   A: Smart Switch lets you easily transfer data from your old phone to your new Samsung device via USB cable or wirelessly.
#
#     *   **Q: My phone won't turn on. What should I do?**
#         *   A: Try charging your phone for at least a few minutes. If it still doesn't turn on, force restart by pressing and holding the Side button and Volume Down button simultaneously.
#
#     *   **Q: How do I take a screenshot?**
#         *    A: Press the Side button and the Volume Down button simultaneously, or swipe the edge of your hand across the screen.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use the **Expand** macro to create collapsible sections for each QA pair. This keeps the page clean and allows users to focus on the questions relevant to them.
#     *   Use **bold** text for the questions to make them stand out.
#     *   Consider using a two-column layout (using the `/columns` macro) to present questions and answers side-by-side for a more compact view.
#
# ---
#
# ### 2. Structured QA Pairs (Problem-Solution Focus)
#
# *   **Prompt Type:**  Problem-solution focused pairs.
# *   **Prompt Example:**
#
# ```
# Create problem-solution pairs from Samsung docs. Format:
# Question: [Issue description]
# Answer: [Step-by-step fix]
# Include severity indicators (!) for critical issues.
# Text: {text}
# ```
#
# * **Prompt Description:**
# This prompts for problem-solution Q&A with severity indicators for critical issues.
# *   **Generated QA Pairs:**
#
#     *   **Question:** ! [Device doesn't turn on]
#         *   **Answer:** When the battery is completely discharged, your device will not turn on. Fully charge the battery before turning on the device.
#
#     *   **Question:** [Others cannot hear you speaking on a call]
#         *   **Answer:**
#             1.  Ensure that you are not covering the built-in microphone.
#             2.  Ensure that the microphone is close to your mouth.
#             3.  If you are using headphones, ensure that they are properly connected.
#
#     *   **Question:** [The battery does not charge properly (For Samsung-approved chargers)]
#         *   **Answer:**
#             1.  Ensure that the charger is connected properly.
#             2.  Visit a Samsung Service Centre or an authorised service centre and have the battery replaced.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to clearly separate the "Question" (problem description) and "Answer" (step-by-step fix).
#     *   Use the **Status** macro (with a red color) to visually represent the "!" severity indicator for critical issues.
#     *   For multi-step answers, use a numbered list within the "Answer" cell of the table.
#
# ---
#
# ### 3. Step-by-Step Procedural Guides
#
# *   **Prompt Type:**  Procedural guidance pairs.
# *   **Prompt Example:**
#
# ```
# Extract step-by-step procedures and generate Q&A pairs with:
# Sequential questions Tool requirements Time estimates
# Format steps with numbered sub-items.
# Text: {text}
# ```
#
# * **Prompt Description:**
# Extracts step-by-step procedures, generating Q&A with questions, tools, and time estimates.
#
# *   **Generated QA Pairs:**
#
#     *   **Procedure:** Charging the Battery
#         1.  **Wired Charging:**
#             1.  Connect the USB cable to the USB power adapter.
#             2.  Plug the cable into the device's multipurpose jack (USB Type-C).
#             3.  After fully charging, disconnect the charger from the device.
#         2.  **Wireless Charging:**
#             1.  Place the center of the device's back on the center of the wireless charger (sold separately).
#             2.  After fully charging, disconnect the device from the wireless charger.
#
#     *   **Q&A:**
#         *   **Q1:** What is the first step in charging the device via a wired connection?
#             *   **A1:** Connect the USB cable to the USB power adapter.
#         *   **Q2:** What tools are needed for wired charging?
#             *   **A2:** USB cable, USB power adapter.
#         *   **Q5:** How long does it take to charge the battery?
#             *   **A5:** The estimated charging time will appear on the notification panel. The actual charging time assumes normal conditions.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a top-level heading for the overall procedure (e.g., "Charging the Battery").
#     *   Use subheadings for different methods (e.g., "Wired Charging," "Wireless Charging").
#     *   Use numbered lists for each step within a procedure.
#     *   Create a separate section for the Q&A, using the Expand macro or a table as described above.
#
# ---
#
# ### 4. Anticipated User Questions (FAQs)
#
# *   **Prompt Type:** Anticipated user questions.
# *   **Prompt Example:**
#
# ```
# Predict common FAQs from Samsung users based on this text.
# Phrase questions as natural customer inquiries.
# Include 'Why', 'How', and 'What if' scenarios.
# Text: {text}
# ```
# * **Prompt Description:**
# Predicts common FAQs, phrased as natural customer inquiries, including 'Why', 'How', and 'What if' scenarios.
# *   **Generated QA Pairs:**
#
#     *   "How do I turn my new Galaxy S25 on for the first time?"
#     *   "Where is the SIM card slot on my Galaxy S25+?"
#     *   "How do I transfer all my stuff from my old phone to my new Galaxy S25?"
#     *   "Why isn't my phone charging when I plug it in?"
#     *  "What if my phone gets wet? Is it really waterproof?"
#     *   "How do I download new apps onto my phone?"
#     *   "How can I make contactless payments with my phone?"
#     *   "How do I change the wallpaper on my home screen?"
#     *    "What if my phone isn't connecting to Wi-Fi?"
#     *   "How do I use Call Assist to translate phone calls in real-time?"
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a heading like "Frequently Asked Questions (FAQs)".
#     *   Use the Expand macro or a simple bulleted list for each question, followed by the answer.  This format is very common for FAQs.
#
# ---
#
# ### 5. Troubleshooting Guides
#
# *   **Prompt Type:**  Diagnostic-focused pairs.
# *   **Prompt Example:**
# ```
# Create advanced troubleshooting pairs including:
# Error symptoms Diagnostic checks Repair procedures
# Format solutions with priority levels (Critical/High/Medium).
# Text: {text}
# ```
# * **Prompt Description:**
# Creates advanced troubleshooting Q&A, with error symptoms, diagnostics, and repair procedures.
#
# *   **Generated QA Pairs:**
#
#     *   **Pair 1: Device Not Turning On**
#         *   **Error Symptom:** Device completely unresponsive, screen remains black, no lights or sounds when attempting to power on.
#         *   **Diagnostic Checks:**
#             1.  **Critical:** Check battery level. Connect the device to a known working charger and power outlet. Allow the device to charge for at least 30 minutes.
#             2.  **Critical:** Force Restart.  Press and hold the Side button and Volume Down button simultaneously for more than 7 seconds.
#             3.  **Medium:** Check the charging port for debris or damage.  Inspect the USB-C port for bent pins, lint, or other obstructions.
#         *   **Repair Procedures:**
#             1.  **Critical:** If the device starts after charging, monitor the charging behavior. Replace the charging cable and power adapter if necessary.
#             2.  **Critical:** If the device still fails to power on after charging and attempting a force restart, the battery may be faulty or there may be a hardware issue.  Seek professional repair at a Samsung Service Centre or authorized repair provider.
#             3.  **Medium:** If the charging port is damaged, professional repair/replacement is necessary. *Do not attempt to repair the charging port yourself.*
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a heading like "Troubleshooting".
#     *   Use a table with columns for "Error Symptom," "Diagnostic Checks," and "Repair Procedures."
#     *   Use the Status macro (with appropriate colors) to indicate priority levels (Critical, High, Medium).
#     *   Use numbered lists within the "Diagnostic Checks" and "Repair Procedures" columns.
#
# ---
# ### 6. Feature Explanation
#
# *   **Prompt Type:** Technology deep-dive pairs.
# *   **Prompt Example:**
# ```
# Explain Samsung technologies with Q&A pairs covering:
# Technical specifications Use cases Compatibility notes
# Include diagrams in markdown when relevant.
# Text: {text}
# ```
# *   **Prompt Description:**
# Explains Samsung technologies with Q&A, covering specs, use cases, and compatibility.
#
# *   **Generated QA Pairs:**
#
#     *   **1. Display Technology (Motion Smoothness):**
#         *   **Q:** What is "Motion Smoothness" on Samsung phones, and what are the technical differences between the available options?
#         *   **A:** Motion Smoothness refers to the refresh rate of the display, measured in Hertz (Hz). A higher refresh rate makes motion appear smoother, especially when scrolling or playing games.
#             *   **Adaptive:** Automatically adjusts the screen refresh rate to a higher one (likely 120Hz) for smoother animations and scrolling, and a lower one (likely 60Hz) to conserve battery when the screen content is static.
#             *   **Standard:** Uses a standard refresh rate (likely 60Hz) to conserve battery power.
#             * Use Cases
#                 *   **Adaptive:** Best for gaming, watching fast-paced videos, or any scenario where smooth visuals are important.
#                 *   **Standard:** Suitable for everyday use, reading, or when battery life is a priority.
# *   **Confluence Formatting Notes:**
#     * Use headings to group related technology explanations.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
#
# ### 7. Setup/Installation Guides
# * **Prompt type:** Installation/Configuration Pairs
# * **Prompt Example:**
# ```
# Generate setup-related Q&A with:
# Pre-installation checks Configuration options Post-setup tests
# Include recommended settings for different user types.
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates Q&A for setup, with pre-installation, configuration, and post-setup steps.
#
# *   **Generated QA Pairs:**
#     *   **I. Pre-Installation Checks Q&A:**
#         *   **Q: What should I do before using the device for the first time?**
#             *   **A:** Charge the battery fully. It's recommended to charge it before first use, especially if it's been unused for a while.
#         *   **Q: Are there any potential problems when the sim tray is wet?**
#            *   **A:** Yes, if you insert the SIM tray while it is wet, it may cause damage to your device. Ensure that the tray is completely dry before inserting it.
#         *   **Q: What type of SIM card does this device use?**
#             *   **A:** It uses a nano-SIM card. Additionally, it may support eSIM functionality depending on the region, carrier, and model.
#
#     *   **II. Configuration Options Q&A:**
#         *   **Q: How do I turn on the device for the first time?**
#             *   **A:** Press and hold the Side button for a few seconds.
#         *   **Q: How do I complete the initial setup?**
#             *   **A:** Follow the on-screen instructions after turning on the device. You'll be prompted to connect to a Wi-Fi network, sign in to your Google account, and set up other preferences.
#         *  **Q: How do I transfer data from my old device?**
#             * **A:** Use Smart Switch. Go to Settings > Accounts and backup > Transfer data for device setup.  You can transfer data wirelessly or using a USB cable.
#         *   **Q: How do I set up a Samsung account?**
#             *   **A:** Go to Settings > Sign in to your Galaxy (or Accounts and backup > Manage accounts > Add account > Samsung account). Follow the on-screen instructions.
#         *   **Q: How do I download an eSIM?**
#             *   **A:** Open Settings and tap Connections → SIM manager → Add eSIM.  You may need a QR code from your carrier.
#     *  **III. Post-Setup Tests & Verification Q&A:**
#         *   **Q: How do I verify that Wi-Fi is working correctly?**
#             *   **A:** Go to Settings > Connections > Wi-Fi. Ensure Wi-Fi is turned on and connected to your network. Open a web browser and try loading a website.
#         *   **Q: How do I test the screen touch responsiveness?**
#             *   **A:** Open the dialer app and type `#0#`. The options for different tests are available.
#         *   **Q: How can I reset my device?**
#             *   **A:** To reset your device, perform a factory data reset. Open Settings and tap General management → Reset → Factory data reset. *Warning: This will erase all data on your device.*
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
# ### 8. Error Code Explanations
# * **Prompt type:** Error code explanation.
# * **Prompt Example:**
# ```
# Create error code Q&A with:
# Code interpretations Immediate actions
# Format codes in bold with severity colors (
#
# ).
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates Q&A for errors, with interpretations, actions, and colored severity indicators.
# *   **Generated QA Pairs:**
#
#     *   ### **ERROR 001: Device Overheating**
#         *   **Code Interpretation:** The device has exceeded a safe operating temperature threshold. This can be triggered by intensive use, high ambient temperatures, or a potential hardware issue.
#         *   **Immediate Actions:**
#             1.  Stop using the device immediately.
#             2.  Disconnect the charger if connected.
#             3.  Close all running apps.
#             4.  Move the device to a cooler environment.
#             5.  Allow the device to cool down completely before resuming use.
#         *   **Service Triggers:**
#             *   If the overheating persists even with minimal use and in a cool environment.
#             *   If the device displays warning messages about overheating despite not being used heavily.
#             *   If the device shuts down unexpectedly due to overheating.
#             *   If physical damage to the device is suspected to be the cause of the overheating.
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
#
# ### 9. Safety and Compliance
#
# * **Prompt Type:**  Safety/compliance pairs
# *   **Prompt Example:**
#
# ```
# Generate safety Q&A covering:
# Hazard prevention Compliance standards Recall information
# Use warning boxes for critical items.
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates safety Q&A, covering hazards, compliance, and recalls, with warning boxes for critical items.
#
# *   **Generated QA Pairs:**
#     *   **Q: Is it safe to use the speakers close to my ears?**
#         *   A: When using the speakers, such as when playing media files or using speakerphone, do not place the device close to your ears. Prolonged exposure to loud audio can damage your hearing.
#     *   **Q: What should I do if the glass or acrylic body of the device is broken?**
#         *   A: If you use the device with its glass or acrylic body broken, there may be a risk of injury. Use the device only after it has been repaired by a Samsung Service Centre.
#     *  **Q: What should I do if dust or foreign materials enter the microphone, speaker, or receiver?**
#         *   A: If dust or foreign materials enter the microphone, speaker, or receiver, or if these parts are covered, the device's volume or call quality may be affected.  Do not insert sharp objects into the microphone, speaker, or receiver.
#     *    **Q: Can metallic stickers or covers affect connectivity or battery life?**
#         *    A: Yes, connectivity problems and battery drain may occur if you attach metallic stickers on the antenna area, use metallic phone cases, or non-Samsung-approved covers.
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
# ---
# ### 10. Device Compatibility
# * **Prompt Type:** Device compatibility pairs
# * **Prompt Example:**
# ```
# Create compatibility Q&A with:
# Supported models - Version requirements - Regional variations
# Present compatibility as tables when possible.
# Text: {text}
# ```
# *   **Prompt Description:**
# Creates Q&A on compatibility, with models, versions, and regional variations, using tables when possible.
#
# *   **Generated QA Pairs:**
#
#     *   **Supported Models:** SM-S931B, SM-S931B/DS, SM-S936B, SM-S936B/DS, SM-S938B, SM-S938B/DS.
#     *   **Version Requirements:** The text mentions *English 01/2025 Rev1 0*, which indicates software/documentation versioning, but doesn't explicitly list minimum OS requirements for features.
#     *   **Regional Variations:** The document mentions that some features are region-dependent.
#
#     *   **Compatibility Q&A:**
#         *   **General Device Support**
#             *   **Q: Which phone models does this user guide cover?**
#                 *   **A:** This user guide is applicable to the following Samsung Galaxy models:
#                     *   SM-S931B
#                     *   SM-S931B/DS
#                     *   SM-S936B
#                     *   SM-S936B/DS
#                     *   SM-S938B
#                     *   SM-S938B/DS
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to clearly present compatibility information.  Columns could include "Model," "Supported Feature," "Minimum OS Version," "Regional Availability," and "Notes."
#     *   If there are many compatibility variations, consider creating separate tables for different feature categories (e.g., "Connectivity Features," "Multimedia Features").
#
# ---
# ### 11. Preventive Maintenance
# *   **Prompt Type:** Preventive care pairs.
# *   **Prompt Example:**
#
# ```
# Generate maintenance Q&A including:
# Service intervals - Cleaning procedures - Part replacements
# Add maintenance checklists with timelines.
# Text: {text}
# ```
#
# *   **Prompt Description:**
# Generates maintenance Q&A, including intervals, cleaning, replacements, and checklists with timelines.
#
# * **Generated QA Pairs**
#      *   **Q: How often should I service my Galaxy S25 device?**
#         *   **A:** While there are no specific "service intervals" in the traditional sense for smartphones (like with a car), regular maintenance is crucial for optimal performance and longevity.
#             *   Check for software updates regularly (Settings > Software update).
#             *   Monitor battery health and performance (Settings > Battery > Battery Information).
#             *   Utilize the Device Care feature to optimize performance (Settings > Device care).
#
#     *   **Q: What's the best way to clean my Galaxy S25 device?**
#         *   **A:**
#             1.  **Power Off:** Turn off your device before cleaning.
#             2.  **Microfiber Cloth:** Use a soft, lint-free microfiber cloth to wipe the exterior surfaces (screen, back, sides). Avoid abrasive materials like paper towels.
#             3.  **Avoid Liquids:** Do not spray liquids directly onto the device. If necessary, *lightly* dampen the microfiber cloth with distilled water. *Never* use harsh chemicals, solvents, or abrasive cleaners.
#             4.  **Ports and Openings:** Use a dry, soft brush (like a clean toothbrush) or compressed air to gently remove dust and debris from the charging port, speaker grilles, and other openings.
#             5.  **Camera Lens:** Clean the camera lens with a lens cloth designed for optics. Avoid abrasive materials.
#             6.  **S Pen (S25 Ultra):** Clean the S Pen with a dry cloth. Ensure no debris is lodged in the S Pen slot.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to organize maintenance tasks, intervals, and any specific instructions.
#     *   Include a "Notes" column for additional tips or warnings.
#     *   Consider using the Checklist macro for recurring tasks.
#
# ---
# ### 12. Warranty and Service
#
# *   **Prompt Type:** Warranty/service pairs
# *   **Prompt Example:**
#
# ```
# Create warranty Q&A covering:
# Coverage details Claim processes Void conditions
# Include regional policy variations.
# Text: {text}
# ```
# *Prompt Description*
# Creates Q&A about warranties, claims, void conditions, and regional variations.
# *Confluence Formating Notes*
# *   Organize information using headings and subheadings (e.g., "Warranty Coverage," "Making a Claim," "Warranty Void Conditions").
# *   Use bullet points to list key details.
# *   If regional variations are extensive, create separate sections or tables for each region.
# *   Provide links to the official Samsung warranty information page for your target region.
#
# ---
#
# **Conclusion**
#
# By strategically using different types of prompts, you can leverage the power of LLMs to create a comprehensive and user-friendly QA knowledge base from your existing support documentation.  This not only improves the user experience but also streamlines support operations and empowers users to find answers quickly and efficiently. Remember to always review and refine the AI-generated content to ensure accuracy and clarity.  This approach allows you to transform static documentation into a dynamic, searchable, and highly effective self-service resource.
