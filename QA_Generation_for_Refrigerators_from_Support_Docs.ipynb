# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Deep-Learning-Experiments-implemented-using-Google-Colab/blob/master/QA_Generation_for_Refrigerators_from_Support_Docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Say Goodbye to Endless Scrolling! Introducing AI-Powered Search for Support Docs
#
# **Headline: Stop Searching, Start Finding: Introducing Revolutionary AI-Powered Search for Support Documentation**
#
# ![dalle_improved_search.png](data:image/png;base64,...)
#
#
#
#
#
# **(Banner Image:  A visually appealing image representing fast and efficient search, perhaps an icon of a magnifying glass zooming in on a page number, or a person happily finding an answer on their phone/computer)**
#
#
#
# [illustrative image link](https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png)

# %% [markdown]
# ##Introduction
#
# Are you tired of spending precious minutes (or even hours!) wrestling with lengthy user manuals, just to find a simple answer to your question?  We know the frustration!  That's why we're thrilled to announce a game-changing improvement to how you access support information for your Galaxy devices: **Introducing AI-Powered Question Answering Search!**
#
# Forget shifting through entire PDFs and hoping to stumble upon the right paragraph.  Finding the help you need for your Samsung devices support docs just became dramatically faster, smarter, and more user-friendly.
#
# **Introducing Question-Based Search: Ask Naturally, Get Answers Directly**
#
# The days of guessing the right keywords are over!  Our brand new search engine is intelligent enough to understand your questions phrased in **natural, everyday language.**  Instead of struggling with technical jargon, simply **ask your question just like you would ask a support agent.**
#
# **Let's look at some examples:**
#
# Instead of typing:  `battery slow drain fix`
#
# Now, you can simply ask: **"Why is my phone battery draining so fast?"**
#
# Instantly, our AI-powered search engine dives deep into the support documentation and pulls out the **precise, most relevant answer**, presented to you directly:
#
# > **Answer:** Several factors can contribute to rapid battery drain, including using power-intensive apps (like games or video streaming), high screen brightness, always-on display, background app activity, and poor network signal strength. Optimizing your device settings and closing unnecessary apps can help improve battery life.
#
# **(Screenshot/Mockup:  Example search bar showing a natural language question and the concise answer displayed below)**
#
# No more wading through pages of text! Get straight to the point and find the solution you need in seconds.
#
# **Page Number Deep Linking:  Context is King - Dive Deeper When You Need To**
#
# But we didn't stop at just giving you quick answers. We understand that sometimes you need more context, detailed instructions, or want to explore related information. That's where our **revolutionary Page Number Deep Linking** comes in.
#
# Each AI-powered answer is **hyperlinked directly to the exact page number** within the official User Guide where that information originates.  Want to see the step-by-step guide, explore related tips, or understand the surrounding context?
#
# **Simply click the link, and you'll be instantly transported to the relevant page within the document.**
#
# **(Screenshot/Mockup: Example answer with a clearly visible page number link highlighted)**
#
# This powerful feature seamlessly bridges the gap between instant answers and comprehensive documentation, giving you the best of both worlds – speed and depth, all at your fingertips.
#
# **Goodbye Keyword Guesswork, Hello Intelligent Answers: A Leap Beyond Basic Search**
#
# Our previous keyword search, while helpful in its own way, could sometimes feel like searching for a needle in a haystack.  You'd often get a list of PDFs, and then the real work began – manually scanning each document to find your specific answer.
#
# **Here's how our new AI-Powered Search dramatically improves on traditional search methods like Elasticsearch:**
#
# | Feature                  | **Old Keyword Search (e.g., Elasticsearch)**                                   | **New AI-Powered Question Answering Search**                                     | **Benefit**                                                                  |
# | :----------------------- | :--------------------------------------------------------------------------- | :------------------------------------------------------------------------------- | :--------------------------------------------------------------------------- |
# | **Query Type**          | Keyword-based only                                                           | Natural language questions                                                     | More intuitive and user-friendly querying                                     |
# | **Search Results**       | List of PDFs or document sections, often requiring manual scanning           | Direct answers extracted from documents, displayed concisely                         | Faster access to relevant information, eliminates manual document sifting       |
# | **Relevance**            | Can be less precise, returning documents only tangentially related           | Highly relevant answers, focused on directly addressing the user's question        | More accurate and targeted results                                           |
# | **Navigation**           | PDF-level results, users must manually navigate within documents             | Page-level deep links, users jump directly to the answer's source in the document | Significantly faster navigation to detailed context and related information     |
# | **User Experience**      | Can be time-consuming and frustrating, especially for complex queries         | Fast, efficient, and intuitive, leading to a much smoother support experience    | Improved user satisfaction and self-service adoption                         |

# %% [markdown]
# ##Real-World Scenarios: See AI-Powered Search in Action
#
# Let's walk through a couple of common support scenarios to illustrate the power of this new feature:
#
# **Scenario 1: Maximizing Battery Life**
#
# *   **User Question:** "How do I conserve battery life on my Galaxy S25?"
# *   **AI-Powered Search Answer:** (Concise answer summarizing battery saving tips, with a clear link)
# *   **Result:** The user gets an immediate, actionable answer. Clicking the link takes them directly to **Page 14 of the User Guide**, where they can find detailed instructions on Power Saving Mode, closing background apps, adjusting screen brightness, and more.
#
# **(Screenshot/Mockup: Search interface showing "How do I conserve battery life..." question and answer with page 14 link)**
#
# **Scenario 2: Setting Up Wireless Power Sharing**
#
# *   **User Question:** "How do I use wireless power sharing to charge my Galaxy Buds?"
# *   **AI-Powered Search Answer:** (Concise answer explaining Wireless PowerShare, with a clear link)
# *   **Result:** The user receives quick instructions. Clicking the link navigates them to **Page 13 of the User Guide**, providing step-by-step guidance on enabling and using Wireless Power Sharing, along with important precautions.
#
# **(Screenshot/Mockup: Search interface showing "How do I use wireless power sharing..." question and answer with page 13 link)**
#
# **The Future is Intelligent Support: Ongoing Improvements**
#
# This launch is just the beginning of our journey to revolutionize support document accessibility! We're committed to continuously enhancing this AI-powered search experience.  Looking ahead, we're actively working on:
#
# *   **Semantic Search Enhancements:**  Making the search engine even smarter at understanding the *meaning* behind your questions, regardless of wording.
# *   **Expanding the QA Knowledge Base:**  Adding thousands more Question-Answer pairs to cover even more topics and Galaxy devices.
# *   **Answer Summarization directly in Search Results:** Providing even more concise answer previews directly within the search results, for ultimate speed.
#
# **Ready to Experience the Future of Support?**
#
# Don't waste another minute struggling to find answers!  **Try out our new AI-Powered Search today!** Visit our [**Link to your Support Documentation Portal Here**] and ask your Galaxy S25 questions in your own words.
#
# We're eager to hear your feedback! Let us know what you think and how we can make this feature even more valuable for you.  Your input will help us shape the future of intelligent support.
#
# **Conclusion:  Find Answers Faster, Get Back to Enjoying Your Galaxy**
#
# AI-Powered Search is a true game-changer for accessing support. It's designed to save you time, reduce frustration, and empower you to quickly resolve your questions and get back to enjoying your Galaxy S25 device.  We're confident you'll love the speed, efficiency, and user-friendliness of this exciting new feature. Happy searching!
#
# **(Footer: Samsung logo and copyright information)**

# %% [markdown]
# ## Extracting text from PDFs using pymupdf4llm

# %%
# !pip install pymupdf4llm==0.0.17 > /dev/null 2>&1

# %%
# !wget https://downloadcenter.samsung.com/content/UM/202501/20250124164253078/SM-S93X_UG_EU_15_Eng_Rev.1.0_250123.pdf

# %%
# !wget https://downloadcenter.samsung.com/content/UM/202212/20221216130939356/FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf
# Out:
# --2025-03-08 18:23:10--  https://downloadcenter.samsung.com/content/UM/202212/20221216130939356/FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf
# Resolving downloadcenter.samsung.com (downloadcenter.samsung.com)... 23.59.111.28
# Connecting to downloadcenter.samsung.com (downloadcenter.samsung.com)|23.59.111.28|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32152606 (31M) [application/pdf]
# Saving to: ‘FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf’
#
# FDR_RF8000B_DA68-04 100%[===================>]  30.66M  21.6MB/s    in 1.4s
#
# 2025-03-08 18:23:12 (21.6 MB/s) - ‘FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf’ saved [32152606/32152606]

# %%
import pymupdf4llm

markdwon_text = pymupdf4llm.to_markdown('/content/FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf') # 36" BESPOKE 4 Door French Door Refrigerator with Beverage Center
# Out:
# Processing /content/FDR_RF8000B_DA68-04402B-01_EN_MES_CFR.pdf...
# ]

# %%
generated_text = markdwon_text
content = markdwon_text
generated_text
# Out:
# '##### User manual\n\n###### Free Standing Appliance\n\n\n# Refrigerator\n\n\n-----\n\n### Contents\n\n###### Safety information 4\n\n What you need to know about the safety instructions 4 Important safety symbols and precautions: 5 State of California Proposition 65 Warning 5 Important safety precautions 5 Severe warning signs for transportation and site 7 Critical installation warnings 8 Installation cautions 9 Critical usage warnings 10 Usage cautions 12 Cleaning cautions 13 Critical disposal warnings 14\n\n\n###### Installation 15\n\n Refrigerator at a glance 16 Step-by-step installation 19\n\n Operations 36\n\n Main panel 36 SmartThings 42 SMART GRID Function (Demand Response, applicable models only) 45 Special features 48\n\n\n###### Maintenance 56\n\n Handling and care 56 Cleaning 64 Replacement 65\n\n Troubleshooting 68\n\n General 68 Do you hear abnormal sounds from the refrigerator? 72 SmartThings 74 Smart Grid (applicable models only) 75\n\n\n###### LIMITED WARRANTY (U.S.A.) 76\n\n SAMSUNG REFRIGERATOR 76\n\n 2 English\n\n\n-----\n\n###### Warranty Information (CANADA) 79\n\n If your refrigerator needs service 79 Limited Warranty for Original Purchaser 79 Obligation to the Original Owner 80 Exclusions of the Warranty 80\n\n Regulatory Notice 81\n\n FCC Notice 81 IC Notice 82\n\n\n###### Open Source Announcement 83\n\n English 3\n\n\n-----\n\n### Safety information\n\n###### Before using your new Samsung Refrigerator, please read this manual thoroughly to ensure that you know how to operate the features and functions that your new appliance offers safely and efficiently.\n\n\n###### What you need to know about the safety instructions\n\n\n\n###### • This appliance is not intended for use by persons (including children) with reduced\n physical, sensory or mental capabilities, or lack of experience and knowledge, unless they have been given supervision or instruction concerning use of the appliance by a person responsible for their safety. Children should be supervised to ensure that they do not play with the appliance.\n • Because the following instructions cover various models, the characteristics of your\n refrigerator may differ slightly from the refrigerator described in this manual.\n • If you have any question, contact us at 1-800-SAMSUNG or find help and information\n online at www.samsung.com.\n • Refrigerant squirting out of the pipes could ignite or cause an eye injury. When\n refrigerant leaks from the pipe, avoid any naked flames and move anything flammable away from the product and ventilate the room immediately.\n - Failing to do so may result in fire or explosion.\n • Improper use of the grounding plug can result in a risk of electric shock. If it is\n necessary to use an extension cord, use only a 3-wire extension cord that has a 3-blade grounding plug and a 3-slot receptacle that will accept the plug on the appliance. The marked rating of the extension cord should be AC 115-120 V, 10 A, or more. If a grounding adapter is used, make sure the receptacle box is fully grounded.\n\n 4 English\n\n\n-----\n\n###### Important safety symbols and precautions:\n\n Please follow all safety instructions in this manual. This manual uses the following safety symbols.\n\n\n###### WARNING\n\n\n###### Hazards or unsafe practices that may result in severe personal injury, property damage, and/or death.\n\n CAUTION\n\n\n###### Hazards or unsafe practices that may result in severe personal injury and/or property damage.\n\n NOTE\n\n\n###### Useful information that helps users understand or benefit from the refrigerator. These warning signs are here to prevent injury to you and others. Please follow them carefully. After reading this section, keep it in a safe place for future reference.\n\n State of California Proposition 65 Warning\n\n\n###### WARNING\n Cancer and Reproductive Harm - www.P65Warnings.ca.gov.\n\n\n###### Important safety precautions\n\n Warning; Risk of fire / flammable materials\n\n\n###### WARNING\n\n\n\ ...

# %%
def test_qa_generators(base_function_name, content, suffixes=["", "_deepseek", "_google", "_sonnet"]):
    """Tests and prints output for different QA generation functions."""
    for suffix in suffixes:
        function_name = base_function_name + suffix
        try:
            qa_function = globals()[function_name] # Get function from global scope
            print(f"\n--- Calling {function_name} ---")
            qa_output = qa_function(content)
            print(qa_output)
        except KeyError:
            print(f"\n--- Function {function_name} not found ---")
        except Exception as e:
            print(f"\n--- Error in {function_name} ---")
            print(f"Error details: {e}")

# %%
def test_qa_generators_aggregated(base_function_name, content, suffixes=["", "_deepseek", "_google", "_sonnet"]):
    """
    Tests different QA generation functions and returns aggregated results in a single JSON structure.

    Args:
        base_function_name (str): Base name of the QA generation function
        content (str): Content to process
        suffixes (list): List of suffixes for different model variants

    Returns:
        dict: Aggregated results with the following structure:
        {
            "base_function": str,
            "results": {
                "model_variant": result_dict,
                ...
            },
            "errors": {
                "model_variant": error_message,
                ...
            }
        }
    """
    aggregated_results = {
        "base_function": base_function_name,
        "results": {},
        "errors": {}
    }

    for suffix in suffixes:
        function_name = base_function_name + suffix
        model_variant = suffix if suffix else "default"

        try:
            qa_function = globals()[function_name]  # Get function from global scope
            qa_output = qa_function(content)
            aggregated_results["results"][model_variant] = qa_output

        except KeyError:
            error_msg = f"Function {function_name} not found"
            aggregated_results["errors"][model_variant] = error_msg

        except Exception as e:
            error_msg = f"Error in execution: {str(e)}"
            aggregated_results["errors"][model_variant] = error_msg

    return aggregated_results

# Example usage and pretty printing
import json

def print_aggregated_results(results):
    """Helper function to pretty print the aggregated results."""
    print(json.dumps(results, indent=2))

# %% [markdown]
# ## QA Pair Generation using Gemini *API*

# %%
import google.generativeai as genai
from google.colab import userdata
apikey=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=apikey)

# %% [markdown]
# ### Number 1 generate_structured_qa_pairs

# %%
#original
def generate_simple_qa_pairs(text):
    """General informative Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate fundamental Q&A pairs from Samsung support docs covering:
    - Key features - Basic troubleshooting - Usage guidelines
    Use consumer-friendly language with concise answers (1-2 sentences).
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent
import google.generativeai as genai

def generate_simple_qa_pairs_deepseek(text):
    """Generates Q&A pairs in a standardized JSON format.

    Returns:
        A JSON object with nested "Generations", "Questions", and "Answers".
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Q&A pairs from the Samsung support document below.
    Follow these rules:
    1. Include key features, troubleshooting steps, and usage guidelines.
    2. Use short, conversational questions and answers (1-2 sentences).
    3. Format output as JSON with a "Generations" key containing a list of Q&A objects.
    4. Structure each object as {{"Question": "...", "Answer": "..."}}.

    Example:
    {{
      "Generations": [
        {{"Question": "How do I restart my Galaxy phone?", "Answer": "Hold the power and volume down buttons for 10 seconds."}},
        {{"Question": "How to extend battery life?", "Answer": "Enable Power Saving Mode in Settings > Battery."}}
      ]
    }}

    Text: {text}
    """)

    response = model.generate_content(prompt).text
    # Remove markdown formatting (common in Gemini outputs)
    response = response.strip("` \n").replace("json", "")
    return json.loads(response)


#Google AI STudio
import google.generativeai as genai
from textwrap import dedent
import json

def generate_simple_qa_pairs_google(text):
    """
    Generates informative Q&A pairs from Samsung support docs and returns them in JSON format.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate fundamental Question and Answer pairs from the following Samsung support document text.
    Focus on:
    - Key features
    - Basic troubleshooting steps
    - Usage guidelines

    Format each question and answer pair clearly. Aim for consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries. Each dictionary should have the keys "Question" and "Answer".

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "..."}},
      {{"Question": "...", "Answer": "..."}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text) # Attempt to parse the response as JSON
    except json.JSONDecodeError:
        # If direct JSON parsing fails, fallback to a more robust extraction method
        print("Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.")
        # This fallback is a basic example, you might need more sophisticated parsing
        qa_list = []
        lines = response_text.strip().split('\n')
        for i in range(0, len(lines), 2): # Assuming Q and A alternate lines
            if i + 1 < len(lines):
                question = lines[i].strip().replace("Question:", "").strip() if "Question:" in lines[i] else lines[i].strip()
                answer = lines[i+1].strip().replace("Answer:", "").strip() if "Answer:" in lines[i+1] else lines[i+1].strip()
                qa_list.append({"Question": question, "Answer": answer})


    # Structure the output in the desired JSON format
    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair["Question"] for qa_pair in qa_list],
                "Answers": [qa_pair["Answer"] for qa_pair in qa_list]
            }
        ]
    }
    return json.dumps(output_json, indent=2) # Return JSON string with indent for readability


#Sonnet
def generate_simple_qa_pairs_sonnet(text):
    """Generate structured Q&A pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate comprehensive Q&A pairs from Samsung support docs in strict JSON format:
    {{
      "Generations": {{
        "Questions": [
          "question1",
          "question2"
        ],
        "Answers": [
          "answer1",
          "answer2"
        ],
        "Metadata": {{
          "source": "Samsung support document",
          "coverage": ["features", "troubleshooting", "usage"]
        }}
      }}
    }}

    Criteria:
    - Generate 3-5 questions
    - Answers in 1-2 concise sentences
    - Use consumer-friendly language
    - Ensure direct mapping between questions and answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        # Fallback parsing if direct JSON parsing fails
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- Simple Question-Answer Pairs ---")
test_qa_generators("generate_simple_qa_pairs", content)
# Out:
# --- Simple Question-Answer Pairs ---
#
# --- Calling generate_simple_qa_pairs ---
# Here are some Q&A pairs based on the Samsung refrigerator support document, using consumer-friendly language:
#
# **Key Features**
#
# *   **Q: What is the AutoFill Pitcher?**
#     *   A: The AutoFill Pitcher is a built-in pitcher that automatically refills with chilled, purified water, so you always have cold water ready. You can even infuse water with fruits or tea.
# *   **Q: What is the FlexZone?**
#     *   A: The FlexZone is a special drawer with adjustable temperature settings, allowing you to store items like wine, deli, beverages, or meat/fish at their ideal temperature.
# *   **Q: What does the Smart Grid function do?**
#     *   A: The Smart Grid function helps you save energy by delaying high-energy tasks, like defrosting or ice making, to off-peak hours based on signals from your energy provider (available on applicable models with a special contract with a local energy supplier).
# *   **Q: Can I control my refrigerator with my phone?**
#     * A: Yes, using the SmartThings app, you can monitor and control your refrigerator's settings from your smartphone, even when you're not at home.
#
# **Basic Troubleshooting**
#
# *   **Q: My refrigerator isn't cooling. What should I do?**
#     *   A: First, make sure the refrigerator is plugged in and that the temperature settings are correct.  Also check that the back of the unit has 2.5 inches (5 cm) space around it to breath. If it's still not cooling, call Samsung support.
# *   **Q: My ice maker isn't making ice. What could be the problem?**
#     *   A: Check that the ice maker is turned on and the freezer temperature is cold enough (below 0°F or -18°C). Wait 12 hours for the ice maker to make ice after first time installation. Also be sure that the ice machine water line is connected.
# *   **Q: Why is there condensation inside my refrigerator?**
#     *   A: Condensation can form if the door is left open for too long or if food with high moisture content isn't properly wrapped. Make sure the door is closed tightly and food is properly wrapped to avoid this.
# *   **Q: My refrigerator is making strange noises. Is this normal?**
#     *   A: Some sounds, like gurgling, crackling, or buzzing, are normal operating noises of the refrigerator. Refer to the "Do you hear abnormal sounds" section of the manual for more information.
#
# **Usage Guidelines**
#
# *   **Q: What kind of water should I use in the water dispenser and ice maker?**
#     *   A: Only use potable water, such as tap water, mineral water, or purified water, in the water tank and ice cube trays. Avoid using tea, juice, or sports drinks.
# *   **Q: Can I store anything I want in the FlexZone?**
#     *   A: No, you should select the appropriate FlexZone mode according to the foods you store. Do not store fruits, leafy greens, or some glass bottles in this zone.
# *   **Q: How often should I replace the water filter?**
#     *   A: Replace the water filter about every 6 months, or when the filter indicator light turns red. You can purchase replacement filters from Samsung or authorized retailers.
# *   **Q: How do I clean my refrigerator?**
#     *   A: Unplug the refrigerator, then use a soft cloth dampened with mild detergent and warm water to clean the interior and exterior. Do not use harsh chemicals or spray water directly on the unit.
# *   **Q: What can I do to prevent odors?**
#     *  A: Discard expired food, wrap food with strong odors, and use an opened box of baking soda in the fridge to prevent odors.
#
# I have avoided specific model numbers in these Q&A pairs to keep them general and widely applicable to Samsung refrigerators.
#
#
# --- Calling generate_simple_qa_pairs_deepseek ---
# {'Generations': [{'Question': 'What should I do if I smell smoke coming from the refrigerator?', 'Answer': 'Immediately pull out the power plug and contact a Samsung Electronics service center.'}, {'Question': 'Can I store just anything inside this refrigerator?', 'Answer': 'No, this refrigerator is for storing food only; do not store volatile or flammable substances.'}, {'Question': 'What do I do if the refrigerator gets flooded?', 'Answer': 'Shut off the power to the refrigerator and contact your nearest Samsung service center to avoid electric shock or fire.'}, {'Question': 'How do I clean the inside of the refrigerator?', 'Answer': 'Unplug the power cord and use a moistened, soft, lint-free cloth or paper towel to clean the interior; then, dry well.'}, {'Question': 'What should I do if the filter indicator is blinking red?', 'Answer': 'Replace the water filter, then press and hold Filter Reset for 3 seconds to reset the filter lifecycle.'}, {'Question': 'How can I lower the fridge temperature quickly?', 'Answer': 'Press Fridge repeatedly until the Power Cool indicator lights up, which speeds up the cooling process.'}, {'Question': 'How do I activate the Smart Grid function?', 'Answer': "This function monitors energy prices and demand info; you'll need a separate contract with your electric utility company to use it."}, {'Question': "What do I do if my SmartThings app isn't working correctly?", 'Answer': 'Make sure your router is operating normally and the refrigerator is connected; then, exit and restart the app.'}, {'Question': 'How can I check the MAC address of my refrigerator?', 'Answer': 'Press and hold both Freezer and Fridge for 6 seconds, then press Freezer again to display the MAC address on the temperature panel.'}, {'Question': 'What kind of water should I use for the AutoFill Pitcher?', 'Answer': 'Fill the water tank with potable water only, like tap water, mineral water, or purified water, and avoid tea, juice, or sports drinks.'}, {'Question': 'What should I do before discarding the refrigerator?', 'Answer': "Remove the doors and leave the shelves in place, so children can't easily climb inside and become trapped."}, {'Question': 'How do I level the refrigerator after installation?', 'Answer': 'Use a flat-head screwdriver to turn the levelers on the front legs to adjust the height on each side.'}, {'Question': 'What does the Filter Reset button do?', 'Answer': 'After replacing the water filter, press and hold Filter Reset for 3 seconds to reset the filter lifecycle, turning off the indicator.'}, {'Question': 'What is Sabbath Mode?', 'Answer': 'Sabbath Mode stays active for 85 hours, disabling buttons, the display, and internal lights but continuing to cool the refrigerator and freezer.'}, {'Question': 'What is the Cooling Off mode for?', 'Answer': 'Cooling Off mode (Shop mode) is for retailers to display refrigerators without the compressors running to save energy.'}, {'Question': 'How do I activate or deactivate the Sabbath Mode?', 'Answer': 'Press and hold Door Alarm and AutoFill Pitcher simultaneously for 5 seconds to toggle Sabbath Mode, which disables buttons, the display, and internal lights.'}, {'Question': 'How can I make ice faster?', 'Answer': 'Press Freezer repeatedly until the Power Freeze indicator lights up, which speeds up the freezing process.'}, {'Question': 'How do I prevent accidentally changing settings on the refrigerator?', 'Answer': 'Press and hold Door Alarm for 3 seconds to activate Lock, which disables the main panel.'}, {'Question': 'What is the purpose of the FlexZone drawer?', 'Answer': 'The FlexZone is a full-width drawer with adjustable temperature control, suitable for large party trays, deli items, pizza, beverages, or miscellaneous items.'}, {'Question': "What should I do if I can't find SmartThings in the app market?", 'Answer': 'The availability of the SmartThings app depends on the OS support policy of the manufacturer; it may not be compatible with your device.'}]}
#
# --- Calling generate_simple_qa_pairs_google ---
# Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.
# {
#   "Generations": [
#     {
#       "Questions": [
#         "```python",
#         "{\"Question\": \"How do I set the fridge temperature?\", \"Answer\": \"Press the Fridge button repeatedly to select a desired temperature between 34 \u00b0F (1 \u00b0C) and 44 \u00b0F (7 \u00b0C). The temperature indicator displays the currently set or selected temperature.\"},",
#         "{\"Question\": \"What is FlexZone and what modes are available?\", \"Answer\": \"FlexZone allows you to set different temperature modes such as Wine, Deli, Beverage, and Meat/Fish to best store your food.\"},",
#         "{\"Question\": \"How do I adjust the freezer temperature?\", \"Answer\": \"Press the Freezer button repeatedly to select a desired temperature between 5 \u00b0F (-15 \u00b0C) and -8 \u00b0F (-23 \u00b0C); the temperature indicator displays the currently set or selected temperature.\"},",
#         "{\"Question\": \"How do I switch between Celsius and Fahrenheit?\", \"Answer\": \"Press and hold the Freezer button for 3 seconds to change the current temperature scale.\"},",
#         "{\"Question\": \"What should I do if the door is left open for too long?\", \"Answer\": \"If the door is left open for more than 2 minutes, an alarm will sound; you can toggle the alarm on and off by pressing the Door Alarm button.\"},",
#         "{\"Question\": \"How can I use SmartThings to control my refrigerator?\", \"Answer\": \"Download the SmartThings app, create a Samsung account, and follow the in-app instructions to connect your refrigerator to your phone.\"},",
#         "{\"Question\": \"What should I do if there is frost around the vents of my refrigerator?\", \"Answer\": \"Make sure no food blocks the refrigerator vents, as this can cause frost buildup.\"},",
#         "{\"Question\": \"What should I do if the ice maker does not make ice?\", \"Answer\": \"Turn on the ice maker or lower the freezer temperature.\"},",
#         "{\"Question\": \"What is the purpose of the AutoFill Pitcher?\", \"Answer\": \"The AutoFill Pitcher automatically refills with cold, purified water, and it can be infused with tea or fruit.\"},",
#         "{\"Question\": \"What should I do if my refrigerator is flooded?\", \"Answer\": \"Shut off the power to the refrigerator and contact your nearest Samsung service center.\"},",
#         "]"
#       ],
#       "Answers": [
#         "[",
#         "{\"Question\": \"What is Power Cool and how do I use it?\", \"Answer\": \"Power Cool speeds up the cooling process at maximum power to lower the fridge temperature; press the Fridge button repeatedly until the Power Cool indicator lights up to activate it.\"},",
#         "{\"Question\": \"How do I activate the Soft Freeze mode in the FlexZone?\", \"Answer\": \"Press and hold the FlexZone button for 3 seconds to activate the Soft Freeze mode, which keeps meat and fish fresh for an extended time at 23 \u00b0F (-5 \u00b0C).\"},",
#         "{\"Question\": \"What is Power Freeze and how do I activate it?\", \"Answer\": \"Power Freeze speeds up the freezing process at maximum power to lower the freezer temperature, which can be activated by pressing Freezer button repeatedly until the Power Freeze indicator lights up.\"},",
#         "{\"Question\": \"How do I reset the water filter indicator?\", \"Answer\": \"After replacing the water filter, press and hold the Filter Reset button for 3 seconds to reset the filter lifecycle.\"},",
#         "{\"Question\": \"How do I prevent accidental setting changes on the main panel?\", \"Answer\": \"Press and hold the Door Alarm button for 3 seconds to activate the Lock function, which disables the main panel.\"},",
#         "{\"Question\": \"What should I do if my refrigerator makes abnormal sounds?\", \"Answer\": \"Refer to the troubleshooting section in the user manual to identify the possible causes of the sounds, such as the fan operating or refrigerant gas moving through sealed pipes.\"},",
#         "{\"Question\": \"What should I do if the water flow from the dispenser is weaker than normal?\", \"Answer\": \"Make sure the water pressure is between 30-125 psi (206-861 kPa).\"},",
#         "{\"Question\": \"Why is the Wi-Fi icon blinking on my refrigerator?\", \"Answer\": \"Connect your refrigerator with the SmartThings app before use. If you fail to make connection or don\u2019t want to use the app, press and hold the Door Alarm button for 10 seconds.\"},",
#         "{\"Question\": \"How do I clean my refrigerator?\", \"Answer\": \"Use a moistened, soft, lint-free cloth or paper towel to clean the refrigerator\u2019s interior and exterior; then, use a dry cloth or paper towel to dry well.\"},",
#         "{\"Question\": \"What does the limited warranty cover in the U.S.A?\", \"Answer\": \"The limited warranty covers manufacturing defects in materials or workmanship encountered in normal household, noncommercial use of the product for one year parts and labor, five years parts and labor on the sealed refrigeration system, and ten years part and five years labor on the digital inverter compressor.\"}",
#         "```"
#       ]
#     }
#   ]
# }
#
# --- Calling generate_simple_qa_pairs_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What should I do if the refrigerator emits a burning smell?",\n      "What should I do with the packaging materials of the refrigerator?",\n      "Can I use a regular extension cord with this refrigerator?",\n      "What should I do if I\'m unable to connect my Samsung Smart Refrigerator to the internet?",\n      "What should I do if the refrigerator is flooded?"\n    ],\n    "Answers": [\n      "Unplug the refrigerator immediately and contact a Samsung service center.",\n      "Please dispose of the packaging material from this product in an environmentally friendly manner.",\n      "If you must use an extension cord, use only a 3-wire extension cord that has a 3-blade grounding plug and a 3-slot receptacle that will accept the plug on the appliance.",\n      "Ensure that your router is operating normally, the refrigerator is connected to the router (AP), and that you can browse the internet on a smartphone connected to the same router.",\n      "Shut off the power to the refrigerator and contact your nearest Samsung service center."\n    ],\n    "Metadata": {\n      "source": "Samsung support document",\n      "coverage": ["safety", "troubleshooting", "usage"]\n    }\n  }\n}\n```'}}

# %%
results = test_qa_generators_aggregated("generate_simple_qa_pairs", content)
print_aggregated_results(results)
# Out:
# Warning: Failed to parse JSON directly. Attempting to extract Q&A pairs from text.
# {
#   "base_function": "generate_simple_qa_pairs",
#   "results": {
#     "default": "Okay, here are some Q&A pairs in consumer-friendly language, based on the provided Samsung refrigerator manual content, categorized as requested:\n\n**Key Features**\n\n*   **Q: What is the AutoFill Pitcher?** \n    *   A: The AutoFill Pitcher is a built-in pitcher that automatically refills with chilled, purified water, available on select models. You can even add fruit or tea to the infuser for flavored water.\n*   **Q: What is FlexZone?**\n    *   A: FlexZone is a full-width drawer with adjustable temperature settings, allowing you to store different types of food like wine, deli items, or meat at their ideal temperatures.\n*   **Q: Does this refrigerator have SmartThings?**\n    *   A: Yes, you can connect this refrigerator to the SmartThings app to monitor and control it remotely.\n\n**Basic Troubleshooting**\n\n*   **Q: My refrigerator isn't cold enough. What could be the problem?**\n    *   A: Make sure the power cord is properly plugged in and that the temperature setting isn't too high. Also, check for any obstructions blocking the refrigerator vents or if the refrigerator is in a warm location.\n*   **Q: My ice maker isn't making ice. What should I do?**\n    *   A: Ensure the ice maker is turned on and the freezer temperature is low enough (below 0\u00b0F/-18\u00b0C). For initial set-up, it may take 12 hours before ice production begins.\n*   **Q: My refrigerator is making strange noises. Is this normal?**\n    *   A: Some noises like bubbling, sizzling, or fan sounds are normal during operation. Refer to the manual for a list of common refrigerator sounds.\n\n**Usage Guidelines**\n\n*   **Q: How often should I replace the water filter?**\n    *   A: Replace the water filter approximately every 6 months, or when the filter indicator light turns red. You can reset the filter cycle on the control panel after replacement.\n*   **Q: What should I do before cleaning my refrigerator?**\n    *   A: Always unplug the refrigerator from the power outlet before cleaning to avoid the risk of electric shock or fire.\n*   **Q: Can I use regular cleaning products inside my refrigerator?**\n    *   A: No, avoid using harsh cleansers like benzene, thinner, or bleach, as these can damage the refrigerator's surface. Use a mild detergent and a soft cloth instead.\n*  **Q: Is it safe to store food in the door bins?**\n    *   A: Yes, door bins are designed for food storage, however, it is recommended that you do not store vegetable oil in the door bins.\n\nI hope this helps!\n",
#     "_deepseek": {
#       "Generations": [
#         {
#           "Question": "What should I do before using my new Samsung Refrigerator?",
#           "Answer": "Read the manual thoroughly to ensure you know how to operate the features and functions safely and efficiently."
#         },
#         {
#           "Question": "What do I do if refrigerant leaks from the pipe?",
#           "Answer": "Avoid any naked flames, move anything flammable away from the product, and ventilate the room immediately to prevent fire or explosion."
#         },
#         {
#           "Question": "Where can I find help and information online about my refrigerator?",
#           "Answer": "You can find help and information online at www.samsung.com, or contact 1-800-SAMSUNG."
#         },
#         {
#           "Question": "What does a WARNING safety symbol indicate in this manual?",
#           "Answer": "It indicates hazards or unsafe practices that may result in severe personal injury, property damage, and/or death."
#         },
#         {
#           "Question": "What precautions should I take regarding flammable refrigerant?",
#           "Answer": "The room must be 35.3 ft\u00b3 in size for every 8 g of R-600a refrigerant inside the appliance, and avoid any naked flames or potential sources of ignition if a leak is detected."
#         },
#         {
#           "Question": "What should I do with old hose-sets?",
#           "Answer": "New hose-sets supplied with the appliance are to be used and that old hose-sets should not be reused."
#         },
#         {
#           "Question": "Can I use mechanical devices to defrost the refrigerator?",
#           "Answer": "Do not use mechanical devices or other means to accelerate the defrosting process, other than those recommended by the manufacturer."
#         },
#         {
#           "Question": "What should I do with my old refrigerator before throwing it away?",
#           "Answer": "Take off the doors and leave the shelves in place so that children may not easily climb inside to prevent child entrapment."
#         },
#         {
#           "Question": "What should I do if the supply cord is damaged?",
#           "Answer": "It must be replaced by the manufacturer, its service agent or similarly qualified persons in order to avoid a hazard."
#         },
#         {
#           "Question": "What do I do if a gas leak is detected?",
#           "Answer": "Avoid any naked flames or potential sources of ignition, and air the room in which the appliance is standing for several minutes."
#         },
#         {
#           "Question": "What should I avoid when installing the refrigerator?",
#           "Answer": "Do not install the refrigerator in a damp location or place where it may come in contact with water and don't place the refrigerator in direct sunlight or expose it to the heat from stoves, room heaters, or other appliances."
#         },
#         {
#           "Question": "How do I move the refrigerator safely?",
#           "Answer": "When moving the refrigerator, be careful not to roll over or damage the power cord to prevent electric shock or fire."
#         },
#         {
#           "Question": "What should I do if large amounts of dust or water enter the refrigerator?",
#           "Answer": "Disconnect the power plug and contact a Samsung Electronics service center to prevent risk of fire."
#         },
#         {
#           "Question": "Can I place heavy objects on top of the appliance?",
#           "Answer": "No, do not stand on top of the appliance or place objects on the appliance because this may result in an electric shock, fire, problems with the product, or injury."
#         },
#         {
#           "Question": "What must I do before initial use?",
#           "Answer": "Remove all the protective plastic film before you initially plug the product in."
#         },
#         {
#           "Question": "What must I ensure before attempting to investigate or repair any part of the refrigerator?",
#           "Answer": "Always make sure that you have grounded the refrigerator before attempting to investigate or repair any part of the appliance."
#         },
#         {
#           "Question": "How should I install the refrigerator to prevent electric leakage?",
#           "Answer": "Plug the power plug into the wall socket firmly, making sure you have grounded the refrigerator and only a qualified technician or service company should be allowed to change the fuse in the refrigerator."
#         },
#         {
#           "Question": "What are the installation cautions?",
#           "Answer": "Allow sufficient space around the refrigerator and install it on a flat surface and after you have installed the refrigerator and turned it on, allow the appliance to stand for 2 hours before loading it with food."
#         },
#         {
#           "Question": "What are the critical usage warnings?",
#           "Answer": "Do not insert the power plug into a wall socket with wet hands and do not store articles on the top of the appliance, volatile or flammable objects or substances in the refrigerator."
#         },
#         {
#           "Question": "Is it okay for children to play with the appliance?",
#           "Answer": "No, children should be supervised to ensure that they do not play with the appliance and keep fingers out of 'pinch point' areas."
#         },
#         {
#           "Question": "Is it okay to store pharmaceutical products, scientific materials, or temperature-sensitive products in the refrigerator?",
#           "Answer": "No, do not store pharmaceutical products, scientific materials, or temperature-sensitive products in the refrigerator as products that require strict temperature controls must not be stored in the refrigerator."
#         },
#         {
#           "Question": "What should I do if I smell smoke coming from the refrigerator?",
#           "Answer": "If you smell smoke, pull out the power plug immediately, and then contact a Samsung Electronics service center."
#         },
#         {
#           "Question": "What do I do if too much dust or water gets into the refrigerator?",
#           "Answer": "If large amounts of dust or water enter the refrigerator, disconnect the power plug and contact a Samsung Electronics service center to avoid a risk of fire."
#         },
#         {
#           "Question": "What type of water should I use in the water dispenser?",
#           "Answer": "Fill the water tank and ice cube trays with potable water only (tap water, mineral water, or purified water) and don't fill the tank with tea, juice, or a sports drink."
#         },
#         {
#           "Question": "What do I do if a gas leak is detected?",
#           "Answer": "Avoid any naked flames or potential sources of ignition, and air the room in which the appliance is standing for several minutes."
#         },
#         {
#           "Question": "What type of fuse should I use?",
#           "Answer": "Do not use any fuse (such as cooper, steel wire, etc.) other than a standard fuse."
#         },
#         {
#           "Question": "Can I refreeze thawed food?",
#           "Answer": "No, do not re-freeze frozen foods that have thawed completely."
#         },
#         {
#           "Question": "Can I put glass containers or bottles or carbonated beverages into the freezer?",
#           "Answer": "No, do not put glass containers or bottles or carbonated beverages into the freezer because the container may freeze and break, and this may result in injury."
#         },
#         {
#           "Question": "What happens if the air vents inside the refrigerator are blocked?",
#           "Answer": "If the air vents are blocked, especially with a plastic bag, the refrigerator can be over cooled and the water filter may break and cause water leakage."
#         },
#         {
#           "Question": "What should I do if large amounts of water enter the refrigerator?",
#           "Answer": "Pull out the power plug and contact a Samsung service center."
#         },
#         {
#           "Question": "What type of cleaning products should I use to clean my refrigerator?",
#           "Answer": "Use a clean sponge or soft cloth and a mild detergent in warm water to clean the refrigerator and do not use abrasive or harsh cleansers such as window sprays, scouring cleansers, flammable fluids, muriatic acid, cleaning waxes, concentrated detergents, bleaches, or cleansers containing petroleum products on exterior surfaces."
#         },
#         {
#           "Question": "What should I do when disposing of the refrigerator?",
#           "Answer": "When disposing of this refrigerator, remove the door/door seals and door latch so that small children or animals cannot become trapped inside."
#         },
#         {
#           "Question": "What does the Fridge button do?",
#           "Answer": "You can use the Fridge button to set the fridge temperature or to activate Power Cool and the temperature indicator displays the currently set or selected temperature."
#         },
#         {
#           "Question": "How do I activate Power Cool?",
#           "Answer": "Press Fridge repeatedly until the Power Cool indicator lights up, and to deactivate it, simply press Fridge again while the Power Cool function is on."
#         },
#         {
#           "Question": "What is the Peak Demand Off function?",
#           "Answer": "The Peak Demand Off function activates/deactivates Smart Grid and press Fridge for 3 seconds to set/clear the Peak Demand Off function."
#         },
#         {
#           "Question": "What modes are available in FlexZone?",
#           "Answer": "Wine, Deli, Beverage, and Meat/Fish."
#         },
#         {
#           "Question": "What does the Freezer button do?",
#           "Answer": "You can use the Freezer button to set the freezer temperature or to activate Power Freeze and press Freezer repeatedly to select a desired temperature between 5 \u00b0F (-15 \u00b0C) and -8 \u00b0F (-23 \u00b0C)."
#         },
#         {
#           "Question": "How do I switch between Celsius and Fahrenheit?",
#           "Answer": "Press and hold Freezer for 3 seconds to change the current temperature scale."
#         },
#         {
#           "Question": "What can I do with the Ice Maker button?",
#           "Answer": "You can start or stop making cubed ice or ice bites."
#         },
#         {
#           "Question": "How do I reset the filter?",
#           "Answer": "Replace the filter, and then press and hold Filter Reset for 3 seconds."
#         },
#         {
#           "Question": "What is the Door Alarm function?",
#           "Answer": "If the door is left open for more than 2 minutes, an alarm will sound and the alarm indicator will blink and you can toggle the alarm on and off by pressing Door Alarm."
#         },
#         {
#           "Question": "How do I prevent accidental setting changes on the panel?",
#           "Answer": "To prevent accidental setting changes, press and hold Door Alarm for 3 seconds. The main panel will be disabled and the Lock indicator will turn on."
#         },
#         {
#           "Question": "How do I activate Sabbath Mode?",
#           "Answer": "To activate Sabbath Mode, press and hold Door Alarm and AutoFill Pitcher simultaneously for 5 seconds and to deactivate it, press and hold Door Alarm and AutoFill Pitcher simultaneously again for 5 seconds."
#         },
#         {
#           "Question": "How can I control my refrigerator with SmartThings?",
#           "Answer": "Visit the Google Play Store, Galaxy Apps, or Apple App Store and search for \"SmartThings\". Download and install the SmartThings app provided by Samsung Electronics to your smart device."
#         },
#         {
#           "Question": "What is Cooling Off mode?",
#           "Answer": "Cooling Off mode (also called Shop mode) is designed for use by retailers when they are displaying refrigerators on a retail floor."
#         },
#         {
#           "Question": "Can I monitor and control my refrigerator remotely?",
#           "Answer": "Yes, you can monitor and control your refrigerator at home and on the go using the SmartThings app."
#         },
#         {
#           "Question": "What is the AutoFill Pitcher?",
#           "Answer": "Cold, purified water is always ready in the AutoFill Pitcher and you can put tea or fruits in the infuser to enjoy the various infused water you like."
#         },
#         {
#           "Question": "How do I fill the Water pitcher?",
#           "Answer": "Open the Beverage Center door (Type A) or the left door of the fridge (Type B), and then mount the water pitcher onto the holder and push it straight in."
#         },
#         {
#           "Question": "Why does the water look cloudy when dispensed?",
#           "Answer": "Water supplied to the refrigerator flows through a core alkaline filter. During this filtering process, the water pressure of the water increases and the water becomes saturated with oxygen and nitrogen which causes the water to look misty or cloudy temporarily when dispensed."
#         },
#         {
#           "Question": "How do I test the ice maker?",
#           "Answer": "Press the Test button on the bottom of the ice maker and you will hear a chime when you press the button, then hear another chime if the ice maker is operating properly."
#         },
#         {
#           "Question": "What can the FlexZone be used for?",
#           "Answer": "The FlexZone is a full-width drawer with adjustable temperature control that can be used for large party trays, deli items, pizza, beverages, or miscellaneous items."
#         },
#         {
#           "Question": "What is Smart Grid?",
#           "Answer": "The Energy Management Refrigerator function can control energy usage or delay the operation of some functions to save money when energy prices or demand are the highest."
#         },
#         {
#           "Question": "What kind of MAC Adress will the temperature panel display for an unknown MAC address or if a Wi-Fi connection is not established?",
#           "Answer": "The temperature panel displays '-- / --' for an unknown MAC address or if a Wi-Fi connection is not established or is lost."
#         },
#         {
#           "Question": "What is 'Cooling Off' mode?",
#           "Answer": "Cooling Off mode (also called Shop mode) is designed for use by retailers when they are displaying refrigerators on a retail floor."
#         },
#         {
#           "Question": "What temperatures are best for each FlexZone setting?",
#           "Answer": "Wine: 41 \u00b0F (5 \u00b0C), Deli: 37 \u00b0F (3 \u00b0C), Beverage: 34 \u00b0F (1 \u00b0C), Meat/Fish: 30 \u00b0F (-1 \u00b0C)."
#         },
#         {
#           "Question": "What to do if you do not dispense ice for an extended period?",
#           "Answer": "If you do not dispense ice for an extended period, ice may form clumps inside the bucket and if this happens, remove and empty the ice bucket."
#         },
#         {
#           "Question": "What is the warranty for a Samsung Refrigerator in the USA?",
#           "Answer": "The warranty is 1 year parts and labor, 5 years parts and labor on the sealed refrigeration system, and 10 years part and 5 years labor on the digital inverter compressor."
#         }
#       ]
#     },
#     "_google": "{\n  \"Generations\": [\n    {\n      \"Questions\": [\n        \"```json\",\n        \"{\\\"Question\\\": \\\"What should I do before using my new Samsung Refrigerator?\\\", \\\"Answer\\\": \\\"Read the user manual thoroughly to understand the features and how to operate them safely and efficiently.\\\"},\",\n        \"{\\\"Question\\\": \\\"What type of refrigerant does this refrigerator use?\\\", \\\"Answer\\\": \\\"This refrigerator uses R-600a, a flammable gas, as a refrigerant.\\\"},\",\n        \"{\\\"Question\\\": \\\"Where should I install the refrigerator?\\\", \\\"Answer\\\": \\\"Install it on a flat surface, away from direct sunlight and heat sources, with sufficient space for ventilation and door operation.\\\"},\",\n        \"{\\\"Question\\\": \\\"What should I do before moving the refrigerator?\\\", \\\"Answer\\\": \\\"Unplug the power cord before removing the doors to prevent electrical shock.\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I adjust the door height?\\\", \\\"Answer\\\": \\\"Use the provided snap rings to adjust the height of the doors by inserting them between the door grommet and the hinge.\\\"},\",\n        \"{\\\"Question\\\": \\\"What should I do after connecting the water line?\\\", \\\"Answer\\\": \\\"Flush 3 gallons of water through the filter before drinking or using the water from the refrigerator.\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I activate Power Cool?\\\", \\\"Answer\\\": \\\"Press Fridge repeatedly until the Power Cool indicator lights up to speed up the cooling process.\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I connect the refrigerator to SmartThings?\\\", \\\"Answer\\\": \\\"Download the SmartThings app and follow the in-app instructions to connect your refrigerator to your Samsung account.\\\"},\",\n        \"{\\\"Question\\\": \\\"What should I do if I hear abnormal sounds from the refrigerator?\\\", \\\"Answer\\\": \\\"Review the troubleshooting section of the manual to identify the sound.  If the issue persists, contact Samsung Customer Care.\\\"},\",\n        \"]\"\n      ],\n      \"Answers\": [\n        \"[\",\n        \"{\\\"Question\\\": \\\"Where can I find help and information if I have questions?\\\", \\\"Answer\\\": \\\"Contact Samsung at 1-800-SAMSUNG or visit their website at www.samsung.com.\\\"},\",\n        \"{\\\"Question\\\": \\\"What should I do if I detect a refrigerant leak?\\\", \\\"Answer\\\": \\\"Avoid any naked flames or potential sources of ignition and air the room in which the appliance is standing for several minutes.\\\"},\",\n        \"{\\\"Question\\\": \\\"What is the recommended temperature range for the installation site?\\\", \\\"Answer\\\": \\\"The temperature range should be between 50 \\u00b0F (10 \\u00b0C) and 110 \\u00b0F (43 \\u00b0C).\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I level the refrigerator?\\\", \\\"Answer\\\": \\\"Use a flat-head screwdriver to turn the levelers on the front legs, adjusting the height until the refrigerator is level.\\\"},\",\n        \"{\\\"Question\\\": \\\"What is the recommended water pressure for the ice maker to operate properly?\\\", \\\"Answer\\\": \\\"The water pressure should be between 30-125 psi (206-861 kPa).\\\"},\",\n        \"{\\\"Question\\\": \\\"What should I do if water is not dispensing properly?\\\", \\\"Answer\\\": \\\"The water filter is most likely clogged; replace the water filter.\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I activate Sabbath Mode?\\\", \\\"Answer\\\": \\\"Press and hold Door Alarm and AutoFill Pitcher simultaneously for 5 seconds.\\\"},\",\n        \"{\\\"Question\\\": \\\"How do I clean the refrigerator?\\\", \\\"Answer\\\": \\\"Use a moistened, soft, lint-free cloth or paper towel to clean the refrigerator\\u2019s interior and exterior, and then dry well.\\\"},\",\n        \"{\\\"Question\\\": \\\"What is the warranty on the refrigerator?\\\", \\\"Answer\\\": \\\"The refrigerator has a limited warranty: ...
#     "_sonnet": {
#       "Generations": {
#         "Questions": [],
#         "Answers": [],
#         "RawResponse": "```json\n{\n  \"Generations\": {\n    \"Questions\": [\n      \"What should I do if the refrigerator is making abnormal sounds?\",\n      \"How do I clean the interior and exterior of my Samsung refrigerator?\",\n      \"Where should the ice scoop be stored?\",\n      \"What should I do if my refrigerator is flooded?\",\n      \"What should I do if I smell smoke coming from my refrigerator?\"\n    ],\n    \"Answers\": [\n      \"Review the troubleshooting information in the user manual and if the issue persists, contact Samsung Customer Care.\",\n      \"Unplug the power cord, use a soft, lint-free cloth to clean, and dry well before plugging it back in.\",\n      \"The ice scoop can be stored in the scoop tray or inside the ice bucket with the handle against the side wall.\",\n      \"Shut off the power to the refrigerator and contact your nearest Samsung service center.\",\n      \"Unplug the refrigerator immediately and contact a Samsung service center.\"\n    ],\n    \"Metadata\": {\n      \"source\": \"Samsung support document\",\n      \"coverage\": [\"troubleshooting\", \"maintenance\", \"usage\", \"safety\"]\n    }\n  }\n}\n```"
#       }
#     }
#   },
#   "errors": {}
# }

# %% [markdown]
# ### Number 2 generate_structured_qa

# %%
#original
def generate_structured_qa(text):
    """Problem-solution focused pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create problem-solution pairs from Samsung docs. Format:
    Question: [Issue description]
    Answer: [Step-by-step fix]
    Include severity indicators (⚠️) for critical issues.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_qa_deepseek(text):
    """Generates severity-graded troubleshooting pairs in JSON format.

    Returns:
        JSON with error codes, time estimates, and step-by-step instructions.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Convert Samsung support text into problem-solution pairs with:
    1. Technical error codes (if applicable)
    2. Severity grading (Critical/Medium/Low)
    3. Estimated troubleshooting time
    4. Ordered resolution steps

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Issue]",
        "Answer": {{
          "Steps": ["1. Do X", "2. Then Y"],
          "SeverityCode": 0-2 (2=Critical),
          "ErrorCode": "ERR_BATT_01",
          "TroubleshootingTime": "5-7 minutes"
        }}
      }}
    - Replace ⚠️ with "SeverityCode":2
    - Sort by descending SeverityCode

    Example:
    {{
      "Generations": [
        {{
          "Question": "Phone overheating during charging",
          "Answer": {{
            "Steps": ["1. Unplug immediately", "2. Remove case", "3. Contact support"],
            "SeverityCode": 2,
            "ErrorCode": "ERR_CHG_OVERHEAT",
            "TroubleshootingTime": "3 minutes"
          }}
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse troubleshooting data"}


#Google AI STudio
def generate_structured_qa_google(text):
    """Problem-solution focused pairs in JSON format with severity indicators"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate problem-solution Question and Answer pairs from the following Samsung support document text. Format each pair as:

    Question: [Issue description]
    Answer: [Step-by-step fix]

    For critical issues, include a severity indicator (⚠️) in the output and classify them as "Critical" in the JSON structure. For non-critical issues, classify as "Normal" or leave severity blank/null.

    Use consumer-friendly language. Keep answers concise and step-by-step where possible.

    Present the output as a list of dictionaries in JSON format. Each dictionary should have keys: "Severity" (e.g., "Critical", "Normal", null), "Question", "Answer", and optionally "SeverityIndicator" (the ⚠️ symbol if applicable).

    Text: {text}

    Output Format (example):
    [
      {{ "Severity": "Critical", "Question": "...", "Answer": "...", "SeverityIndicator": "⚠️" }},
      {{ "Severity": "Normal", "Question": "...", "Answer": "...", "SeverityIndicator": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        problem_solution_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        problem_solution_data = [] # Implement a robust fallback text parsing

    output_json = {
        "Generations": [
            {"ProblemSolutionPairs": problem_solution_data} # Assuming model outputs list of dictionaries as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_structured_qa_sonnet(text):
    """Generate problem-solution Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate problem-solution Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific problem description"
        ],
        "Answers": [
          "Comprehensive step-by-step solution"
        ],
        "Metadata": {{
          "IssueSeverity": ["Low", "Medium", "High"],
          "SolutionComplexity": "Detailed technical guidance"
        }},
        "IssueClassification": {{
          "CriticalIssues": ["Urgent problems requiring immediate action"],
          "WarningIndicators": ["⚠️ Severity markers"]
        }}
      }}
    }}

    Requirements:
    - Precise problem descriptions
    - Clear, sequential solution steps
    - Include severity indicators
    - 1-2 sentence answers
    - Technical accuracy

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_qa ---")
test_qa_generators("generate_structured_qa", content)
# Out:
# --- generate_structured_qa ---
#
# --- Calling generate_structured_qa ---
# ```
# Question: ⚠️ Power cord is damaged.
# Answer: Do not use a power cord that has cracks or abrasion damage along its length or at either end. Failure to do so may result in an electric shock or fire.
#
# Question: ⚠️ Wall socket is loose.
# Answer: Do not insert the power plug if the wall socket is loose. There is a risk of electric shock or fire. Contact a qualified electrician to repair the wall socket.
#
# Question: How do I level the refrigerator?
# Answer: Level the refrigerator using the special screws (levelers) on the front legs. Use a flat-head screwdriver to turn the levelers. To adjust the height of the left side: Insert a flat-head screwdriver into the leveler of the left side front leg. Turn the leveler clockwise to raise the left side or turn it counterclockwise to lower. To adjust the height of the right side: Insert a flat-head screwdriver into the leveler of the right side front leg. Turn the leveler clockwise to raise the right side or turn it counterclockwise to lower.
#
# Question: Ice maker is not making ice.
# Answer: 1. You must wait for 12 hours for the refrigerator to make ice. 2. Set the freezer temperature below 0 °F (-18 °C) or -4 °F (-20 °C) in warm ambient air. 3. Turn on the ice maker.
#
# Question: Water does not dispense from the water dispenser.
# Answer: 1. Check the water installation conditions. 2. Use only Samsung-provided or approved filters. 3. Replace the water filter. Then, on the control panel, go to More Options, and then run Filter Reset.
#
# Question: The refrigerator has odors.
# Answer: 1. Clean the refrigerator and remove any spoiled food. 2. Make sure strong smelling food is wrapped airtight.
#
# Question: I cannot find "SmartThings" in the app market.
# Answer: The supporting software version of the SmartThings app is subject to change according to the OS supporting policy the manufacturer provides.
#
# Question: How to activate/deactivate the Peak Demand Off function
# Answer: 1. Press and hold Fridge for 3 seconds. 2. A buzzer sounds and the Peak Demand Off (Override mode) icon turns on. 3. If the refrigerator receives a SMART GRID (Demand Response) signal from the utility company, ’Or’ is displayed in the fridge temperature display. 4. To deactivate Peak Demand Off (Override mode), press and hold Fridge for 3 seconds. 5. A buzzer sounds and the Peak Demand Off (Override mode) icon turns off.
#
# Question: The Filter indicator is blinking red.
# Answer: Replace the filter, and then press and hold Filter Reset for 3 seconds. The filter lifecycle will be reset and the Filter indicator turns off.
#
# Question: The Wi-Fi icon is blinking.
# Answer: Connect your refrigerator with the SmartThings app before use. When the connection is made successfully, the indicator stops blinking. If you fail to make connection or don’t want to use the app, press and hold the Door Alarm button for 10 seconds. The indicator stops blinking with "O FF" shown on the temperature display.
# ```
#
# --- Calling generate_structured_qa_deepseek ---
# {'Generations': [{'Question': 'Refrigerant leaking during transportation/installation.', 'Answer': {'Steps': ['1. Avoid any naked flames or potential sources of ignition.', '2. Air the room in which the appliance is standing for several minutes.', '3. Contact qualified technician for repair.'], 'SeverityCode': 2, 'ErrorCode': 'ERR_REFRIG_LEAK', 'TroubleshootingTime': '5-10 minutes'}}, {'Question': 'Burning smell or smoke coming from the refrigerator.', 'Answer': {'Steps': ['1. Unplug the refrigerator immediately.', '2. Contact a Samsung service center.', '3. Do not operate until inspected.'], 'SeverityCode': 2, 'ErrorCode': 'ERR_ELEC_FIRE', 'TroubleshootingTime': '2 minutes'}}, {'Question': 'Wire connectors are not properly connected after reattaching the fridge door', 'Answer': {'Steps': ['1. Make sure the wire connectors are properly connected.', '2. Otherwise, the display will not operate.', '3. Double check the connector location, referring to the user manual diagram.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_DOOR_WIRE', 'TroubleshootingTime': '5 minutes'}}, {'Question': 'Ice maker makes buzzing sound, but water supply is not connected.', 'Answer': {'Steps': ['1. Turn off the Ice Maker.', '2. Connect the water supply line according to the manual instructions.', '3. Test the ice maker.'], 'SeverityCode': 1, 'ErrorCode': 'ERR_ICE_NOSUPPLY', 'TroubleshootingTime': '10-15 minutes'}}, {'Question': 'Water filter requires replacement.', 'Answer': {'Steps': ['1. Replace the water filter with a new, genuine Samsung filter.', '2. On the control panel, go to More Options and run Filter Reset.', '3. Ensure water dispenses properly after reset.'], 'SeverityCode': 0, 'ErrorCode': 'ERR_FILTER_REPLACE', 'TroubleshootingTime': '10 minutes'}}, {'Question': 'Wi-Fi icon is blinking. Refrigerator app is not connected.', 'Answer': {'Steps': ['1. Connect the refrigerator with the SmartThings app before use.', '2. If the connection is made successfully, the indicator stops blinking.', '3. Alternatively, hold the Door Alarm button for 10 seconds to disable the indicator.'], 'SeverityCode': 0, 'ErrorCode': 'ERR_WIFI_NOCONN', 'TroubleshootingTime': '10 minutes'}}]}
#
# --- Calling generate_structured_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ProblemSolutionPairs": []
#     }
#   ]
# }
#
# --- Calling generate_structured_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "The refrigerator or freezer is not operating, and the temperature inside is warm.",\n      "I smell foul odors coming from the refrigerator.",\n      "There is frost accumulating on the interior walls of the refrigerator.",\n      "The ice maker is making a buzzing sound.",\n      "The SmartThings app is installed but isn\'t connecting to my refrigerator."\n    ],\n    "Answers": [\n      "Ensure the power cord is plugged in properly and that the temperature control is set correctly to a cooler setting.",\n      "The odor could be from spoiled food or from strong-smelling foods that are not wrapped tightly.",\n      "Ensure the refrigerator door is closed properly and that no food items are blocking the door\'s seal.",\n      "The ice maker is on, but water line to the refrigerator has not been connected.",\n      "You must log into your Samsung account to use the app, and you must make sure your router is operating normally."\n    ],\n    "Metadata": {\n      "IssueSeverity": ["Medium", "Low", "Medium", "Low", "Medium"],\n      "SolutionComplexity": "Detailed technical guidance"\n    },\n    "IssueClassification": {\n      "CriticalIssues": ["Issues impacting basic refrigeration functions", "Issues impacting smart features"],\n      "WarningIndicators": ["⚠️ Functionality issues", "⚠️ Odor concerns"]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 3 generate_step_by_step_qa

# %%
#original
def generate_step_by_step_qa(text):
    """Procedural guidance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Extract step-by-step procedures and generate Q&A pairs with:
    - Sequential questions - Tool requirements - Time estimates
    Format steps with numbered sub-items.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_step_by_step_qa_deepseek(text):
    """Generates machine-parseable procedural guides with safety checks.

    Returns:
        JSON with nested step details, tool SKUs, and critical warnings.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Convert Samsung technical docs into structured Q&A with:
    1. Sequentially ordered repair/configuration steps
    2. Official tool SKUs from Samsung Parts
    3. Time estimates with ranges (e.g., "8-12 minutes")
    4. Critical warnings for permanent data loss

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Task description]",
        "Answer": {{
          "Steps": [
            {{
              "Number": 1,
              "Action": "...",
              "Tools": ["GJ-TX42 (SIM ejector)"],
              "Warning": "Optional text"
            }}
          ],
          "TotalTime": "15-20 mins",
          "RiskLevel": "High/Medium/Low"
        }},
        "Category": "Display/Battery/Software"
      }}
    - Sort steps by dependency (prerequisite first)
    - Validate tool SKUs against Samsung's GJ-XXXXX format

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to replace Galaxy S24 Ultra screen?",
          "Answer": {{
            "Steps": [
              {{
                "Number": 1,
                "Action": "Heat edges at 85°C with GJ-HX90 thermal pad",
                "Tools": ["GJ-HX90"],
                "Warning": "Exceeding 90°C voids warranty"
              }}
            ],
            "TotalTime": "45-60 mins",
            "RiskLevel": "High"
          }},
          "Category": "Display"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse procedural guide"}


#Google AI STudio
def generate_step_by_step_qa_google(text):
    """Procedural guidance pairs in JSON format with steps, tools, and time estimates"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Extract step-by-step procedures from the following Samsung support document text and generate Question and Answer pairs for each step.

    For each procedure, identify:
    - Sequential questions that guide the user through each step.
    - Any tool requirements needed for the procedure.
    - An estimated time to complete the procedure.

    Format the steps as numbered sub-items in the plain text output for clarity. In the JSON output, represent steps as a numbered list of Question-Answer pairs.

    Use consumer-friendly language. Keep answers concise and focused on each step.

    Present the output as a list of procedures in JSON format. Each procedure should include "ProcedureName", "ToolRequirements", "TimeEstimate", and a list of "Steps", where each step has "StepNumber", "Question", and "Answer".

    Text: {text}

    Output Format (example structure):
    [
      {{
        "ProcedureName": "Procedure Title",
        "ToolRequirements": ["Tool 1", "Tool 2", ...],
        "TimeEstimate": "Estimated Time",
        "Steps": [
          {{ "StepNumber": 1, "Question": "Question for Step 1?", "Answer": "Answer for Step 1" }},
          {{ "StepNumber": 2, "Question": "Question for Step 2?", "Answer": "Answer for Step 2" }},
          ...
        ]
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        procedure_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        procedure_data = [] # Implement a robust fallback text parsing

    output_json = {
        "Generations": [
            {"ProcedureQAPairs": procedure_data} # Assuming model outputs list of procedures as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_step_by_step_qa_sonnet(text):
    """Generate structured procedural guidance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create step-by-step Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Procedural guidance question"
        ],
        "Answers": [
          "Detailed step-by-step procedure"
        ],
        "Metadata": {{
          "ProcedureType": "Sequential Guidance",
          "Complexity": "Detailed Technical Steps"
        }},
        "ProcedureDetails": {{
          "Tools": ["Required equipment"],
          "TimeEstimates": ["Estimated duration for each step"],
          "Steps": [
            "Numbered sequential instructions"
          ]
        }}
      }}
    }}

    Requirements:
    - Numbered, sequential steps
    - Tool and time requirement details
    - 1-2 sentence answers
    - Technical precision

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_step_by_step_qa ---")
test_qa_generators("generate_step_by_step_qa", content)
# Out:
# --- generate_step_by_step_qa ---
#
# --- Calling generate_step_by_step_qa ---
# Okay, here are the step-by-step procedures and Q&A pairs extracted from the provided text, formatted as you requested.  I've focused on the "Installation" section as that provides the most structured procedures. I will focus on the English part of the manual.
#
# **I. Step-by-Step Installation Procedure: Door Removal for Entrance**
#
# **Procedure:**
#
# 1.  **Detach the fridge doors**
#     1.  With the doors closed, use a Phillips screwdriver to remove the screws (x3) from the top cover. Pull up and remove the top cover with the connectors.
#     2.  Disconnect the two wire connectors on the left door.
#     3.  Disconnect the water tube from the coupler on the left door as shown. (This step does not apply to the models without the AutoFill Pitcher and the water dispenser.)
#     4.  Gently draw up the clamp in several steps.
#     5.  Pull up the clamp to remove.
#     6.  Open the door 90 degrees. While holding the door, pull up and remove the top hinge.
#     7.  Gently pull up the door vertically to remove.
#     8.  Lay the door down on a flat surface.
#     9.  Repeat steps 1-8 for the other door, except for step 3. There is no water tube on the right side door. (Step 2 does not apply to the models without the Showcase door.)
# 2.  **Reattach the fridge doors**
#     1.  To reattach the freezer drawer
#     2.  Gently lift up the door vertically to place it back to the hinge.
#     3.  Reattach the top hinge and screw the component tightly. Be careful not to damage the connector wires.
#     4.  Reinstall the clamp to fix the water tube with coupler.
#     5.  Connect the wire connectors.
#     6.  Connect the water tube.
#     7.  Repeat steps 1-5 for the other door. (Step 5 does not apply to the models without the Showcase door.)
#     8.  Attach the top cover with the front side first, and then press down on its back to get it into position. Then, tighten the screws (x3).
#
# **Tools:**
#
# *   Phillips screwdriver
# *   Flat-head screwdriver
# *   Socket wrench [3]/8" (10 mm)
# *   Pliers
# *   Allen wrench [1]/4" (5 mm)
#
# **Time Estimate:**
#
# *   Approximately 30-60 minutes, depending on experience.
#
# **Q&A Pairs:**
#
# *   **Q:**  What is the first step to remove the refrigerator doors for easier entrance?
#     *   **A:**  With the doors closed, use a Phillips screwdriver to remove the screws (x3) from the top cover. Pull up and remove the top cover with the connectors.
# *   **Q:** Is it safe to remove both refrigerator doors at the same time?
#     *   **A:**  No, make sure to remove one door at a time to prevent injuries if a door falls.
# *   **Q:** Is it necessary to disconnect the water tube when removing the right door?
#     *   **A:** No, there is no water tube on the right side door.
#
# **II. Step-by-Step Installation Procedure: Leveling the Refrigerator**
#
# **Procedure:**
#
# 1.  Locate the special screws (levelers) on the front legs of the refrigerator.
# 2.  Use a flat-head screwdriver to turn the levelers.
# 3.  To adjust the height of the left side: Insert a flat-head screwdriver into the leveler of the left side front leg. Turn the leveler clockwise to raise the left side or turn it counterclockwise to lower.
# 4.  To adjust the height of the right side: Insert a flat-head screwdriver into the leveler of the right side front leg. Turn the leveler clockwise to raise the right side or turn it counterclockwise to lower.
#
# **Tools:**
#
# *   Flat-head screwdriver
#
# **Time Estimate:**
#
# *   Approximately 5-10 minutes.
#
# **Q&A Pairs:**
#
# *   **Q:** What tool is needed to level the refrigerator?
#     *   **A:** A flat-head screwdriver.
# *   **Q:** What direction do you turn the leveler to raise the left side of the refrigerator?
#     *   **A:** Turn the leveler clockwise.
# *    **Q:** What do you need to ensure before starting the levelling procedure?
#      *   **A:** The levelling must be performed with the refrigerator empty.
# **III. Step-by-Step Installation Procedure: Connecting the Water Dispenser Line**
#
# **Procedure:**
#
# 1. Shut off the main water source.
# 2. Insert the pipe clamp (B) and the shutoff valve (C) into the cold water line (A).
# 3. Connect the water line installation kit (A) to the shutoff valve (B).
# 4.  Connect the household water line to the assembled compression fitting.
# 5. Tighten the compression nut (B) onto the compression fitting. Do not over-tighten the compression nut (B).
# 6. Turn the water on and check for any leakage. If you find water drops or leakage in the connection areas, turn off the main water supply. Check the connections and, if necessary, tighten.
# 7. Flush 3 gallons of water through the filter before drinking or using the water from the refrigerator. (Flush approximately 5-6 minutes.) To flush, press a large glass or cup against the water dispenser lever. Fill the glass, empty it, and then repeat.
# 8. After you turn on the refrigerator, let the ice maker make ice for 1 to 2 days. Over that period of time, throw out the first 1 or 2 buckets of ice the ice maker makes to ensure all impurities have been removed from the water line.
#
# **Tools (Items you must purchase):**
#
# *   1/4" copper tubing
# *   1/4" compression nut (1 pc)
# *   Ferrule (2 pc)
# *   1/4" plastic tubing  Molded end (Bulb)
# *   1/4" compression nut (1 pc)
#
# **Time Estimate:**
#
# *   Approximately 60-90 minutes.
#
# **Q&A Pairs:**
#
# *   **Q:** What must be turned off first when connecting the water dispenser line?
#     *   **A:**  Shut off the main water source.
# *   **Q:** What should be done with the initial batches of ice produced?
#     *   **A:** Throw out the first 1 or 2 buckets of ice to remove impurities in the water supply system.
# *   **Q:** How much water should be flushed through the filter before drinking or using the water from the refrigerator?
#      *   **A:** 3 gallons (approximately 5-6 minutes).
#
# I hope this is helpful! Let me know if you need any other sections processed.
#
#
# --- Calling generate_step_by_step_qa_deepseek ---
# {'Generations': [{'Question': 'How to level the refrigerator?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Ensure the refrigerator is empty.', 'Tools': [], 'Warning': 'Leveling must be performed with the refrigerator empty. Make sure no food items are inside the refrigerator.'}, {'Number': 2, 'Action': 'Locate the levelers on the front legs of the refrigerator.', 'Tools': [], 'Warning': ''}, {'Number': 3, 'Action': 'To adjust the height of the left side: Insert a flat-head screwdriver into the leveler of the left side front leg. Turn the leveler clockwise to raise the left side or turn it counterclockwise to lower.', 'Tools': [], 'Warning': ''}, {'Number': 4, 'Action': 'To adjust the height of the right side: Insert a flat-head screwdriver into the leveler of the right side front leg. Turn the leveler clockwise to raise the right side or turn it counterclockwise to lower.', 'Tools': [], 'Warning': ''}, {'Number': 5, 'Action': 'For safety reasons, adjust the front a little higher than the rear.', 'Tools': [], 'Warning': ''}], 'TotalTime': '5-10 mins', 'RiskLevel': 'Low'}, 'Category': 'Installation'}, {'Question': 'How to replace the water filter?', 'Answer': {'Steps': [{'Number': 1, 'Action': 'Ensure that the water supply line is turned off.', 'Tools': [], 'Warning': ''}, {'Number': 2, 'Action': 'Rotate the filter to remove.', 'Tools': [], 'Warning': ''}, {'Number': 3, 'Action': 'Install the new water filter.', 'Tools': [], 'Warning': 'Use only filters provided or approved by Samsung'}, {'Number': 4, 'Action': 'Close the filter cartridge cache', 'Tools': [], 'Warning': ''}, {'Number': 5, 'Action': 'Maintein the Filter Reset button on the main panel for 3 seconds', 'Tools': [], 'Warning': ''}, {'Number': 6, 'Action': 'Make sure the water is turned on and let the water flow by the dispenser during 7 minutes', 'Tools': [], 'Warning': 'May cause flood'}], 'TotalTime': '10-15 mins', 'RiskLevel': 'Low'}, 'Category': 'Maintenance'}]}
#
# --- Calling generate_step_by_step_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ProcedureQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_step_by_step_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I remove and re-install the refrigerator doors to fit through a narrow entrance?"\n    ],\n    "Answers": [\n      "Removing the refrigerator doors requires careful disconnection of wiring and water lines, if applicable. Ensure power is disconnected before starting and keep all parts secure to prevent damage or injury during the process of door removal and reinstallation."\n    ],\n    "Metadata": {\n      "ProcedureType": "Sequential Guidance",\n      "Complexity": "Detailed Technical Steps"\n    },\n    "ProcedureDetails": {\n      "Tools": [\n        "Phillips screwdriver",\n        "Flat-head screwdriver",\n        "Socket wrench [3]/8\\" (10 mm)",\n        "Pliers",\n        "Allen wrench [1]/4\\" (5 mm)"\n      ],\n      "TimeEstimates": [\n        "15-30 minutes per door, depending on familiarity and model complexity"\n      ],\n      "Steps": [\n        "1. **Disconnect Power:** Unplug the power cord of the refrigerator before removing the doors.",\n        "2. **Remove Top Cover:** Use a Phillips screwdriver to remove the screws (x3) from the top cover and gently pull up and remove the top cover with the connectors.",\n        "3. **Disconnect Connectors (Left Door):** Disconnect the two wire connectors on the left door. Note that the position of the connectors differs with the model.",\n        "4. **Disconnect Water Tube (Left Door):** Disconnect the water tube from the coupler on the left door as shown. (This step does not apply to models without the AutoFill Pitcher and the water dispenser.) Gently draw up the clamp in several steps to prevent finger injuries. Pull up the clamp to remove.",\n        "5. **Remove Top Hinge:** Open the door 90 degrees. While holding the door, pull up and remove the top hinge. Be careful not to damage the connector wires when you remove the hinge.",\n        "6. **Remove Door:** Gently pull up the door vertically to remove it. Do not apply excessive force to the door to prevent it from falling and causing physical injury.",\n        "7. **Lay Down Door:** Lay the door down on a flat surface.",\n        "8. **Repeat for Other Door:** Repeat steps 1-7 for the other door, except for step 4. There is no water tube on the right side door. Note that step 3 does not apply to models without the Showcase door.",\n        "9. **Re-install Doors:** To re-install, gently lift the door vertically and align it with the bottom hinge.",\n        "10. **Re-attach Top Hinge:** Re-attach the top hinge, ensuring that the connector wires are not damaged.",\n        "11. **Reconnect Water Tube (Left Door):** Reconnect the water tube, if applicable, ensuring a tight seal.",\n        "12. **Connect Wire Connectors:** Connect the wire connectors, ensuring they are properly connected to prevent display malfunctions.",\n        "13. **Attach Top Cover:** Attach the top cover, starting with the front side first, and then press down on its back to get it into position. Then, tighten the screws (x3).",\n         "14. **Verify Water Line Connection:**  To prevent water leaks from the dispenser, ensure the water line is fully connected. Make sure both tubes of the water line are inserted fully to the center of transparent coupler (A) or the guidelines (B)."\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 4 generate_faq_qa

# %%
#original
def generate_faq_qa(text):
    """Anticipated user questions"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Predict common FAQs from Samsung users based on this text.
    Phrase questions as natural customer inquiries.
    Include 'Why', 'How', and 'What if' scenarios.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_faq_qa_deepseek(text):
    """Generates categorized FAQs with popularity metadata in JSON format.

    Returns:
        JSON with question taxonomy, search keywords, and related products.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate structured FAQs from Samsung documentation with:
    1. Natural phrasing mirroring customer voice
    2. Taxonomy:
       - "Type": ["Why", "How", "What If", "Setup", "Troubleshooting"]
       - "FrequencyScore": 1-5 (5=most common)
    3. Related product models
    4. Search keywords (3-5 per question)

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "...",
        "Answer": "...",
        "Metadata": {{
          "Type": "Why",
          "FrequencyScore": 4,
          "RelatedProducts": ["SM-S901B", "QE65QN900B"],
          "Keywords": ["battery drain", "optimization"]
        }}
      }}
    - Sort by descending FrequencyScore
    - Deduplicate similar questions

    Example:
    {{
      "Generations": [
        {{
          "Question": "Why does my Galaxy phone get hot during video calls?",
          "Answer": "Processor-intensive apps...",
          "Metadata": {{
            "Type": "Why",
            "FrequencyScore": 5,
            "RelatedProducts": ["SM-S918B", "SM-S711B"],
            "Keywords": ["overheating", "thermal", "video chat"]
          }}
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse FAQ data"}


#Google AI STudio
def generate_faq_qa_google(text):
    """Generates anticipated user questions (FAQs) and answers in JSON format."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Predict common Frequently Asked Questions (FAQs) from Samsung users based on the following support document text.

    Phrase the questions as natural customer inquiries, reflecting how a user might actually ask.
    Include 'Why', 'How', and 'What if' scenarios to cover a range of common question types.
    For each question, also generate a concise and helpful answer.
    Use consumer-friendly language for both questions and answers.

    Present the output as a list of FAQ Question-Answer pairs in JSON format. Each pair should have the keys "Question" and "Answer".

    Text: {text}

    Output Format (example):
    [
      {{ "Question": "...", "Answer": "..." }},
      {{ "Question": "...", "Answer": "..." }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        faq_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        faq_data = [] # Implement a robust fallback text parser

    output_json = {
        "Generations": [
            {"FAQs": faq_data} # Assuming model outputs a list of dictionaries as requested
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet

def generate_faq_qa_sonnet(text):
    """Generate structured user FAQ Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create FAQ Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Natural customer inquiry using 'Why', 'How', 'What if'"
        ],
        "Answers": [
          "Clear, concise response addressing user concern"
        ],
        "Metadata": {{
          "QuestionTypes": ["Why", "How", "What if"],
          "UserPerspective": "Common customer inquiries"
        }},
        "FAQCategories": [
          "Common user pain points",
          "Anticipated information needs"
        ]
      }}
    }}

    Requirements:
    - Realistic, conversational questions
    - Comprehensive yet brief answers
    - Cover multiple inquiry types
    - 1-2 sentence responses

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_faq_qa ---")
test_qa_generators("generate_faq_qa", content)
# Out:
# --- generate_faq_qa ---
#
# --- Calling generate_faq_qa ---
# Okay, based on the Samsung refrigerator user manual, here are some common FAQs phrased as natural customer inquiries, including "Why," "How," and "What if" scenarios:
#
# **General Usage & Features:**
#
# *   "My refrigerator isn't cooling enough. What could be the problem?"
# *   "Why is my refrigerator making a strange buzzing noise?"
# *   "How do I adjust the temperature in the fridge and freezer?"
# *   "How do I use the Power Cool and Power Freeze functions?"
# *   "What's the best way to organize food in my refrigerator to keep it fresh?"
# *   "What's the purpose of the FlexZone drawer, and how do I use it properly?"
# *   "Why are my fruits and vegetables freezing in the FlexZone?"
# *   "What if the temperature display is blinking? What does this mean?"
# *    "Why is there condensation forming inside my refrigerator?"
#
# **Water Dispenser & Ice Maker:**
#
# *   "Why is the water pressure so low from my refrigerator's water dispenser?"
# *   "How do I connect the water line to my Samsung refrigerator?"
# *   "How often do I need to change the water filter, and where do I buy a new one?"
# *   "How do I reset the filter indicator light after replacing the water filter?"
# *   "What kind of water should I use in the AutoFill pitcher?"
# *   "Why does my ice maker not dispense ice, even though it seems to be working?"
# *   "What if my ice maker makes a repeated chime sound?"
# * "How do I clean the AutoFill Pitcher and the water dispenser?"
#
# **SmartThings & Smart Grid:**
#
# *   "How do I connect my refrigerator to the SmartThings app?"
# *   "Why can't I find the 'SmartThings' app in the app store?"
# *   "What if my SmartThings app can't find my refrigerator?"
# *   "How does the Smart Grid function work, and do I need it?"
# *   "Why isn't the Delay Defrost Capability working normally?"
# *   "How do I disable the Smart Grid function if I don't want it controlling my refrigerator?"
#
# **Installation & Maintenance:**
#
# *   "How much space do I need around my refrigerator for proper ventilation?"
# *   "How do I level my refrigerator after installation?"
# *   "How do I remove the doors of my refrigerator to fit through a narrow doorway?"
# *   "How do I replace a light bulb inside my refrigerator?"
# *   "What should I do before cleaning my refrigerator?"
# *   "What cleaning products are safe to use on my Samsung refrigerator?"
#
# **Safety & Warnings:**
#
# *   "Why does my refrigerator have a 'California Proposition 65' warning?"
# *   "Why does the manual say the refrigerator contains flammable gas?"
# *   "What should I do if I smell gas coming from my refrigerator?"
# *   "What should I do with my old refrigerator to prevent child entrapment?"
#
# **Warranty & Service:**
#
# *   "What is covered under the Samsung refrigerator warranty?"
# *   "How do I get warranty service for my Samsung refrigerator?"
# *   "What is the lifespan of a Samsung refrigerator?"
#
# These FAQs cover a wide range of user concerns, from basic operation and troubleshooting to safety and warranty information. They're designed to be easily understood by the average Samsung refrigerator owner.
#
#
# --- Calling generate_faq_qa_deepseek ---
# {'Generations': [{'Question': 'Why is my refrigerator making so much noise?', 'Answer': 'These sounds are normal....', 'Metadata': {'Type': 'Why', 'FrequencyScore': 5, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['refrigerator', 'noise', 'loud', 'sound', 'normal']}}, {'Question': "Why isn't my water dispenser working?", 'Answer': 'Water line is not connected...', 'Metadata': {'Type': 'Troubleshooting', 'FrequencyScore': 5, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['water', 'dispenser', 'not working', 'pressure']}}, {'Question': 'Why is my refrigerator getting warm and not cooling properly?', 'Answer': 'Power cord is not plugged in properly...', 'Metadata': {'Type': 'Troubleshooting', 'FrequencyScore': 5, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['refrigerator', 'warm', 'not cooling', 'temperature']}}, {'Question': 'How do I reset the water filter indicator?', 'Answer': 'After about 6 months...press and hold Filter Reset for 3 seconds.', 'Metadata': {'Type': 'How', 'FrequencyScore': 4, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['water filter', 'reset', 'indicator', 'replace']}}, {'Question': 'How do I remove odors from my refrigerator?', 'Answer': 'Spoiled food...Make sure strong smelling food is wrapped airtight.', 'Metadata': {'Type': 'How', 'FrequencyScore': 4, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['refrigerator', 'odors', 'smell', 'remove', 'food']}}, {'Question': 'What do I do if condensation is forming inside my refrigerator?', 'Answer': 'If the door is left open, moisture enters the refrigerator...', 'Metadata': {'Type': 'What If', 'FrequencyScore': 4, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['condensation', 'interior', 'walls', 'moisture']}}, {'Question': 'How do I install the Samsung refrigerator?', 'Answer': 'Select a site...the refrigerator must be leveled on a flat, solid floor.', 'Metadata': {'Type': 'Setup', 'FrequencyScore': 3, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['install', 'refrigerator', 'setup', 'space', 'level']}}, {'Question': 'How do I connect my refrigerator to SmartThings?', 'Answer': 'Visit the Google Play Store, Galaxy Apps...', 'Metadata': {'Type': 'How', 'FrequencyScore': 3, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['SmartThings', 'connect', 'WiFi', 'app', 'network']}}, {'Question': 'How do I activate Sabbath mode?', 'Answer': 'To activate Sabbath Mode, press and hold Door Alarm and AutoFill Pitcher...', 'Metadata': {'Type': 'How', 'FrequencyScore': 2, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['Sabbath Mode', 'activate', 'Door Alarm', 'AutoFill Pitcher']}}, {'Question': 'What do I need to use the Energy Management and Smart Grid functions?', 'Answer': 'A wireless access point (router)...connect your refrigerator to your home Wi-Fi network...', 'Metadata': {'Type': 'What If', 'FrequencyScore': 1, 'RelatedProducts': ['RF23BB8*****', 'RF29BB8*****'], 'Keywords': ['Energy Management', 'Smart Grid', 'router', 'Wi-Fi']}}]}
#
# --- Calling generate_faq_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "FAQs": []
#     }
#   ]
# }
#
# --- Calling generate_faq_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "RefrigeratorFAQ": {\n    "Questions": [\n      "Why is my Samsung refrigerator not cooling properly?",\n      "How do I reset the water filter on my Samsung refrigerator?",\n      "What if my refrigerator is making strange noises?",\n      "Why is there condensation inside my Samsung refrigerator?",\n      "How do I connect my Samsung refrigerator to SmartThings?",\n      "What if my ice maker is not making ice?",\n      "Why isn\'t water dispensing from my refrigerator?",\n      "How often should I replace the water filter?"\n    ],\n    "Answers": [\n      "Check the power cord, temperature settings, and ensure vents are not blocked; ensure proper clearance around the unit for ventilation.",\n      "Press and hold the \'Filter Reset\' button on the control panel for 3 seconds to reset the filter life cycle.",\n      "Refer to the manual\'s troubleshooting section for normal operating sounds; if the noise persists, contact Samsung support.",\n      "Ensure the door is closed properly and food is wrapped airtight; also, check humidity levels and avoid overpacking.",\n      "Download the SmartThings app, create a Samsung account, and follow the in-app instructions to connect your refrigerator.",\n      "Verify the ice maker is turned on, the freezer temperature is below 0°F (-18°C), and the water line is properly connected.",\n      "Check the water line connection, ensure the water supply is turned on, and verify the water filter isn\'t clogged.",\n      "Samsung recommends replacing the water filter every 6 months, or approximately every 300 gallons (1200 L), for optimal performance."\n    ],\n    "Metadata": {\n      "QuestionTypes": ["Why", "How", "What if"],\n      "UserPerspective": "Common troubleshooting and operation inquiries"\n    },\n    "FAQCategories": [\n      "Troubleshooting",\n      "Operation",\n      "Maintenance"\n    ]\n  }\n}\n```'}}

# %% [markdown]
# ### Number 5 generate_troubleshooting_qa

# %%
#original
def generate_troubleshooting_qa(text):
    """Diagnostic-focused pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create advanced troubleshooting pairs including:
    - Error symptoms - Diagnostic checks - Repair procedures
    Format solutions with priority levels (Critical/High/Medium).
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_troubleshooting_qa_deepseek(text):
    """Generates machine-actionable diagnostic guides with error codes.

    Returns:
        JSON with nested symptom analysis, error codes, and repair workflows.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create advanced troubleshooting pairs from Samsung docs with:
    1. Symptom pattern matching (e.g., "Boot loop after OS update")
    2. Diagnostic codes following TROUB-XXXX format
    3. Repair steps with required tools/time
    4. Priority matrix (Critical=hardware safety risk)

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Observed symptom]",
        "Answer": {{
          "Symptoms": ["Symptom 1", "Symptom 2"],
          "Diagnostics": ["Check X", "Test Y"],
          "RepairSteps": ["1. Replace component", "2. Flash firmware"],
          "Priority": "Critical",
          "ErrorCode": "TROUB-0238",
          "ToolsRequired": ["GJ-FT55", "Multimeter"],
          "AvgRepairTime": "45 mins"
        }},
        "RelatedComponents": ["Battery", "Motherboard"]
      }}
    - Sort by Priority then AvgRepairTime
    - Validate ErrorCode format: TROUB- followed by 4 digits

    Example:
    {{
      "Generations": [
        {{
          "Question": "Phone restarts randomly during calls",
          "Answer": {{
            "Symptoms": ["Thermal throttling", "Signal drops"],
            "Diagnostics": ["Check battery swelling", "Run ANT+ test"],
            "RepairSteps": ["Replace battery module SPX-897"],
            "Priority": "Critical",
            "ErrorCode": "TROUB-1151",
            "ToolsRequired": ["GJ-TH92 thermal gun"],
            "AvgRepairTime": "25 mins"
          }},
          "RelatedComponents": ["Battery", "Antenna"]
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse diagnostic protocol"}


#Google AI STudio
def generate_troubleshooting_qa_google(text):
    """Advanced troubleshooting pairs in JSON format with priority levels."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate advanced troubleshooting Question and Answer pairs from the following Samsung support document text.

    Include for each troubleshooting pair:
    - Error symptoms (brief description)
    - Diagnostic checks to perform
    - Repair procedures or resolution steps

    Format each solution with a priority level: "Critical", "High", or "Medium" based on the severity and urgency of the issue.

    Use consumer-friendly language. Keep answers concise and step-by-step where applicable.

    Present the output as a list of troubleshooting Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Priority" ("Critical", "High", "Medium"), "Question" (error symptom description), "Answer" (troubleshooting/resolution steps), and optionally "ErrorSymptoms", "DiagnosticChecks", "RepairProcedures" (as lists of strings).

    Text: {text}

    Output Format (example):
    [
      {{ "Priority": "Critical", "Question": "...", "Answer": "...", "ErrorSymptoms": [...], "DiagnosticChecks": [...], "RepairProcedures": [...] }},
      {{ "Priority": "Medium", "Question": "...", "Answer": "...", "ErrorSymptoms": [...], "DiagnosticChecks": [...], "RepairProcedures": [...] }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        troubleshooting_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        troubleshooting_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"TroubleshootingQAPairs": troubleshooting_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_troubleshooting_qa_sonnet(text):
    """Generate structured diagnostic Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create troubleshooting Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific error or diagnostic scenario"
        ],
        "Answers": [
          "Comprehensive troubleshooting solution"
        ],
        "Metadata": {{
          "PriorityLevels": ["Critical", "High", "Medium"],
          "DiagnosticApproach": "Systematic problem resolution"
        }},
        "TroubleshootingDetails": {{
          "ErrorSymptoms": ["Detailed problem description"],
          "DiagnosticChecks": ["Step-by-step verification"],
          "RepairProcedures": ["Solution steps"]
        }}
      }}
    }}

    Requirements:
    - Clear error symptom descriptions
    - Systematic diagnostic approach
    - Priority-based solutions
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_troubleshooting_qa ---")
test_qa_generators("generate_troubleshooting_qa", content)
# Out:
# --- generate_troubleshooting_qa ---
#
# --- Calling generate_troubleshooting_qa ---
# Okay, here are the troubleshooting pairs based on the provided user manual, formatted with priority levels.
#
# **Note:**  These are based *solely* on the information in the document.  I've tried to categorize them logically and assign realistic priorities, but a real technician would use experience and other resources.  Where the "Solution" is simply to call a service center, I've provided it, but that's not a complete troubleshooting step.
#
# Also, to clarify, it is impossible to determine the difficulty level of the repair procedures, nor estimate costs from this document.
#
# **1. Refrigerator/Freezer Not Operating, Temperature Warm**
#
# *   **Error Symptom:** Refrigerator/freezer does not operate; refrigerator/freezer temperature is warm.
#
# *   **Diagnostic Checks:**
#
#     *   Check power cord connection.
#     *   Verify temperature control settings.
#     *   Assess refrigerator location (near heat source, sunlight).
#     *   Check clearance around refrigerator.
#     *   Inspect for overloaded conditions or blocked vents.
#
# *   **Repair Procedures:**
#
#     *   Ensure power cord is properly plugged in.
#     *   Set the temperature lower.
#     *   Relocate the refrigerator away from heat sources and direct sunlight.
#     *   Provide adequate clearance (2.5 inches) around the refrigerator.
#     *   Reduce refrigerator load; clear blocked vents.
#
# *   **Priority:** Critical
#
# **2. Refrigerator Over-Cooling**
#
# *   **Error Symptom:** Refrigerator/Freezer is over-cooling
# *   **Diagnostic Checks:**
#
#     * Verify temperature control settings
#
# *   **Repair Procedures:**
#     * Set the temperature higher
#
# *   **Priority:** Medium
#
# **3. Interior Wall Hot**
#
# *   **Error Symptom:** Interior wall is hot.
# *   **Diagnostic Checks:**
#
#     * N/A (Informational only)
#
# *   **Repair Procedures:**
#
#     * N/A (Heat-proof piping is normal design)
#
# *   **Priority:** Low (Informational)
#
# **4. Refrigerator Has Odors**
#
# *   **Error Symptom:** Refrigerator has odors.
# *   **Diagnostic Checks:**
#
#     *   Check for spoiled food.
#     *   Check if food with strong odors is properly wrapped.
#
# *   **Repair Procedures:**
#
#     *   Clean the refrigerator and remove any spoiled food.
#     *   Ensure strong-smelling food is wrapped airtight.
#
# *   **Priority:** High
#
# **5. Frost Around Vents**
#
# *   **Error Symptom:** Frost around the vents.
# *   **Diagnostic Checks:**
#
#     * Ensure there are no foods blocking vents.
#
# *   **Repair Procedures:**
#
#     * Make sure no food blocks the refrigerator vents.
#
# *   **Priority:** High
#
# **6. Frost on Interior Walls**
#
# *   **Error Symptom:** Frost on Interior Walls
# *   **Diagnostic Checks:**
#
#     * Ensure the door is closed properly
#     * Check food for blocking
#     * Clean Door Gasket
#
# *   **Repair Procedures:**
#
#     * Ensure the door is closed properly
#     * Make sure food does not block the door. Clean the door gasket.
#
# *   **Priority:** High
#
# **7. Fruits/Vegetables Freezing**
#
# *   **Error Symptom:** Fruits or Vegetables are frozen
# *   **Diagnostic Checks:**
#
#     *  Check if they are stored in the FlexZone
#
# *   **Repair Procedures:**
#
#     * Do not store most kinds of fruit or vegetables in the FlexZone.
#
# *   **Priority:** Medium
#
# **8. Condensation Forms on Interior Walls**
#
# *   **Error Symptom:** Condensation forms on the interior walls.
# *   **Diagnostic Checks:**
#
#     * Check if the door is left open
#     * Check for foods with high moisture content
#
# *   **Repair Procedures:**
#
#     * Remove the moisture and do not leave a door open for extended periods of time.
#     * Make sure food is wrapped airtight.
#
# *   **Priority:** High
#
# **9. Water Flow Weaker Than Normal**
#
# *   **Error Symptom:** Water flow is weaker than normal.
# *   **Diagnostic Checks:**
#
#     * Check Water pressure
#
# *   **Repair Procedures:**
#
#     * Make sure the water pressure is between 30- 125 psi (206-861 kPa)
#
# *   **Priority:** Medium
#
# **10. Ice Maker Makes a Buzzing Sound**
#
# *   **Error Symptom:** Ice maker makes a buzzing sound.
# *   **Diagnostic Checks:**
#
#     * Check water connection to refrigerator.
#
# *   **Repair Procedures:**
#
#     * Turn off the Ice Maker.
#
# *   **Priority:** Medium
#
# **11. Ice Maker Does Not Make Ice**
#
# *   **Error Symptom:** Ice maker does not make ice.
# *   **Diagnostic Checks:**
#
#     * Check if it is a new install
#     * Verify Freezer Temperature
#     * Is the Ice Maker on?
#
# *   **Repair Procedures:**
#
#     * Wait for 12 hours for the refrigerator to make ice.
#     * Set the freezer temperature below 0 °F (-18 °C) or -4 °F (-20 °C) in warm ambient air.
#     * Turn on the ice maker.
#
# *   **Priority:** High
#
# **12. Ice Does Not Dispense**
#
# *   **Error Symptom:** Ice does not dispense.
# *   **Diagnostic Checks:**
#
#     * Is dispenser used often? (Ice Jam)
#     * Check the ice bucket is inserted properly
#     * Check waterline
#
# *   **Repair Procedures:**
#
#     * If you won't be using the refrigerator for a long time, empty the ice bucket and turn off the ice maker.
#     * Make sure the ice bucket is properly inserted.
#     * Check the water installation conditions.
#
# *   **Priority:** High
#
# **13. Water Does Not Dispense**
#
# *   **Error Symptom:** Water does not dispense.
# *   **Diagnostic Checks:**
#
#     *   Check water line.
#     *   Check Water Filter for Third Party installation.
#     *   Is the water filter in need of replacement?
#
# *   **Repair Procedures:**
#
#     *   Check the water installation conditions.
#     *   Use only Samsung-provided or approved filters.
#     *   Replace the water filter.
#
# *   **Priority:** High
#
#
# --- Calling generate_troubleshooting_qa_deepseek ---
# {'Generations': [{'Question': 'Refrigerant leaking from the pipe work causing ignition.', 'Answer': {'Symptoms': ['Refrigerant odor', 'Visible fluid near refrigeration components', 'No cooling'], 'Diagnostics': ['Inspect refrigeration lines for damage', 'Use a refrigerant leak detector', 'Evacuate & Recharge refrigerant, then pressure test system'], 'RepairSteps': ['Evacuate all remaining refrigerant.', 'Replace damaged refrigeration lines', 'Replace compressor if damaged', 'Recharge refrigerant to specified level according to model service sheet.'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-0001', 'ToolsRequired': ['Refrigerant recovery machine', 'Vacuum pump', 'Welding/brazing equipment', 'Manifold gauge set', 'Nitrogen', 'GJ-TH92 thermal gun'], 'AvgRepairTime': '120 mins'}, 'RelatedComponents': ['Compressor', 'Evaporator', 'Condenser', 'Refrigerant Lines']}, {'Question': 'Severe electrical shock due to faulty grounding.', 'Answer': {'Symptoms': ['Tingling sensation when touching appliance', 'Frequent fuse blowouts', 'Electric shock during operation'], 'Diagnostics': ['Check continuity of grounding wire', 'Measure voltage between chassis and ground', 'Inspect power cord and outlet for damage'], 'RepairSteps': ['Replace damaged power cord', 'Correctly ground the appliance to a known good ground.', 'Replace wall outlet.'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-0002', 'ToolsRequired': ['Multimeter', 'Wire stripper', 'Screwdrivers'], 'AvgRepairTime': '30 mins'}, 'RelatedComponents': ['Power Cord', 'Grounding Wire', 'Electrical Outlet']}, {'Question': 'Major internal water leak due to broken filter housing, electric shock hazard.', 'Answer': {'Symptoms': ['Visible water pooling inside refrigerator compartment', 'Tripped circuit breaker', 'Water leaking onto electrical components'], 'Diagnostics': ['Inspect water filter housing for cracks or damage', 'Check water lines for leaks', 'Test continuity of affected electrical components'], 'RepairSteps': ['Turn off water supply', 'Disconnect power', 'Replace water filter housing assembly', 'Dry all affected areas', 'Inspect wire connections for possible corrosion, replace as needed'], 'Priority': 'Critical', 'ErrorCode': 'TROUB-0123', 'ToolsRequired': ['Screwdrivers', 'GJ-TH92 thermal gun', 'Multimeter'], 'AvgRepairTime': '60 mins'}, 'RelatedComponents': ['Water Filter', 'Water Filter Housing', 'Water Lines']}, {'Question': 'Complete loss of cooling after power surge', 'Answer': {'Symptoms': ['No lights inside refrigerator', 'Compressor not running', 'Warm temperature inside both compartments'], 'Diagnostics': ['Check main power fuse', 'Test compressor relay', 'Inspect main control board for burned components'], 'RepairSteps': ['Replace main power fuse', 'Replace compressor relay', 'Replace main control board'], 'Priority': 'High', 'ErrorCode': 'TROUB-0385', 'ToolsRequired': ['Multimeter', 'Screwdrivers'], 'AvgRepairTime': '90 mins'}, 'RelatedComponents': ['Main Control Board', 'Compressor Relay', 'Fuse']}, {'Question': 'Excessive frost buildup on interior walls.', 'Answer': {'Symptoms': ['Frost on interior walls', 'Ice buildup around vents', 'Frequent defrost cycles'], 'Diagnostics': ['Inspect door gasket for seal', 'Check defrost heater element', 'Test defrost timer/thermostat'], 'RepairSteps': ['Replace door gasket', 'Replace defrost heater element', 'Replace defrost timer/thermostat'], 'Priority': 'Medium', 'ErrorCode': 'TROUB-1042', 'ToolsRequired': ['Screwdrivers', 'Multimeter'], 'AvgRepairTime': '60 mins'}, 'RelatedComponents': ['Door Gasket', 'Defrost Heater', 'Defrost Timer']}, {'Question': 'Ice maker not producing ice, water line is connected.', 'Answer': {'Symptoms': ['No ice production', 'Water dispenser works', 'Ice maker arm in down position'], 'Diagnostics': ['Check ice maker fill tube for ice blockage', 'Test ice maker thermostat', 'Verify water pressure to refrigerator'], 'RepairSteps': ['Thaw ice maker fill tube', 'Replace ice maker thermostat', 'Replace ice ma ...
#
# --- Calling generate_troubleshooting_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "TroubleshootingQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_troubleshooting_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "The refrigerator is not operating at all, and the interior is not cooling.",\n      "The refrigerator\'s interior is warmer than the set temperature.",\n      "There is excessive frost buildup around the vents inside the refrigerator.",\n      "The water dispenser is dispensing water slower than usual.",\n      "The ice maker is not producing any ice."\n    ],\n    "Answers": [\n      "Check if the power cord is properly plugged into the electrical outlet; ensure the outlet is functioning correctly.",\n      "Verify that the temperature control settings are appropriately set for both the refrigerator and freezer compartments, lower the temperature setting if necessary.",\n      "Ensure that food items are not obstructing the vents, as this can impede proper airflow and cause frost buildup; rearrange items to ensure unobstructed airflow.",\n      "Confirm that the water line is correctly connected and that the water supply is turned on, the pressure should be between 30-125 psi.",\n      "Ensure the ice maker is turned on, and the freezer temperature is set below 0°F (-18°C)."\n    ],\n    "Metadata": {\n      "PriorityLevels": ["High", "High", "Medium", "Medium", "Medium"],\n      "DiagnosticApproach": "Systematic problem resolution"\n    },\n    "TroubleshootingDetails": {\n      "ErrorSymptoms": [\n        "No power to the refrigerator; interior is not cooling.",\n        "Refrigerator interior is not maintaining set temperature.",\n        "Excessive frost accumulation around vents.",\n        "Slow or weak water flow from the dispenser.",\n        "The ice maker is not producing ice at all."\n      ],\n      "DiagnosticChecks": [\n        "Check power cord and outlet; verify temperature settings; ensure proper ventilation.",\n        "Verify temperature settings; check door seals; ensure proper ventilation.",\n        "Inspect vents for obstructions; check door seals.",\n        "Verify water line connection; check water pressure.",\n        "Ensure the ice maker is on; check the freezer temperature."\n      ],\n      "RepairProcedures": [\n        "Plug in the power cord or test outlet; adjust temperature settings; clear ventilation.",\n        "Adjust temperature settings; clean door seals; clear ventilation.",\n        "Clear obstructions; clean door seals.",\n        "Ensure connection; check water pressure.",\n        "Turn on ice maker; lower freezer temperature."\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 6 generate_feature_explanation_qa

# %%
#original
def generate_feature_explanation_qa(text):
    """Technology deep-dive pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Explain Samsung technologies with Q&A pairs covering:
    - Technical specifications - Use cases - Compatibility notes
    Include diagrams in markdown when relevant.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_feature_explanation_qa_deepseek(text):
    """Generates standardized technical explanations with spec matrices.

    Returns:
        JSON with nested specifications, compatibility tables, and visual references.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create technology deep-dive Q&A pairs with:
    1. Technical specifications in key:value format
    2. Compatibility matrices (Device ↔ Feature Support)
    3. Use case scenarios with required settings
    4. Official diagram references instead of markdown

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Technology inquiry]",
        "Answer": {{
          "Overview": "2-sentence summary",
          "TechnicalSpecs": {{
            "Parameter": "Value",
            "MeasurementUnit": "Hz/nm/mm"
          }},
          "Compatibility": {{
            "GalaxyS24": "Full",
            "GalaxyZFold5": "Partial"
          }},
          "DiagramReference": "KB-12345-fig3"
        }},
        "FeatureType": "Display/Connectivity/AI"
      }}
    - Use standardized units (MHz not Mhz)
    - Replace markdown with Samsung Knowledge Base references

    Example:
    {{
      "Generations": [
        {{
          "Question": "How does Quantum Matrix Technology improve display quality?",
          "Answer": {{
            "Overview": "Uses AI-controlled mini-LED clusters...",
            "TechnicalSpecs": {{
              "DimmingZones": 2048,
              "PeakBrightness": "2500 nits",
              "ResponseTime": "1ms"
            }},
            "Compatibility": {{
              "S95C TV": "Yes",
              "QN900C Neo QLED": "No"
            }},
            "DiagramReference": "KB-DISPLAY-2024-FIG12"
          }},
          "FeatureType": "Display"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse technical explanation"}


#Google AI STudio
def generate_feature_explanation_qa_google(text):
    """Technology deep-dive pairs in JSON format, with diagram URLs."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Explain Samsung technologies using Question and Answer pairs from the following support document text, covering:
    - Technical specifications
    - Use cases
    - Compatibility notes

    When diagrams are relevant to illustrate a technology, include references to diagram file names or URLs in the output. Assume diagrams are available as images and you can reference their filenames or URLs.  In the JSON output, include a list of "Diagrams" (URLs or filenames) for each Q&A pair if applicable.

    Use clear and informative language, suitable for users interested in understanding the technology in detail.  Keep answers concise and focused.

    Present the output as a list of technology explanation Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "TechnicalSpecifications" (list of specs), "UseCases" (list of use cases), "CompatibilityNotes" (list of notes), and "Diagrams" (list of diagram URLs/filenames).

    Text: {text}

    Output Format (example):
    [
      {{ "Question": "...", "Answer": "...", "TechnicalSpecifications": [...], "UseCases": [...], "CompatibilityNotes": [...], "Diagrams": [...] }},
      {{ "Question": "...", "Answer": "...", "TechnicalSpecifications": [...], "UseCases": [...], "CompatibilityNotes": [...], "Diagrams": [...] }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        feature_explanation_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        feature_explanation_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"FeatureExplanationQAPairs": feature_explanation_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_feature_explanation_qa_sonnet(text):
    """Generate structured technology deep-dive Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create feature explanation Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Technical feature inquiry"
        ],
        "Answers": [
          "Comprehensive technology explanation"
        ],
        "Metadata": {{
          "ExplanationDepth": "Technical deep-dive",
          "CoverageAreas": ["Specifications", "Use Cases", "Compatibility"]
        }},
        "TechnicalDetails": {{
          "Specifications": ["Detailed technical parameters"],
          "UseCases": ["Practical application scenarios"],
          "CompatibilityNotes": ["Integration and limitation insights"]
        }},
        "VisualizationSupport": {{
          "DiagramMarkdown": "Optional technical illustration"
        }}
      }}
    }}

    Requirements:
    - In-depth technical explanations
    - Practical use case descriptions
    - Compatibility insights
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_feature_explanation_qa ---")
test_qa_generators("generate_feature_explanation_qa", content)
# Out:
# --- generate_feature_explanation_qa ---
#
# --- Calling generate_feature_explanation_qa ---
# Okay, here's a breakdown of Samsung Refrigerator technologies based on the provided user manual, framed as Q&A pairs covering technical specifications, use cases, and compatibility notes:
#
# **1.  AutoFill Pitcher (Applicable Models Only)**
#
# *   **Q: What is the AutoFill Pitcher, and what are its technical specifications?**
# *   **A:** The AutoFill Pitcher is a feature that automatically refills a built-in pitcher with chilled, purified water.  It also includes an infuser basket for adding fruits or tea.  Specific technical details like pitcher volume, fill rate, and sensor accuracy are not provided in the manual. It also requires water line installation and a water pressure between 30-125 psi (206-861 kPa).
#
# *   **Q: What are the use cases for the AutoFill Pitcher?**
# *   **A:**  The primary use case is convenient access to chilled, purified water.  The infuser allows users to create flavored water or tea infusions.
#
# *   **Q: Are there any compatibility notes or limitations for the AutoFill Pitcher?**
# *   **A:**
#     *   This feature is only available on applicable models (indicated by "*applicable models only*").
#     *   The pitcher must be mounted correctly on the holder for it to fill.
#     *   If the pitcher doesn't fill, check the water line connection.
#     *   Do not fill with tea, juice, or sports drinks as they can damage the refrigerator.
#     *   Fruit-infused water should be consumed within 24 hours.
#     *   The pitcher and lid are not microwave safe.
#     *   Water pressure must be within the specified range for proper filling.
#
# **2. Water Dispenser (Applicable Models Only)**
#
# *   **Q: What is the water dispenser and what are it's technical specifications?**
# *   **A:** The water dispenser allows users to dispense chilled water from the refrigerator door. The technical details like water flow rate, cooling capacity, temperature range, and water filter capacity are not provided. Water pressure must be between 30-125 psi (206-861 kPa).
#
# *   **Q: What are the use cases for the water dispenser?**
# *   **A:**  The main use case is convenient access to chilled water without opening the refrigerator.
#
# *   **Q: Are there any compatibility notes or limitations for the water dispenser?**
# *   **A:**
#     *   It requires a water line connection.
#     *   Water pressure must be within the specified range for proper operation.
#     *   If the water line is not installed properly, it can emit a buzzing noise. Turn off ice making function in this case.
#     *   Use only Samsung-provided or approved filters.
#     *   If it is not used for 2-3 days, the dispensed water may have an abnormal smell or taste. Discard the first 1-2 glasses of water.
#
# **3.  FlexZone**
#
# *   **Q: What is FlexZone, and what are its technical specifications?**
# *   **A:** FlexZone is a full-width drawer with adjustable temperature settings. The manual specifies temperature presets for different modes, like Wine (41°F/5°C), Deli (37°F/3°C), Beverage (34°F/1°C), and Meat/Fish (30°F/-1°C), as well as Soft Freeze (23°F/-5°C). It provides adjustable temperature control.
#
# *   **Q: What are the use cases for the FlexZone?**
# *   **A:**  It can be used for storing wine, deli items, beverages, meat/fish, pizza, and other miscellaneous items at optimal temperatures.
#
# *   **Q: Are there any compatibility notes or limitations for FlexZone?**
# *   **A:**
#     *   Select the FlexZone mode accordingly to the type of food you store in there.
#     *   Do not store most kinds of fruit or vegetables.
#     *   Do not store glass bottles in the FlexZone in Beverage mode.
#
# **4. Power Cool/Power Freeze**
#
# *   **Q: What are Power Cool and Power Freeze, and what are their technical specifications?**
# *   **A:** Power Cool rapidly cools the fridge, and Power Freeze rapidly freezes the freezer. There are no specific technical specs regarding the temperature drop rate or power consumption, but the manual states they operate at "maximum power" for several hours.
#
# *   **Q: What are the use cases for Power Cool and Power Freeze?**
# *   **A:** Power Cool is useful for quickly cooling perishable foods or rapidly cooling the refrigerator after the door has been left open. Power Freeze is useful for freezing large quantities of food quickly or speeding up the ice-making process.
#
# *   **Q: Are there any compatibility notes or limitations for Power Cool and Power Freeze?**
# *   **A:**
#     *   Using these functions increases power consumption.
#     *   They should be turned off manually when no longer needed.
#     *   For Power Freeze, activate for at least 20 hours before putting the food in the freezer.
#
# **5. SmartThings Integration**
#
# *   **Q: What is the purpose of SmartThings integration with the Samsung Refrigerator?**
# *   **A:**  SmartThings allows users to monitor and control their refrigerator remotely using a smartphone app.
#
# *   **Q: What are the capabilities offered through SmartThings?**
# *   **A:**  Remote monitoring of fridge and freezer temperatures, FlexZone settings, energy consumption, ice-making status, and enabling/disabling Power Cool/Power Freeze and Sabbath Mode.  It also provides alarms for abnormally high temperatures, door openings, water filter replacement, and AutoFill Pitcher overflow.
#
# *   **Q: What are the limitations and compatibility notes for SmartThings integration?**
# *   **A:**
#     *   Requires a Samsung account and a compatible smartphone with the SmartThings app installed.
#     *   Requires a Wi-Fi connection and a properly functioning home router.
#     *   Not all options or settings of the refrigerator are available for remote control.
#     *   May require contacting your Internet service provider if you have issues connecting due to MAC address registration or firewall settings.
#     *   It is recommend to connect your refrigerator with the SmartThings app before use. If you fail to make connection or don’t want to use the app, press and hold the Door Alarm button for 10 seconds.
#
# **6. Smart Grid (Demand Response, Applicable Models Only)**
#
# *   **Q: What is the SMART GRID Function and what are it's technical specifications?**
# *   **A:** The SMART GRID (Demand Response) function allows the refrigerator to respond to signals from the utility company to control energy usage during peak demand times. There is also the Delay Appliance Load (DAL) and Temporary Appliance Load Reduction (TALR) mode. The signal must have an Energy Management System that supports SEP (Smart Energy profile). DAL function controls functions that consume a lot of energy such as adjusting the Cooling system, running the defrost cycle, and making ice (max. 4.5 hours). TALR function reduces energy consumption by stopping the compressor and controlling the functions that consume a lot of energy such as the defrost cycle and making ice (max 15 minutes). The functions is activated by the utility company and not user. The function cannot be activated if there's no contract with the utility company.
#
# *   **Q: What are the use cases for the SMART GRID Function?**
# *   **A:** To control energy usage or delay the operation of some functions to save money when energy prices or demand are the highest.
#
# *   **Q: Are there any compatibility notes or limitations for the SMART GRID Function?**
# *   **A:**
#     * To use the Smart Grid (Demand Response) function, you need a separate contract with your electric utility company. The company must have an EMS (Energy Management System) that supports SEP (Smart Energy profile).
#     * MAC address can be obtained by pressing and holding both Freezer and Fridge for 6 seconds and press Freezer again to display the MAC address.
#     * You can deactivate the SMART GRID (Demand Response) function at any time using the Peak Demand Off function.
#
# **General Notes based on the Manual:**
#
# *   **Filter Reset:** This functionality can be used to reset the filter after replacing the filter.
#
# *   **Door Alarm/Lock:** The Door Alarm can be toggled on and off by pressing the Door Alarm button and will sound if door is left open for more than 2 minutes. To prevent accidental setting changes, press and hold Door Alarm for 3 seconds.
#
# This information should help you understand the technologies featured in the Samsung refrigerator based on the manual.
#
#
# --- Calling generate_feature_explanation_qa_deepseek ---
# {'Generations': [{'Question': 'What is the recommended temperature range for operating this refrigerator?', 'Answer': {'Overview': 'The refrigerator should operate in ambient temperature for adequate cooling...', 'TechnicalSpecs': {'TemperatureRange': '50-110 °F', 'TemperatureRangeCelsius': '10-43 °C', 'MeasurementUnit': '°F/°C'}, 'Compatibility': {'RF23BB8*****': 'Yes', 'RF29BB8*****': 'Yes', 'Other Models': 'Check Specs'}, 'DiagramReference': 'KB-REF-2024-INSTALL-1'}, 'FeatureType': 'Refrigeration'}, {'Question': "What is the ice maker's required water pressure for optimal ice production?", 'Answer': {'Overview': 'The refrigerator ice maker requires specific water pressure to generate...', 'TechnicalSpecs': {'WaterPressure': '30-125 psi', 'WaterPressurekPa': '206-861 kPa', 'MeasurementUnit': 'psi/kPa'}, 'Compatibility': {'All Dispenser Models': 'Yes', 'NonDispenser Models': 'No'}, 'DiagramReference': 'KB-REF-2024-ICEMAKER-WATER'}, 'FeatureType': 'Connectivity'}, {'Question': 'How frequently should the water filter be replaced, and what is the replacement process?', 'Answer': {'Overview': 'To maintain water quality and optimal performance, the water filter must...', 'TechnicalSpecs': {'FilterReplacementInterval': '6 Months', 'WaterVolume': '300 gallons', 'WaterVolumeLiters': '1200 L', 'MeasurementUnit': 'Months/gallons/L'}, 'Compatibility': {'All Filtered Water Models': 'Yes', 'NonFiltered Models': 'N/A'}, 'DiagramReference': 'KB-REF-2024-FILTER-REPLACE'}, 'FeatureType': 'Maintenance'}, {'Question': 'How do I enable Sabbath mode?', 'Answer': {'Overview': 'Sabbath mode adheres to religious observances, disabling specific functions for...', 'TechnicalSpecs': {'SabbathModeDuration': '85 hours', 'FunctionalityDisabled': 'Buttons, Display, Internal lights'}, 'Compatibility': {'Models with Door Alarm and AutoFill Pitcher': 'Yes', 'Other Models': 'N/A'}, 'DiagramReference': 'KB-REF-2024-SABBATHMODE-ENABLE'}, 'FeatureType': 'AI'}, {'Question': 'What is the purpose of the Peak Demand Off function and how can it be activated or deactivated?', 'Answer': {'Overview': 'Peak Demand Off allows the refrigerator to ignore Smart Grid signals from utility...', 'TechnicalSpecs': {'OverrideMode': 'Smart Grid Signals', 'Activation': 'Fridge Button 3 seconds', 'Icon': 'Override icon'}, 'Compatibility': {'Smart Grid Supported Models': 'Yes', 'Models Without Smart Grid': 'N/A'}, 'DiagramReference': 'KB-REF-2024-PEAKDEMAND-ENABLE'}, 'FeatureType': 'Connectivity'}, {'Question': 'How is the refrigerator connected to the SmartThings app, and what are its requirements?', 'Answer': {'Overview': 'This Samsung smart refrigerator can be managed using the SmartThings app...', 'TechnicalSpecs': {'WiFi': '2.4 GHz', 'Protocol': 'IEEE 802.11 b/g/n', 'Security': 'WPA/TKIP, WPA2/AES'}, 'Compatibility': {'Compatible Samsung Refrigerators': 'Yes', 'Incompatible Refrigerators': 'Check Specs'}, 'DiagramReference': 'KB-REF-2024-SMARTTHINGS-SETUP'}, 'FeatureType': 'Connectivity'}, {'Question': 'What is the operating principle of the Autofill pitcher?', 'Answer': {'Overview': 'The Autofill pitcher keeps cold and purified water always ready...', 'TechnicalSpecs': {'Modes': 'On/Off', 'Additions': 'Tea, Fruit for infusion'}, 'Compatibility': {'Models with AutoFill Pitcher': 'Yes', 'Models without AutoFill Pitcher': 'N/A'}, 'DiagramReference': 'KB-REF-2024-AUTOFILL-FUNC'}, 'FeatureType': 'Display'}, {'Question': 'How do I remove and re-install the FlexZone drawer?', 'Answer': {'Overview': 'The FlexZone drawer can be removed for cleaning or maintenance and must be re-installed...', 'TechnicalSpecs': {'RemovalSteps': 'Open drawer, lift basket, unlock rail assembly.', 'ReinstallationSteps': 'Align wheels, slide to the front, ensure smooth operation.'}, 'Compatibility': {'Models with FlexZone drawer': 'Yes', 'Models without FlexZone drawer': 'N/A'}, 'DiagramReference': 'KB-REF-2024-FLEXZONE-REMOVE'}, 'FeatureType': 'Maintenance'}, {'Question': 'What steps are involved in removing  ...
#
# --- Calling generate_feature_explanation_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "FeatureExplanationQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_feature_explanation_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What is the purpose of the AutoFill Pitcher and how is it used?",\n      "How does Power Cool function and when should it be used?",\n      "What is FlexZone and what are the available modes?",\n      "How does Power Freeze function and when should I use it?",\n      "What does Sabbath Mode do and how do I activate/deactivate it?",\n      "What is Cooling Off mode (Shop mode) used for?",\n      "How does the Smart Grid function work?",\n      "What do the \'L3\' and \'L4\' indicators mean in Smart Grid mode?",\n      "How do I find the MAC address of the refrigerator for Smart Grid setup?",\n      "What is Peak Demand Off (Override mode) and how do I use it?"\n    ],\n    "Answers": [\n      "The AutoFill Pitcher automatically refills with purified water and can infuse it with tea or fruit; you can manually fill the water pitcher if needed, then the AutoFill Pitcher function can be turned off.",\n      "Power Cool rapidly cools the fridge compartment; it\'s best used for quickly cooling food or after leaving the door open for an extended period.",\n      "FlexZone is a drawer with adjustable temperature; available modes include Wine, Deli, Beverage, and Meat/Fish, allowing flexible food storage at optimal temperatures.",\n      "Power Freeze rapidly freezes the freezer compartment, which is best for freezing large amounts of food; you should activate it at least 20 hours before putting the food in the freezer.",\n      "Sabbath Mode disables buttons, the display, and internal lights while maintaining cooling; activate/deactivate by holding Door Alarm and AutoFill Pitcher for 5 seconds.",\n      "Cooling Off mode (Shop mode) is designed for retailers to display refrigerators on a retail floor; the fan and lights work, but the compressors do not cool the refrigerator or freezer.",\n      "The Smart Grid function adjusts energy usage based on signals from the utility company; it can delay functions to save money during peak energy demand.",\n      "In Smart Grid mode, \'L3\' indicates Delay Appliance Load (DAL), a moderate load reduction; \'L4\' indicates Temporary Appliance Load Reduction (TALR), aggressively reducing the load for a short period.",\n      "To find the MAC address, press and hold Freezer and Fridge for 6 seconds, then press Freezer again; the temperature panel will display the MAC address sequentially.",\n      "Peak Demand Off (Override mode) makes the refrigerator ignore the Smart Grid signal from the utility company, allowing you to control the refrigerator yourself; hold Fridge for 3 seconds to toggle it on/off."\n    ],\n    "Metadata": {\n      "ExplanationDepth": "Technical deep-dive",\n      "CoverageAreas": [\n        "Specifications",\n        "Use Cases",\n        "Compatibility"\n      ]\n    },\n    "TechnicalDetails": {\n      "Specifications": [\n        "Temperature ranges",\n        "Power consumption adjustments",\n        "Operational modes",\n        "Connectivity protocols"\n      ],\n      "UseCases": [\n        "Food preservation",\n        "Energy saving",\n        "Remote control",\n        "Retail display"\n      ],\n      "CompatibilityNotes": [\n        "SmartThings app compatibility",\n        "Utility company requirements for Smart Grid"\n      ]\n    },\n    "VisualizationSupport": {\n      "DiagramMarkdown": "N/A"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 7 generate_setup_qa

# %%
#original
def generate_setup_qa(text):
    """Installation/configuration pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate setup-related Q&A with:
    - Pre-installation checks - Configuration options - Post-setup tests
    Include recommended settings for different user types.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_setup_qa_deepseek(text):
    """Generates installation guides with user-type presets in JSON format.

    Returns:
        JSON with prerequisites, timed steps, and configuration profiles.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create structured setup Q&A from Samsung docs with:
    1. Prerequisites (tools, OS versions, space requirements)
    2. Configuration profiles: Basic/Advanced/Custom
    3. Step durations and cumulative time estimates
    4. Post-setup verification tests

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Setup scenario]",
        "Answer": {{
          "UserType": "Basic/Advanced",
          "RequiredTools": ["GJ-SETUP45"],
          "SetupDuration": "20-25 mins",
          "ConfigurationSteps": [
            {{
              "Order": 1,
              "Action": "...",
              "Parameters": {{"Resolution": "4K", "FrameRate": 60}}
            }}
          ],
          "PostSetupVerification": ["Check firmware version", "Test HDMI handshake"]
        }},
        "DeviceModel": "QE75QN900C"
      }}
    - Validate model numbers as SM/QE-XXXXX format
    - Sort by setup complexity (Basic first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to configure The Frame TV for art mode?",
          "Answer": {{
            "UserType": "Advanced",
            "RequiredTools": ["One Connect Box"],
            "SetupDuration": "15 mins",
            "ConfigurationSteps": [
              {{
                "Order": 1,
                "Action": "Mount Art Store-certified USB",
                "Parameters": {{"Format": "FAT32", "Capacity": "≥64GB"}}
              }}
            ],
            "PostSetupVerification": ["Validate art metadata parsing"]
          }},
          "DeviceModel": "LS03B"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse setup configuration"}


#Google AI STudio
def generate_setup_qa_google(text):
    """Setup/installation/configuration pairs in JSON format with user-type settings."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate setup-related Question and Answer pairs from the following Samsung support document text, covering:
    - Pre-installation checks
    - Configuration options
    - Post-setup tests

    For configuration options, include recommended settings tailored for different user types (e.g., "Beginner", "Advanced", "Gamer", etc.) when applicable. If settings are generally applicable, indicate that.

    Use consumer-friendly language. Keep answers concise and step-by-step where relevant.

    Present the output as a list of setup Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Stage" ("Pre-installation Checks", "Configuration Options", "Post-Setup Tests"), "Question", "Answer", and "RecommendedSettings". "RecommendedSettings" should be a dictionary where keys are user types (e.g., "Beginner", "Advanced") and values are the recommended settings for that user type. If no user-type specific settings are relevant, "RecommendedSettings" should be null.

    Text: {text}

    Output Format (example):
    [
      {{ "Stage": "...", "Question": "...", "Answer": "...", "RecommendedSettings": {{ "Beginner": "...", "Advanced": "..." }} }},
      {{ "Stage": "...", "Question": "...", "Answer": "...", "RecommendedSettings": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        setup_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        setup_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"SetupQAPairs": setup_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_setup_qa_sonnet(text):
    """Generate structured setup configuration Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create setup Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Setup and configuration inquiry"
        ],
        "Answers": [
          "Comprehensive installation guidance"
        ],
        "Metadata": {{
          "SetupStages": ["Pre-installation", "Configuration", "Post-setup"],
          "UserTypeSettings": ["Recommended configurations"]
        }},
        "SetupDetails": {{
          "PreInstallationChecks": ["Essential preparatory steps"],
          "ConfigurationOptions": ["Detailed setup parameters"],
          "PostSetupTests": ["Verification procedures"]
        }}
      }}
    }}

    Requirements:
    - Detailed setup instructions
    - User-type specific guidance
    - Comprehensive verification steps
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_setup_qa ---")
test_qa_generators("generate_setup_qa", content)
# Out:
# --- generate_setup_qa ---
#
# --- Calling generate_setup_qa ---
# Okay, here's a comprehensive Q&A based on the provided user manual, covering pre-installation checks, configuration options, and post-setup tests, along with recommended settings for different user types.
#
# **I. Pre-Installation Checks**
#
# *   **Q: What are the key factors to consider when selecting a location for the refrigerator?**
#     *   **A:** The site should have a solid level surface, be out of direct sunlight, have adequate room for opening the door, be away from any heat source, provide room for maintenance, and have a temperature range between 50°F (10°C) and 110°F (43°C). Also, verify the correct clearance needed, as indicated in the manual.
#
# *   **Q: What type of flooring is recommended for the refrigerator?**
#     *   **A:** A solid, level surface without carpeting or flooring that obstructs ventilation is ideal. Consider using cardboard to protect the floor during installation.
#
# *   **Q: The refrigerator is too big to fit through the entrance. What should I do?**
#     *   **A:** The manual describes removing the refrigerator doors to make it easier to move the appliance through doorways. (See Step 3, "Door removal for entrance" on page 22-27)
#
# *   **Q: Are there any electrical considerations before installation?**
#     *   **A:** The refrigerator should always be plugged into its own individual electrical outlet, which has a voltage rating that matches the voltage listed on the refrigerator's rating plate.  Using a dedicated outlet prevents overloading house wiring circuits.  Check the wall socket is firmly in place. Do not use cracked or damaged power cords. Do not use multiple appliances and the refrigerator into the same multiple power strip.
#
# *   **Q: Is grounding required? How do I ensure it?**
#     *   **A:** Yes, the refrigerator must be safely grounded.  Use a 3-wire extension cord that has a 3-blade grounding plug and a 3-slot receptacle.  Do not use gas pipes, telephone lines, or lightning attractors as an electrical ground.
#
# *   **Q: Is potable water the only type to fill the water tank?**
#     *   **A:** Fill the water tank and ice cube trays with potable water only (tap water, mineral water, or purified water).
#         Do not fill the tank with tea, juice, or a sports drink. They can damage the
#         refrigerator.
#
# **II. Configuration Options**
#
# *   **Q: How do I set the refrigerator and freezer temperatures?**
#     *   **A:** Use the 'Fridge' and 'Freezer' buttons on the main panel. Repeatedly press the buttons to cycle through the temperature options. Fridge temperature 34 °F (1 °C) and 44 °F (7 °C). Freezer temperature 5 °F (-15 °C) and -8 °F (-23 °C). The temperature indicator displays the currently set or selected temperature.
#
# *   **Q: What is the 'FlexZone' and how do I configure it?**
#     *   **A:** The FlexZone is a full-width drawer with adjustable temperature control.  Press the 'FlexZone' button to cycle through the available modes: Wine (41°F/5°C), Deli (37°F/3°C), Beverage (34°F/1°C), and Meat/Fish (30°F/-1°C).
#
# *   **Q: What is 'Soft Freeze' and when should I use it?**
#     *   **A:** Soft Freeze keeps meat and fish fresh for an extended time at 23°F (-5°C). Press and hold FlexZone for 3 seconds to activate the Soft Freeze mode
#
# *   **Q: How do I activate 'Power Cool' and 'Power Freeze'?**
#     *   **A:** Repeatedly press the 'Fridge' or 'Freezer' button until the Power Cool or Power Freeze indicator lights up. These functions speed up the cooling or freezing process.  Remember to turn them off manually when no longer needed to conserve energy.
#
# *   **Q: How do I activate 'Peak Demand Off' and what does it do?**
#     *   **A:** Press and hold the 'Fridge' button for 3 seconds to activate/deactivate Peak Demand Off. This function temporarily overrides Smart Grid, ignoring signals from the utility company to reduce energy consumption.
#
# *   **Q: How do I use the 'Ice Maker' function and what are the options?**
#     *   **A:** The ice maker has 2 indicators (Cubed Ice On/Ice Bites On) to indicate its operating status.
#     *   Cubed Ice *: You can start or stop making cubed ice.
#     *   Ice Bites *: You can start or stop making ice bites.
#
# *   **Q: How do I use the 'Sabbath Mode'?**
#     *   **A:** To activate Sabbath Mode, press and hold Door Alarm and AutoFill Pitcher simultaneously for 5 seconds. To deactivate, repeat the process. This disables buttons, the display, and internal lights, but the refrigerator continues to cool.
#
# *   **Q: What is 'AutoFill Pitcher' and how does it work?**
#     *   **A:** It automatically refills a water pitcher inside the refrigerator.  You can also add tea or fruit to the infuser. The water pitcher will start to fill with chilled water a short time later. To access, open the Beverage Center door (Type A) or the left door of the fridge (Type B), and then detach the water pitcher. Pull it straight out.
#     *   Turn off to keep the infused water in its initial concentration.
#
# *   **Q: How do I connect the refrigerator to Wi-Fi and use the SmartThings app?**
#     *   **A:** Download the SmartThings app, create a Samsung account, and follow the in-app instructions to connect to your refrigerator. The app allows for remote monitoring and control of temperature settings, ice making, and alarms.
#
# **III. Post-Setup Tests**
#
# *   **Q: How do I check if the refrigerator is properly installed?**
#     *   **A:** After completing installation, confirm that the refrigerator is plugged in and grounded, installed on a level surface, has sufficient clearance, is level and stable, and that the door opens and closes freely with the interior light functioning.
#
# *   **Q: How long should I wait before loading the refrigerator with food?**
#     *   **A:** Allow the appliance to stand for 2 hours before loading it with food.
#
# *   **Q: How do I check if the water dispenser is working correctly?**
#     *   **A:** After connecting the water line, press the water dispenser lever until the water runs from the water outlet.
#
# *   **Q: How long does the ice maker take to produce ice?**
#     *   **A:** It can take 1-2 days for the ice maker to produce ice. Discard the first 1-2 buckets of ice to remove impurities in the water supply system.
#
# *   **Q: How can I test the ice maker is working properly?**
#     *   **A:** Status of ice maker using the Test button on the bottom of the ice maker.
#         Press the Test button on the bottom of
#         the ice maker. You will hear a chime (ding-dong) when you press the button. You will hear another chime if the ice maker is operating properly.
#
# *   **Q: How do I reset the water filter indicator?**
#     *   **A:** After replacing the water filter, press and hold the 'Filter Reset' button for 3 seconds.
#
# *   **Q: How do I check the Wi-Fi connection is working?**
#     *   **A:** Check if the Wi-Fi indicator is flashing when opening or closing the fridge door, this indicates
#         that the refrigerator is not connected with the SmartThings app. If this is the case, it is recommended to make connection again before using the refrigerator.
#         A fixed light indicates a successful connection.
#
# **IV. Recommended Settings for Different User Types**
#
# *   **Standard User (General Food Storage):**
#     *   Fridge Temperature: 37°F (3°C) to 40°F (4°C)
#     *   Freezer Temperature: 0°F (-18°C)
#     *   FlexZone: Based on typical contents (Deli or Beverage)
#     *   Ice Maker: On (if desired)
#     *   AutoFill Pitcher: On (if desired, but consider turning off to avoid over-dilution of infusions)
#
# *   **User Prioritizing Energy Savings:**
#     *   Fridge Temperature:  44°F (7°C) (highest safe setting)
#     *   Freezer Temperature: 5°F (-15°C) (highest safe setting)
#     *   Use Power Cool/Freeze sparingly
#     *   Activate Peak Demand Off when available
#     *   Enable Delay Defrost Capability.
#
# *   **User Storing a Lot of Meat/Fish:**
#     *   Fridge Temperature: 34°F (1°C)
#     *   Freezer Temperature: -8°F (-23°C)
#     *   FlexZone: Meat/Fish (30°F/-1°C) or Soft Freeze (23°F/-5°C)
#     *   Consider using Power Freeze before loading large amounts of meat.
#
# *   **User with a Vacation Home (Infrequent Use):**
#     *   Fridge Temperature: Turn off and empty the refrigerator to save energy
#     *   Freezer Temperature: -8°F (-23°C) to keep ice and reduce food waste
#     *   Ice Maker: Off
#     *   AutoFill Pitcher: Off and emptied to prevent mildew or stale water
#         Remember to empty the ice bucket and wipe out any excess water to help prevent mold and mildew
#
# This Q&A is designed to cover most common setup and usage scenarios based on the provided manual. Always refer to the manual for detailed instructions and safety information.
#
#
# --- Calling generate_setup_qa_deepseek ---
# {'Generations': [{'Question': 'How to level the refrigerator during installation?', 'Answer': {'UserType': 'Basic', 'RequiredTools': ['Flat-head screwdriver'], 'SetupDuration': '5-10 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Locate levelers on front legs', 'Parameters': {}}, {'Order': 2, 'Action': 'Adjust height using a flat-head screwdriver', 'Parameters': {'Clockwise': 'Raise', 'Counterclockwise': 'Lower'}}], 'PostSetupVerification': ['Ensure refrigerator sits firmly on the floor']}, 'DeviceModel': 'RF23BB8*****'}, {'Question': 'How to connect water dispenser line to the refrigerator (applicable models only)?', 'Answer': {'UserType': 'Advanced', 'RequiredTools': ['1/4" copper tubing', '1/4" compression nut', 'Ferrule', 'Pipe clamp', 'Shutoff valve'], 'SetupDuration': '20-30 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Shut off main water source', 'Parameters': {}}, {'Order': 2, 'Action': 'Insert pipe clamp and shutoff valve into cold water line', 'Parameters': {}}, {'Order': 3, 'Action': 'Connect water line installation kit to the shutoff valve', 'Parameters': {}}, {'Order': 4, 'Action': 'Connect household water line to the compression fitting', 'Parameters': {}}, {'Order': 5, 'Action': 'Tighten the compression nut onto the compression fitting', 'Parameters': {}}, {'Order': 6, 'Action': 'Turn the water on and check for any leakage', 'Parameters': {}}, {'Order': 7, 'Action': 'Flush 3 gallons of water through the filter', 'Parameters': {}}], 'PostSetupVerification': ['Check if the water dispenser works properly']}, 'DeviceModel': 'RF29BB8*****'}, {'Question': 'How to remove refrigerator doors for entrance?', 'Answer': {'UserType': 'Advanced', 'RequiredTools': ['Phillips screwdriver', 'Flat-head screwdriver', 'Socket wrench [3]/8" (10 mm)', 'Pliers', 'Allen wrench [1]/4" (5 mm)'], 'SetupDuration': '30-45 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Unplug the power cord of the refrigerator', 'Parameters': {}}, {'Order': 2, 'Action': 'Remove screws from the top cover', 'Parameters': {}}, {'Order': 3, 'Action': 'Disconnect wire connectors on the doors', 'Parameters': {}}, {'Order': 4, 'Action': 'Disconnect the water tube from the coupler on the left door', 'Parameters': {'Models': 'AutoFill Pitcher and the water dispenser'}}, {'Order': 5, 'Action': 'Remove the top hinge', 'Parameters': {}}, {'Order': 6, 'Action': 'Gently pull up the door vertically to remove', 'Parameters': {}}], 'PostSetupVerification': ['Check the water installation conditions', 'Make sure the wire connectors are connected properly']}, 'DeviceModel': 'RF23BB8*****'}, {'Question': 'How to use the SmartThings app to connect to my refrigerator?', 'Answer': {'UserType': 'Advanced', 'RequiredTools': ['Smartphone with internet access', 'Samsung account'], 'SetupDuration': '15-20 mins', 'ConfigurationSteps': [{'Order': 1, 'Action': 'Download and install SmartThings app from app store', 'Parameters': {}}, {'Order': 2, 'Action': 'Create or log into Samsung account', 'Parameters': {}}, {'Order': 3, 'Action': 'Turn on the refrigerator and open the SmartThings app', 'Parameters': {}}, {'Order': 4, 'Action': 'Add the refrigerator to SmartThings using available devices or supported devices list', 'Parameters': {}}], 'PostSetupVerification': ['Ensure the refrigerator is listed as a card on the SmartThings Dashboard']}, 'DeviceModel': 'RF29BB8*****'}]}
#
# --- Calling generate_setup_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "SetupQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_setup_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How to select the right location for my refrigerator installation?",\n      "What are the recommended clearances to be aware of when installing my refrigerator?",\n      "What steps are involved to remove refrigerator doors for tight spaces?",\n      "How do I reattach the freezer drawer if it comes loose?",\n      "How to level the refrigerator correctly?",\n      "How to adjust door height and gap?",\n      "How do I connect the water dispenser line?",\n      "What are the initial settings I need to configure after installing the refrigerator?",\n      "How do I change the fridge or freezer temperatures using the main panel?",\n      "How do I use the SmartThings app to monitor and control my refrigerator?",\n      "What is the SMART GRID function and how does it work?",\n      "How do I reassemble the auto fill pitcher?"\n    ],\n    "Answers": [\n      "Choose a location on a solid, level surface, away from sunlight and heat sources, with enough room for opening the door, servicing, and a temperature range of 50°F to 110°F.",\n      "Leave a gap of at least 2.5 inches (5 cm) between the refrigerator back and sides and any nearby walls or cabinets. Dimensions vary depending on the model so refer to the manual table and diagrams to calculate your models measurements.",\n      "Unplug the refrigerator, detach the top cover, disconnect the wire connectors and water tube (if applicable), remove the top hinge, and gently pull the door vertically, one at a time.",\n      "Ensure the wire connectors are properly connected. Place the drawer into the frame rails and then slide inward making sure that it is placed.",\n      "Use a flat-head screwdriver to turn the levelers located on the front legs to adjust the refrigerator until it\'s level, ensuring the front is slightly higher than the rear for safety.",\n      "Adjust the height of a door can be adjusted using the provided snap rings. Check the height difference between the doors, and then lift up and hold the door with the lower height and insert a suitable-sized snap ring.",\n      "Shut off the main water source, connect the water line installation kit to the shutoff valve, and then connect the water supply line to the refrigerator, ensuring proper tightening and leak checks.",\n      "Plug in the power cord, check if the interior light works, set the temperature to the coldest setting, and wait for about an hour until the freezer is slightly chilled and the motor is running smoothly.",\n      "Use the Fridge/Freezer buttons repeatedly to select the desired temperature or activate/deactivate Power Cool/Power Freeze.",\n      "Install the SmartThings app, log in to your Samsung account, and follow the on-screen instructions to add and control your refrigerator remotely. Check operation status and notifications.",\n      "SMART GRID monitors energy prices and demand, then sends notifications to the refrigerator, reducing energy usage or delaying operation of some functions during peak times to save money.",\n      "Grasp a handle groove of the lid, and then pull up to remove the lid.  Clean the infuser with neutral agents and running water and then, Reassemble the AutoFill Pitcher in the reverse order of disassembly."\n    ],\n    "Metadata": {\n      "SetupStages": ["Pre-installation", "Configuration", "Post-setup", "Usage"],\n      "UserTypeSettings": ["Basic setup", "Advanced configuration", "Troubleshooting"]\n    },\n    "SetupDetails": {\n      "PreInstallationChecks": [\n        "Site selection",\n        "Clearance requirements",\n        "Required tools",\n        "Door removal guidance",\n        "Power connection"\n      ],\n      "ConfigurationOptions": [\n        "Leveling",\n        "Water line connection",\n        "Temperature setting",\n        "Feature configuration",\n        "SmartThings integration"\n      ],\n      "PostSetupTests": [ ...

# %% [markdown]
# ### Number 8 generate_error_code_qa

# %%
#original
def generate_error_code_qa(text):
    """Error code explanations"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code Q&A with:
    - Code interpretations - Immediate actions - Service triggers
    Format codes in bold with severity colors (🔴🟠🟢).
    Text: {text}
    """)
    return model.generate_content(prompt).text

#Deepseek
import json
from textwrap import dedent

def generate_error_code_qa_deepseek(text):
    """Generates machine-actionable error code guides with severity tiers.

    Returns:
        JSON with standardized codes, automated responses, and service flags.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code explanations from Samsung docs with:
    1. Code validation using ERR-XXXX format (X=digit)
    2. Severity: Critical(🔴)/High(🟠)/Medium(🟢) mapped to 0-2
    3. Automated system response actions
    4. Service center escalation thresholds

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "ErrorCode": "ERR-0451",
        "Description": "Battery temperature critical",
        "Severity": {{
          "Level": 0,
          "Label": "Critical",
          "HexColor": "#FF0000"
        }},
        "ImmediateResponse": ["Disconnect charger", "Power down"],
        "ServiceRequired": {{
          "Threshold": "Immediate",
          "Code": "SVC-BATT-EMERG"
        }},
        "UserMessage": "Visit Samsung Service within 24hrs"
      }}
    - Validate ErrorCode format: ERR- followed by 4 digits
    - Map colors to standard hex values

    Example:
    {{
      "Generations": [
        {{
          "ErrorCode": "ERR-1123",
          "Description": "Display panel communication failure",
          "Severity": {{
            "Level": 1,
            "Label": "High",
            "HexColor": "#FFA500"
          }},
          "ImmediateResponse": ["Restart device", "Check flex cable"],
          "ServiceRequired": {{
            "Threshold": "If persists after reboot",
            "Code": "SVC-DISP-1123"
          }},
          "UserMessage": "Backup data before service visit"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse error code protocol"}



#Google AI STudio
def generate_error_code_qa_google(text):
    """Error code explanations in JSON format with severity levels and color codes."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs explaining Samsung error codes from the following support document text.

    For each error code, include:
    - Code interpretation (what the error means)
    - Immediate actions users can take
    - Service triggers (when to seek professional help)

    Format error codes clearly and indicate their severity level as "Critical", "Warning", or "Informational".  In the JSON output, include a "Severity" field with these levels and optionally a "SeverityColor" field with the corresponding color emoji (🔴 for Critical, 🟠 for Warning, 🟢 for Informational).  In plain text examples within the output, you can format the error codes in bold with the color emojis.

    Use consumer-friendly language. Keep answers concise and action-oriented.

    Present the output as a list of error code Q&A pairs in JSON format. Each pair should be a dictionary with keys: "ErrorCode", "Severity" ("Critical", "Warning", "Informational"), "Interpretation", "ImmediateActions" (list of actions), "ServiceTriggers", and optionally "SeverityColor" (color emoji string).

    Text: {text}

    Output Format (example):
    [
      {{ "ErrorCode": "...", "Severity": "Critical", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🔴" }},
      {{ "ErrorCode": "...", "Severity": "Warning", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🟠" }},
      {{ "ErrorCode": "...", "Severity": "Informational", "Interpretation": "...", "ImmediateActions": [...], "ServiceTriggers": "...", "SeverityColor": "🟢" }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        error_code_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        error_code_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"ErrorCodeQAPairs": error_code_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_error_code_qa_sonnet(text):
    """Generate structured error code Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create error code Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Specific error code query"
        ],
        "Answers": [
          "Comprehensive error interpretation and resolution"
        ],
        "Metadata": {{
          "ErrorSeverity": ["Critical", "Warning", "Informational"],
          "ResolutionApproach": "Systematic troubleshooting"
        }},
        "ErrorCodeDetails": {{
          "CodeInterpretation": ["Detailed error meaning"],
          "ImmediateActions": ["Recommended quick fixes"],
          "ServiceTriggers": ["Escalation scenarios"]
        }},
        "VisualIndicators": {{
          "SeverityColors": ["🔴 Critical", "🟠 Warning", "🟢 Low Impact"]
        }}
      }}
    }}

    Requirements:
    - Clear error code explanations
    - Actionable resolution steps
    - Severity classification
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_error_code_qa ---")
test_qa_generators("generate_error_code_qa", content)
# Out:
# --- generate_error_code_qa ---
#
# --- Calling generate_error_code_qa ---
# Okay, here are some Error Code Q&A entries based on the provided user manual text.  Since there are no actual error codes defined in the document, these will be hypothetical and based on common refrigerator issues and the functions described in the manual.
#
# **Important Considerations:**
#
# *   **This is hypothetical.**  The codes and their meanings are *not* from the document, but based on typical refrigerator problems. A real service manual will have specific error code definitions.
# *   **Severity:** Severity is based on potential impact. Critical issues that could damage the refrigerator or represent a safety hazard get 🔴.  Moderate issues that affect performance get 🟠.  Minor issues get 🟢.
# *   **Service Triggers:** This indicates whether the error likely requires a qualified service technician.
#
# ---
#
# ### Error Code Q&A
#
# **🔴 E01: Compressor Failure**
#
# *   **Code Interpretation:** The compressor, the heart of the refrigerator's cooling system, has failed or is not functioning correctly. This could be due to mechanical failure, electrical issues, or refrigerant problems.
# *   **Immediate Actions:**
#     *   Check the power cord and outlet to ensure the refrigerator is receiving power.
#     *   Unplug the refrigerator for 10 minutes, then plug it back in to see if the compressor restarts.
# *   **Service Triggers:** **YES**. This usually requires a qualified technician to diagnose and repair or replace the compressor.
#
# **🟠 E02: Temperature Sensor Error (Fridge)**
#
# *   **Code Interpretation:** The temperature sensor in the refrigerator compartment is faulty or disconnected.  The refrigerator may not maintain the correct temperature.
# *   **Immediate Actions:**
#     *   Try power cycling the refrigerator (unplug for 10 minutes).
#     *   Ensure the vents inside the refrigerator are not blocked by food. (See "General" Troubleshooting section)
# *   **Service Triggers:**  **YES**.  A technician is needed to replace the sensor.
#
# **🟠 E03: Temperature Sensor Error (Freezer)**
#
# *   **Code Interpretation:** The temperature sensor in the freezer compartment is faulty or disconnected. The freezer may not maintain the correct temperature.
# *   **Immediate Actions:**
#     *   Try power cycling the refrigerator.
#     *   Ensure the vents inside the freezer are not blocked by food. (See "Frost around the vents" troubleshooting)
#     *   Verify freezer temperature setting is set correctly (below 0 °F (-18 °C)).
# *   **Service Triggers:** **YES**. A technician is needed to replace the sensor.
#
# **🟠 E04: Defrost System Malfunction**
#
# *   **Code Interpretation:** The automatic defrost system is not functioning correctly. Ice may build up in the freezer, reducing efficiency and potentially damaging components.
# *   **Immediate Actions:**
#     *   Ensure nothing is blocking the door, preventing a tight seal which can cause excess frost. (See "Frost on interior walls" troubleshooting)
#     *   Manually defrost the freezer (unplug the refrigerator and let the ice melt).
# *   **Service Triggers:** **YES**. Defrost system issues often involve faulty heaters, sensors, or control boards, requiring a technician.
#
# **🟢 E05: Door Ajar Alarm Fault**
#
# *   **Code Interpretation:** The door ajar alarm system is malfunctioning.  The alarm may sound even when the door is closed, or it may not sound when the door is open.
# *   **Immediate Actions:**
#     *   Check that the door is closing completely and is not being blocked by objects inside.
#     *   Toggle the Door Alarm on/off by pressing the Door Alarm button (See "Door Alarm" Operations)
# *   **Service Triggers:** **POSSIBLY**. If the alarm continues after the immediate actions, a technician may need to check or replace the door sensor or control board.
#
# **🟠 E06: Ice Maker Error**
#
# *   **Code Interpretation:**  There is a problem with the ice maker. This could be a water supply issue, a mechanical problem with the ice maker itself, or a sensor malfunction.
# *   **Immediate Actions:**
#     *   Ensure the ice maker is turned on (Cubed Ice and Ice Bites lights).
#     *   Verify the water line is properly connected and the water supply is on. (See "Water/ice (dispenser models only)" troubleshooting)
#     *   Press the Test button on the bottom of the ice maker.
# *   **Service Triggers:** **POSSIBLY**. If the immediate actions don't resolve the problem, a technician may be needed to diagnose and repair the ice maker.
#
# **🟢 E07: Filter Change Reminder (Past Due)**
#
# *   **Code Interpretation:** The water filter replacement is overdue.
# *   **Immediate Actions:**
#     *   Replace the water filter.
#     *   Reset the filter timer by pressing and holding the Filter Reset button for 3 seconds. (See "Reset" Operations)
# *   **Service Triggers:** **NO**. This is a maintenance reminder, not a malfunction, unless it persists after filter replacement and reset.
#
# **🟠 E08: Water Dispenser Error**
#
# *   **Code Interpretation:** There is a problem with the water dispenser. This could be a water supply issue, a blockage in the line, or a problem with the dispenser valve.
# *   **Immediate Actions:**
#     *   Ensure the water line is properly connected and the water supply is on. (See "Water/ice (dispenser models only)" troubleshooting)
#     *   Replace the water filter (a clogged filter can reduce water flow).
# *   **Service Triggers:** **POSSIBLY**. If the immediate actions don't resolve the problem, a technician may be needed to diagnose and repair the dispenser valve or check for line blockages.
#
# **🟠 E09: Communication Error (SmartThings)**
#
# *   **Code Interpretation:** The refrigerator is unable to communicate with the SmartThings app.
# *   **Immediate Actions:**
#     *   Ensure your home router is operating normally with proper internet service and connection.
#     *   Make sure that the refrigerator is connected to the access point (AP) of your house. (See "SmartThings" Troubleshooting section)
#     *   Exit and restart the SmartThings app, or disconnect and reconnect the router.
#     *   Power off the refrigerator, and then power it on again after 1 minute.
# *   **Service Triggers:** **POSSIBLY**. If the troubleshooting steps do not work, there may be an issue with the refrigerator's WiFi card that may need a technician to repair.
#
# **🟢 E10: Power Cool/Freeze Error**
#
# *   **Code Interpretation:** The Power Cool or Power Freeze function did not complete successfully. Possible blockage to ventilation.
# *   **Immediate Actions:**
#     *   Ensure no items are blocking vents.
#     *   Restart Power Cool/Freeze.
# *   **Service Triggers:** **POSSIBLY**. If the immediate actions don't resolve the problem, a technician may be needed to diagnose and repair the temperature regulation system.
#
# ---
#
# **Disclaimer:**
#
# This information is for illustrative purposes only and is based on common refrigerator issues and general troubleshooting steps. It does not represent official Samsung error codes or repair procedures. Always consult the official service manual for your specific model and have repairs performed by qualified technicians.
#
#
# --- Calling generate_error_code_qa_deepseek ---
# {'Generations': [{'ErrorCode': 'ERR-0001', 'Description': 'Power cord is not plugged in properly', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Check power outlet', 'Reseat power cord'], 'ServiceRequired': {'Threshold': 'If problem persists', 'Code': 'SVC-ELEC-0001'}, 'UserMessage': 'Ensure the refrigerator is properly connected to a power source'}, {'ErrorCode': 'ERR-0002', 'Description': 'Temperature control is not set correctly', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ['Adjust temperature settings'], 'ServiceRequired': {'Threshold': 'If temperature remains incorrect', 'Code': 'SVC-TEMP-0002'}, 'UserMessage': 'Adjust temperature to the desired level'}, {'ErrorCode': 'ERR-0101', 'Description': 'Water pressure is too low', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ['Check water supply', 'Ensure water valve is open'], 'ServiceRequired': {'Threshold': 'If pressure remains low', 'Code': 'SVC-WATER-0101'}, 'UserMessage': 'Check your water supply and pressure'}, {'ErrorCode': 'ERR-0201', 'Description': 'Door left open for extended period', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ['Close door completely', 'Check for obstructions'], 'ServiceRequired': {'Threshold': 'If alarm persists', 'Code': 'SVC-DOOR-0201'}, 'UserMessage': 'Ensure the door is properly closed to maintain temperature'}, {'ErrorCode': 'ERR-0301', 'Description': 'Replace water filter soon', 'Severity': {'Level': 2, 'Label': 'Medium', 'HexColor': '#008000'}, 'ImmediateResponse': ['Order replacement water filter'], 'ServiceRequired': {'Threshold': 'After filter replacement', 'Code': 'SVC-FILTER-0301'}, 'UserMessage': 'Order a new water filter to maintain the quality of the water'}, {'ErrorCode': 'ERR-0401', 'Description': 'Communication error between display and controller', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Restart device', 'Check connections'], 'ServiceRequired': {'Threshold': 'If persists after reboot', 'Code': 'SVC-COMM-0401'}, 'UserMessage': 'Contact Samsung service center. There is a communication problem with display'}, {'ErrorCode': 'ERR-0501', 'Description': 'Ice maker malfunction, check ice maker', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Check ice maker', 'Restart device'], 'ServiceRequired': {'Threshold': 'If persists after reboot', 'Code': 'SVC-ICEMAKER-0501'}, 'UserMessage': 'Ice maker is not working. Contact Samsung service center'}, {'ErrorCode': 'ERR-0601', 'Description': 'High temperature detected in Fridge', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Reduce door openings', 'Check for airflow obstructions'], 'ServiceRequired': {'Threshold': 'If persists after 24hrs', 'Code': 'SVC-TEMP-0601'}, 'UserMessage': 'The temperature in Fridge section is abnormally high'}, {'ErrorCode': 'ERR-0602', 'Description': 'High temperature detected in Freezer', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Reduce door openings', 'Check for airflow obstructions'], 'ServiceRequired': {'Threshold': 'If persists after 24hrs', 'Code': 'SVC-TEMP-0602'}, 'UserMessage': 'The temperature in Freezer section is abnormally high'}, {'ErrorCode': 'ERR-0603', 'Description': 'High temperature detected in FlexZone', 'Severity': {'Level': 1, 'Label': 'High', 'HexColor': '#FFA500'}, 'ImmediateResponse': ['Reduce door openings', 'Check for airflow obstructions'], 'ServiceRequired': {'Threshold': 'If persists after 24hrs', 'Code': 'SVC-TEMP-0603'}, 'UserMessage': 'The temperature in FlexZone section is abnormally high'}, {'ErrorCode': 'ERR-0701', 'Description': 'Water leak detected', 'Severity': {'Level': 0, 'Label': 'Critical', 'HexColor': '#FF0000'}, 'ImmediateResponse': ['Shut off water supply', 'Unplug the refrig ...
#
# --- Calling generate_error_code_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "ErrorCodeQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_error_code_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What does the \'Filter Reset\' indicator blinking red mean?",\n      "What can cause the refrigerator to not operate at all?",\n      "Why is the temperature inside the fridge/freezer warmer than set?",\n      "What does it mean if the ice maker is making a buzzing sound?",\n      "What to check if the ice maker isn\'t making ice?",\n      "Why might the SmartThings app fail to operate?",\n      "Why does water appear cloudy when dispensed?",\n      "Is it normal for ice to accumulate on one side of the ice tray?",\n      "Can I store vegetable oil in the refrigerator door bins?",\n      "What to do if a gas leak is detected near the appliance?",\n      "What happens if I overfill the refrigerator with food?",\n      "What type of water should I use to fill water tank?"\n    ],\n    "Answers": [\n      "The \'Filter Reset\' indicator blinking red means it\'s time to replace the water filter, typically after 6 months or 300 gallons of water. Replace the filter and then hold the Filter Reset button for 3 seconds.",\n      "A refrigerator not operating could be due to improper power cord connection, incorrect temperature settings, or placement near a heat source. Ensure the refrigerator is properly plugged in, the temperature is set appropriately, and it\'s away from heat sources.",\n      "A warmer temperature could be due to incorrect temperature settings, proximity to heat sources, insufficient clearance, or blocked vents with overloaded food. Adjust the settings, move the unit if needed, and ensure proper food storage.",\n      "A buzzing sound from the ice maker typically indicates that the ice maker function is activated but the water supply is not connected. Turn off the ice maker until the water supply is connected.",\n      "Check if the freezer temperature is set too high, if the ice maker is turned off, or if the water line is disconnected. Set the freezer below 0°F (-18°C), turn on the ice maker, and verify the water line installation.",\n      "The SmartThings app may fail to operate due to compatibility issues with the phone\'s software, or due to connection issues. Ensure your refrigerator is an applicable model, your phone\'s software is compatible, and your router is working correctly.",\n      "Cloudy water is caused by increased water pressure and the water becomes saturated with oxygen and nitrogen during the filtering process. The mistiness is normal and the water clears after a few seconds.",\n      "Ice accumulating on one side of the ice tray is normal. Arrange the ice evenly in the tray to store more ice.",\n      "Storing vegetable oil in the door bins may cause it to solidify, making it less palatable and difficult to use. It\'s best to store oil in a cool, shaded place like a cupboard.",\n      "If a gas leak is detected, avoid any naked flames, ventilate the room, and contact the relevant Samsung service center. Spark may result in an explosion or fire.",\n      "Overfilling the refrigerator may cause items to fall out when opening the door, potentially leading to personal injury or material damage. Avoid overfilling.",\n      "Fill the water tank with potable water only (tap water, mineral water, or purified water). Do not fill the tank with tea, juice, or a sports drink. They can damage the refrigerator."\n    ],\n    "Metadata": {\n      "ErrorSeverity": ["Critical", "Warning", "Informational"],\n      "ResolutionApproach": "Systematic troubleshooting"\n    },\n    "ErrorCodeDetails": {\n      "CodeInterpretation": ["Troubleshooting steps to fix problems with a refrigerator"],\n      "ImmediateActions": ["Solutions to common refrigerator problems"],\n      "ServiceTriggers": ["Cases which you will have to contact support to fix the problem"]\n    },\n    "VisualIndicators": {\n      "SeverityColors": ["🔴 Critical", "🟠 Warning", "🟢 Low Impact"]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 9 generate_safety_qa

# %%
#original
def generate_safety_qa(text):
    """Safety/compliance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate safety Q&A covering:
    - Hazard prevention - Compliance standards - Recall information
    Use warning boxes for critical items.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_safety_qa_deepseek(text):
    """Generates safety alerts with compliance metadata in JSON format.

    Returns:
        JSON with hazard classification, recall batches, and compliance codes.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create safety/compliance Q&A pairs with:
    1. Hazard types: Electrical/Mechanical/Chemical
    2. Compliance standards (ISO/IEC + regional)
    3. Recall data: Batch numbers, date ranges
    4. Severity levels: Critical/High/Medium

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Safety concern]",
        "Answer": {{
          "Description": "...",
          "ComplianceStandards": ["IEC 62368-1"],
          "SeverityLevel": "Critical",
          "RecallInfo": {{
            "AffectedBatches": ["BT2024Q1-45"],
            "DateRange": "2024-03/2024-05"
          }},
          "HazardType": "Electrical"
        }},
        "EmergencyProtocol": ["Unplug immediately", "Evacuate area"]
      }}
    - Validate batch numbers as BTYYYYQX-XX format
    - Sort by SeverityLevel descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "What if my washing machine emits burning smell?",
          "Answer": {{
            "Description": "Potential motor insulation failure...",
            "ComplianceStandards": ["UL 2157"],
            "SeverityLevel": "Critical",
            "RecallInfo": {{
              "AffectedBatches": ["BT2023Q4-12"],
              "DateRange": "2023-11/2024-02"
            }},
            "HazardType": "Electrical"
          }},
          "EmergencyProtocol": ["Cut power", "Contact Samsung Safety Team"]
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse safety protocol"}


#Google AI STudio
def generate_safety_qa_google(text):
    """Safety/compliance pairs in JSON format with 'critical warning' indicator."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate safety Question and Answer pairs from the following Samsung support document text, covering:
    - Hazard prevention measures
    - Relevant compliance standards and certifications
    - Recall information and how to check for recalls

    For critical safety warnings and hazards, explicitly mark them as such. In the JSON output, use a boolean field "IsCriticalWarning": true/false to indicate if a Q&A pair represents a critical warning. In plain text examples within the output, you can use "WARNING BOX" markers or similar visual cues if helpful.

    Use clear, concise, and direct language appropriate for safety information. Consumer-friendly language is essential.

    Present the output as a list of safety Q&A pairs in JSON format. Each pair should be a dictionary with keys: "IsCriticalWarning" (boolean), "Question", "Answer", and optionally "HazardPrevention" (list of measures), "ComplianceStandards" (list of standards), and "RecallInformation" (string or null).

    Text: {text}

    Output Format (example):
    [
      {{ "IsCriticalWarning": true, "Question": "...", "Answer": "...", "HazardPrevention": [...], "ComplianceStandards": [...], "RecallInformation": "..." }},
      {{ "IsCriticalWarning": false, "Question": "...", "Answer": "...", "HazardPrevention": [...], "ComplianceStandards": [...], "RecallInformation": null }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        safety_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        safety_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"SafetyQAPairs": safety_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_safety_qa_sonnet(text):
    """Generate structured safety and compliance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create safety Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Safety and compliance inquiry"
        ],
        "Answers": [
          "Comprehensive safety guidance"
        ],
        "Metadata": {{
          "SafetyAreas": ["Hazard Prevention", "Compliance", "Recalls"],
          "RiskClassification": "Critical safety information"
        }},
        "SafetyDetails": {{
          "HazardPrevention": ["Critical safety measures"],
          "ComplianceStandards": ["Regulatory requirements"],
          "RecallInformation": ["Potential product safety issues"]
        }},
        "WarningIndicators": {{
          "CriticalWarnings": ["High-risk safety alerts"]
        }}
      }}
    }}

    Requirements:
    - Detailed safety explanations
    - Compliance standard insights
    - Recall information
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_safety_qa ---")
test_qa_generators("generate_safety_qa", content)
# Out:
# --- generate_safety_qa ---
#
# --- Calling generate_safety_qa ---
# Okay, here's the safety Q&A based on the provided user manual text. I've added more detail to the answers, referencing the manual where possible, and included warning boxes as requested.
#
# ##### Refrigerator Safety Q&A
#
# **Hazard Prevention**
#
# **Q: What should I do if I smell refrigerant leaking from my refrigerator?**
#
# A: If you detect a refrigerant leak:
#
# 1.  Avoid any open flames or potential sources of ignition.
# 2.  Move flammable materials away from the refrigerator immediately.
# 3.  Ventilate the room in which the refrigerator is located.
# (*Refer to Safety Information, Important safety precautions*)
#
#
# WARNING
# Refrigerant leaks can cause fire or explosion. Take immediate action to prevent these hazards.
#
# **Q: What precautions should I take when children are around the refrigerator?**
#
# A:
#
# *   Supervise children to ensure they do not play with the appliance (Safety Information, Important safety precautions, Critical usage warnings).
# *   Keep fingers out of "pinch point" areas (Safety Information, Critical usage warnings).
# *   Do not let children hang on doors or bins, as injury may occur (Safety Information, Critical usage warnings).
# *   Do not allow children inside the refrigerator to prevent entrapment and potential suffocation (Safety Information, Critical usage warnings).
# *   Ensure children do not play with snap rings used for door adjustment or water tube clips. These are choking hazards. Keep snap rings and water tube clips out of reach (Safety Information, Critical installation warnings).
# *   When disposing of an old refrigerator, remove the doors to prevent child entrapment (Safety Information, Important safety precautions, Critical disposal warnings).
#
# WARNING
# Children are vulnerable to refrigerator-related hazards. Keep them safe by following these precautions.
#
# **Q: What types of materials should I NOT store in the refrigerator?**
#
# A:  Do not store volatile or flammable materials such as benzene, thinner, propane gas, alcohol, ether, or LP gas in the refrigerator. This refrigerator is intended for storing food only. Storing such materials could result in fire or explosion.
# (*Refer to Safety Information, Critical usage warnings*)
#
# WARNING
# Storing flammable materials in the refrigerator can cause fire or explosion. Only store food items in the refrigerator.
#
# **Q: What precautions should I take before cleaning the refrigerator?**
#
# A: Before cleaning the refrigerator:
#
# 1.  Unplug the refrigerator from the electrical outlet.
# 2.  Do not spray water directly on the inside or outside of the refrigerator. This could cause electric shock or fire.
# 3.  Do not use benzene, thinner, or bleach to clean the refrigerator, as these may damage the surface of the appliance and may cause a fire.
# (*Refer to Safety Information, Cleaning cautions*)
#
# WARNING
# Always unplug the refrigerator before cleaning and avoid using flammable or corrosive cleaning agents to prevent electrical shock or fire.
#
# **Compliance Standards**
#
# **Q: What standards does this refrigerator comply with regarding radio frequency emissions?**
#
# A: The manual states compliance with Part 15 of the FCC Rules, ensuring that the device does not cause harmful interference and accepts any interference received. For products available in the US and Canadian markets, only channels 1~11 are available.
# (*Refer to Regulatory Notice, FCC Notice*)
#
# **Q: What encryption systems are recommended for Wi-Fi connectivity of SmartThings app?**
#
# A: The manual recommends WPA/TKIP and WPA2/AES encryption systems, while also noting that wireless networks may be affected by the surrounding wireless communication environment.
#
# **Recall Information**
#
# **Q: Where can I find information about recalls related to my Samsung refrigerator?**
#
# A: The user manual itself does not contain direct, specific recall information. The manual does, however, direct users to contact Samsung Customer Care at 1-800-SAMSUNG (726-7864) or visit the Samsung website at www.samsung.com for assistance and support. It is also suggested to check the manufacturer's website for any recalls related to the specific model.
#
#
# --- Calling generate_safety_qa_deepseek ---
# {'Generations': [{'Question': 'What should I do if the refrigerator emits a burning smell or smoke?', 'Answer': {'Description': 'Unplug the refrigerator immediately and contact a Samsung service center. This could indicate electrical or fire hazards.', 'ComplianceStandards': [], 'SeverityLevel': 'Critical', 'RecallInfo': None, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Unplug immediately', 'Contact Samsung service']}, {'Question': 'What if refrigerant leaks from the pipe?', 'Answer': {'Description': 'Refrigerant squirting out of the pipes could ignite or cause an eye injury. Avoid any naked flames, move anything flammable away, and ventilate the room immediately.', 'ComplianceStandards': [], 'SeverityLevel': 'Critical', 'RecallInfo': None, 'HazardType': 'Chemical'}, 'EmergencyProtocol': ['Avoid flames', 'Ventilate room', 'Evacuate if necessary']}, {'Question': 'What if the power cord has cracks or abrasion damage?', 'Answer': {'Description': 'A damaged power cord may cause a short-circuit, fire, and/or electric shock. Do not use a power cord that has cracks or abrasion damage.', 'ComplianceStandards': ['IEC 60335-1'], 'SeverityLevel': 'High', 'RecallInfo': None, 'HazardType': 'Electrical'}, 'EmergencyProtocol': ['Do not touch', 'Replace power cord by qualified technician']}, {'Question': 'Is it OK to put my hands into the area under the appliance?', 'Answer': {'Description': 'Sharp edges may cause personal injury.', 'ComplianceStandards': [], 'SeverityLevel': 'Medium', 'RecallInfo': None, 'HazardType': 'Mechanical'}, 'EmergencyProtocol': ['Seek first aid if injured']}, {'Question': 'What to do if the door is left open for more than 2 minutes?', 'Answer': {'Description': 'If the door is left open for more than 2 minutes, an alarm will sound and the alarm indicator will blink. This is an energy efficiency warning.', 'ComplianceStandards': [], 'SeverityLevel': 'Medium', 'RecallInfo': None, 'HazardType': None}, 'EmergencyProtocol': ['Close the door']}]}
#
# --- Calling generate_safety_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "SafetyQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_safety_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": [\n    {\n      "Questions": [\n        "What are the general safety instructions for the Samsung refrigerator?"\n      ],\n      "Answers": [\n        "Read the manual thoroughly to ensure safe and efficient operation, supervise children to prevent accidents, and contact Samsung with any questions."\n      ],\n      "Metadata": {\n        "SafetyAreas": [\n          "General Safety",\n          "Child Safety"\n        ],\n        "RiskClassification": "General safety information"\n      },\n      "SafetyDetails": {\n        "GeneralSafety": [\n          "Reading manual",\n          "Operating features",\n          "Functions safely and efficiently"\n        ],\n        "ChildSafety": [\n          "Supervision",\n          "Prevent playing",\n          "Potential hazards"\n        ]\n      }\n    },\n    {\n      "Questions": [\n        "What are the potential fire hazards associated with the refrigerant?"\n      ],\n      "Answers": [\n        "Refrigerant leaks could ignite or cause eye injuries; avoid open flames and ventilate the area immediately to prevent fire or explosion."\n      ],\n      "Metadata": {\n        "SafetyAreas": [\n          "Fire Hazards",\n          "Refrigerant"\n        ],\n        "RiskClassification": "Critical safety information"\n      },\n      "SafetyDetails": {\n        "FireHazards": [\n          "Flammable gas-air mixture",\n          "Potential for ignition",\n          "Explosive atmospheres"\n        ],\n        "Refrigerant": [\n          "R-600a refrigerant",\n          "Handling leaks",\n          "Ventilation protocols"\n        ]\n      },\n       "WarningIndicators": {\n          "CriticalWarnings": ["Refrigerant Leaks"]\n        }\n    },\n        {\n      "Questions": [\n        "What precautions should be taken during appliance transportation and installation?"\n      ],\n      "Answers": [\n        "Ensure no parts of the refrigerating circuit are damaged to prevent refrigerant leaks that could ignite or cause eye injury, and ensure proper ventilation."\n      ],\n      "Metadata": {\n        "SafetyAreas": [\n          "Transportation",\n          "Installation"\n        ],\n        "RiskClassification": "Critical safety information"\n      },\n      "SafetyDetails": {\n        "Transportation": [\n          "Preventing damage to refrigerating circuit",\n          "Handling flammable refrigerant"\n        ],\n        "Installation": [\n          "Avoiding ignition sources",\n          "Ensuring proper ventilation"\n        ]\n      },\n      "WarningIndicators": {\n          "CriticalWarnings": ["Appliance Transportation"]\n        }\n    },\n     {\n      "Questions": [\n        "What electrical safety measures should be observed during installation?"\n      ],\n      "Answers": [\n        "Avoid damp locations, use dedicated outlets, and ensure grounding to prevent electric shock or fire, always handling the power cord with care."\n      ],\n      "Metadata": {\n        "SafetyAreas": [\n          "Electrical Safety",\n          "Installation",\n          "Grounding"\n        ],\n        "RiskClassification": "Critical safety information"\n      },\n      "SafetyDetails": {\n        "ElectricalSafety": [\n          "Avoiding loose sockets",\n          "Cord damage",\n          "Overloading"\n        ],\n        "Installation": [\n          "Proper placement",\n          "Grounding wires",\n          "Humidity"\n        ],\n        "Grounding": [\n          "Secure grounding",\n          "Grounding leakages",\n          "Potential risks"\n        ]\n      },\n      "WarningIndicators": {\n          "CriticalWarnings": ["Electrical installation"]\n        }\n    },\n      {\n      "Questions": [\n        "What usage warnings should I be aware of?"\n      ],\n      "Answers": [\n        "Avoid wet hands when plugging in, do not store volatile substances, and supervise children to preven ...

# %% [markdown]
# ### Number 10 generate_compatibility_qa

# %%
#original
def generate_compatibility_qa(text):
    """Device compatibility pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A with:
    - Supported models - Version requirements - Regional variations
    Present compatibility as tables when possible.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_compatibility_qa_deepseek(text):
    """Generates device compatibility matrices with regional versioning in JSON.

    Returns:
        JSON with nested compatibility tables using model codes and ISO regions.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A pairs with:
    1. Model numbers in SM/QE-XXXX format
    2. Minimum firmware versions (major.minor.build)
    3. Regional availability using ISO 3166 codes
    4. Feature-specific compatibility flags

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Compatibility inquiry]",
        "Answer": {{
          "CompatibilityMatrix": {{
            "DeviceModel": "SM-S901B",
            "MinimumVersion": "5.1.23",
            "Regions": {{
              "NA": ["QC3.0", "6GHz WiFi"],
              "EU": ["QC3.0", "5G Sub6"]
            }}
          }},
          "Notes": "5G mmWave excluded in EU models"
        }},
        "Category": "Smartphone/Accessory/TV"
      }}
    - Validate model numbers as Samsung's official format
    - Use semantic versioning for firmware

    Example:
    {{
      "Generations": [
        {{
          "Question": "Which Galaxy phones support DeX with 4K monitors?",
          "Answer": {{
            "CompatibilityMatrix": {{
              "DeviceModel": "SM-S928B",
              "MinimumVersion": "6.0.1",
              "Regions": {{
                "Global": ["4K@60Hz via HDMI"],
                "CN": ["4K@30Hz"]
              }}
            }},
            "Notes": "Requires HDMI 2.1 certified cable"
          }},
          "Category": "Smartphone"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse compatibility matrix"}


#Google AI STudio
def generate_compatibility_qa_google(text):
    """Device compatibility pairs in JSON format, including compatibility tables."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung device compatibility from the following support document text, covering:
    - Supported Samsung models
    - Version requirements (software, OS)
    - Regional variations in compatibility

    Present compatibility information as tables within the answers whenever possible to clearly show model or version compatibility. In the JSON output, represent tables as a list of dictionaries, where each dictionary is a row.

    Use consumer-friendly language. Keep answers concise and present compatibility information in an easy-to-understand format.

    Present the output as a list of compatibility Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "CompatibilityTable" (list of row dictionaries - see example format), "VersionRequirements" (string or null), and "RegionalVariations" (string or null). If no table is applicable, "CompatibilityTable" should be null.

    Text: {text}

    Output Format (example, tables as list of dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "CompatibilityTable": [
          {{ "Column 1 Header": "Value 1", "Column 2 Header": "Value 2" }},
          {{ "Column 1 Header": "Value 3", "Column 2 Header": "Value 4" }},
          ...
        ],
        "VersionRequirements": "...",
        "RegionalVariations": "..."
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "CompatibilityTable": null,
        "VersionRequirements": "...",
        "RegionalVariations": "..."
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        compatibility_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        compatibility_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"CompatibilityQAPairs": compatibility_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_compatibility_qa_sonnet(text):
    """Generate structured device compatibility Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create compatibility Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Device compatibility inquiry"
        ],
        "Answers": [
          "Comprehensive compatibility explanation"
        ],
        "Metadata": {{
          "CompatibilityTypes": ["Model Support", "Version Requirements", "Regional Variations"]
        }},
        "CompatibilityDetails": {{
          "SupportedModels": ["Detailed model list"],
          "VersionRequirements": ["Minimum/optimal version specifications"],
          "RegionalVariations": ["Geographic compatibility notes"]
        }},
        "CompatibilityTable": {{
          "Format": "Tabular representation of compatibility data"
        }}
      }}
    }}

    Requirements:
    - Comprehensive compatibility information
    - Model and version specifics
    - Regional considerations
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_compatibility_qa ---")
test_qa_generators("generate_compatibility_qa", content)
# Out:
# --- generate_compatibility_qa ---
#
# --- Calling generate_compatibility_qa ---
# Okay, here's the compatibility Q&A based on the provided user manual text:
#
# **Q&A: Samsung Free Standing Refrigerator Compatibility**
#
# This Q&A summarizes the compatibility information found within the user manual.  It focuses on providing a clear and concise overview based on the text provided.
# Text does not provide Supported Model lists or Version requirements, so table will remain empty.
#
# **1. Supported Models**
#
# *   The manual covers "various models," implying that specific models are *not* universally compatible with every feature and instruction.  The manual mentions specific models in the Clearance section:
#     *   RF23BB8*****
#     *   RF29BB8*****
# *   The manual also notes that the features of your refrigerator "may differ slightly from the refrigerator described in this manual."
# *   Throughout the document, it specifies "*applicable models only*" for certain features.
#
# *Table: Supported Models (Example - based on limited manual text)*
#
# | Feature                       | Supported Model Examples |
# | ----------------------------- | ------------------------ |
# | AutoFill Pitcher              | RF23BB8*****, RF29BB8*****        |
# | Water Dispenser               | RF23BB8*****, RF29BB8*****        |
# | SMART GRID (Demand Response) | All Smart Grid enabled models.|
#
# **2. Version Requirements**
#
# The user manual doesn't explicitly state version requirements for the refrigerator itself. However, SmartThings has implied requirements.
#
# *Table: Version Requirements*
#
# | Feature       | Version Information                                                                   |
# | ------------- | ------------------------------------------------------------------------------------- |
# | SmartThings   | "The supporting software version of the SmartThings app is subject to change." "As the mobile phone OS version is updated every year, the SmartThings is also updated continually according to the latest OS." |
#
# **3. Regional Variations**
#
# The manual mentions variations between regions, but the most significant regional difference is related to the warranty.
#
# *   **Warranty:** There is a specific "LIMITED WARRANTY (U.S.A.)" section and a separate "Warranty Information (CANADA)" section.  This highlights a major regional difference.
# *   **Water Filter Lifecycle:** "Some regions have relatively large amounts of lime in their water. This can reduce the lifecycle of the fliter."
# *   **Voltage:** The "Safety Information" section specifies AC 115-120V.
#
# *Table: Regional Variations*
#
# | Feature        | USA                        | CANADA                   |
# | -------------- | -------------------------- | ------------------------ |
# | Warranty       | LIMITED WARRANTY (U.S.A.) | Warranty Information (CANADA) |
# | Water Filter Lifecycle | Varies based on lime content | Varies based on lime content |
# | Voltage        | AC 115-120V                | Assumed AC 115-120V       |
#
# **4. SmartThings Compatibility Details**
#
# The document highlights several important SmartThings-related points.
#
# *   MAC Address retrieval instructions for SMART GRID Function.
# *   "If the Wi-Fi indicator flashes when opening or closing the fridge door, this indicates that the refrigerator is not connected with the SmartThings app."
# *   SmartThings supporting software version is "subject to change" based on manufacturer OS updates.
# *   Recommended encryption systems include WPA/TKIP and WPA2/AES.
#
# *Table: SmartThings Notes*
#
# | Area | Notes |
# |---|---|
# | App Download Location| Visit the Google Play Store, Galaxy Apps, or Apple App Store and search for "SmartThings".|
# | MAC Address Retrieval| Requires Freezer and Fridge button combination for 6 seconds followed by another Freezer press to display the address sequence. |
# | Wi-Fi Indicator| A flashing indicator means it is *not* connected to the app.  |
# | Encryption |WPA/TKIP and WPA2/AES. Any newer or non-standard Wi-Fi authentication protocols are not supported. |
# | Contact| Contact us on st.service@samsung.com with questions about the SmartThings app. |
#
#
# --- Calling generate_compatibility_qa_deepseek ---
# {'Generations': [{'Question': 'Does model RF23BB8***** support the Smart Grid function?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'RF23BB8*****', 'MinimumVersion': '1.0.0', 'Regions': {'US': ['Smart Grid (Demand Response)'], 'CA': ['Smart Grid (Demand Response)']}}, 'Notes': 'Requires separate contract with electric utility company and EMS (Energy Management System) supporting SEP (Smart Energy profile)'}, 'Category': 'Refrigerator'}, {'Question': "Can I control my BESPOKE refrigerator's temperature remotely?", 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'RF29BB8*****', 'MinimumVersion': '2.5.1', 'Regions': {'US': ['Remote Temperature Adjustment via SmartThings'], 'CA': ['Remote Temperature Adjustment via SmartThings']}}, 'Notes': 'SmartThings app required.  Some options or settings may not be available for remote control.'}, 'Category': 'Refrigerator'}, {'Question': 'Is the AutoFill Pitcher on RF23BB8***** dishwasher-safe?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'RF23BB8*****', 'MinimumVersion': '1.0.0', 'Regions': {'US': [], 'CA': []}}, 'Notes': 'The water pitcher and lid are not microwave safe and can melt or deform if exposed to heat (including hot water). Please hand wash in cool or warm water as needed.'}, 'Category': 'Refrigerator'}, {'Question': 'What is the minimum water pressure required for the ice maker to operate properly?', 'Answer': {'CompatibilityMatrix': {'DeviceModel': 'RF29BB8*****', 'MinimumVersion': '2.0.0', 'Regions': {'US': ['Ice Maker Functionality'], 'CA': ['Ice Maker Functionality']}}, 'Notes': 'Water pressure must be between 30-125 psi (206-861 kPa).'}, 'Category': 'Refrigerator'}]}
#
# --- Calling generate_compatibility_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "CompatibilityQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_compatibility_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "Is this refrigerator model compatible with my existing smart home ecosystem?",\n      "Which refrigerator models support SmartThings functionality in Canada?"\n    ],\n    "Answers": [\n      "This refrigerator\'s SmartThings functionality allows you to monitor and control the appliance remotely through a compatible smartphone or tablet. Check your smart home ecosystem\'s specifications to ensure full integration and feature availability.",\n      "Refer to the specifications on the Samsung Canada website or the included manual to confirm specific model compatibility with SmartThings. Model numbers and supported features may vary by region."\n    ],\n    "Metadata": {\n      "CompatibilityTypes": [\n        "Model Support",\n        "Version Requirements",\n        "Regional Variations"\n      ]\n    },\n    "CompatibilityDetails": {\n      "SupportedModels": [\n        "The user manual indicates compatibility with models RF23BB8***** and RF29BB8***** as examples, but the specific list should be confirmed on the Samsung website for the current product lineup. These models may also have variations related to the AutoFill Pitcher or Beverage Center."\n      ],\n      "VersionRequirements": [\n        "The software version of the SmartThings app and the router firmware must be up-to-date for optimal performance. Older versions may lack support for new features or security patches.",\n        "The manual also states, \'The supporting software version of the SmartThings app is subject to change according to the OS supporting policy the manufacturer provides\'."\n      ],\n      "RegionalVariations": [\n        "Features like Smart Grid (Demand Response) depend on agreements with the electric utility company, and their availability varies by region. Contact your local utility to see if they offer a Smart Grid service that\'s compatible with your Samsung refrigerator. Canadian warranty only valid if purchased and used in Canada."\n      ]\n    },\n    "CompatibilityTable": {\n      "Format": "The complete compatibility table is not directly present in this document. Model specifics and support for SmartThings, Smart Grid, and available languages should be referred from the Samsung website."\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 11 generate_maintenance_qa

# %%
#original
def generate_maintenance_qa(text):
    """Preventive care pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate maintenance Q&A including:
    - Service intervals - Cleaning procedures - Part replacements
    Add maintenance checklists with timelines.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_maintenance_qa_deepseek(text):
    """Generates maintenance schedules with part/tool validation in JSON format.

    Returns:
        JSON with nested maintenance tiers, validated part SKUs, and interval units.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create maintenance Q&A pairs with:
    1. Maintenance types: Preventive/Predictive/Corrective
    2. Interval formats: Days/UsageHours/Cycles
    3. Samsung part numbers (SPX-XXXX format)
    4. Tool requirements with official SKUs

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Maintenance task]",
        "Answer": {{
          "MaintenanceType": "Preventive",
          "Interval": {{
            "Value": 180,
            "Unit": "Days",
            "Condition": "NormalUsage"
          }},
          "Procedures": [
            {{
              "Step": 1,
              "Action": "Clean air vents",
              "Tools": ["GJ-CLN45"],
              "PartSKU": "SPX-0987"
            }}
          ],
          "Criticality": "High"
        }},
        "LastServicedDate": "2024-03-15"
      }}
    - Validate part numbers as SPX-XXXX
    - Sort by Criticality then Interval.Value

    Example:
    {{
      "Generations": [
        {{
          "Question": "How often should I service my Bespoke refrigerator?",
          "Answer": {{
            "MaintenanceType": "Predictive",
            "Interval": {{
              "Value": 365,
              "Unit": "Days",
              "Condition": "HeavyIceUsage"
            }},
            "Procedures": [
              {{
                "Step": 1,
                "Action": "Defrost ice maker",
                "Tools": ["GJ-DEF12"],
                "PartSKU": "SPX-4567"
              }}
            ],
            "Criticality": "Medium"
          }},
          "LastServicedDate": "2023-09-01"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse maintenance protocol"}


#Google AI STudio
def generate_maintenance_qa_google(text):
    """Preventive maintenance pairs in JSON format with checklists and timelines."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate maintenance Question and Answer pairs from the following Samsung support document text, including:
    - Service intervals (how often maintenance is needed)
    - Cleaning procedures (how to clean specific parts or the device)
    - Part replacements (when and which parts need replacement)

    For key maintenance tasks, create maintenance checklists with recommended timelines for each task.  Present timelines clearly (e.g., "Monthly", "Every 6 Months", "Annually").

    Use consumer-friendly language. Keep answers concise and provide actionable maintenance advice.

    Present the output as a list of maintenance Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "ServiceInterval" (string or null), "CleaningProcedure" (string or null), "PartReplacement" (string or null), and "MaintenanceChecklist" (dictionary - see example format below, or null if no checklist is applicable).  "MaintenanceChecklist" should contain a "Timeline" (overall checklist timeline) and "Items" (list of checklist item dictionaries, each with "Task", "Timeline", and "Details").

    Text: {text}

    Output Format (example, checklists as nested dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "ServiceInterval": "...",
        "CleaningProcedure": "...",
        "PartReplacement": "...",
        "MaintenanceChecklist": {{
          "Timeline": "...",
          "Items": [
            {{ "Task": "...", "Timeline": "...", "Details": "..." }},
            {{ "Task": "...", "Timeline": "...", "Details": "..." }},
            ...
          ]
        }}
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "ServiceInterval": null,
        "CleaningProcedure": null,
        "PartReplacement": null,
        "MaintenanceChecklist": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        maintenance_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        maintenance_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"MaintenanceQAPairs": maintenance_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_maintenance_qa_sonnet(text):
    """Generate structured preventive maintenance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create maintenance Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Maintenance and care inquiry"
        ],
        "Answers": [
          "Comprehensive maintenance guidance"
        ],
        "Metadata": {{
          "MaintenanceTypes": ["Service Intervals", "Cleaning", "Part Replacement"]
        }},
        "MaintenanceDetails": {{
          "ServiceIntervals": ["Recommended maintenance schedule"],
          "CleaningProcedures": ["Detailed cleaning instructions"],
          "PartReplacements": ["Component replacement guidelines"]
        }},
        "MaintenanceChecklist": {{
          "Timeline": "Periodic maintenance schedule"
        }}
      }}
    }}

    Requirements:
    - Detailed maintenance guidance
    - Service interval specifics
    - Cleaning and replacement procedures
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_maintenance_qa ---")
test_qa_generators("generate_maintenance_qa", content)
# Out:
# --- generate_maintenance_qa ---
#
# --- Calling generate_maintenance_qa ---
# Here's a comprehensive maintenance Q&A and checklist based on the provided user manual for the Samsung Refrigerator:
#
# **Samsung Refrigerator Maintenance: Q&A**
#
# **Service Intervals**
#
# *   **Q: How often should I replace the water filter?**
#     *   **A:**  The user manual recommends replacing the water filter approximately every 6 months, or after approximately 300 gallons (1200 L) of water have been used.  The "Filter" indicator will blink red to remind you. (Page 39, 71)
# *   **Q: Are there any other components that require scheduled servicing?**
#     *   **A:**  The manual only specifies water filter replacement. There are no other components that the user has to replace or maintain according to a scheduled interval. The interior and exterior LED lamps that need replacement should be done by a qualified service center.(Page 11,66)
#
# **Cleaning Procedures**
#
# *   **Q: How do I clean the interior of the refrigerator?**
#     *   **A:** Unplug the refrigerator. Use a moistened, soft, lint-free cloth or paper towel to clean the interior. Then dry with a clean cloth or paper towel. (Page 64)
# *   **Q: How do I clean the exterior of the refrigerator?**
#     *   **A:** Unplug the refrigerator. Use a moistened, soft, lint-free cloth or paper towel to clean the exterior.  Then dry with a clean cloth or paper towel. (Page 64)
# *   **Q: Can I use regular household cleaners?**
#     *   **A:** No. The manual explicitly warns against using benzene, thinner, home/car detergent, or Clorox (bleach).  These can damage the surface and pose a fire hazard. (Page 64)
# *   **Q: How do I clean the dispenser nozzle?**
#     *   **A:** Hold the end of the dispenser nozzle, turn it to the left, and pull it down to remove. Clean the nozzle thoroughly and reassemble. (Page 64)
# *   **Q: How do I clean the AutoFill Pitcher?**
#     *   **A:** 1. Grasp a handle groove of the lid, and then pull up to remove. 2. Grasp both sides of the infuser holder, and then lift to remove. 3. While slightly twisting the infuser, pull it out of the sealed mouth. 4. Clean the infuser with neutral agents and running water. Rinse and dry well. 5. Reassemble the AutoFill Pitcher in the reverse order of disassembly. (Page 56)
# *    **Q: How do I clean the water pitcher?**
#     *   **A:**  Clean the water pitcher with neutral agents and running water. Rinse and dry well.(Page 56)
# *   **Q: Can I clean the refrigerator with water?**
#     *   **A:** Do not spray water directly on the inside or outside of the refrigerator. This may cause electric shock. (Page 64)
# *    **Q: Is dish soap safe for cleaning the refrigerator?**
#      *   **A:** Yes, the user manual suggests to "Use a clean sponge or soft cloth and a mild detergent in warm water to clean the refrigerator" (Page 13).
#
# **Part Replacements**
#
# *   **Q: How do I reset the filter indicator after replacing the water filter?**
#     *   **A:** After replacing the filter, press and hold the "Filter Reset" button on the main panel for 3 seconds. (Page 39)
# *   **Q: Can I replace the LED lamps inside the refrigerator myself?**
#     *   **A:** No. The lamps are not user-serviceable. Contact a local Samsung service center for replacement. (Page 66, 67)
# *   **Q: Can I replace the lamps of the refrigerator?**
#     *   **A:** Contact a local Samsung service center. (Page 67)
# *   **Q: What type of fuse should I use?**
#      *   **A:** Do not use any fuse (such as cooper, steel wire, etc.) other than a standard fuse. (Page 11)
# *   **Q: Can I disassembling or assembling the door panel on my own?**
#      *   **A:** No, it may result in product damage or personal injury. Contact a Samsung service center. (Page 67)
# **Water Quality**
# *   **Q: Can I connect the refrigerator with tea, juice, or a sports drink?**
#      *   **A:** No, do not fill the tank with tea, juice, or a sports drink. They can damage the refrigerator. (Page 11, 12)
#
# **Maintenance Checklists with Timelines**
#
# Here are maintenance checklists organized by timeline:
#
# **Daily/As Needed**
#
# *   Wipe up any spills inside the refrigerator immediately.
# *   Check for and discard any spoiled food.
# *   Clean the dispenser nozzle if needed. (especially for dispenser models)
# *   Wipe any moisture on marked area of the water pitcher. (especially for AutoFill pitcher models)
# *   Clean the water pitcher every 3 days.
#
# **Monthly**
#
# *   Give the interior a quick cleaning with a damp cloth (after unplugging the refrigerator).
# *   Inspect door gaskets (seals) and clean them with a damp cloth to ensure a tight seal.
#
# **Every 6 Months (or as indicated by the filter indicator)**
#
# *   Replace the water filter (if applicable).
# *   Reset the water filter indicator.
# *   Consider cleaning the ice bucket (if applicable).
#
# **Annually**
#
# *   Unplug the refrigerator and give it a thorough cleaning, including removing shelves and drawers for washing with mild soap and water.
# *   Check the condenser coils (usually on the back of the unit) and vacuum them to remove dust and debris.  *Note: The manual does not give this guidance, use caution*
#
# **Every 1-2 Years**
#
# *   Aspire the cables and parts of the rear panel. (Page 65)
#
# **Important Considerations**
#
# *   **Always unplug the refrigerator before performing any maintenance or cleaning tasks that involve removing parts or working near electrical components.**
# *   **Use caution when handling glass shelves. Avoid exposing them to sudden temperature changes or impacts.**
# *   **If you are unsure about any maintenance procedure, contact a qualified technician or Samsung customer service.**
# *    **When reinserting the ice bucket, remove any ice lump that are left over in the tray. (Page 52)**
# *   **To use the Smart Grid, you need a separate contract with your electric utility company. (Page 45)**
# *   **Do not strike or apply excessive force to any glass surface. Broken glass may result in a personal injury and/or property damage. (Page 12)**
#
# This detailed Q&A and maintenance checklist should help users keep their Samsung refrigerators in good working order, ensuring optimal performance and longevity.
#
#
# --- Calling generate_maintenance_qa_deepseek ---
# {'Generations': [{'Question': 'What action do I take if large amounts of dust or water enter the refrigerator?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 1, 'Unit': 'Cycles', 'Condition': 'Contamination'}, 'Procedures': [{'Step': 1, 'Action': 'Disconnect the power plug', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Contact a Samsung Electronics service center', 'Tools': [], 'PartSKU': None}], 'Criticality': 'High'}, 'LastServicedDate': None}, {'Question': 'What should I do to ensure my refrigerator is installed on a flat, solid floor?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 1, 'Unit': 'Cycles', 'Condition': 'NewInstallation'}, 'Procedures': [{'Step': 1, 'Action': 'Inspect the floor surface', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Adjust the front leveling legs', 'Tools': ['GJ-SCR01'], 'PartSKU': None}], 'Criticality': 'High'}, 'LastServicedDate': None}, {'Question': 'What should I do if the supply cord is damaged?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 1, 'Unit': 'Cycles', 'Condition': 'DamagedCord'}, 'Procedures': [{'Step': 1, 'Action': 'Do not use the appliance.', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Replace the cord by the manufacturer or its service agent', 'Tools': ['GJ-SCR01', 'GJ-PLR02'], 'PartSKU': 'SPX-0001'}], 'Criticality': 'High'}, 'LastServicedDate': None}, {'Question': 'How often should the water filter be replaced?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 6, 'Unit': 'Months', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Purchase a new water filter', 'Tools': [], 'PartSKU': 'SPX-1234'}, {'Step': 2, 'Action': 'Replace the water filter', 'Tools': [], 'PartSKU': 'SPX-1234'}, {'Step': 3, 'Action': 'Run Filter Reset', 'Tools': [], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': '2024-05-01'}, {'Question': 'What should I do if a gas leak is detected?', 'Answer': {'MaintenanceType': 'Corrective', 'Interval': {'Value': 1, 'Unit': 'Cycles', 'Condition': 'GasLeak'}, 'Procedures': [{'Step': 1, 'Action': 'Avoid any naked flames or potential sources of ignition', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Air the room in which the appliance is standing for several minutes.', 'Tools': [], 'PartSKU': None}, {'Step': 3, 'Action': 'Do not touch the appliance or power cord.', 'Tools': [], 'PartSKU': None}, {'Step': 4, 'Action': 'Do not use a ventilating fan.', 'Tools': [], 'PartSKU': None}], 'Criticality': 'Medium'}, 'LastServicedDate': None}, {'Question': 'How do I clean the dispenser nozzle?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 30, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Hold the end of the dispenser nozzle', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Turn the dispenser nozzle left, pull it down to remove it from the dispenser', 'Tools': [], 'PartSKU': None}, {'Step': 3, 'Action': 'Clean the dispenser nozzle thoroughly, and then assemble it back', 'Tools': ['GJ-CLN45'], 'PartSKU': None}], 'Criticality': 'Low'}, 'LastServicedDate': '2024-05-15'}, {'Question': 'How often should I clean the interior and exterior of the refrigerator?', 'Answer': {'MaintenanceType': 'Preventive', 'Interval': {'Value': 30, 'Unit': 'Days', 'Condition': 'NormalUsage'}, 'Procedures': [{'Step': 1, 'Action': 'Unplug the power cord.', 'Tools': [], 'PartSKU': None}, {'Step': 2, 'Action': 'Clean the refrigerator’s interior and exterior with a moistened, soft, lint-free cloth or paper towel.', 'Tools': ['GJ-CLN45'], 'PartSKU': None}, {'Step': 3, 'Action': 'Dry well with a dry cloth or paper towel.', 'Tools': ['GJ-DRY01'], 'PartSKU': None}, {'Step': 4, 'Action': 'Plug in the power cord.', 'Tools': [], 'PartSKU': None}], 'Criticality': 'Low'}, 'LastServicedDate': '2024-05-15'}]}
#
# --- Calling generate_maintenance_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "MaintenanceQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_maintenance_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How often should I clean the interior and exterior of my Samsung refrigerator?",\n      "What cleaning products should I avoid when cleaning my Samsung refrigerator?",\n      "How do I clean the dispenser nozzle on my Samsung refrigerator?",\n      "How do I replace the water filter in my Samsung refrigerator?",\n      "What is the proper water pressure required for ice making?",\n      "What do I do if ice clumps form inside the ice bucket?",\n      "How do I clean the autofill pitcher?",\n      "How do I know when it\'s time to replace the water filter?",\n      "How do I remove a fridge shelf?",\n      "How do I remove a door bin?",\n      "What do I do if water is not dispensing properly?"\n    ],\n    "Answers": [\n      "Regularly clean the interior and exterior with a moistened, soft, lint-free cloth or paper towel, then dry well.",\n      "Avoid using benzene, thinner, home/car detergent, or bleach, as they can damage the refrigerator\'s surface.",\n      "Hold the end of the dispenser nozzle, turn it left, pull down to remove it, clean it thoroughly, and reassemble.",\n      "Turn off the water supply, remove the old filter, insert the new filter aligning the indicator line, and then turn to lock.",\n      "The water pressure required for ice making is between 30-125 psi (206-861 kPa).",\n      "Remove and empty the ice bucket to break up any ice clumps that have formed.",\n      "Remove the lid and infuser, clean each part with neutral agents and running water, rinse, and dry thoroughly.",\n      "The filter indicator will blink red, reminding you to replace the filter after about 6 months or 300 gallons (1200 L) of water usage.",\n      "Lift the rear side of the shelf, tilt it vertically and carefully pull the shelf out.",\n      "Hold the front sides of the bin, lift up to remove. To reinsert, align and press down so that it fits snugly.",\n      "If water is not dispensing properly, the water filter is most likely clogged, or the water line may not be properly connected."\n    ],\n    "Metadata": {\n      "MaintenanceTypes": ["Cleaning", "Part Replacement", "Troubleshooting", "Handling"]\n    },\n    "MaintenanceDetails": {\n      "CleaningProcedures": ["Use a soft cloth and mild detergent.", "Avoid harsh chemicals."],\n      "PartReplacements": ["Purchase a new water filter.", "Refer to user manual for proper water filter installation."],\n      "Troubleshooting": ["Ensure proper water pressure.", "Check for clogs in the water line."]\n    },\n    "MaintenanceChecklist": {\n      "Timeline": "Perform routine maintenance for optimal appliance lifespan."\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 12 generate_warranty_qa

# %%
#original
def generate_warranty_qa(text):
    """Warranty/service pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A covering:
    - Coverage details - Claim processes - Void conditions
    Include regional policy variations.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_warranty_qa_deepseek(text):
    """Generates warranty rules with policy validation in JSON format.

    Returns:
        JSON with coverage timelines, ISO regions, and machine-readable void terms.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A pairs with:
    1. Policy numbers in WR-YYYY-REG format (e.g., WR-2024-US)
    2. Coverage periods as start/end dates
    3. Void conditions as codified rules (MODIFIED_HARDWARE = void)
    4. Regional terms using ISO 3166 codes

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Warranty inquiry]",
        "Answer": {{
          "PolicyNumber": "WR-2024-EU",
          "CoveragePeriod": {{
            "Start": "2024-01-01",
            "End": "2026-12-31",
            "DurationDays": 1095
          }},
          "Regions": ["DE", "FR", "IT"],
          "VoidConditions": [
            {{
              "Code": "LIQUID_DAMAGE",
              "Description": "Water ingress signs present"
            }}
          ],
          "ClaimProcess": ["Submit form W-45", "Provide proof of purchase"]
        }},
        "ProductCategory": "Smartphone/HomeAppliance"
      }}
    - Validate PolicyNumber format
    - Sort by CoveragePeriod.DurationDays descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "Does installing third-party parts void my TV warranty?",
          "Answer": {{
            "PolicyNumber": "WR-2024-GLOBAL",
            "CoveragePeriod": {{
              "Start": "2024-03-01",
              "End": "2027-03-01",
              "DurationDays": 1096
            }},
            "Regions": ["GLOBAL"],
            "VoidConditions": [
              {{
                "Code": "UNAUTH_PARTS",
                "Description": "Non-Samsung display components detected"
              }}
            ],
            "ClaimProcess": ["Contact ASC", "Run diagnostic tool"]
          }},
          "ProductCategory": "TV"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse warranty policy"}


#Google AI STudio
def generate_warranty_qa_google(text):
    """Warranty/service pairs in JSON format, including regional policy variations."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate warranty Question and Answer pairs from the following Samsung support document text, covering:
    - Warranty coverage details (what is covered, duration)
    - Warranty claim processes (how to initiate a claim)
    - Conditions that void the warranty

    Crucially, include regional policy variations. Warranty policies often differ significantly by region.  Represent these regional differences clearly in the output. In the JSON output, structure regional variations under a "RegionalPolicyVariations" key, with regions (e.g., "USA", "Europe", "Asia") as keys and policy details as values.

    Use consumer-friendly language. Keep answers concise and provide accurate warranty information.

    Present the output as a list of warranty Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "CoverageDetails" (list of strings or null), "ClaimProcess" (string or null), "VoidConditions" (list of strings or null), and "RegionalPolicyVariations" (dictionary - see example format below, or null if no regional variations are mentioned in the Q&A pair).

    Text: {text}

    Output Format (example, regional variations as nested dictionary):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "CoverageDetails": [...],
        "ClaimProcess": "...",
        "VoidConditions": [...],
        "RegionalPolicyVariations": {{
          "Region 1 Name": {{ "Policy Detail 1": "Value 1", "Policy Detail 2": "Value 2" }},
          "Region 2 Name": {{ "Policy Detail 1": "Value 3", "Policy Detail 2": "Value 4" }},
          ...
        }}
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "CoverageDetails": null,
        "ClaimProcess": null,
        "VoidConditions": null,
        "RegionalPolicyVariations": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        warranty_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        warranty_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"WarrantyQAPairs": warranty_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_warranty_qa_sonnet(text):
    """Generate structured warranty and service Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create warranty Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Warranty and service inquiry"
        ],
        "Answers": [
          "Comprehensive warranty guidance"
        ],
        "Metadata": {{
          "WarrantyAreas": ["Coverage", "Claims", "Void Conditions"]
        }},
        "WarrantyDetails": {{
          "CoverageSpecifics": ["Detailed warranty terms"],
          "ClaimProcess": ["Step-by-step claim procedures"],
          "VoidConditions": ["Warranty invalidation scenarios"]
        }},
        "RegionalVariations": {{
          "PolicyDifferences": "Geographic policy variations"
        }}
      }}
    }}

    Requirements:
    - Detailed warranty information
    - Claim process insights
    - Regional policy differences
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_warranty_qa ---")
test_qa_generators("generate_warranty_qa", content)
# Out:
# --- generate_warranty_qa ---
#
# --- Calling generate_warranty_qa ---
# Okay, here's a comprehensive warranty Q&A based on the provided user manual, covering coverage details, claim processes, void conditions, and regional policy variations.
#
# **Samsung Refrigerator Warranty: Your Questions Answered**
#
# **General Questions**
#
# *   **Q: Where is my refrigerator covered under warranty?**
#
#     *   **A:** The included warranty applies to refrigerators purchased and used within the country specified in the warranty information. (e.g., U.S.A. or Canada).
# *   **Q: How do I get service for my refrigerator?**
#
#     *   **A:** For warranty service, contact Samsung at the provided address or phone number to troubleshoot your issue.  A Samsung-authorized service center must perform any repair.
# *   **Q: What is needed to claim warranty?**
#
#     *   **A:** When requesting warranty service, have your original dated bill of sale available as proof of purchase.
#
# **Coverage Details**
#
# *   **Q: What does the warranty cover?**
#
#     *   **A:** The warranty covers manufacturing defects in materials and workmanship under normal household, non-commercial use.
# *   **Q: What is the warranty period?**
#
#     *   **A (U.S.A):**
#         *   One (1) year parts and labor
#         *   Five (5) years parts and labor on Sealed Refrigeration System Only (Compressor, Evaporator, Condenser, Drier, and Connecting Tubing)
#         *   Ten (10) years part and Five (5) years labor on Digital Inverter Compressor Only.
#     *   **A (Canada):**
#         *   Labor: 1 year (in-home)
#         *   Parts: 1 year
#         *   Inverter Compressor: 10 years (Part only).
# *   **Q: Does the warranty include in-home service?**
#
#     *   **A (U.S.A):** Samsung will provide in-home service within the contiguous United States during the warranty period at no charge, subject to availability of Samsung authorized servicers within the customer’s geographic area. If in-home service is not available, SAMSUNG may elect, at its option, to provide transportation of the product to and from an authorized service center.
#     *   **A (Canada):** In-home service is not available in all areas. Contact us to find out if in-home service is currently available in your area by using the contact information at the back of this warranty.
#
# *   **Q: What is included in the Sealed Refrigeration System warranty?**
#
#     *   **A:** The sealed system includes the compressor, evaporator, condenser, drier, and connecting tubing. (Applies to U.S.A. warranty)
# *   **Q: Are replacement parts covered under warranty?**
#
#     *   **A:** Yes. Replacement parts and products are warranted for the remaining portion of the original product’s warranty or ninety (90) days, whichever is longer.
#
# **Claim Process**
#
# *   **Q: How do I initiate a warranty claim?**
#
#     *   **A:** 1. Contact Samsung at the provided customer service number or website. 2.  Describe the issue with your refrigerator. 3. Follow their instructions for troubleshooting and/or scheduling a service appointment. 4. Provide your proof of purchase (original dated bill of sale).
# *   **Q: Will Samsung come to my home to service the refrigerator?**
#
#     *   **A (U.S.A.):**  Samsung will provide in-home service within the contiguous United States during the warranty period at no charge, subject to availability of Samsung authorized servicers within the customer’s geographic area. If in-home service is not available, SAMSUNG may elect, at its option, to provide transportation of the product to and from an authorized service center.
#
#     *   **A (Canada):** In-home service is not available in all areas. Contact us to find out if in-home service is currently available in your area by using the contact information at the back of this warranty.
#
# *   **Q: What happens if in-home service isn't available?**
#
#     *   **A (U.S.A):** SAMSUNG may elect, at its option, to provide transportation of the product to and from an authorized service center.
#     *   **A (Canada):** For all carry-in models, transportation to and from the Authorized Service Center is the responsibility of the customer.
# *   **Q: What are my responsibilities for in-home service?**
#
#     *   **A:** To receive in-home service, your refrigerator must be unobstructed and accessible to the service agent.
#
# **Void Conditions**
#
# *   **Q: What circumstances void the warranty?**
#
#     *   **A:** The warranty does not cover the following:
#         *   Damage during shipment, delivery, or installation.
#         *   Use for which the product was not intended.
#         *   Unauthorized modification or alteration of the product.
#         *   Products with removed, defaced, or altered serial numbers.
#         *   Cosmetic damage (scratches, dents, etc.).
#         *   Damage caused by abuse, misuse, pest infestations, accident, fire, floods, or acts of nature.
#         *   Use of equipment, utilities, services, parts, supplies, accessories, applications, installations, repairs, external wiring or connectors not supplied or authorized by SAMSUNG.
#         *   Damage from incorrect electrical line current, voltage, fluctuations and surges.
#         *   Failure to operate and maintain the product according to instructions.
#         *   In-home instruction on product use.
#         *   Service to correct improper installation or household electrical/plumbing issues.
#         *   Commercial use
# *   **Q: Does the warranty cover adjustments I can make myself as described in the owner's manual?**
#
#     *   **A (Canada):** Customer adjustments which are explained in this owners manual are not covered under the terms of this warranty.
# *    **Q: Does the warranty cover third-party modification?**
#      *   **A:** The service of warranty of Samsung does not cover the changes or the modifications performed by a 3rd party.
# **Regional Policy Variations**
#
# *   **Q: What's the difference in the warranty between the U.S.A and Canada?**
#
#     *   **A:**
#         *   The US warranty includes a 5-year parts and labor warranty on the sealed refrigeration system and a 10-year parts and 5 year labor warranty on the digital inverter compressor. The Canadian warranty provides parts warranty only for the inverter compressor.
#
# **Disclaimer:**
#
# *   This Q&A is based solely on the provided user manual. Samsung reserves the right to change its warranty policies without notice. Always refer to the official warranty documentation included with your product or available on the Samsung website for the most up-to-date information.
# *   Consumers in Canada should contact Samsung customer care to confirm in-home service availability in their area.
# *   *It is important to always retain your sales receipt as proof of purchase when claiming warranty*.
# *   *Please consult your local Samsung service center for the most accurate warranty policies in your area.
#
# I hope this comprehensive Q&A is helpful!
#
#
# --- Calling generate_warranty_qa_deepseek ---
# {'Generations': [{'Question': 'What is the warranty coverage for the digital inverter compressor?', 'Answer': {'PolicyNumber': 'WR-2024-US', 'CoveragePeriod': {'Start': '2024-01-01', 'End': '2034-01-01', 'DurationDays': 3653}, 'Regions': ['US'], 'VoidConditions': [], 'ClaimProcess': ['Contact Samsung at 1-800-SAMSUNG', 'Present original dated bill of sale']}, 'ProductCategory': 'Refrigerator'}, {'Question': 'What part of the refrigerator has a 5 year warranty?', 'Answer': {'PolicyNumber': 'WR-2024-US', 'CoveragePeriod': {'Start': '2024-01-01', 'End': '2029-01-01', 'DurationDays': 1826}, 'Regions': ['US'], 'VoidConditions': [{'Code': 'UNAUTH_MOD', 'Description': 'Damage caused by unauthorized modification or alteration of the product'}], 'ClaimProcess': ['Contact Samsung at 1-800-SAMSUNG', 'Present original dated bill of sale']}, 'ProductCategory': 'Refrigerator'}, {'Question': 'Does the warranty cover damage caused by power surges?', 'Answer': {'PolicyNumber': 'WR-2024-US', 'CoveragePeriod': {'Start': '2024-01-01', 'End': '2025-01-01', 'DurationDays': 366}, 'Regions': ['US'], 'VoidConditions': [{'Code': 'ELEC_ISSUES', 'Description': 'Damage caused by incorrect electrical line current, voltage, fluctuations and surges'}], 'ClaimProcess': ['Contact Samsung at 1-800-SAMSUNG', 'Present original dated bill of sale']}, 'ProductCategory': 'Refrigerator'}, {'Question': 'What does the warranty cover in Canada?', 'Answer': {'PolicyNumber': 'WR-2024-CA', 'CoveragePeriod': {'Start': '2024-01-01', 'End': '2025-01-01', 'DurationDays': 366}, 'Regions': ['CA'], 'VoidConditions': [{'Code': 'SERIAL_ALTERED', 'Description': 'Unit found with a missing or altered serial number'}, {'Code': 'SHIPPING_DAMAGE', 'Description': 'Damage that occurs during shipping'}], 'ClaimProcess': ['Call Samsung Authorized Service Center', 'Present original dated sales receipt']}, 'ProductCategory': 'Refrigerator'}, {'Question': 'Does the warranty cover damage due to floods?', 'Answer': {'PolicyNumber': 'WR-2024-CA', 'CoveragePeriod': {'Start': '2024-01-01', 'End': '2025-01-01', 'DurationDays': 366}, 'Regions': ['CA'], 'VoidConditions': [{'Code': 'ACT_OF_GOD', 'Description': 'Damage due to accident, fire, flood, and/or other Acts of God'}, {'Code': 'UNAUTH_REPAIR', 'Description': 'Improper or unauthorized repairs'}], 'ClaimProcess': ['Call Samsung Authorized Service Center', 'Present original dated sales receipt']}, 'ProductCategory': 'Refrigerator'}]}
#
# --- Calling generate_warranty_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "WarrantyQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_warranty_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "WarrantyFAQ": {\n    "Generations": {\n      "Questions": [\n        "What does the warranty cover?",\n        "What is the warranty period for the refrigerator?",\n        "How do I make a warranty claim?",\n        "What are some exclusions to the warranty?",\n        "Is in-home service available?",\n        "Are there different warranty terms in the US and Canada?"\n      ],\n      "Answers": [\n        "The warranty covers manufacturing defects in materials or workmanship encountered in normal household, noncommercial use. Damage during shipment, installation issues and damage caused by misuse are not covered.",\n        "There is a one (1) year warranty for parts and labor, five (5) years parts and labor on the Sealed Refrigeration System, and ten (10) years for the Digital Inverter Compressor.",\n        "To make a claim, contact Samsung at 1-800-SAMSUNG for problem determination and service procedures.  Provide the original dated bill of sale as proof of purchase to receive warranty service.",\n        "The warranty does not cover damage during shipment, unauthorized modification, cosmetic damage, damage from misuse, or damage from incorrect electrical supply.",\n        "Samsung provides in-home service within the contiguous United States during the warranty period, subject to availability of authorized servicers.  If in-home service is unavailable, Samsung may transport the product to and from an authorized service center.",\n        "Yes, the US warranty includes parts and labor, while the Canadian warranty has a different structure, particularly regarding Inverter Compressor coverage."\n      ],\n      "Metadata": {\n        "WarrantyAreas": ["Coverage", "Claims", "Void Conditions", "Service Options", "Regional Differences"],\n        "ProductType": "Refrigerator",\n        "Brand": "Samsung"\n      },\n      "WarrantyDetails": {\n        "CoverageSpecifics": ["Manufacturing defects, sealed refrigeration system components, digital inverter compressor"],\n        "ClaimProcess": ["Contact Samsung support, provide proof of purchase, authorized service center repair"],\n        "VoidConditions": ["Unauthorized modifications, misuse, incorrect installation, altered serial numbers"],\n        "ServiceOptions": ["In-home service, authorized service center repair, transportation options"],\n        "RegionalDifferences": ["Specifics for US and Canadian warranties differ in coverage details"]\n      },\n      "RegionalVariations": {\n        "PolicyDifferences": "Warranty terms can differ between U.S.A. and Canada, with specific exclusions and coverage periods.",\n        "ContactInformationUS": "Samsung Electronics America, Inc., 85 Challenger Road, Ridgefield Park, NJ 07660, 1-800-SAMSUNG (726-7864), www.samsung.com/us/support",\n        "ContactInformationCA": "Samsung Electronics Canada Inc., 2050 Derry Road West Mississauga, Ontario L5N 0B9, Canada, 1-800-SAMSUNG (726-7864), www.samsung.com/ca/support (English), www.samsung.com/ca_fr/support (French)"\n      }\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 13 generate_update_qa

# %%
#original
def generate_update_qa(text):
    """Software update pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create update-related Q&A including:
    - Version histories - Rollback methods - Security patches
    Add update compatibility matrices.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_update_qa_deepseek(text):
    """Generates update guides with version validation and security metadata.

    Returns:
        JSON with semantic versioning, CVE tracking, and rollback metrics.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create software update Q&A pairs with:
    1. Semantic versioning (major.minor.patch)
    2. CVE numbers for security patches
    3. Rollback success rates (%) and prerequisites
    4. Model-specific compatibility using SM-XXXX codes

    Format requirements:
    - JSON with "Generations" containing:
      {{
        "Question": "[Update inquiry]",
        "Answer": {{
          "CurrentVersion": "6.1.1",
          "TargetVersion": "7.0.0",
          "SecurityPatches": [
            {{
              "CVE": "CVE-2024-1234",
              "Severity": "Critical",
              "PatchDate": "2024-03-15"
            }}
          ],
          "Compatibility": {{
            "DeviceModel": "SM-S901B",
            "MinOSVersion": "5.0.0"
          }},
          "Rollback": {{
            "Possible": true,
            "SuccessRate": 92,
            "Steps": ["Enter recovery", "Select rollback image"]
          }},
          "UpdateSize": "1.4GB"
        }},
        "ReleaseChannel": "Stable/Beta"
      }}
    - Validate versions as X.Y.Z numbers
    - Sort by TargetVersion descending

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to revert from One UI 6.1 to 6.0?",
          "Answer": {{
            "CurrentVersion": "6.1.0",
            "TargetVersion": "6.0.1",
            "SecurityPatches": [],
            "Compatibility": {{
              "DeviceModel": "SM-S918B",
              "MinOSVersion": "5.1.2"
            }},
            "Rollback": {{
              "Possible": true,
              "SuccessRate": 85,
              "Steps": ["Backup data", "Download rollback package"]
            }},
            "UpdateSize": "2.1GB"
          }},
          "ReleaseChannel": "Stable"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse update protocol"}


#Google AI STudio
def generate_update_qa_google(text):
    """Software update pairs in JSON format, including compatibility matrices."""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung software updates from the following support document text, including:
    - Version histories and key changes in each version
    - Methods to rollback or revert to previous versions
    - Security patches included in updates

    Present update compatibility information as compatibility matrices whenever possible to clearly show which devices are compatible with which updates. In the JSON output, represent matrices as a list of dictionaries, where each dictionary is a row.

    Use consumer-friendly language. Keep answers concise and provide accurate update information.

    Present the output as a list of update Q&A pairs in JSON format. Each pair should be a dictionary with keys: "Question", "Answer", "VersionHistories" (list of strings or null), "RollbackMethods" (list of strings or null), "SecurityPatches" (list of strings or null), and "UpdateCompatibilityMatrix" (list of row dictionaries - see example format below, or null if no matrix is applicable).

    Text: {text}

    Output Format (example, matrices as list of dictionaries):
    [
      {{
        "Question": "...",
        "Answer": "...",
        "VersionHistories": [...],
        "RollbackMethods": [...],
        "SecurityPatches": [...],
        "UpdateCompatibilityMatrix": [
          {{ "Column 1 Header": "Value 1", "Column 2 Header": "Value 2" }},
          {{ "Column 1 Header": "Value 3", "Column 2 Header": "Value 4" }},
          ...
        ]
      }},
      {{
        "Question": "...",
        "Answer": "...",
        "VersionHistories": null,
        "RollbackMethods": null,
        "SecurityPatches": null,
        "UpdateCompatibilityMatrix": null
      }},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        update_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        update_data = [] # Implement robust fallback parsing

    output_json = {
        "Generations": [
            {"UpdateQAPairs": update_data} # Assuming model outputs list of dictionaries
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_update_qa_sonnet(text):
    """Generate structured software update Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create update Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Software update inquiry"
        ],
        "Answers": [
          "Comprehensive update guidance"
        ],
        "Metadata": {{
          "UpdateTypes": ["Version History", "Rollback", "Security Patches"]
        }},
        "UpdateDetails": {{
          "VersionHistory": ["Detailed update progression"],
          "RollbackMethods": ["Reversal procedures"],
          "SecurityPatches": ["Critical security updates"]
        }},
        "CompatibilityMatrix": {{
          "DeviceModelSupport": "Update compatibility information"
        }}
      }}
    }}

    Requirements:
    - Update version details
    - Rollback process
    - Security update insights
    - 1-2 sentence answers

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_update_qa ---")
test_qa_generators("generate_update_qa", content)
# Out:
# --- generate_update_qa ---
#
# --- Calling generate_update_qa ---
# Okay, here are some Q&A and update compatibility matrices based on the provided user manual content:
#
# **Q&A: Software Updates and Security**
#
# *   **Q: Does this refrigerator receive software updates?**
#     *   A: While not explicitly stated, the presence of SmartThings integration and Smart Grid functionality strongly suggests that the refrigerator can receive software updates. The user manual references to "app update policy" and  the ability to control the refrigerator through the SmartThings app indicate software functionality that may be subject to updates.
#
# *   **Q: How do I update the refrigerator's software?**
#     *   A: The user manual doesn't detail the update process. It likely occurs automatically through the SmartThings app or a built-in over-the-air (OTA) update mechanism. Check the SmartThings app for update settings or contact Samsung customer support for instructions.
#
# *   **Q: Will I get security patches for this refrigerator?**
#     *   A: Because the refrigerator has SmartThings and Smart Grid functionality, it may receive security patches as part of software updates. Check the SmartThings app or contact Samsung customer support for specific information about security updates for your model.
#
# *   **Q: Where can I find the version history for this refrigerator's software?**
#     *   A: The user manual doesn't include version history information. Check the SmartThings app for version details or contact Samsung customer support.
#
# *   **Q: Is it possible to roll back to a previous software version if I experience problems after an update?**
#     *   A: The manual does not provide rollback information. Rolling back software may not be possible, or may require assistance from a qualified service technician. It is best to contact Samsung customer service.
#
# **Update Compatibility Matrices:**
#
# Because the user manual lacks specific detail on software versions and compatibilities, I'll create hypothetical matrices based on common update scenarios and the functionality described in the manual.  These are *examples* only. You'll need to check with Samsung Support to get real compatibility information.
#
# **Matrix 1: SmartThings App Compatibility**
#
# | Refrigerator Model  | Minimum SmartThings App Version |  Features Supported                               |  Notes                                                                                      |
# | -------------------- | ------------------------------ | ----------------------------------------------- | -------------------------------------------------------------------------------------------- |
# | RF23BB8*****         | 1.7.50                          | Remote Temperature Control, Energy Monitoring, Smart Grid Control, Alarm Notifications | Requires Wi-Fi connection.                                                                |
# | RF29BB8*****         | 1.7.50                          | Remote Temperature Control, Energy Monitoring, Smart Grid Control, Alarm Notifications | Requires Wi-Fi connection.                                                                |
#
# **Matrix 2: Smart Grid Compatibility (Example - Consult Your Utility Company)**
#
# | Refrigerator Model | Smart Energy Profile (SEP) Version |  Utility Company Support Required? | Peak Demand Off Override Available? |
# | ------------------ | --------------------------------- | ----------------------------------- | ------------------------------------ |
# | RF23BB8*****        | 2.0                               | Yes                                  | Yes                                   |
# | RF29BB8*****        | 2.0                               | Yes                                  | Yes                                   |
#
# **Matrix 3: Feature Support by Software Update**
# _(This is extremely hypothetical based on common device update behaviors.)_
#
# | Feature                     | Initial Software Version | Version Added/Improved | Notes                                                                                                                                                                           |
# | --------------------------- | ------------------------- | --------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------ |
# | AutoFill Pitcher Algorithm | 1.0                      | 1.1                   | Improved fill accuracy and leak detection. Also, improved the ability of the AutoFill Pitcher to shut off after an internal leak was detected.        |
# | SmartThings Connectivity  | 1.0                      | N/A                  | Initial Release                                                                                                                                                              |
# | Smart Grid Support         | 1.0                      | N/A                   | Initial Release                                                                                                                                                              |
#
# **Important Considerations:**
#
# *   **Contact Samsung:**  The provided user manual lacks detailed technical specifications and update information.  The *most important* step is to contact Samsung customer support directly for specifics related to your refrigerator model. Use the contact information in the manual.
# *   **SmartThings App:** Pay close attention to the SmartThings app for update notifications and compatibility information.
# *   **Utility Company:** If you plan to use the Smart Grid features, confirm compatibility with your specific utility company and their EMS.
# *   **Model Number:**  Provide your full refrigerator model number (e.g., RF23BB8*AAAA*) when contacting Samsung.
# *   **User safety:** For your safety, it is important to understand that unauthorized modifications can cause safety problems. To reverse an unauthorized modification, Samsung will charge the full cost of parts and labor.
# *   **Warranty considerations:** Any changes or modifications performed by a 3rd party on this finished appliance are not covered under Samsung warranty service, nor is Samsung responsible for safety issues that result from 3rd party modifications.
#
# By asking Samsung directly, you'll gain the most accurate and up-to-date information about software updates, security patches, compatibility, and rollback options for your specific refrigerator.
#
#
# --- Calling generate_update_qa_deepseek ---
# {'Generations': [{'Question': 'Will this update fix the buzzing sound I hear from the ice maker?', 'Answer': {'CurrentVersion': '6.0.2', 'TargetVersion': '7.0.1', 'SecurityPatches': [{'CVE': 'CVE-2024-5678', 'Severity': 'Moderate', 'PatchDate': '2024-04-20'}], 'Compatibility': {'DeviceModel': 'SM-T970', 'MinOSVersion': '6.0.0'}, 'Rollback': {'Possible': True, 'SuccessRate': 95, 'Steps': ['Backup personal data', 'Reboot into recovery mode', "Select 'Apply update from SD card'"]}, 'UpdateSize': '250MB'}, 'ReleaseChannel': 'Stable'}, {'Question': "What's new with the SmartThings integration?", 'Answer': {'CurrentVersion': '6.0.0', 'TargetVersion': '7.0.0', 'SecurityPatches': [{'CVE': 'CVE-2024-4321', 'Severity': 'High', 'PatchDate': '2024-04-10'}], 'Compatibility': {'DeviceModel': 'SM-F721U', 'MinOSVersion': '5.0.0'}, 'Rollback': {'Possible': False, 'SuccessRate': 0, 'Steps': ['Factory reset will revert to previous version']}, 'UpdateSize': '1.2GB'}, 'ReleaseChannel': 'Beta'}, {'Question': 'Are there any improvements to Shabbath mode?', 'Answer': {'CurrentVersion': '6.1.0', 'TargetVersion': '6.2.0', 'SecurityPatches': [], 'Compatibility': {'DeviceModel': 'SM-G991U', 'MinOSVersion': '5.0.0'}, 'Rollback': {'Possible': True, 'SuccessRate': 98, 'Steps': ['Backup device settings', 'Flash older firmware via Smart Switch']}, 'UpdateSize': '15MB'}, 'ReleaseChannel': 'Stable'}, {'Question': 'Is there a fix for the dispenser leaking issues?', 'Answer': {'CurrentVersion': '6.0.0', 'TargetVersion': '6.1.1', 'SecurityPatches': [], 'Compatibility': {'DeviceModel': 'SM-A525F', 'MinOSVersion': '4.0.0'}, 'Rollback': {'Possible': True, 'SuccessRate': 90, 'Steps': ['Download previous version', 'Initiate manual update from settings']}, 'UpdateSize': '150MB'}, 'ReleaseChannel': 'Stable'}, {'Question': 'Does the latest patch address the recent vulnerability?', 'Answer': {'CurrentVersion': '6.1.0', 'TargetVersion': '6.1.0', 'SecurityPatches': [{'CVE': 'CVE-2024-0001', 'Severity': 'Critical', 'PatchDate': '2024-05-03'}], 'Compatibility': {'DeviceModel': 'SM-S901U', 'MinOSVersion': '5.0.0'}, 'Rollback': {'Possible': False, 'SuccessRate': 0, 'Steps': ['Security patch cannot be rolled back']}, 'UpdateSize': '50MB'}, 'ReleaseChannel': 'Stable'}]}
#
# --- Calling generate_update_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "UpdateQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_update_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I find information on the latest update version for my Samsung refrigerator?",\n      "What is the rollback process for my Samsung refrigerator if an update causes issues?",\n      "Where can I find details about security updates for my Samsung refrigerator?",\n      "How do I check the version history for recent updates to my refrigerator?"\n    ],\n    "Answers": [\n      "This user manual does not explicitly provide version details; visit Samsung\'s website (www.samsung.com) or contact their support for specific software version information.",\n      "This user manual does not provide rollback instructions; contact Samsung support for specific procedures, as rollback processes can vary.",\n      "This user manual doesn\'t contain a section for security updates; check the Samsung website (www.samsung.com) or contact their support.",\n      "This user manual does not contain version history; refer to Samsung\'s official website or contact their support for specific information on update progression."\n    ],\n    "Metadata": {\n      "UpdateTypes": [\n        "Version History",\n        "Rollback",\n        "Security Patches"\n      ]\n    },\n    "UpdateDetails": {\n      "VersionHistory": [],\n      "RollbackMethods": [],\n      "SecurityPatches": []\n    },\n    "CompatibilityMatrix": {\n      "DeviceModelSupport": "Visit samsung.com/us/support for device-specific compatibility information."\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 14 generate_preventive_qa

# %%
#original
def generate_preventive_qa(text):
    """Failure prevention pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care Q&A with:
    - Best practices - Early warning signs - Monitoring tips
    Format as do's/don'ts lists.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_preventive_qa_deepseek(text):
    """Generates preventive Q&A with risk prioritization in JSON format.

    Returns:
        JSON with nested maintenance categories, severity levels, and action lists.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate failure prevention Q&A from this text with:
    1. Do’s/don’ts for device longevity
    2. Early hardware/software warning signs
    3. Monitoring frequency guidelines

    Format requirements:
    - Return JSON with "Generations" containing:
      {{
        "Question": "...",
        "Answer": {{
          "Do": ["list", "items"],
          "Dont": ["list", "items"]
        }},
        "Category": "Battery/Screen/Software",
        "SeverityLevel": "High/Medium/Low",
        "MonitoringFrequency": "Daily/Weekly/Monthly"
      }}
    - Prioritize entries by SeverityLevel (High first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to prevent battery swelling in Galaxy phones?",
          "Answer": {{
            "Do": ["Use 25W official charger", "Store at 15°-25°C"],
            "Dont": ["Charge overnight", "Use while gaming >1hr"]
          }},
          "Category": "Battery",
          "SeverityLevel": "High",
          "MonitoringFrequency": "Weekly"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse preventive maintenance data"}


#Google AI STudio
def generate_preventive_qa_google(text):
    """Failure prevention pairs in JSON format, accommodating do's/don'ts lists"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care information from the following Samsung support document text.
    Focus on:
    - Best practices for device maintenance and longevity
    - Early warning signs of potential issues
    - Monitoring tips to proactively identify problems

    Format preventive advice primarily as do's and don'ts lists where suitable for clear, actionable guidance. For other information, use Question and Answer pairs.
    Use consumer-friendly language and keep answers concise (1-2 sentences for Q&A, short phrases for do's/don'ts).

    Present the output in JSON format. Structure it to include topics, and for each topic, indicate if it's presented as "DosAndDonts" or "Q&A", and provide the corresponding lists or Q&A pairs.

    Text: {text}

    Output Format (example - model should generate similar structure):
    [
      {{
        "Topic": "Topic Name",
        "Format": "DosAndDonts",
        "Dos": ["Do this...", "Do that..."],
        "Donts": ["Don't do this...", "Don't do that..."]
      }},
      {{
        "Topic": "Another Topic",
        "Format": "Q&A",
        "Questions": ["Question 1...", "Question 2..."],
        "Answers": ["Answer 1...", "Answer 2..."]
      }}
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        preventive_care_data = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        preventive_care_data = [] # Implement a robust fallback text parsing if needed

    output_json = {
        "Generations": [
            {"PreventiveCareQAPairs": preventive_care_data} # Assuming the model directly outputs the list as in "Output Format"
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_preventive_qa_sonnet(text):
    """Generate structured preventive care Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate preventive care Q&A in JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Best practice identification question",
          "Early warning signs inquiry",
          "Monitoring technique question"
        ],
        "Answers": [
          "Comprehensive best practices explanation",
          "Detailed early warning signs description",
          "Effective monitoring techniques guidance"
        ],
        "Metadata": {{
          "PreventionCategories": ["Best Practices", "Warning Signs", "Monitoring"],
          "ApproachType": "Proactive Care"
        }},
        "DosDonts": {{
          "Dos": ["Recommended actions", "Preventive measures"],
          "Donts": ["Actions to avoid", "Potential risk behaviors"]
        }}
      }}
    }}

    Key Requirements:
    - Provide clear, actionable preventive guidance
    - Include specific, measurable recommendations
    - 1-2 sentence answers
    - Balance technical accuracy with user comprehension

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_preventive_qa ---")
test_qa_generators("generate_preventive_qa", content)
# Out:
# --- generate_preventive_qa ---
#
# --- Calling generate_preventive_qa ---
# Okay, here are some preventive care Q&A in a Do's and Don'ts format, based on the provided Samsung Refrigerator user manual.  I've focused on areas relevant to long-term maintenance and preventing problems.
#
# **Preventive Care Q&A for Your Samsung Refrigerator**
#
# **I. Location and Installation:**
#
# *Q: What are the best practices for choosing a location for my refrigerator?*
#
# **Do's:**
# *   **Do** Choose a location with a solid, level surface.
# *   **Do** Select a spot away from direct sunlight and heat sources (oven, stove, radiator).
# *   **Do** Ensure there's adequate space around the refrigerator for proper ventilation and door opening (refer to manual's clearance specifications).
# *   **Do** Ensure the location is within the specified temperature range (50°F (10°C) - 110°F (43°C)).
#
# **Don'ts:**
#
# *   **Don't** Install in a damp or wet location.
# *   **Don't** Place on carpeting or flooring that might obstruct ventilation.
# *   **Don't** Locate near flammable materials.
# *   **Don't** Overlook the importance of correct levelling.
#
# *Q:  Are there any early warning signs during installation that indicate a potential problem?*
#
# *   **Do** Pay attention to whether the refrigerator levels correctly. Difficulty leveling could suggest an uneven floor, which over time may strain the refrigerator and cause leaks.
# *   **Do** Make sure the power cord isn’t crushed or damaged after moving the refrigerator. This can be a fire hazard and will lead to problems sooner than later.
#
# *Q: What monitoring can I do right after installation?*
#
# *   **Do** After plugging in, check that the interior light works.
# *   **Do** Set the temperature to the coldest setting initially and ensure the freezer starts chilling and the motor runs smoothly.
# *   **Do** Check to ensure the doors open and close freely and the interior lights turn on when you open the door.
# *   **Do** Check if there is a reasonable clearance from walls and cabinets.
# *   **Do** Check to ensure that the refrigerator is level and sitting firmly on the floor.
#
# **II. Power and Electrical Safety**
#
# *Q: What are some best practices related to electrical safety?*
#
# **Do's:**
#
# *   **Do** Plug the refrigerator into its own dedicated electrical outlet.
# *   **Do** Ensure the outlet's voltage matches the refrigerator's rating plate.
# *   **Do** Ground the refrigerator properly.
# *   **Do** Use a 3-wire extension cord with a 3-blade grounding plug if an extension cord is necessary.
#
# **Don'ts:**
#
# *   **Don't** Use a power cord that is cracked or damaged.
# *   **Don't** Overload a multiple outlet with the refrigerator and other appliances.
# *   **Don't** Plug in the refrigerator with wet hands.
# *   **Don't** Bend the power cord excessively or place heavy objects on it.
# *   **Don't** Use damaged wall socket.
#
# *Q: What are some early warning signs of electrical issues?*
#
# *   **Do** Monitor for a loose wall socket.  A loose connection can create heat and is a fire risk.
# *   **Do** Pay attention to any burning smells emanating from the refrigerator. This is a sign of dangerous shorting and must be investigated immediately.
#
# *Q: How can I monitor the refrigerator's electrical system?*
#
# *   **Do** Use a dry cloth to remove any dust or water from the power plug terminals regularly.
# *   **Do** Monitor for unusual hissing, popping, or clicking sounds from the back of the refrigerator, as these could indicate electrical arcing. If these exist, turn it OFF and get qualified service.
#
# **III. Cleaning and Maintenance**
#
# *Q: What are the best practices for cleaning my refrigerator?*
#
# **Do's:**
#
# *   **Do** Unplug the refrigerator before cleaning.
# *   **Do** Use a soft, lint-free cloth or paper towel moistened with a mild detergent and warm water.
# *   **Do** Dry the interior and exterior well after cleaning.
# *   **Do** Regularly clean the dispenser nozzle (if applicable).
# *   **Do** Clean dust from the back panel a couple of times a year
#
# **Don'ts:**
#
# *   **Don't** Spray water directly onto the refrigerator (interior or exterior).
# *   **Don't** Use harsh or abrasive cleaners (benzene, thinner, bleach, etc.).
# *   **Don't** Clean with warm water when the glass shelves are cold.
#
# *Q:  What cleaning or maintenance issues can lead to big problems if ignored?*
#
# *   **Do** Check Door seals. Make sure they are clean and in good condition. Deteriorated seals lead to inefficiency and food spoilage.
# *   **Do** Clean the interior of the water pitcher if equipped.
# *   **Do** After you consume the infused water, clean the water pitcher.
# *   **Do** Check inside for foods blocking the vents as this can lead to frosting issues.
#
# *Q: What should I regularly monitor?*
# *   **Do** Make sure no foods are blocking the vents to prevent frost.
# *   **Do** Monitor ice dispenses to ensure it is working properly.
# *   **Do** Check water flow to ensure it is normal.
# *   **Do** Monitor and replace water filter every 6 months.
#
# **IV. Water Filter (if applicable)**
#
# *Q: How do I best maintain the water filter system?*
#
# **Do's:**
#
# *   **Do** Replace the water filter every 6 months.
# *   **Do** Flush 3 gallons of water through the filter after replacing it.
# *   **Do** Use only Samsung-provided or approved filters.
#
# **Don'ts:**
#
# *   **Don't** Use third-party water filters.
# *   **Don't** Mount the water filter on any part of the refrigerator.
#
# *Q: What are the early warning signs of a failing water filter?*
#
# *   **Do** Be mindful of the "Replace Water Filter" indicator light.
# *   **Do** Watch for weaker than normal water flow from the dispenser.
#
# *Q: What should I regularly monitor?*
#
# *   **Do** Check water tastes abnormal.
# *   **Do** Check water is not dispensing properly.
# *   **Do** Check if the refrigerator is in the process of making ice.
#
# **V. Ice Maker (if applicable)**
#
# *Q: What maintenance practices are important for the ice maker?*
#
# **Do's:**
#
# *   **Do** Empty the ice bucket periodically, especially if you don't use ice often.
# *   **Do** Keep the scoop inside the scoop tray.
# *   **Do** Follow instructions for first-time use to remove impurities.
#
# **Don'ts:**
#
# *   **Don't** Put food in the ice bucket.
# *   **Don't** Put fingers or objects into the ice maker.
# *   **Don't** Re-use old hoses when connecting the water line.
#
# *Q: What are the early warning signs of ice maker issues?*
#
# *   **Do** Listen for a buzzing sound, which can indicate the ice maker is on but not properly connected to the water supply.
#
# *Q: How can I monitor the ice maker's performance?*
#
# *   **Do** Press the "Test" button on the bottom of the ice maker to confirm it's operating properly. If ice does not dispense, first check status of ice maker using Test button on the bottom of the ice maker.
# *   **Do** Listen to ice making chime if it rings repeatedly contact the waterline installer or a local Samsung service center.
# *   **Do** Inspect ice bucket for ice accumulation.
#
# **VI. SmartThings Connectivity (if applicable)**
#
# *Q: What should I do to maintain a stable SmartThings connection?*
#
# **Do's:**
#
# *   **Do** Ensure your home router is operating normally.
# *   **Do** Connect your smartphone to the same router as the refrigerator for troubleshooting.
# *   **Do** Power cycle (turn off and on) the refrigerator if the SmartThings app is not running.
#
# **Don'ts:**
#
# *   **Don't** Use unauthorized Wi-Fi routers.
#
# *Q: What are the warning signs of SmartThings connectivity problems?*
#
# *   **Do** The Wi-Fi icon blinking means it is not connected.
#
# *Q: What can I do monitor about the smart things connection*
#
# *   **Do** Make connection again before using the refrigerator.
#
# **VII. General Operation**
#
# *Q: Any other key "do's" and "don'ts" to prolong the life of my refrigerator?*
#
# **Do's:**
#
# *   **Do** Wrap food properly or place it in airtight containers.
# *   **Do** Wipe up spills immediately.
# *   **Do** Keep the refrigerator reasonably full (a full refrigerator maintains temperature more efficiently).
# *   **Do** Be careful when closing the door to avoid the pinch point area.
# *   **Do** Ensure door bins are fitted well.
# *   **Do** Check all shelves, drawers and baskets are in original positions.
#
# **Don'ts:**
#
# *   **Don't** Overfill the refrigerator.
# *   **Don't** Store volatile or flammable substances in the refrigerator.
# *   **Don't** Re-freeze thawed foods.
# *   **Don't** Attempt to repair, disassemble or modify the refrigerator yourself.
#
# This list should provide a comprehensive foundation for preventative refrigerator maintenance. Remember to consult the full user manual for detailed instructions and model-specific information.
#
#
# --- Calling generate_preventive_qa_deepseek ---
# {'Generations': [{'Question': 'What can happen if large amounts of dust or water enter the refrigerator?', 'Answer': {'Do': ['Disconnect the power plug', 'Contact a Samsung Electronics service center'], 'Dont': []}, 'Category': 'Electrical', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Monthly'}, {'Question': 'How to prevent fire and explosion hazards?', 'Answer': {'Do': ['Keep flammable materials away', 'Ensure proper ventilation when gas leak occurs'], 'Dont': ['Store aerosol cans or explosive substances in the refrigerator']}, 'Category': 'Fire Safety', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Monthly'}, {'Question': 'What to do if the refrigerator emits a burning smell or smoke?', 'Answer': {'Do': ['Unplug the refrigerator immediately', 'Contact a Samsung service center'], 'Dont': []}, 'Category': 'Fire Safety', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'How to prevent electric shock?', 'Answer': {'Do': ['Grip the plug firmly and pull straight out from the outlet', 'Use a clean, dry cloth to clean the power plug blades', 'Make sure the refrigerator is safely grounded'], 'Dont': ['Touch the inside walls of the freezer or products stored in the freezer with wet hands', 'Insert the power plug into a wall socket with wet hands', 'Spray water directly on the inside or outside of the refrigerator', 'Attempt to replace a lamp yourself', 'Use a damaged power plug, damaged power cord, or loose wall socket']}, 'Category': 'Electrical', 'SeverityLevel': 'High', 'MonitoringFrequency': 'Daily'}, {'Question': 'How to prevent refrigerator from falling and causing injury?', 'Answer': {'Do': ['Ensure leveling on a flat, solid floor', 'Avoid overloading one door with food'], 'Dont': []}, 'Category': 'Physical Safety', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'Monthly'}, {'Question': 'What to do if the refrigerator is flooded?', 'Answer': {'Do': ['Shut off the power to the refrigerator', 'Contact your nearest Samsung service center'], 'Dont': []}, 'Category': 'Electrical', 'SeverityLevel': 'Medium', 'MonitoringFrequency': 'As needed'}, {'Question': "What to check if the ice maker doesn't make ice?", 'Answer': {'Do': ['Turn on the ice maker', 'Set the freezer temperature below 0 °F (-18 °C) or -4 °F (-20 °C) in warm ambient air', 'Make sure water pressure is between 30- 125 psi (206-861 kPa)'], 'Dont': []}, 'Category': 'Ice Maker', 'SeverityLevel': 'Low', 'MonitoringFrequency': 'As needed'}, {'Question': 'How often should I clean the water filter?', 'Answer': {'Do': ['Replace the filter about every 6 months or approximately 300 gallons (1200 L) of water', 'Check the water filter if water is not dispensing properly'], 'Dont': ['Use third-party water filters']}, 'Category': 'Water Filter', 'SeverityLevel': 'Low', 'MonitoringFrequency': 'Monthly'}]}
#
# --- Calling generate_preventive_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "PreventiveCareQAPairs": []
#     }
#   ]
# }
#
# --- Calling generate_preventive_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How often should I clean my refrigerator to prevent the buildup of odors and maintain optimal performance?",\n      "What are some signs that my refrigerator\'s water filter needs replacing, even before the indicator light comes on?",\n      "What are some techniques to ensure proper airflow within the refrigerator to prevent food spoilage?"\n    ],\n    "Answers": [\n      "Clean your refrigerator every 3-6 months with a solution of mild detergent and warm water, paying special attention to spills and food debris to prevent odors and bacterial growth.",\n      "Reduced water flow from the dispenser, cloudy water, or an off-taste can indicate your water filter needs replacement before the indicator light activates.",\n      "Avoid overcrowding shelves, ensure vents are clear from obstructions, and properly wrap or contain foods to promote proper airflow, which prevents spoilage and maintains even temperatures."\n    ],\n    "Metadata": {\n      "PreventionCategories": ["Hygiene", "Maintenance", "Food Storage"],\n      "ApproachType": "Proactive Care"\n    },\n    "DosDonts": {\n      "Dos": [\n        "Regularly clean interior and exterior surfaces with a mild detergent and water.",\n        "Inspect and replace water filters every 6 months or as needed based on water quality."\n      ],\n      "Donts": [\n        "Use harsh chemicals or abrasive cleaners that can damage the refrigerator\'s surfaces.",\n        "Block air vents with food items, hindering airflow and potentially causing over-cooling or spoilage."\n      ]\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 15 generate_accessory_qa

# %%
#original
def generate_structured_accessory_qa(text):
    """Accessory integration pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Create accessory Q&A covering:
    - Pairing steps - Compatibility checks - Optimal usage
    Include specific model numbers and SKUs.
    Text: {text}
    """)
    return model.generate_content(prompt).text


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_accessory_qa_deepseek(text):
    """Generates accessory Q&A with technical specs in standardized format.

    Returns:
        JSON with nested device models, SKUs, and setup complexity levels.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate accessory integration Q&A from this text with:
    1. Pairing instructions (Bluetooth/USB-C/Wireless Dock)
    2. Compatibility matrices (Galaxy model-to-accessory matching)
    3. Usage best practices (charging limits, cleaning methods)

    Format requirements:
    - Use JSON with "Generations" containing list of:
      {{
        "Question": "...",
        "Answer": "...",
        "DeviceModel": "Galaxy S24 Ultra",
        "SKU": "EJ-TG980BBEGUS",
        "ConnectionType": "Wireless Charging",
        "Complexity": "Medium"
      }}
    - Order by setup complexity (Simple -> Complex)
    - Validate SKUs match Samsung's 10-char alphanumeric format

    Example:
    {{
      "Generations": [
        {{
          "Question": "How to pair Galaxy Buds2 Pro with S23 FE?",
          "Answer": "Open case > tap phone notification > follow in-app steps",
          "DeviceModel": "SM-S711B",
          "SKU": "EI-R510NBEGUS",
          "ConnectionType": "Bluetooth 5.3",
          "Complexity": "Simple"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse accessory integration data"}


#Google AI STudio
def generate_structured_accessory_qa_google(text):
    """Accessory integration pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate Question and Answer pairs about Samsung accessory integration from the following support document text.
    Focus on:
    - Pairing steps for accessories
    - Compatibility checks between devices and accessories
    - Optimal usage tips and features for accessories

    Whenever relevant, include specific Samsung model numbers and/or SKUs for devices and accessories mentioned.
    Format each question and answer pair clearly. Use consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries in JSON format. Each dictionary should have the keys "Question", "Answer", "Model/SKU". If no specific model or SKU is relevant to a Q&A pair, the "Model/SKU" key can be null or omitted.

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "...", "Model/SKU": "ModelXYZ"}},
      {{"Question": "...", "Answer": "...", "Model/SKU": null}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        qa_list = [] # Implement a robust fallback text parsing as needed

    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair.get("Question") for qa_pair in qa_list],
                "Answers": [qa_pair.get("Answer") for qa_pair in qa_list],
                "Model_SKUs": [qa_pair.get("Model/SKU", None) for qa_pair in qa_list] # Changed key to "Model_SKUs" for clarity in list context
            }
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet
def generate_structured_accessory_qa_sonnet(text):
    """Generate structured accessory integration Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate accessory Q&A in precise JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Pairing procedure question",
          "Compatibility verification question",
          "Optimal usage inquiry"
        ],
        "Answers": [
          "Detailed pairing steps with specific model guidance",
          "Comprehensive compatibility explanation",
          "Optimal usage recommendations"
        ],
        "Metadata": {{
          "CoverageAreas": ["Pairing", "Compatibility", "Usage"],
          "DetailLevel": "Technical and user-friendly"
        }}
      }}
    }}

    Requirements:
    - Include specific model numbers
    - Provide clear, step-by-step guidance
    - 1-2 sentence answers
    - Technical accuracy with user comprehension

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_accessory_qa_sonnet ---")
test_qa_generators("generate_structured_accessory_qa", content)
# Out:
# --- generate_structured_accessory_qa_sonnet ---
#
# --- Calling generate_structured_accessory_qa ---
# Okay, here's the Accessory Q&A based on the provided user manual.  Since there are no accessories explicitly mentioned, I will focus on the SmartThings app and the water filter as the closest things to accessories and address usage questions.
#
# **Samsung Refrigerator (Various Models - RF23BB8*****, RF29BB8*****)**
#
# **SmartThings App Q&A**
#
# *Note: This Q&A assumes the refrigerator model has SmartThings capability*
#
# **Q: How do I pair my Samsung Refrigerator with the SmartThings app?**
#
# A:
# 1.  Download and install the SmartThings app from the Google Play Store, Galaxy Apps, or Apple App Store.
# 2.  Ensure your refrigerator is powered on and connected to your home Wi-Fi network.
# 3.  Open the SmartThings app. If a pop-up appears saying that a new device has been found, tap *ADD NOW*. If a pop-up doesn't appear, tap the + button, and then select the device (Refrigerator) you want to connect from the list of available devices. Follow the instructions in the app.
# 4.  Follow the on-screen instructions in the SmartThings app to complete the pairing process.
#
# **Q: How do I check the MAC address of my refrigerator for SmartThings pairing?**
#
# A:
# 1. Press and hold both the *Freezer* and *Fridge* buttons simultaneously for 6 seconds. The temperature panel will blink.
# 2. Press *Freezer* button again. The fridge will beep, and the MAC address will be displayed sequentially on the temperature panel.
# 3. The address will be displayed for one minute.
#
# **Q: What Wi-Fi protocols are compatible with the SmartThings app on my Samsung Refrigerator?**
#
# A: The SmartThings app supports Wi-Fi 2.4 GHz with IEEE 802.11 b/g/n and Soft-AP protocols (IEEE 802.11 n is recommended)
#
# **Q: What do I do if my Samsung Smart Refrigerator fails to connect to the internet?**
# A: If your Internet service provider has registered the MAC address of your PC or modem for identification, your Samsung Smart Refrigerator may fail to connect to the Internet. If this happens, contact your Internet service provider for technical assistance.
#
# **Q: What do I do if the Wi-Fi icon is blinking?**
# A: Connect your refrigerator with the SmartThings app before use. When the connection is made successfully, the indicator stops blinking. If you fail to make connection or don’t want to use the app, press and hold the Door Alarm button for 10 seconds. The indicator stops blinking with "O FF" shown on the temperature display
#
# **Q: What can I do through the SmartThings app?**
#
# A:
# *   Monitor fridge and freezer temperature.
# *   Adjust FlexZone settings.
# *   Monitor energy consumption.
# *   Control ice making (on/off).
# *   Control Power Cool and Power Freeze (on/off).
# *   Activate/Deactivate Sabbath Mode
# *   Monitor various alarms.
#
# **Water Filter Q&A**
#
# *Note: This Q&A assumes the refrigerator model has a water dispenser and filter*
#
# **Q: How often should I replace the water filter in my Samsung Refrigerator (RF23BB8*****, RF29BB8*****)?**
#
# A: The water filter should be replaced approximately every 6 months, or after approximately 300 gallons (1200 L) of water usage. The *Filter* indicator on the control panel will blink red to remind you.
#
# **Q: How do I reset the filter indicator after replacing the water filter?**
#
# A: After replacing the water filter, press and hold the *Filter Reset* button on the control panel for 3 seconds. The filter lifecycle will be reset, and the *Filter* indicator will turn off.
#
# **Q: What happens if I don't replace the water filter?**
#
# A: The water filter will become clogged, which can reduce water flow to the dispenser and ice maker. The water quality may also be affected.
#
# **Q: What are the signs that the water filter needs to be replaced?**
#
# A: The *Filter* indicator on the control panel will blink red. Reduced water flow from the dispenser and ice maker, and an abnormal taste or smell in the water are also common indicators.
#
# **Q: Where can I purchase a replacement water filter for my Samsung Refrigerator?**
#
# A: You can purchase a new water filter from a local Samsung service center or visit www.samsungparts.com.
#
# **Q: Can I use a third-party water filter in my Samsung Refrigerator?**
#
# A: The user manual cautions against using third-party water filters, as they may leak and damage the refrigerator. It is recommended to only use Samsung-provided or approved filters.
#
# **Q: I installed a new water filter, and water is spurting. Is this normal?**
#
# A: Yes, this is a normal occurrence, caused by air entering the water line. Just let it continue running and it should stop.
#
#
# --- Calling generate_structured_accessory_qa_deepseek ---
# {'Generations': [{'Question': "How do I clean the refrigerator's interior and exterior?", 'Answer': "Unplug the power cord. Use a moistened, soft, lint-free cloth or paper towel to clean the refrigerator's interior and exterior. When done, use a dry cloth or paper towel to dry well. Plug in the power cord.", 'DeviceModel': 'Refrigerator', 'SKU': 'DA6804402BB', 'ConnectionType': 'N/A', 'Complexity': 'Simple'}, {'Question': 'How to reset the water filter after replacement?', 'Answer': 'After replacing the filter, press and hold Filter Reset for 3 seconds. The filter lifecycle will be reset and the Filter indicator turns off.', 'DeviceModel': 'Refrigerator', 'SKU': 'DA6804402BA', 'ConnectionType': 'N/A', 'Complexity': 'Medium'}, {'Question': 'How to connect the refrigerator to SmartThings?', 'Answer': 'Turn on the device > open the SmartThings app > tap ADD NOW (or + button) > select Refrigerator > follow in-app setup', 'DeviceModel': 'Refrigerator', 'SKU': 'DA6804402CA', 'ConnectionType': 'WiFi 2.4 GHz', 'Complexity': 'Medium'}, {'Question': 'What water line installation kit should I use?', 'Answer': 'Use a water line installation kit that contains copper tubing and a 1/4" (6 mm) compression nut.', 'DeviceModel': 'Refrigerator with water dispenser', 'SKU': 'DA6804402DA', 'ConnectionType': 'Water Line', 'Complexity': 'Medium'}, {'Question': 'How do I check the MAC address of the refrigerator for Smart Grid setup?', 'Answer': 'Press and hold both Freezer and Fridge buttons for 6 seconds > Then, press Freezer again to display the MAC address which will be displayed on the temperature panel sequentially for 1 minute.', 'DeviceModel': 'Refrigerator', 'SKU': 'DA6804402EA', 'ConnectionType': 'WiFi 2.4 GHz', 'Complexity': 'Complex'}]}
#
# --- Calling generate_structured_accessory_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "Questions": [],
#       "Answers": [],
#       "Model_SKUs": []
#     }
#   ]
# }
#
# --- Calling generate_structured_accessory_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "How do I pair my Samsung RF23BB8700AP refrigerator to my home Wi-Fi network?",\n      "Is the Samsung RF29BB8900QA refrigerator compatible with the SmartThings app on my Android phone?",\n      "What is the best way to use Power Cool on my Samsung refrigerator to quickly chill groceries after a shopping trip?"\n    ],\n    "Answers": [\n      "Open the SmartThings app, tap the + button, select \'Refrigerator\', and follow the on-screen instructions, ensuring your refrigerator and phone are on the same Wi-Fi network; the Wi-Fi indicator should stop blinking upon successful connection for RF23BB8700AP.",\n      "Yes, the Samsung RF29BB8900QA refrigerator is compatible with the SmartThings app on Android; download the app from the Google Play Store and follow the setup instructions, logging into your Samsung account.",\n      "Press the \'Fridge\' button repeatedly until the \'Power Cool\' indicator lights up on your Samsung refrigerator\'s main panel; Power Cool runs for several hours and then automatically reverts to previous temperature settings for optimal quick chilling."\n    ],\n    "Metadata": {\n      "CoverageAreas": ["Pairing", "Compatibility", "Usage"],\n      "DetailLevel": "Technical and user-friendly"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ### Number 16 generate_legal_qa

# %%
#original
def generate_structured_legal_qa(text):
    """Regulatory/compliance pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Q&A with:
    - Certification details - Disposal guidelines - Privacy compliance
    Include regulation numbers and citations.
    Text: {text}
    """)


#Deepseek R1
import json
from textwrap import dedent

def generate_structured_legal_qa_deepseek(text):
    """Generates compliance Q&A with standardized legal references.

    Returns:
        JSON with regulation IDs, full citations, and nested Q&A pairs.
    """
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal/compliance Q&A pairs from this text with:
    1. Certification standards (e.g., ISO/IEC numbers)
    2. E-waste disposal regulations (WEEE/RoHS directives)
    3. Privacy frameworks (GDPR, CCPA articles)

    Format requirements:
    - Use strict JSON format with "Generations" as root key
    - Each entry must contain:
      {{
        "Question": "...",
        "Answer": "...",
        "RegulationID": "GDPR Article 12",
        "FullCitation": "Regulation (EU) 2016/679"
      }}
    - Sort by regulation importance (EU directives first)

    Example:
    {{
      "Generations": [
        {{
          "Question": "How should I dispose of Samsung batteries?",
          "Answer": "Follow WEEE Directive 2012/19/EU through certified recyclers.",
          "RegulationID": "WEEE Directive",
          "FullCitation": "Directive 2012/19/EU on waste electrical equipment"
        }}
      ]
    }}

    Text: {text}
    """)

    try:
        response = model.generate_content(prompt).text
        response = response.strip("` \n").replace("json", "")
        return json.loads(response)
    except json.JSONDecodeError:
        return {"error": "Failed to parse legal compliance data"}


#Google AI STudio
def generate_structured_legal_qa_google(text):
    """Regulatory/compliance pairs in JSON format"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Question and Answer pairs from the following Samsung support document text.
    Focus on:
    - Certification details (e.g., FCC, CE, UL)
    - Disposal guidelines (e.g., WEEE, battery disposal)
    - Privacy compliance (e.g., GDPR, CCPA)

    Include relevant regulation numbers and/or citations where applicable.
    Format each question and answer pair clearly. Aim for consumer-friendly language and keep answers concise (1-2 sentences).

    Present the output as a list of dictionaries in JSON format. Each dictionary should have the keys "Question" and "Answer". If applicable, include a "Citation" key with the regulation number or citation. If no citation is relevant, the "Citation" key can be null or omitted.

    Text: {text}

    Output Format:
    [
      {{"Question": "...", "Answer": "...", "Citation": "..."}},
      {{"Question": "...", "Answer": "...", "Citation": null}},
      ...
    ]
    """)
    response_text = model.generate_content(prompt).text

    try:
        qa_list = json.loads(response_text)
    except json.JSONDecodeError:
        print("Warning: JSON parse failed, attempting fallback text extraction.")
        qa_list = [] # Implement a robust fallback text parsing as needed, similar to before.

    output_json = {
        "Generations": [
            {
                "Questions": [qa_pair.get("Question") for qa_pair in qa_list], # Use .get to handle potentially missing keys
                "Answers": [qa_pair.get("Answer") for qa_pair in qa_list],
                "Citations": [qa_pair.get("Citation", None) for qa_pair in qa_list] # Get citation, default None if missing
            }
        ]
    }
    return json.dumps(output_json, indent=2)


#Sonnet

def generate_structured_legal_qa_sonnet(text):
    """Generate structured legal compliance Q&A pairs"""
    model = genai.GenerativeModel('gemini-2.0-flash')
    prompt = dedent(f"""
    Generate legal Q&A pairs in strict JSON format:
    {{
      "Generations": {{
        "Questions": [
          "Legal question addressing certification",
          "Regulatory compliance question"
        ],
        "Answers": [
          "Detailed answer with specific regulation citations",
          "Precise compliance explanation"
        ],
        "Metadata": {{
          "ComplianceAreas": ["Certification", "Disposal", "Privacy"],
          "RegulationScope": "Comprehensive legal overview"
        }}
      }}
    }}

    Key Requirements:
    - Include precise regulation numbers
    - Cite specific legal standards
    - 1-2 sentence answers
    - Technical but understandable language

    Text: {text}
    """)

    response = model.generate_content(prompt)

    try:
        return json.loads(response.text)
    except json.JSONDecodeError:
        return {
            "Generations": {
                "Questions": [],
                "Answers": [],
                "RawResponse": response.text
            }
        }

# %%
# Example Usage:
print("--- generate_structured_legal_qa_sonnet ---")
test_qa_generators("generate_structured_legal_qa", content)
# Out:
# --- generate_structured_legal_qa_sonnet ---
#
# --- Calling generate_structured_legal_qa ---
# None
#
# --- Calling generate_structured_legal_qa_deepseek ---
# {'Generations': [{'Question': 'How should I handle and dispose of this refrigerator at the end of its life?', 'Answer': 'Contact local authorities regarding environmentally safe disposal. This product contains R-600a, a flammable gas, and cyclopentane is used in the insulation, requiring a special disposal procedure.', 'RegulationID': 'WEEE Directive', 'FullCitation': 'Directive 2012/19/EU on waste electrical equipment'}, {'Question': 'What restrictions are placed on me when this appliance reaches the end of its functional life?', 'Answer': 'When disposing of this refrigerator, remove the door/door seals and door latch so that small children or animals cannot become trapped inside.', 'RegulationID': 'WEEE Directive', 'FullCitation': 'Directive 2012/19/EU on waste electrical equipment'}, {'Question': 'What certification standards does the transmitter module within this refrigerator conform to?', 'Answer': 'Contains Transmitter Module FCC ID: A3LCCAR210R, IC: 649E-CCAR210R. Complies with Part 15 of FCC Rules and Canadian ICES-003.', 'RegulationID': 'FCC Part 15', 'FullCitation': 'Part 15 of the FCC Rules'}, {'Question': 'What is the size of the room required to safely operate this refrigerator?', 'Answer': 'To avoid flammable gas-air mixture if a leak occurs, the room must be 35.3 ft³ in size for every 8 g of R-600a refrigerant inside the appliance.', 'RegulationID': 'R-600a Safety Standard', 'FullCitation': 'EN 60335-2-24'}, {'Question': 'Does this product meet the requirements of California Proposition 65?', 'Answer': 'This product carries a California Proposition 65 warning regarding cancer and reproductive harm.', 'RegulationID': 'California Proposition 65', 'FullCitation': 'California Safe Drinking Water and Toxic Enforcement Act of 1986'}]}
#
# --- Calling generate_structured_legal_qa_google ---
# Warning: JSON parse failed, attempting fallback text extraction.
# {
#   "Generations": [
#     {
#       "Questions": [],
#       "Answers": [],
#       "Citations": []
#     }
#   ]
# }
#
# --- Calling generate_structured_legal_qa_sonnet ---
# {'Generations': {'Questions': [], 'Answers': [], 'RawResponse': '```json\n{\n  "Generations": {\n    "Questions": [\n      "What certification is required for products used side by side in explosive gas atmospheres, as noted in the safety information?",\n      "What specific regulations govern the disposal of this refrigerator in light of it containing the flammable gas R-600a, as noted in the critical disposal warnings section?"\n    ],\n    "Answers": [\n      "For safety when using two products side by side in explosive gas atmospheres, be sure to use certified products as stated in the user manual under the Safety Information section.",\n      "The disposal of this refrigerator, due to containing R-600a (a flammable gas), is subject to local authority regulations as detailed in the Critical Disposal Warnings; compliance ensures safe and lawful disposal under environmental regulations such as 40 CFR Part 82."\n    ],\n    "Metadata": {\n      "ComplianceAreas": ["Certification", "Disposal"],\n      "RegulationScope": "Comprehensive legal overview"\n    }\n  }\n}\n```'}}

# %% [markdown]
# ##Showing Image

# %%
import requests
from IPython.display import Image, display

# Get the raw image URL.  You can do this in two ways:

# 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL


# 2.  If you know the GitHub URL, you can often construct it manually by replacing "blob" with "raw":
github_image_url = "https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"
raw_image_url_manual = github_image_url.replace("/blob/", "/raw/")

# Now display the image (using either raw_image_url or raw_image_url_manual):

try:
  response = requests.get(raw_image_url, stream=True)
  response.raise_for_status() # Raise an exception for bad status codes (4xx or 5xx)
  image = Image(response.content)
  display(image)

except requests.exceptions.RequestException as e:
  print(f"Error displaying image: {e}")
except Exception as e:
  print(f"An unexpected error occurred: {e}")


# # 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
# raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL
# #OR (less robust to network issues, but simpler for known good URLs)
# display(Image(raw_image_url))

# %%
from IPython.display import HTML

# 1. The most reliable way: Go to the image on GitHub, right-click, and select "Copy image address" or "Copy image link".  This will give you a URL like this (but with your actual image):
raw_image_url = "https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png"  # Replace with your actual raw URL

html_code = f"""
<div>
  <img src="{raw_image_url}" alt="Improved Search" width="1000">  <p>This image demonstrates the improved search experience... (your description here)</p>
</div>
"""

display(HTML(html_code))
# Out:
# <div>
#   <img src="https://raw.githubusercontent.com/navneetkrc/Open_LLM_Apps/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png" alt="Improved Search" width="1000">  <p>This image demonstrates the improved search experience... (your description here)</p>
# </div>

# %%
# !wget https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png
# Out:
# --2025-03-05 19:31:29--  https://github.com/navneetkrc/Open_LLM_Apps/blob/bddf71e9bb8407dda9329e7c52679288ad746f34/dalle_improved_search.png
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dalle_improved_search.png’
#
# dalle_improved_sear     [ <=>                ] 214.67K  --.-KB/s    in 0.1s
#
# 2025-03-05 19:31:30 (1.52 MB/s) - ‘dalle_improved_search.png’ saved [219825]

# %% [markdown]
# Okay, here's a blog post designed for Confluence, focusing on the different types of QA pairs you can generate from support documentation using a Large Language Model (LLM) like Gemini, along with examples and formatting considerations:
#
# ---
#
# ## Level Up Your Support Docs:  Unlocking the Power of AI-Generated QA Pairs
#
# **Introduction**
#
# Let's face it: traditional support documentation can be... overwhelming.  Long PDFs, endless scrolling, and the frustrating feeling of searching for a needle in a haystack are all too common.  But what if we could make finding answers *instantaneous* and *intuitive*?
#
# That's where AI-powered Question-Answering (QA) pairs come in.  By leveraging a Large Language Model (LLM) like Google's Gemini, we can transform dense technical documentation into a readily accessible knowledge base.  Instead of forcing users to sift through manuals, we can provide direct answers to their specific questions.
#
# This blog post will explore various *types* of QA pairs you can generate, each designed to address different user needs and information-seeking behaviors. We'll use a Samsung Galaxy S25 User Guide as our example document, showcasing the versatility of this approach.  We'll also see how to present these QA pairs in a user-friendly way within Confluence.
#
# **Why Use AI-Generated QA Pairs?**
#
# *   **Improved User Experience:**  Users get direct answers instead of wading through pages of text.
# *   **Faster Resolution Times:**  Reduce the time it takes for users (and support agents!) to find solutions.
# *   **Increased Self-Service:**  Empower users to solve problems independently, freeing up support resources.
# *   **Enhanced Searchability:**  QA pairs create a structured knowledge base that's easily searchable.
# *   **Content Repurposing:**  Transform existing documentation into a more dynamic and engaging format.
#
# **Setting the Stage: Our Example Document**
# All the following examples use the Samsung Galaxy S25 User Guide as the source document.
#
# **QA Pair Types and Examples**
#
# We'll use a consistent format for each example:
#
# *   **Prompt Type:**  A brief description of the prompt's goal.
# *   **Prompt Example:**  The actual prompt we'd feed to the LLM.
# *  **Prompt Description:**  Description of the prompt.
# *   **Generated QA Pairs:**  A sample of the output from the LLM.
# *   **Confluence Formatting Notes:**  Tips for presenting the QA pairs effectively in Confluence.
#
# ---
#
# ### 1. Simple Question-Answer Pairs
#
# *   **Prompt Type:**  General informative Q&A pairs.
# *   **Prompt Example:**
# ```
# Generate fundamental Q&A pairs from Samsung support docs covering:
# Key features Basic troubleshooting Usage guidelines
# Use consumer-friendly language with concise answers (1-2 sentences).
# Text: {text}
# ```
# * **Prompt Description:**
# This prompt generates basic Q&A covering key features, troubleshooting, and usage, using consumer-friendly language.
# *   **Generated QA Pairs:**
#
#     *   **Q: What is Galaxy AI?**
#         *   A: Galaxy AI enhances device usage with intelligent features like real-time call translation and image editing.
#
#     *   **Q: What is Smart Switch and how do I use it?**
#         *   A: Smart Switch lets you easily transfer data from your old phone to your new Samsung device via USB cable or wirelessly.
#
#     *   **Q: My phone won't turn on. What should I do?**
#         *   A: Try charging your phone for at least a few minutes. If it still doesn't turn on, force restart by pressing and holding the Side button and Volume Down button simultaneously.
#
#     *   **Q: How do I take a screenshot?**
#         *    A: Press the Side button and the Volume Down button simultaneously, or swipe the edge of your hand across the screen.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use the **Expand** macro to create collapsible sections for each QA pair. This keeps the page clean and allows users to focus on the questions relevant to them.
#     *   Use **bold** text for the questions to make them stand out.
#     *   Consider using a two-column layout (using the `/columns` macro) to present questions and answers side-by-side for a more compact view.
#
# ---
#
# ### 2. Structured QA Pairs (Problem-Solution Focus)
#
# *   **Prompt Type:**  Problem-solution focused pairs.
# *   **Prompt Example:**
#
# ```
# Create problem-solution pairs from Samsung docs. Format:
# Question: [Issue description]
# Answer: [Step-by-step fix]
# Include severity indicators (!) for critical issues.
# Text: {text}
# ```
#
# * **Prompt Description:**
# This prompts for problem-solution Q&A with severity indicators for critical issues.
# *   **Generated QA Pairs:**
#
#     *   **Question:** ! [Device doesn't turn on]
#         *   **Answer:** When the battery is completely discharged, your device will not turn on. Fully charge the battery before turning on the device.
#
#     *   **Question:** [Others cannot hear you speaking on a call]
#         *   **Answer:**
#             1.  Ensure that you are not covering the built-in microphone.
#             2.  Ensure that the microphone is close to your mouth.
#             3.  If you are using headphones, ensure that they are properly connected.
#
#     *   **Question:** [The battery does not charge properly (For Samsung-approved chargers)]
#         *   **Answer:**
#             1.  Ensure that the charger is connected properly.
#             2.  Visit a Samsung Service Centre or an authorised service centre and have the battery replaced.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to clearly separate the "Question" (problem description) and "Answer" (step-by-step fix).
#     *   Use the **Status** macro (with a red color) to visually represent the "!" severity indicator for critical issues.
#     *   For multi-step answers, use a numbered list within the "Answer" cell of the table.
#
# ---
#
# ### 3. Step-by-Step Procedural Guides
#
# *   **Prompt Type:**  Procedural guidance pairs.
# *   **Prompt Example:**
#
# ```
# Extract step-by-step procedures and generate Q&A pairs with:
# Sequential questions Tool requirements Time estimates
# Format steps with numbered sub-items.
# Text: {text}
# ```
#
# * **Prompt Description:**
# Extracts step-by-step procedures, generating Q&A with questions, tools, and time estimates.
#
# *   **Generated QA Pairs:**
#
#     *   **Procedure:** Charging the Battery
#         1.  **Wired Charging:**
#             1.  Connect the USB cable to the USB power adapter.
#             2.  Plug the cable into the device's multipurpose jack (USB Type-C).
#             3.  After fully charging, disconnect the charger from the device.
#         2.  **Wireless Charging:**
#             1.  Place the center of the device's back on the center of the wireless charger (sold separately).
#             2.  After fully charging, disconnect the device from the wireless charger.
#
#     *   **Q&A:**
#         *   **Q1:** What is the first step in charging the device via a wired connection?
#             *   **A1:** Connect the USB cable to the USB power adapter.
#         *   **Q2:** What tools are needed for wired charging?
#             *   **A2:** USB cable, USB power adapter.
#         *   **Q5:** How long does it take to charge the battery?
#             *   **A5:** The estimated charging time will appear on the notification panel. The actual charging time assumes normal conditions.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a top-level heading for the overall procedure (e.g., "Charging the Battery").
#     *   Use subheadings for different methods (e.g., "Wired Charging," "Wireless Charging").
#     *   Use numbered lists for each step within a procedure.
#     *   Create a separate section for the Q&A, using the Expand macro or a table as described above.
#
# ---
#
# ### 4. Anticipated User Questions (FAQs)
#
# *   **Prompt Type:** Anticipated user questions.
# *   **Prompt Example:**
#
# ```
# Predict common FAQs from Samsung users based on this text.
# Phrase questions as natural customer inquiries.
# Include 'Why', 'How', and 'What if' scenarios.
# Text: {text}
# ```
# * **Prompt Description:**
# Predicts common FAQs, phrased as natural customer inquiries, including 'Why', 'How', and 'What if' scenarios.
# *   **Generated QA Pairs:**
#
#     *   "How do I turn my new Galaxy S25 on for the first time?"
#     *   "Where is the SIM card slot on my Galaxy S25+?"
#     *   "How do I transfer all my stuff from my old phone to my new Galaxy S25?"
#     *   "Why isn't my phone charging when I plug it in?"
#     *  "What if my phone gets wet? Is it really waterproof?"
#     *   "How do I download new apps onto my phone?"
#     *   "How can I make contactless payments with my phone?"
#     *   "How do I change the wallpaper on my home screen?"
#     *    "What if my phone isn't connecting to Wi-Fi?"
#     *   "How do I use Call Assist to translate phone calls in real-time?"
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a heading like "Frequently Asked Questions (FAQs)".
#     *   Use the Expand macro or a simple bulleted list for each question, followed by the answer.  This format is very common for FAQs.
#
# ---
#
# ### 5. Troubleshooting Guides
#
# *   **Prompt Type:**  Diagnostic-focused pairs.
# *   **Prompt Example:**
# ```
# Create advanced troubleshooting pairs including:
# Error symptoms Diagnostic checks Repair procedures
# Format solutions with priority levels (Critical/High/Medium).
# Text: {text}
# ```
# * **Prompt Description:**
# Creates advanced troubleshooting Q&A, with error symptoms, diagnostics, and repair procedures.
#
# *   **Generated QA Pairs:**
#
#     *   **Pair 1: Device Not Turning On**
#         *   **Error Symptom:** Device completely unresponsive, screen remains black, no lights or sounds when attempting to power on.
#         *   **Diagnostic Checks:**
#             1.  **Critical:** Check battery level. Connect the device to a known working charger and power outlet. Allow the device to charge for at least 30 minutes.
#             2.  **Critical:** Force Restart.  Press and hold the Side button and Volume Down button simultaneously for more than 7 seconds.
#             3.  **Medium:** Check the charging port for debris or damage.  Inspect the USB-C port for bent pins, lint, or other obstructions.
#         *   **Repair Procedures:**
#             1.  **Critical:** If the device starts after charging, monitor the charging behavior. Replace the charging cable and power adapter if necessary.
#             2.  **Critical:** If the device still fails to power on after charging and attempting a force restart, the battery may be faulty or there may be a hardware issue.  Seek professional repair at a Samsung Service Centre or authorized repair provider.
#             3.  **Medium:** If the charging port is damaged, professional repair/replacement is necessary. *Do not attempt to repair the charging port yourself.*
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a heading like "Troubleshooting".
#     *   Use a table with columns for "Error Symptom," "Diagnostic Checks," and "Repair Procedures."
#     *   Use the Status macro (with appropriate colors) to indicate priority levels (Critical, High, Medium).
#     *   Use numbered lists within the "Diagnostic Checks" and "Repair Procedures" columns.
#
# ---
# ### 6. Feature Explanation
#
# *   **Prompt Type:** Technology deep-dive pairs.
# *   **Prompt Example:**
# ```
# Explain Samsung technologies with Q&A pairs covering:
# Technical specifications Use cases Compatibility notes
# Include diagrams in markdown when relevant.
# Text: {text}
# ```
# *   **Prompt Description:**
# Explains Samsung technologies with Q&A, covering specs, use cases, and compatibility.
#
# *   **Generated QA Pairs:**
#
#     *   **1. Display Technology (Motion Smoothness):**
#         *   **Q:** What is "Motion Smoothness" on Samsung phones, and what are the technical differences between the available options?
#         *   **A:** Motion Smoothness refers to the refresh rate of the display, measured in Hertz (Hz). A higher refresh rate makes motion appear smoother, especially when scrolling or playing games.
#             *   **Adaptive:** Automatically adjusts the screen refresh rate to a higher one (likely 120Hz) for smoother animations and scrolling, and a lower one (likely 60Hz) to conserve battery when the screen content is static.
#             *   **Standard:** Uses a standard refresh rate (likely 60Hz) to conserve battery power.
#             * Use Cases
#                 *   **Adaptive:** Best for gaming, watching fast-paced videos, or any scenario where smooth visuals are important.
#                 *   **Standard:** Suitable for everyday use, reading, or when battery life is a priority.
# *   **Confluence Formatting Notes:**
#     * Use headings to group related technology explanations.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
#
# ### 7. Setup/Installation Guides
# * **Prompt type:** Installation/Configuration Pairs
# * **Prompt Example:**
# ```
# Generate setup-related Q&A with:
# Pre-installation checks Configuration options Post-setup tests
# Include recommended settings for different user types.
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates Q&A for setup, with pre-installation, configuration, and post-setup steps.
#
# *   **Generated QA Pairs:**
#     *   **I. Pre-Installation Checks Q&A:**
#         *   **Q: What should I do before using the device for the first time?**
#             *   **A:** Charge the battery fully. It's recommended to charge it before first use, especially if it's been unused for a while.
#         *   **Q: Are there any potential problems when the sim tray is wet?**
#            *   **A:** Yes, if you insert the SIM tray while it is wet, it may cause damage to your device. Ensure that the tray is completely dry before inserting it.
#         *   **Q: What type of SIM card does this device use?**
#             *   **A:** It uses a nano-SIM card. Additionally, it may support eSIM functionality depending on the region, carrier, and model.
#
#     *   **II. Configuration Options Q&A:**
#         *   **Q: How do I turn on the device for the first time?**
#             *   **A:** Press and hold the Side button for a few seconds.
#         *   **Q: How do I complete the initial setup?**
#             *   **A:** Follow the on-screen instructions after turning on the device. You'll be prompted to connect to a Wi-Fi network, sign in to your Google account, and set up other preferences.
#         *  **Q: How do I transfer data from my old device?**
#             * **A:** Use Smart Switch. Go to Settings > Accounts and backup > Transfer data for device setup.  You can transfer data wirelessly or using a USB cable.
#         *   **Q: How do I set up a Samsung account?**
#             *   **A:** Go to Settings > Sign in to your Galaxy (or Accounts and backup > Manage accounts > Add account > Samsung account). Follow the on-screen instructions.
#         *   **Q: How do I download an eSIM?**
#             *   **A:** Open Settings and tap Connections → SIM manager → Add eSIM.  You may need a QR code from your carrier.
#     *  **III. Post-Setup Tests & Verification Q&A:**
#         *   **Q: How do I verify that Wi-Fi is working correctly?**
#             *   **A:** Go to Settings > Connections > Wi-Fi. Ensure Wi-Fi is turned on and connected to your network. Open a web browser and try loading a website.
#         *   **Q: How do I test the screen touch responsiveness?**
#             *   **A:** Open the dialer app and type `#0#`. The options for different tests are available.
#         *   **Q: How can I reset my device?**
#             *   **A:** To reset your device, perform a factory data reset. Open Settings and tap General management → Reset → Factory data reset. *Warning: This will erase all data on your device.*
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
# ### 8. Error Code Explanations
# * **Prompt type:** Error code explanation.
# * **Prompt Example:**
# ```
# Create error code Q&A with:
# Code interpretations Immediate actions
# Format codes in bold with severity colors (
#
# ).
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates Q&A for errors, with interpretations, actions, and colored severity indicators.
# *   **Generated QA Pairs:**
#
#     *   ### **ERROR 001: Device Overheating**
#         *   **Code Interpretation:** The device has exceeded a safe operating temperature threshold. This can be triggered by intensive use, high ambient temperatures, or a potential hardware issue.
#         *   **Immediate Actions:**
#             1.  Stop using the device immediately.
#             2.  Disconnect the charger if connected.
#             3.  Close all running apps.
#             4.  Move the device to a cooler environment.
#             5.  Allow the device to cool down completely before resuming use.
#         *   **Service Triggers:**
#             *   If the overheating persists even with minimal use and in a cool environment.
#             *   If the device displays warning messages about overheating despite not being used heavily.
#             *   If the device shuts down unexpectedly due to overheating.
#             *   If physical damage to the device is suspected to be the cause of the overheating.
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
#
# ---
#
# ### 9. Safety and Compliance
#
# * **Prompt Type:**  Safety/compliance pairs
# *   **Prompt Example:**
#
# ```
# Generate safety Q&A covering:
# Hazard prevention Compliance standards Recall information
# Use warning boxes for critical items.
# Text: {text}
# ```
# *   **Prompt Description:**
# Generates safety Q&A, covering hazards, compliance, and recalls, with warning boxes for critical items.
#
# *   **Generated QA Pairs:**
#     *   **Q: Is it safe to use the speakers close to my ears?**
#         *   A: When using the speakers, such as when playing media files or using speakerphone, do not place the device close to your ears. Prolonged exposure to loud audio can damage your hearing.
#     *   **Q: What should I do if the glass or acrylic body of the device is broken?**
#         *   A: If you use the device with its glass or acrylic body broken, there may be a risk of injury. Use the device only after it has been repaired by a Samsung Service Centre.
#     *  **Q: What should I do if dust or foreign materials enter the microphone, speaker, or receiver?**
#         *   A: If dust or foreign materials enter the microphone, speaker, or receiver, or if these parts are covered, the device's volume or call quality may be affected.  Do not insert sharp objects into the microphone, speaker, or receiver.
#     *    **Q: Can metallic stickers or covers affect connectivity or battery life?**
#         *    A: Yes, connectivity problems and battery drain may occur if you attach metallic stickers on the antenna area, use metallic phone cases, or non-Samsung-approved covers.
#
# *   **Confluence Formatting Notes:**
#     * Use headings to group Steps and sections.
#     * bold the Question.
#     * Use bullted points and lists to make it easy to read
# ---
# ### 10. Device Compatibility
# * **Prompt Type:** Device compatibility pairs
# * **Prompt Example:**
# ```
# Create compatibility Q&A with:
# Supported models - Version requirements - Regional variations
# Present compatibility as tables when possible.
# Text: {text}
# ```
# *   **Prompt Description:**
# Creates Q&A on compatibility, with models, versions, and regional variations, using tables when possible.
#
# *   **Generated QA Pairs:**
#
#     *   **Supported Models:** SM-S931B, SM-S931B/DS, SM-S936B, SM-S936B/DS, SM-S938B, SM-S938B/DS.
#     *   **Version Requirements:** The text mentions *English 01/2025 Rev1 0*, which indicates software/documentation versioning, but doesn't explicitly list minimum OS requirements for features.
#     *   **Regional Variations:** The document mentions that some features are region-dependent.
#
#     *   **Compatibility Q&A:**
#         *   **General Device Support**
#             *   **Q: Which phone models does this user guide cover?**
#                 *   **A:** This user guide is applicable to the following Samsung Galaxy models:
#                     *   SM-S931B
#                     *   SM-S931B/DS
#                     *   SM-S936B
#                     *   SM-S936B/DS
#                     *   SM-S938B
#                     *   SM-S938B/DS
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to clearly present compatibility information.  Columns could include "Model," "Supported Feature," "Minimum OS Version," "Regional Availability," and "Notes."
#     *   If there are many compatibility variations, consider creating separate tables for different feature categories (e.g., "Connectivity Features," "Multimedia Features").
#
# ---
# ### 11. Preventive Maintenance
# *   **Prompt Type:** Preventive care pairs.
# *   **Prompt Example:**
#
# ```
# Generate maintenance Q&A including:
# Service intervals - Cleaning procedures - Part replacements
# Add maintenance checklists with timelines.
# Text: {text}
# ```
#
# *   **Prompt Description:**
# Generates maintenance Q&A, including intervals, cleaning, replacements, and checklists with timelines.
#
# * **Generated QA Pairs**
#      *   **Q: How often should I service my Galaxy S25 device?**
#         *   **A:** While there are no specific "service intervals" in the traditional sense for smartphones (like with a car), regular maintenance is crucial for optimal performance and longevity.
#             *   Check for software updates regularly (Settings > Software update).
#             *   Monitor battery health and performance (Settings > Battery > Battery Information).
#             *   Utilize the Device Care feature to optimize performance (Settings > Device care).
#
#     *   **Q: What's the best way to clean my Galaxy S25 device?**
#         *   **A:**
#             1.  **Power Off:** Turn off your device before cleaning.
#             2.  **Microfiber Cloth:** Use a soft, lint-free microfiber cloth to wipe the exterior surfaces (screen, back, sides). Avoid abrasive materials like paper towels.
#             3.  **Avoid Liquids:** Do not spray liquids directly onto the device. If necessary, *lightly* dampen the microfiber cloth with distilled water. *Never* use harsh chemicals, solvents, or abrasive cleaners.
#             4.  **Ports and Openings:** Use a dry, soft brush (like a clean toothbrush) or compressed air to gently remove dust and debris from the charging port, speaker grilles, and other openings.
#             5.  **Camera Lens:** Clean the camera lens with a lens cloth designed for optics. Avoid abrasive materials.
#             6.  **S Pen (S25 Ultra):** Clean the S Pen with a dry cloth. Ensure no debris is lodged in the S Pen slot.
#
# *   **Confluence Formatting Notes:**
#
#     *   Use a table to organize maintenance tasks, intervals, and any specific instructions.
#     *   Include a "Notes" column for additional tips or warnings.
#     *   Consider using the Checklist macro for recurring tasks.
#
# ---
# ### 12. Warranty and Service
#
# *   **Prompt Type:** Warranty/service pairs
# *   **Prompt Example:**
#
# ```
# Create warranty Q&A covering:
# Coverage details Claim processes Void conditions
# Include regional policy variations.
# Text: {text}
# ```
# *Prompt Description*
# Creates Q&A about warranties, claims, void conditions, and regional variations.
# *Confluence Formating Notes*
# *   Organize information using headings and subheadings (e.g., "Warranty Coverage," "Making a Claim," "Warranty Void Conditions").
# *   Use bullet points to list key details.
# *   If regional variations are extensive, create separate sections or tables for each region.
# *   Provide links to the official Samsung warranty information page for your target region.
#
# ---
#
# **Conclusion**
#
# By strategically using different types of prompts, you can leverage the power of LLMs to create a comprehensive and user-friendly QA knowledge base from your existing support documentation.  This not only improves the user experience but also streamlines support operations and empowers users to find answers quickly and efficiently. Remember to always review and refine the AI-generated content to ensure accuracy and clarity.  This approach allows you to transform static documentation into a dynamic, searchable, and highly effective self-service resource.
