# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Deep-Learning-Experiments-implemented-using-Google-Colab/blob/master/table-qa-pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Source [Youtube Tutorials by Bhavesh Bhat](https://www.youtube.com/watch?v=MclFnA00jkY)

# %% [markdown]
# # Installs

# %%
# !pip install -q transformers==4.4.2

# %%
import torch
torch.__version__ #1.11.0+cu113
# Out:
# '1.11.0+cu113'

# %%
# !pip install torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# ...
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp37-cp37m-linux_x86_64.whl size=279639 sha256=7ce6c87ff5170da15682538b9221d2b6a52a9240b93438494d0f191284ece3d5
#   Stored in directory: /root/.cache/pip/wheels/dd/57/a3/42ea193b77378ce634eb9454c9bc1e3163f3b482a35cdee4d1
# Successfully built torch-scatter
# ...

# %% [markdown]
# # Imports

# %%
from transformers import pipeline
import pandas as pd

# %%
tqa = pipeline(task="table-question-answering", 
               model="google/tapas-base-finetuned-wtq")
# Out:
# Downloading:   0%|          | 0.00/1.66k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/443M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/262k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/154 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/490 [00:00<?, ?B/s]

# %% [markdown]
# # Reading Data

# %%
# !wget https://raw.githubusercontent.com/bhattbhavesh91/table-question-answering-with-automatic-speech-recognition/main/data.csv
# Out:
# --2022-05-26 11:01:25--  https://raw.githubusercontent.com/bhattbhavesh91/table-question-answering-with-automatic-speech-recognition/main/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 699 [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]     699  --.-KB/s    in 0s
#
# 2022-05-26 11:01:26 (22.9 MB/s) - ‘data.csv’ saved [699/699]

# %%
table = pd.read_csv("data.csv")
table = table.astype(str)

# %%
table
# Out:
#   Pos              Player          Team       Span Innings   Runs  \
# 0   1    Sachin Tendulkar         India  1989-2012     452  18426
# 1   2    Kumar Sangakkara     Sri Lanka  2000-2015     380  14234
# 2   3       Ricky Ponting     Australia  1995-2012     365  13704
# 3   4   Sanath Jayasuriya     Sri Lanka  1989-2011     433  13430
# 4   5  Mahela Jayawardene     Sri Lanka  1998-2015     418  12650
# 5   6         Virat Kohli         India  2008-2020     236  11867
# 6   7      Inzamam-ul-Haq      Pakistan  1991-2007     350  11739
# 7   8      Jacques Kallis  South Africa  1996-2014     314  11579
# 8   9      Saurav Ganguly         India  1992-2007     300  11363
# 9  10        Rahul Dravid         India  1996-2011     318  10889
#
#   Highest Score Average Strike Rate
# 0           200   44.83       86.23
# 1           169   41.98       78.86
# 2           164   42.03       80.39
# 3           189   32.36        91.2
# 4           144   33.37       78.96
# ...

# %% [markdown]
# # Natural Language Query to Tabular Data

# %%
query = "Who has scored the highest runs?"
print(tqa(table=table, query=query)["answer"])
# Out:
# Sachin Tendulkar

# %%
query = ["Virat Kohli's highest score?", 
         "Which team does he play for?"]
answer = tqa(table=table, query=query)
for ans in answer:
    print(ans["answer"])
# Out:
# AVERAGE > 183
# India

# %%
query = "Total runs scored by Indian players?"  
print(tqa(table=table, query=query)["answer"])
# Out:
# SUM > 18426, 11867, 11363, 10889
