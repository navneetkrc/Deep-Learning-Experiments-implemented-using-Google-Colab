# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Deep-Learning-Experiments-implemented-using-Google-Colab/blob/master/GLiNER_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Install requirements**

# %%
# !pip install gliner

# %%
from gliner import GLiNER

# %%
# available models: https://huggingface.co/urchade

model = GLiNER.from_pretrained("urchade/gliner_mediumv2.1")
model.eval()
print("ok")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:104: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
# You are not authenticated with the Hugging Face Hub in this notebook.
# If the error persists, please let us know by opening an issue on GitHub (https://github.com/huggingface/huggingface_hub/issues/new).
#   warnings.warn(
# Fetching 5 files:   0%|          | 0/5 [00:00<?, ?it/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.76k [00:00<?, ?B/s]
# gliner_config.json:   0%|          | 0.00/476 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/781M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/781M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# ...

# %%
text = """
Libretto by Marius Petipa, based on the 1822 novella ``Trilby, ou Le Lutin d'Argail`` by Charles Nodier, first presented by the Ballet of the Moscow Imperial Bolshoi Theatre on January 25/February 6 (Julian/Gregorian calendar dates), 1870, in Moscow with Polina Karpakova as Trilby and Ludiia Geiten as Miranda and restaged by Petipa for the Imperial Ballet at the Imperial Bolshoi Kamenny Theatre on January 17–29, 1871 in St. Petersburg with Adèle Grantzow as Trilby and Lev Ivanov as Count Leopold.
"""

labels = ["person", "book", "location", "date", "actor", "character"]

entities = model.predict_entities(text, labels, threshold=0.4)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Trilby => character
# Moscow => location
# January 25/February 6 => date
# 1870 => date
# Moscow => location
# Polina Karpakova => actor
# Trilby => character
# Ludiia Geiten => actor
# Miranda => character
# January 17–29, 1871 => date
# St. Petersburg => location
# Adèle Grantzow => actor
# Trilby => character
# Lev Ivanov => actor
# Count Leopold => character

# %%
text = """
Show me latest samsung galaxy smartphones with atleast 100GB of storage and a quad camera setup,
Find Samsung 4k TV that is atleast 43 inches and has smart TV capabilities,
Show me wireless earbuds with active noise cancellation,
what are best samsung tablets under $400,
Show me samsung galaxy smartphones with atleast 100GB of storage and 8 GB Ram with quad camera setup
"""

# labels = ["person", "book", "location", "date", "actor", "character"]
labels = {'brand': 0, 'product category': 1, 'storage': 2, 'camera': 3, 'display': 4, 'feature': 5, 'price': 6, 'ram': 7, 'others': 8}
entities = model.predict_entities(text, labels, threshold=0.4)

for entity in entities:
  print(entity["text"], "=>", entity["label"])
# Out:
# samsung => brand
# 100GB => storage
# quad camera setup => camera
# Samsung => brand
# smart TV capabilities => feature
# active noise cancellation => feature
# samsung => brand
# $400 => price
# samsung => brand
# 100GB => storage
# 8 GB Ram => ram
# quad camera setup => camera

# %%
import pandas as pd
# Assuming you have a 'model' object with a 'predict_entities' method
# This needs to be an actual model instance in your code.
# Example:
# from your_model_library import YourModelClass
# model = YourModelClass()
#Replace the above lines with your actual model.

queries = [
    "What's the newest Samsung phone with a long-lasting battery?",
    "Find Samsung TVs with HDMI 2.1 for gaming.",
    "Show me the latest Samsung Galaxy Watch models.",
    "Compare Samsung Galaxy S23 and S24 features.",
    "Which Samsung tablets are best for drawing?",
    "What are the best Samsung refrigerators with a water dispenser?",
    "Find a Samsung soundbar that's compatible with my Samsung TV.",
    "Does the Samsung Galaxy A54 have 5G?",
    "How much does the Samsung Galaxy Z Fold 5 cost?",
    "Show me Samsung monitors with a high refresh rate.",
    "Find Samsung washing machines with a steam cycle.",
    "What are the best Samsung dryers with a sensor dry feature?",
    "Recommend a Samsung vacuum cleaner for pet hair.",
    "What are the latest Samsung microwave ovens?",
    "Find Samsung dishwashers with a sanitize cycle.",
    "Show me Samsung air conditioners with smart cooling.",
    "What is the battery life of the Samsung Galaxy Buds Pro 2?",
    "Find Samsung laptops with a dedicated graphics card.",
    "What are the best Samsung Chromebooks for students?",
    "Show me Samsung smart home devices.",
    "What is the warranty on Samsung phones?",
    "Find Samsung phone cases for the Galaxy S23.",
    "Show me Samsung chargers and adapters.",
    "What are the best Samsung memory cards for my phone?",
    "Find Samsung screen protectors for my tablet.",
    "Show me Samsung Galaxy Book laptops.",
    "What are the differences between Samsung QLED and OLED TVs?",
    "Find Samsung TVs with ambient mode.",
    "Show me Samsung home theater systems.",
    "What is the price of the Samsung Galaxy Tab S8 Ultra?",
    "Find Samsung smartwatches with GPS.",
    "Show me Samsung fitness trackers.",
    "What are the best Samsung phone cameras?",
    "Find Samsung phones with expandable storage.",
    "Show me Samsung phones with a headphone jack.",
    "What are the Samsung phones with the best battery life under $500?",
    "Find Samsung phones with wireless charging.",
    "Show me Samsung phones with water resistance.",
    "What are the best Samsung tablets for reading?",
    "Find Samsung tablets with a keyboard case.",
    "Show me Samsung tablets with a pen included.",
    "What is the display resolution of the Samsung Galaxy S23 Ultra?",
    "Find Samsung phones with a fast processor.",
    "Show me Samsung phones with a large screen.",
    "What are the best Samsung monitors for gaming?",
    "Find Samsung monitors with USB-C ports.",
    "Show me Samsung monitors with built-in speakers.",
    "What is the refresh rate of the Samsung Odyssey G9?",
    "Find Samsung refrigerators with a family hub.",
    "Show me Samsung refrigerators with a dual ice maker.",
    "What are the energy-efficient Samsung washing machines?",
    "Find Samsung washing machines with a quick wash cycle.",
    "Show me Samsung washing machines with a self-cleaning function.",
     "Find Samsung dryers with wrinkle prevent.",
    "Show me Samsung dryers with a sanitize cycle.",
    "What are the best Samsung vacuum cleaners for hardwood floors?",
    "Find Samsung vacuum cleaners with a HEPA filter.",
    "Show me Samsung vacuum cleaners with a bagless design.",
    "What are the features of the Samsung Bespoke Jet vacuum?",
    "Find Samsung dishwashers with a third rack.",
    "Show me Samsung dishwashers with a quiet operation.",
    "What are the best Samsung air conditioners for bedrooms?",
    "Find Samsung air conditioners with a sleep mode.",
    "Show me Samsung air conditioners with a smart humidity control.",
    "What is the range of the Samsung SmartTag?",
    "Find Samsung SmartThings compatible devices.",
    "Show me Samsung accessories for my Galaxy phone.",
    "What are the benefits of Samsung Care+?",
    "Find Samsung trade-in offers for old phones.",
    "Show me Samsung student discounts.",
    "What's the latest software update for my Samsung TV?",
    "Find Samsung support articles for my phone.",
    "Show me how to reset my Samsung tablet.",
    "What is Samsung Knox security?",
    "Find Samsung developer resources.",
    "Show me Samsung's sustainability initiatives.",
    "What are the environmental certifications for Samsung products?",
    "Find Samsung's accessibility features.",
    "Show me Samsung products designed for people with disabilities.",
     "Which Samsung tablets have S Pen support?",
    "Find Samsung smartwatches with sleep tracking.",
    "What are the health features on Samsung watches?",
    "Which Samsung phones have the best zoom capabilities?",
    "Find Samsung TVs with HDR10+ support.",
    "Show me Samsung monitors with curved screens.",
    "What's the processor in the latest Samsung Galaxy phone?",
    "Find Samsung phones with fast charging.",
    "What are the best Samsung appliances for a small apartment?",
    "Show me Samsung devices that work with Bixby.",
    "Find Samsung devices with facial recognition.",
    "What are the connectivity options on Samsung laptops?",
    "Show me Samsung accessories for my TV.",
    "What kind of warranty comes with a Samsung refrigerator?",
    "Show me Samsung's latest promotions.",
    "Find Samsung devices with a built-in stylus.",
    "What are the storage options for the Samsung Galaxy S24?",
    "Show me Samsung products that are on sale today.",
    "What is the return policy for Samsung products?",
    "Find Samsung devices that support Dex mode.",
    "Show me Samsung's guide to setting up my new TV.",
    "What are the benefits of creating a Samsung account?",
    "Find Samsung's product comparison tool.",
    "Show me Samsung user manuals.",
    "What is the price range of Samsung's 8K TVs?"
]

labels = {
    'brand': 0,
    'product category': 1,
    'product name': 2, # ADDED
    'storage': 3,
    'camera': 4,
    'display': 5,
    'feature': 6,
    'price': 7,
    'ram': 8,
    'accessory': 9, # ADDED
    'others': 10
}

data = []

for query in queries:
    entities = model.predict_entities(query, labels, threshold=0.4)
    extracted_entities = [(entity["text"], entity["label"]) for entity in entities]  # Store as tuples
    data.append({"query": query, "extracted entities": extracted_entities})

df = pd.DataFrame(data)
df.to_csv("extracted_entities.csv", index=False)

print("Dataframe created and saved to extracted_entities.csv")
# Out:
# Dataframe created and saved to extracted_entities.csv

# %%
import pandas as pd
from transformers import pipeline # Requires transformers library
# Assuming you have a 'model' object with a 'predict_entities' method
# This needs to be an actual model instance in your code.
# Example:
# from your_model_library import YourModelClass
# model = YourModelClass()
#Replace the above lines with your actual model.

queries = [
    "What's the newest Samsung phone with a long-lasting battery?",
    "Find Samsung TVs with HDMI 2.1 for gaming.",
    "Show me the latest Samsung Galaxy Watch models.",
    "Compare Samsung Galaxy S23 and S24 features.",
    "Which Samsung tablets are best for drawing?",
    "What are the best Samsung refrigerators with a water dispenser?",
    "Find a Samsung soundbar that's compatible with my Samsung TV.",
    "Does the Samsung Galaxy A54 have 5G?",
    "How much does the Samsung Galaxy Z Fold 5 cost?",
    "Show me Samsung monitors with a high refresh rate.",
    "Find Samsung washing machines with a steam cycle.",
    "What are the best Samsung dryers with a sensor dry feature?",
    "Recommend a Samsung vacuum cleaner for pet hair.",
    "What are the latest Samsung microwave ovens?",
    "Find Samsung dishwashers with a sanitize cycle.",
    "Show me Samsung air conditioners with smart cooling.",
    "What is the battery life of the Samsung Galaxy Buds Pro 2?",
    "Find Samsung laptops with a dedicated graphics card.",
    "What are the best Samsung Chromebooks for students?",
    "Show me Samsung smart home devices.",
    "What is the warranty on Samsung phones?",
    "Find Samsung phone cases for the Galaxy S23.",
    "Show me Samsung chargers and adapters.",
    "What are the best Samsung memory cards for my phone?",
    "Find Samsung screen protectors for my tablet.",
    "Show me Samsung Galaxy Book laptops.",
    "What are the differences between Samsung QLED and OLED TVs?",
    "Find Samsung TVs with ambient mode.",
    "Show me Samsung home theater systems.",
    "What is the price of the Samsung Galaxy Tab S8 Ultra?",
    "Find Samsung smartwatches with GPS.",
    "Show me Samsung fitness trackers.",
    "What are the best Samsung phone cameras?",
    "Find Samsung phones with expandable storage.",
    "Show me Samsung phones with a headphone jack.",
    "What are the Samsung phones with the best battery life under $500?",
    "Find Samsung phones with wireless charging.",
    "Show me Samsung phones with water resistance.",
    "What are the best Samsung tablets for reading?",
    "Find Samsung tablets with a keyboard case.",
    "Show me Samsung tablets with a pen included.",
    "What is the display resolution of the Samsung Galaxy S23 Ultra?",
    "Find Samsung phones with a fast processor.",
    "Show me Samsung phones with a large screen.",
    "What are the best Samsung monitors for gaming?",
    "Find Samsung monitors with USB-C ports.",
    "Show me Samsung monitors with built-in speakers.",
    "What is the refresh rate of the Samsung Odyssey G9?",
    "Find Samsung refrigerators with a family hub.",
    "Show me Samsung refrigerators with a dual ice maker.",
    "What are the energy-efficient Samsung washing machines?",
    "Find Samsung washing machines with a quick wash cycle.",
    "Show me Samsung washing machines with a self-cleaning function.",
     "Find Samsung dryers with wrinkle prevent.",
    "Show me Samsung dryers with a sanitize cycle.",
    "What are the best Samsung vacuum cleaners for hardwood floors?",
    "Find Samsung vacuum cleaners with a HEPA filter.",
    "Show me Samsung vacuum cleaners with a bagless design.",
    "What are the features of the Samsung Bespoke Jet vacuum?",
    "Find Samsung dishwashers with a third rack.",
    "Show me Samsung dishwashers with a quiet operation.",
    "What are the best Samsung air conditioners for bedrooms?",
    "Find Samsung air conditioners with a sleep mode.",
    "Show me Samsung air conditioners with a smart humidity control.",
    "What is the range of the Samsung SmartTag?",
    "Find Samsung SmartThings compatible devices.",
    "Show me Samsung accessories for my Galaxy phone.",
    "What are the benefits of Samsung Care+?",
    "Find Samsung trade-in offers for old phones.",
    "Show me Samsung student discounts.",
    "What's the latest software update for my Samsung TV?",
    "Find Samsung support articles for my phone.",
    "Show me how to reset my Samsung tablet.",
    "What is Samsung Knox security?",
    "Find Samsung developer resources.",
    "Show me Samsung's sustainability initiatives.",
    "What are the environmental certifications for Samsung products?",
    "Find Samsung's accessibility features.",
    "Show me Samsung products designed for people with disabilities.",
     "Which Samsung tablets have S Pen support?",
    "Find Samsung smartwatches with sleep tracking.",
    "What are the health features on Samsung watches?",
    "Which Samsung phones have the best zoom capabilities?",
    "Find Samsung TVs with HDR10+ support.",
    "Show me Samsung monitors with curved screens.",
    "What's the processor in the latest Samsung Galaxy phone?",
    "Find Samsung phones with fast charging.",
    "What are the best Samsung appliances for a small apartment?",
    "Show me Samsung devices that work with Bixby.",
    "Find Samsung devices with facial recognition.",
    "What are the connectivity options on Samsung laptops?",
    "Show me Samsung accessories for my TV.",
    "What kind of warranty comes with a Samsung refrigerator?",
    "Show me Samsung's latest promotions.",
    "Find Samsung devices with a built-in stylus.",
    "What are the storage options for the Samsung Galaxy S24?",
    "Show me Samsung products that are on sale today.",
    "What is the return policy for Samsung products?",
    "Find Samsung devices that support Dex mode.",
    "Show me Samsung's guide to setting up my new TV.",
    "What are the benefits of creating a Samsung account?",
    "Find Samsung's product comparison tool.",
    "Show me Samsung user manuals.",
    "What is the price range of Samsung's 8K TVs?"
]

labels = {
    'brand': 0,
    'product category': 1,
    'product name': 2, # ADDED
    'storage': 3,
    'camera': 4,
    'display': 5,
    'feature': 6,
    'price': 7,
    'ram': 8,
    'accessory': 9, # ADDED
    'others': 10
}

# Define the list of models.  Make sure to load valid models.
model_names = [
    "dslim/bert-base-NER",  # A general NER model
    "knowledgator/modern-gliner-bi-large-v1.0",   # Italian NER (example of multilingual)  Change to other languages if needed
    "knowledgator/gliner-multitask-large-v0.5",
    "knowledgator/gliner-multitask-v1.0"#French model Change to other languages if needed
    # Add more models that are suited for electronics/e-commerce NER
    # Suggestion, search the huggingface model hub for NER models.
    # Example: https://huggingface.co/models?pipeline_tag=ner&sort=downloads

]

# Load the pipelines
models = []
for model_name in model_names:
    try:
        ner_pipeline = pipeline("ner", model=model_name, aggregation_strategy="simple")
        models.append(ner_pipeline)
        print(f"Model {model_name} loaded successfully.")
    except Exception as e:
        print(f"Error loading model {model_name}: {e}")


def predict_entities_with_ensemble(query, models, labels, threshold=0.4):
    """
    Predicts entities using an ensemble of models.

    Args:
        query (str): The input query.
        models (list): A list of loaded NER models (pipelines).
        labels (dict): The mapping of labels to IDs.
        threshold (float): Confidence threshold for entity extraction.

    Returns:
        list: A list of extracted entities (dictionaries).
    """
    all_entities = []
    for model in models:
        try:
            model_entities = model(query)  # Get predictions from the model
            all_entities.extend(model_entities)
        except Exception as e:
            print(f"Error during prediction with model {model}: {e}")
            continue #Go to next model

    # Aggregate entities (very basic example - improve this based on your needs)
    #  Here, we just take all the entities from all models.  More sophisticated
    # aggregation could involve confidence scores, majority voting, etc.
    extracted_entities = []
    for entity in all_entities:
        if entity['confidence_score'] >= threshold:
            extracted_entities.append({
                "text": query[entity['start']:entity['end']], #Extract the text
                "label": entity['entity_group'].lower()  #Lowercase
            })

    return extracted_entities

data = []

for query in queries:
    extracted_entities = predict_entities_with_ensemble(query, models, labels, threshold=0.4)
    formatted_entities = [(entity["text"], entity["label"]) for entity in extracted_entities]  # Store as tuples
    data.append({"query": query, "extracted entities": formatted_entities})

df = pd.DataFrame(data)
df.to_csv("extracted_entities.csv", index=False)

print("Dataframe created and saved to extracted_entities.csv")
# Out:
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# ...

# %%
# import pandas as pd
# from transformers import pipeline  # Requires transformers library
# # Assuming you have a 'model' object with a 'predict_entities' method
# # This needs to be an actual model instance in your code.
# # Example:
# # from your_model_library import YourModelClass
# # model = YourModelClass()
# # Replace the above lines with your actual model.

# queries = [
#     "What's the newest Samsung phone with a long-lasting battery?",
#     "Find Samsung TVs with HDMI 2.1 for gaming.",
#     "Show me the latest Samsung Galaxy Watch models.",
#     "Compare Samsung Galaxy S23 and S24 features.",
#     "Which Samsung tablets are best for drawing?",
#     "What are the best Samsung refrigerators with a water dispenser?",
#     "Find a Samsung soundbar that's compatible with my Samsung TV.",
#     "Does the Samsung Galaxy A54 have 5G?",
#     "How much does the Samsung Galaxy Z Fold 5 cost?",
#     "Show me Samsung monitors with a high refresh rate.",
#     "Find Samsung washing machines with a steam cycle.",
#     "What are the best Samsung dryers with a sensor dry feature?",
#     "Recommend a Samsung vacuum cleaner for pet hair.",
#     "What are the latest Samsung microwave ovens?",
#     "Find Samsung dishwashers with a sanitize cycle.",
#     "Show me Samsung air conditioners with smart cooling.",
#     "What is the battery life of the Samsung Galaxy Buds Pro 2?",
#     "Find Samsung laptops with a dedicated graphics card.",
#     "What are the best Samsung Chromebooks for students?",
#     "Show me Samsung smart home devices.",
#     "What is the warranty on Samsung phones?",
#     "Find Samsung phone cases for the Galaxy S23.",
#     "Show me Samsung chargers and adapters.",
#     "What are the best Samsung memory cards for my phone?",
#     "Find Samsung screen protectors for my tablet.",
#     "Show me Samsung Galaxy Book laptops.",
#     "What are the differences between Samsung QLED and OLED TVs?",
#     "Find Samsung TVs with ambient mode.",
#     "Show me Samsung home theater systems.",
#     "What is the price of the Samsung Galaxy Tab S8 Ultra?",
#     "Find Samsung smartwatches with GPS.",
#     "Show me Samsung fitness trackers.",
#     "What are the best Samsung phone cameras?",
#     "Find Samsung phones with expandable storage.",
#     "Show me Samsung phones with a headphone jack.",
#     "What are the Samsung phones with the best battery life under $500?",
#     "Find Samsung phones with wireless charging.",
#     "Show me Samsung phones with water resistance.",
#     "What are the best Samsung tablets for reading?",
#     "Find Samsung tablets with a keyboard case.",
#     "Show me Samsung tablets with a pen included.",
#     "What is the display resolution of the Samsung Galaxy S23 Ultra?",
#     "Find Samsung phones with a fast processor.",
#     "Show me Samsung phones with a large screen.",
#     "What are the best Samsung monitors for gaming?",
#     "Find Samsung monitors with USB-C ports.",
#     "Show me Samsung monitors with built-in speakers.",
#     "What is the refresh rate of the Samsung Odyssey G9?",
#     "Find Samsung refrigerators with a family hub.",
#     "Show me Samsung refrigerators with a dual ice maker.",
#     "What are the energy-efficient Samsung washing machines?",
#     "Find Samsung washing machines with a quick wash cycle.",
#     "Show me Samsung washing machines with a self-cleaning function.",
#      "Find Samsung dryers with wrinkle prevent.",
#     "Show me Samsung dryers with a sanitize cycle.",
#     "What are the best Samsung vacuum cleaners for hardwood floors?",
#     "Find Samsung vacuum cleaners with a HEPA filter.",
#     "Show me Samsung vacuum cleaners with a bagless design.",
#     "What are the features of the Samsung Bespoke Jet vacuum?",
#     "Find Samsung dishwashers with a third rack.",
#     "Show me Samsung dishwashers with a quiet operation.",
#     "What are the best Samsung air conditioners for bedrooms?",
#     "Find Samsung air conditioners with a sleep mode.",
#     "Show me Samsung air conditioners with a smart humidity control.",
#     "What is the range of the Samsung SmartTag?",
#     "Find Samsung SmartThings compatible devices.",
#     "Show me Samsung accessories for my Galaxy phone.",
#     "What are the benefits of Samsung Care+?",
#     "Find Samsung trade-in offers for old phones.",
#     "Show me Samsung student discounts.",
#     "What's the latest software update for my Samsung TV?",
#     "Find Samsung support articles for my phone.",
#     "Show me how to reset my Samsung tablet.",
#     "What is Samsung Knox security?",
#     "Find Samsung developer resources.",
#     "Show me Samsung's sustainability initiatives.",
#     "What are the environmental certifications for Samsung products?",
#     "Find Samsung's accessibility features.",
#     "Show me Samsung products designed for people with disabilities.",
#      "Which Samsung tablets have S Pen support?",
#     "Find Samsung smartwatches with sleep tracking.",
#     "What are the health features on Samsung watches?",
#     "Which Samsung phones have the best zoom capabilities?",
#     "Find Samsung TVs with HDR10+ support.",
#     "Show me Samsung monitors with curved screens.",
#     "What's the processor in the latest Samsung Galaxy phone?",
#     "Find Samsung phones with fast charging.",
#     "What are the best Samsung appliances for a small apartment?",
#     "Show me Samsung devices that work with Bixby.",
#     "Find Samsung devices with facial recognition.",
#     "What are the connectivity options on Samsung laptops?",
#     "Show me Samsung accessories for my TV.",
#     "What kind of warranty comes with a Samsung refrigerator?",
#     "Show me Samsung's latest promotions.",
#     "Find Samsung devices with a built-in stylus.",
#     "What are the storage options for the Samsung Galaxy S24?",
#     "Show me Samsung products that are on sale today.",
#     "What is the return policy for Samsung products?",
#     "Find Samsung devices that support Dex mode.",
#     "Show me Samsung's guide to setting up my new TV.",
#     "What are the benefits of creating a Samsung account?",
#     "Find Samsung's product comparison tool.",
#     "Show me Samsung user manuals.",
#     "What is the price range of Samsung's 8K TVs?"
# ]

# labels = {
#     'brand': 0,
#     'product category': 1,
#     'product name': 2, # ADDED
#     'storage': 3,
#     'camera': 4,
#     'display': 5,
#     'feature': 6,
#     'price': 7,
#     'ram': 8,
#     'accessory': 9, # ADDED
#     'others': 10
# }

# # Define the list of models.  Make sure to load valid models.
# model_names = [
#     "dslim/bert-base-NER",  # A general NER model
#     "Davlan/distilbert-base-NER-IT",   # Italian NER (example of multilingual)  Change to other languages if needed
#     "Jean-Baptiste/camembert-ner"  #French model Change to other languages if needed
#     # Add more models that are suited for electronics/e-commerce NER
#     # Suggestion, search the huggingface model hub for NER models.
#     # Example: https://huggingface.co/models?pipeline_tag=ner&sort=downloads

# ]

# Load the pipelines
models = []
for model_name in model_names:
    try:
        ner_pipeline = pipeline("ner", model=model_name, aggregation_strategy="simple")
        models.append(ner_pipeline)
        print(f"Model {model_name} loaded successfully.")
    except Exception as e:
        print(f"Error loading model {model_name}: {e}")


def predict_entities_with_ensemble(query, models, labels, threshold=0.4):
    """
    Predicts entities using an ensemble of models.

    Args:
        query (str): The input query.
        models (list): A list of loaded NER models (pipelines).
        labels (dict): The mapping of labels to IDs.
        threshold (float): Confidence threshold for entity extraction.

    Returns:
        list: A list of extracted entities (dictionaries).
    """
    all_entities = []
    for model in models:
        try:
            model_entities = model(query)  # Get predictions from the model
            all_entities.extend(model_entities)
        except Exception as e:
            print(f"Error during prediction with model {model}: {e}")
            continue #Go to next model

    # Aggregate entities (very basic example - improve this based on your needs)
    #  Here, we just take all the entities from all models.  More sophisticated
    # aggregation could involve confidence scores, majority voting, etc.
    extracted_entities = []
    for entity in all_entities:
        # Check if 'confidence_score' exists in the entity dictionary
        if 'confidence_score' in entity and entity['confidence_score'] >= threshold:
            extracted_entities.append({
                "text": query[entity['start']:entity['end']], #Extract the text
                "label": entity['entity_group'].lower()  #Lowercase
            })
        else:
            # If 'confidence_score' doesn't exist, add the entity without thresholding.
            #  Consider if this is the right behavior for all models.
            extracted_entities.append({
                "text": query[entity['start']:entity['end']],  # Extract the text
                "label": entity['entity_group'].lower()  # Lowercase
            })

    return extracted_entities

data = []

for query in queries:
    extracted_entities = predict_entities_with_ensemble(query, models, labels, threshold=0.4)
    formatted_entities = [(entity["text"], entity["label"]) for entity in extracted_entities]  # Store as tuples
    data.append({"query": query, "extracted entities": formatted_entities})

df = pd.DataFrame(data)
df.to_csv("extracted_entities.csv", index=False)

print("Dataframe created and saved to extracted_entities.csv")
# Out:
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# Model dslim/bert-base-NER loaded successfully.
# ...

# %% [markdown]
# #Gliner Modern bert

# %%
pip install gliner -U

# %%
pip install git+https://github.com/huggingface/transformers.git
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-782abdc3
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-782abdc3
#   Resolved https://github.com/huggingface/transformers.git to commit 92c5ca9dd70de3ade2af2eb835c96215cc50e815
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for transformers: filename=transformers-4.50.0.dev0-py3-none-any.whl size=10849200 sha256=53fbeac828496d886e45f340cb1fbe952d2d1dd55b2a385ab2768b76f9bf5b47
#   Stored in directory: /tmp/pip-ephem-wheel-cache-5fdto5mi/wheels/32/4b/78/f195c684dd3a9ed21f3b39fe8f85b48df7918581b6437be143
# Successfully built transformers
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
# ...

# %%
from gliner import GLiNER

model = GLiNER.from_pretrained("knowledgator/modern-gliner-bi-large-v1.0")

text = """
Cristiano Ronaldo dos Santos Aveiro (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu]; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won five Ballon d'Or awards,[note 3] a record three UEFA Men's Player of the Year Awards, and four European Golden Shoes, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, goals in the European Championship (14), international goals (128) and international appearances (205). He is one of the few players to have made over 1,200 professional career appearances, the most by an outfield player, and has scored over 850 official senior career goals for club and country, making him the top goalscorer of all time.
"""

labels = ["person", "award", "date", "competitions", "teams"]

entities = model.predict_entities(text, labels, threshold=0.3)

for entity in entities:
    print(entity["text"], "=>", entity["label"])
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# pytorch_model.bin:   3%|3         | 73.4M/2.12G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Cristiano Ronaldo dos Santos Aveiro => person
# 5 February 1985 => date
# Ballon d'Or => award
# UEFA Men's Player of the Year Awards => award
# European Golden Shoes => award
# UEFA Nations League => competitions

# %%
import pandas as pd
# Assuming you have a 'model' object with a 'predict_entities' method
# This needs to be an actual model instance in your code.
# Example:
# from your_model_library import YourModelClass
# model = YourModelClass()
#Replace the above lines with your actual model.

queries = [
    "What's the newest Samsung phone with a long-lasting battery?",
    "Find Samsung TVs with HDMI 2.1 for gaming.",
    "Show me the latest Samsung Galaxy Watch models.",
    "Compare Samsung Galaxy S23 and S24 features.",
    "Which Samsung tablets are best for drawing?",
    "What are the best Samsung refrigerators with a water dispenser?",
    "Find a Samsung soundbar that's compatible with my Samsung TV.",
    "Does the Samsung Galaxy A54 have 5G?",
    "How much does the Samsung Galaxy Z Fold 5 cost?",
    "Show me Samsung monitors with a high refresh rate.",
    "Find Samsung washing machines with a steam cycle.",
    "What are the best Samsung dryers with a sensor dry feature?",
    "Recommend a Samsung vacuum cleaner for pet hair.",
    "What are the latest Samsung microwave ovens?",
    "Find Samsung dishwashers with a sanitize cycle.",
    "Show me Samsung air conditioners with smart cooling.",
    "What is the battery life of the Samsung Galaxy Buds Pro 2?",
    "Find Samsung laptops with a dedicated graphics card.",
    "What are the best Samsung Chromebooks for students?",
    "Show me Samsung smart home devices.",
    "What is the warranty on Samsung phones?",
    "Find Samsung phone cases for the Galaxy S23.",
    "Show me Samsung chargers and adapters.",
    "What are the best Samsung memory cards for my phone?",
    "Find Samsung screen protectors for my tablet.",
    "Show me Samsung Galaxy Book laptops.",
    "What are the differences between Samsung QLED and OLED TVs?",
    "Find Samsung TVs with ambient mode.",
    "Show me Samsung home theater systems.",
    "What is the price of the Samsung Galaxy Tab S8 Ultra?",
    "Find Samsung smartwatches with GPS.",
    "Show me Samsung fitness trackers.",
    "What are the best Samsung phone cameras?",
    "Find Samsung phones with expandable storage.",
    "Show me Samsung phones with a headphone jack.",
    "What are the Samsung phones with the best battery life under $500?",
    "Find Samsung phones with wireless charging.",
    "Show me Samsung phones with water resistance.",
    "What are the best Samsung tablets for reading?",
    "Find Samsung tablets with a keyboard case.",
    "Show me Samsung tablets with a pen included.",
    "What is the display resolution of the Samsung Galaxy S23 Ultra?",
    "Find Samsung phones with a fast processor.",
    "Show me Samsung phones with a large screen.",
    "What are the best Samsung monitors for gaming?",
    "Find Samsung monitors with USB-C ports.",
    "Show me Samsung monitors with built-in speakers.",
    "What is the refresh rate of the Samsung Odyssey G9?",
    "Find Samsung refrigerators with a family hub.",
    "Show me Samsung refrigerators with a dual ice maker.",
    "What are the energy-efficient Samsung washing machines?",
    "Find Samsung washing machines with a quick wash cycle.",
    "Show me Samsung washing machines with a self-cleaning function.",
     "Find Samsung dryers with wrinkle prevent.",
    "Show me Samsung dryers with a sanitize cycle.",
    "What are the best Samsung vacuum cleaners for hardwood floors?",
    "Find Samsung vacuum cleaners with a HEPA filter.",
    "Show me Samsung vacuum cleaners with a bagless design.",
    "What are the features of the Samsung Bespoke Jet vacuum?",
    "Find Samsung dishwashers with a third rack.",
    "Show me Samsung dishwashers with a quiet operation.",
    "What are the best Samsung air conditioners for bedrooms?",
    "Find Samsung air conditioners with a sleep mode.",
    "Show me Samsung air conditioners with a smart humidity control.",
    "What is the range of the Samsung SmartTag?",
    "Find Samsung SmartThings compatible devices.",
    "Show me Samsung accessories for my Galaxy phone.",
    "What are the benefits of Samsung Care+?",
    "Find Samsung trade-in offers for old phones.",
    "Show me Samsung student discounts.",
    "What's the latest software update for my Samsung TV?",
    "Find Samsung support articles for my phone.",
    "Show me how to reset my Samsung tablet.",
    "What is Samsung Knox security?",
    "Find Samsung developer resources.",
    "Show me Samsung's sustainability initiatives.",
    "What are the environmental certifications for Samsung products?",
    "Find Samsung's accessibility features.",
    "Show me Samsung products designed for people with disabilities.",
     "Which Samsung tablets have S Pen support?",
    "Find Samsung smartwatches with sleep tracking.",
    "What are the health features on Samsung watches?",
    "Which Samsung phones have the best zoom capabilities?",
    "Find Samsung TVs with HDR10+ support.",
    "Show me Samsung monitors with curved screens.",
    "What's the processor in the latest Samsung Galaxy phone?",
    "Find Samsung phones with fast charging.",
    "What are the best Samsung appliances for a small apartment?",
    "Show me Samsung devices that work with Bixby.",
    "Find Samsung devices with facial recognition.",
    "What are the connectivity options on Samsung laptops?",
    "Show me Samsung accessories for my TV.",
    "What kind of warranty comes with a Samsung refrigerator?",
    "Show me Samsung's latest promotions.",
    "Find Samsung devices with a built-in stylus.",
    "What are the storage options for the Samsung Galaxy S24?",
    "Show me Samsung products that are on sale today.",
    "What is the return policy for Samsung products?",
    "Find Samsung devices that support Dex mode.",
    "Show me Samsung's guide to setting up my new TV.",
    "What are the benefits of creating a Samsung account?",
    "Find Samsung's product comparison tool.",
    "Show me Samsung user manuals.",
    "What is the price range of Samsung's 8K TVs?"
]

labels = {
    'brand': 0,
    'product category': 1,
    'product name': 2, # ADDED
    'storage': 3,
    'camera': 4,
    'display': 5,
    'feature': 6,
    'price': 7,
    'ram': 8,
    'accessory': 9, # ADDED
    'others': 10
}

data = []

for query in queries:
    entities = model.predict_entities(query, labels, threshold=0.4)
    extracted_entities = [(entity["text"], entity["label"]) for entity in entities]  # Store as tuples
    data.append({"query": query, "extracted entities": extracted_entities})

df = pd.DataFrame(data)
df.to_csv("extracted_entities.csv", index=False)

print("Dataframe created and saved to extracted_entities.csv")
# Out:
# Dataframe created and saved to extracted_entities.csv

# %%
df.head(10)
# Out:
#                                                query  \
# 0  What's the newest Samsung phone with a long-la...
# 1         Find Samsung TVs with HDMI 2.1 for gaming.
# 2    Show me the latest Samsung Galaxy Watch models.
# 3       Compare Samsung Galaxy S23 and S24 features.
# 4        Which Samsung tablets are best for drawing?
# 5  What are the best Samsung refrigerators with a...
# 6  Find a Samsung soundbar that's compatible with...
# 7               Does the Samsung Galaxy A54 have 5G?
# 8    How much does the Samsung Galaxy Z Fold 5 cost?
# 9  Show me Samsung monitors with a high refresh r...
#
#                                   extracted entities
# 0  [(Samsung, brand), (long-lasting battery, feat...
# 1            [(Samsung, brand), (HDMI 2.1, feature)]
# 2   [(Samsung, brand), (Galaxy Watch, product name)]
# 3            [(Samsung, brand), (S24, product name)]
# 4    [(Samsung, brand), (tablets, product category)]
# 5  [(Samsung, brand), (refrigerators, product cat...
# ...
