# %% [markdown]
# <a href="https://colab.research.google.com/github/navneetkrc/Colab_fastai/blob/master/Intel_Image_Classification3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Get latest version of fastai using pip.

# %%
# To determine which version you're using:
# !pip show tensorflow

# For the current version: 
# !pip install --upgrade tensorflow

# %%
# http://pytorch.org/
from os.path import exists
from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

# %% [markdown]
# We import all the necessary packages. We are going to work with the [fastai V1 library](http://www.fast.ai/2018/10/02/fastai-ai/) which sits on top of [Pytorch 1.0](https://hackernoon.com/pytorch-1-0-468332ba5163). The fastai library provides many useful functions that enable us to quickly and easily build neural networks and train our models.

# %%
# !pip install torch_nightly -f https://download.pytorch.org/whl/nightly/cu92/torch_nightly.html
# !pip install fastai
# !pip install torchtext==0.2.3
# !pip install Pillow==4.0.0
# !pip install PIL
# !pip install image
# Out:
# Installing collected packages: torch-nightly
# Successfully installed torch-nightly-1.0.0.dev20181206
# Collecting fastai
#   Downloading https://files.pythonhosted.org/packages/3e/4b/acc5d1c2ff0e7e7f2fad042aa75cd9b5e49e0c41fabf4115949850108cad/fastai-1.0.40-py3-none-any.whl (163kB)
#     100% |████████████████████████████████| 163kB 13.4MB/s
# Collecting bottleneck (from fastai)
#   Downloading https://files.pythonhosted.org/packages/05/ae/cedf5323f398ab4e4ff92d6c431a3e1c6a186f9b41ab3e8258dff786a290/Bottleneck-1.2.1.tar.gz (105kB)
#     100% |████████████████████████████████| 112kB 17.7MB/s
# Collecting torch>=1.0.0 (from fastai)
#   Downloading https://files.pythonhosted.org/packages/7e/60/66415660aa46b23b5e1b72bc762e816736ce8d7260213e22365af51e8f9c/torch-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (591.8MB)
#     100% |████████████████████████████████| 591.8MB 27kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x627e4000 @  0x7f93dcdec2a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# Requirement already satisfied: numpy>=1.12 in /usr/local/lib/python3.6/dist-packages (from fastai) (1.14.6)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.6/dist-packages (from fastai) (2.6.9)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from fastai) (18.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from fastai) (2.18.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from fastai) (1.1.0)
# Collecting nvidia-ml-py3 (from fastai)
#   Downloading https://files.pythonhosted.org/packages/6d/64/cce82bddb80c0b0f5c703bbdafa94bfb69a1c5ad7a79cff00b482468f0d3/nvidia-ml-py3-7.352.0.tar.gz
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from fastai) (3.13)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from fastai) (4.6.3)
# Requirement already satisfied: spacy>=2.0.18 in /usr/local/lib/python3.6/dist-packages (from fastai) (2.0.18)
# Collecting torchvision (from fastai)
#   Downloading https://files.pythonhosted.org/packages/ca/0d/f00b2885711e08bd71242ebe7b96561e6f6d01fdb4b9dcf4d37e2e13c5e1/torchvision-0.2.1-py2.py3-none-any.whl (54kB)
#     100% |████████████████████████████████| 61kB 20.5MB/s
# Collecting typing (from fastai)
#   Downloading https://files.pythonhosted.org/packages/4a/bd/eee1157fc2d8514970b345d69cb9975dcd1e42cd7e61146ed841f6e68309/typing-3.6.6-py3-none-any.whl
# Collecting fastprogress>=0.1.18 (from fastai)
#   Downloading https://files.pythonhosted.org/packages/78/57/24a5e20f4a357f7f1c90dd5250071951c832b2480fd4fefd7be48edf4180/fastprogress-0.1.18-py3-none-any.whl
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from fastai) (0.22.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.6/dist-packages (from fastai) (3.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.6/dist-packages (from fastai) (4.0.0)
# Collecting dataclasses; python_version < "3.7" (from fastai)
#   Downloading https://files.pythonhosted.org/packages/26/2f/1095cdc2868052dd1e64520f7c0d5c8c550ad297e944e641dbf1ffbb9a5d/dataclasses-0.6-py3-none-any.whl
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->fastai) (2.3.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->fastai) (1.11.0)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (2018.11.29)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->fastai) (3.0.4)
# Requirement already satisfied: dill<0.3,>=0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (0.2.8.2)
# Requirement already satisfied: thinc<6.13.0,>=6.12.1 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (6.12.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2.0.2)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2.0.1)
# Requirement already satisfied: ujson>=1.35 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (1.35)
# Requirement already satisfied: regex==2018.01.10 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (2018.1.10)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.0.18->fastai) (1.0.1)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas->fastai) (2018.9)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas->fastai) (2.5.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->fastai) (1.0.1)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow->fastai) (0.46)
# Requirement already satisfied: msgpack<0.6.0,>=0.5.6 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.5.6)
# Requirement already satisfied: msgpack-numpy<0.4.4 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.4.3.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (4.28.1)
# Collecting wrapt<1.11.0,>=1.10.0 (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai)
#   Downloading https://files.pythonhosted.org/packages/a0/47/66897906448185fcb77fc3c2b1bc20ed0ecca81a0f2f88eda3fc5a34fc3d/wrapt-1.10.11.tar.gz
# Requirement already satisfied: cytoolz<0.10,>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.9.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib->fastai) (40.6.3)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.6/dist-packages (from cytoolz<0.10,>=0.9.0->thinc<6.13.0,>=6.12.1->spacy>=2.0.18->fastai) (0.9.0)
# Building wheels for collected packages: bottleneck, nvidia-ml-py3, wrapt
# done
#   Stored in directory: /root/.cache/pip/wheels/f2/bf/ec/e0f39aa27001525ad455139ee57ec7d0776fe074dfd78c97e4
# done
#   Stored in directory: /root/.cache/pip/wheels/e4/1d/06/640c93f5270d67d0247f30be91f232700d19023f9e66d735c7
# done
#   Stored in directory: /root/.cache/pip/wheels/48/5d/04/22361a593e70d23b1f7746d932802efe1f0e523376a74f321e
# Successfully built bottleneck nvidia-ml-py3 wrapt
# spacy 2.0.18 has requirement numpy>=1.15.0, but you'll have numpy 1.14.6 which is incompatible.
# torchvision 0.2.1 has requirement pillow>=4.1.1, but you'll have pillow 4.0.0 which is incompatible.
# Installing collected packages: bottleneck, torch, nvidia-ml-py3, torchvision, typing, fastprogress, dataclasses, fastai, wrapt
#   Found existing installation: wrapt 1.11.0
#     Uninstalling wrapt-1.11.0:
#       Successfully uninstalled wrapt-1.11.0
# Successfully installed bottleneck-1.2.1 dataclasses-0.6 fastai-1.0.40 fastprogress-0.1.18 nvidia-ml-py3-7.352.0 torch-1.0.0 torchvision-0.2.1 typing-3.6.6 wrapt-1.10.11
# WARNING: The following packages were previously imported in this runtime:
#   [typing]
# You must restart the runtime in order to use newly installed versions.
# Collecting torchtext==0.2.3
#   Downloading https://files.pythonhosted.org/packages/78/90/474d5944d43001a6e72b9aaed5c3e4f77516fbef2317002da2096fd8b5ea/torchtext-0.2.3.tar.gz (42kB)
#     100% |████████████████████████████████| 51kB 4.9MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (4.28.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from torchtext==0.2.3) (2.18.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2018.11.29)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (1.22)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->torchtext==0.2.3) (2.6)
# Building wheels for collected packages: torchtext
# done
#   Stored in directory: /root/.cache/pip/wheels/42/a6/f4/b267328bde6bb680094a0c173e8e5627ccc99543abded97204
# Successfully built torchtext
# Installing collected packages: torchtext
# Successfully installed torchtext-0.2.3
# Requirement already satisfied: Pillow==4.0.0 in /usr/local/lib/python3.6/dist-packages (4.0.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from Pillow==4.0.0) (0.46)
# Collecting PIL
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# Requirement already satisfied: image in /usr/local/lib/python3.6/dist-packages (1.5.27)
# Requirement already satisfied: django in /usr/local/lib/python3.6/dist-packages (from image) (2.1.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from image) (4.0.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from django->image) (2018.9)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow->image) (0.46)

# %%
import torch
print(torch.__version__)
# Out:
# 1.0.0

# %%
from fastai import *
from fastai.vision import *
import pandas as pd

# %% [markdown]
# If you're using a computer with an unusually small GPU, you may get an out of memory error when running this notebook. If this happens, click Kernel->Restart, uncomment the 2nd line below to use a smaller *batch size* (you'll learn all about what this means during the course), and try again.

# %%
bs = 64
#bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# #  Intel Scene Classification Image Dataset

# %% [markdown]
# ## Looking at the data

# %% [markdown]
# ###Getting Dataset from Kaggle

# %%
# !pip install -U -q kaggle
# !mkdir -p ~/.kaggle
# !echo '{"username":"navneetkrch","key":"4910f3543e9486158ccfa00ca84b274f"}'> ~/.kaggle/kaggle.json  # Replace
# !chmod 600 kaggle.json
# Out:
# chmod: cannot access 'kaggle.json': No such file or directory

# %%
# !mkdir -p data
# !mkdir -p data/test
# !kaggle datasets download -d nitishabharathi/scene-classification
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Downloading scene-classification.zip to /content
#  99% 353M/358M [00:08<00:00, 23.2MB/s]
# 100% 358M/358M [00:08<00:00, 42.9MB/s]

# %%
# !unzip scene-classification.zip
# Out:
# Archive:  scene-classification.zip
#   inflating: test_WyRytb0.csv
#   inflating: train-scene classification.zip

# %%
# !unzip train-scene\ classification.zip -d data/
# !mv test_WyRytb0.csv data/test.csv
# !mv data/train.csv data/train/labels.csv
# Out:
# Archive:  train-scene classification.zip
#    creating: data/train/
#   inflating: data/train.csv
#   inflating: data/train/0.jpg
#   inflating: data/train/1.jpg
#   inflating: data/train/10.jpg
#   inflating: data/train/100.jpg
#   inflating: data/train/1000.jpg
#   inflating: data/train/10000.jpg
#   inflating: data/train/10001.jpg
#   inflating: data/train/10002.jpg
#   inflating: data/train/10003.jpg
#   inflating: data/train/10004.jpg
#   inflating: data/train/10005.jpg
#   inflating: data/train/10006.jpg
#   inflating: data/train/10007.jpg
#   inflating: data/train/10008.jpg
#   inflating: data/train/10009.jpg
#   inflating: data/train/1001.jpg
#   inflating: data/train/10010.jpg
#   inflating: data/train/10011.jpg
#   inflating: data/train/10012.jpg
#   inflating: data/train/10013.jpg
#   inflating: data/train/10014.jpg
#   inflating: data/train/10015.jpg
#   inflating: data/train/10016.jpg
#   inflating: data/train/10017.jpg
#   inflating: data/train/10018.jpg
#   inflating: data/train/10019.jpg
#   inflating: data/train/1002.jpg
#   inflating: data/train/10020.jpg
#   inflating: data/train/10021.jpg
#   inflating: data/train/10022.jpg
#   inflating: data/train/10023.jpg
#   inflating: data/train/10024.jpg
#   inflating: data/train/10025.jpg
#   inflating: data/train/10026.jpg
#   inflating: data/train/10027.jpg
#   inflating: data/train/10028.jpg
#   inflating: data/train/10029.jpg
#   inflating: data/train/1003.jpg
#   inflating: data/train/10030.jpg
#   inflating: data/train/10031.jpg
#   inflating: data/train/10032.jpg
#   inflating: data/train/10033.jpg
#   inflating: data/train/10034.jpg
#   inflating: data/train/10035.jpg
#   inflating: data/train/10036.jpg
#   inflating: data/train/10037.jpg
#   inflating: data/train/10038.jpg
#   inflating: data/train/10039.jpg
#   inflating: data/train/1004.jpg
#   inflating: data/train/10040.jpg
#   inflating: data/train/10041.jpg
#   inflating: data/train/10042.jpg
#   inflating: data/train/10043.jpg
#   inflating: data/train/10044.jpg
#   inflating: data/train/10045.jpg
#   inflating: data/train/10046.jpg
#   inflating: data/train/10047.jpg
#   inflating: data/train/10048.jpg
#   inflating: data/train/10049.jpg
#   inflating: data/train/1005.jpg
#   inflating: data/train/10050.jpg
#   inflating: data/train/10051.jpg
#   inflating: data/train/10052.jpg
#   inflating: data/train/10053.jpg
#   inflating: data/train/10054.jpg
#   inflating: data/train/10055.jpg
#   inflating: data/train/10056.jpg
#   inflating: data/train/10057.jpg
#   inflating: data/train/10058.jpg
#   inflating: data/train/10059.jpg
#   inflating: data/train/1006.jpg
#   inflating: data/train/10060.jpg
#   inflating: data/train/10061.jpg
#   inflating: data/train/10062.jpg
#   inflating: data/train/10063.jpg
#   inflating: data/train/10064.jpg
#   inflating: data/train/10065.jpg
#   inflating: data/train/10066.jpg
#   inflating: data/train/10067.jpg
#   inflating: data/train/10068.jpg
#   inflating: data/train/10069.jpg
#   inflating: data/train/1007.jpg
#   inflating: data/train/10070.jpg
#   inflating: data/train/10071.jpg
#   inflating: data/train/10072.jpg
#   inflating: data/train/10073.jpg
#   inflating: data/train/10074.jpg
#   inflating: data/train/10075.jpg
#   inflating: data/train/10076.jpg
#   inflating: data/train/10077.jpg
#   inflating: data/train/10078.jpg
#   inflating: data/train/10079.jpg
#   inflating: data/train/1008.jpg
#   inflating: data/train/10080.jpg
#   inflating: data/train/10081.jpg
#   inflating: data/train/10082.jpg
#   inflating: data/train/10083.jpg
#   inflating: data/train/10084.jpg
#   inflating: data/train/10085.jpg
#   inflating: data/train/10086.jpg
#   inflating: data/train/10087.jpg
#   inflating: data/train/10088.jpg
#   inflating: data/train/10089.jpg
#   inflating: data/train/1009.jpg
#   inflating: data/train/10090.jpg
#   inflating: data/train/10091.jpg
#   inflating: data/train/10092.jpg
#   inflating: data/train/10093.jpg
#   inflating: data/train/10094.jpg
#   inflating: data/train/10095.jpg
#   inflating: data/train/10096.jpg
#   inflating: data/train/10097.jpg
#   inflating: data/train/10098.jpg
#   inflating: data/train/10099.jpg
#   inflating: data/train/101.jpg
#   inflating: data/train/1010.jpg
#   inflating: data/train/10100.jpg
#   inflating: data/train/10101.jpg
#   inflating: data/train/10102.jpg
#   inflating: data/train/10103.jpg
#   inflating: data/train/10104.jpg
#   inflating: data/train/10105.jpg
#   inflating: data/train/10106.jpg
#   inflating: data/train/10107.jpg
#   inflating: data/train/10108.jpg
#   inflating: data/train/10109.jpg
#   inflating: data/train/1011.jpg
#   inflating: data/train/10110.jpg
#   inflating: data/train/10111.jpg
#   inflating: data/train/10112.jpg
#   inflating: data/train/10113.jpg
#   inflating: data/train/10114.jpg
#   inflating: data/train/10115.jpg
#   inflating: data/train/10116.jpg
#   inflating: data/train/10117.jpg
#   inflating: data/train/10118.jpg
#   inflating: data/train/10119.jpg
#   inflating: data/train/1012.jpg
#   inflating: data/train/10120.jpg
#   inflating: data/train/10121.jpg
#   inflating: data/train/10122.jpg
#   inflating: data/train/10123.jpg
#   inflating: data/train/10124.jpg
#   inflating: data/train/10125.jpg
#   inflating: data/train/10126.jpg
#   inflating: data/train/10127.jpg
#   inflating: data/train/10128.jpg
#   inflating: data/train/10129.jpg
#   inflating: data/train/1013.jpg
#   inflating: data/train/10130.jpg
#   inflating: data/train/10131.jpg
#   inflating: data/train/10132.jpg
#   inflating: data/train/10133.jpg
#   inflating: data/train/10134.jpg
#   inflating: data/train/10135.jpg
#   inflating: data/train/10136.jpg
#   inflating: data/train/10137.jpg
#   inflating: data/train/10138.jpg
#   inflating: data/train/10139.jpg
#   inflating: data/train/1014.jpg
#   inflating: data/train/10140.jpg
#   inflating: data/train/10141.jpg
#   inflating: data/train/10142.jpg
#   inflating: data/train/10143.jpg
#   inflating: data/train/10144.jpg
#   inflating: data/train/10145.jpg
#   inflating: data/train/10146.jpg
#   inflating: data/train/10147.jpg
#   inflating: data/train/10148.jpg
#   inflating: data/train/10149.jpg
#   inflating: data/train/1015.jpg
#   inflating: data/train/10150.jpg
#   inflating: data/train/10151.jpg
#   inflating: data/train/10152.jpg
#   inflating: data/train/10153.jpg
#   inflating: data/train/10154.jpg
#   inflating: data/train/10155.jpg
#   inflating: data/train/10156.jpg
#   inflating: data/train/10157.jpg
#   inflating: data/train/10158.jpg
#   inflating: data/train/10159.jpg
#   inflating: data/train/1016.jpg
#   inflating: data/train/10160.jpg
#   inflating: data/train/10161.jpg
#   inflating: data/train/10162.jpg
#   inflating: data/train/10163.jpg
#   inflating: data/train/10164.jpg
#   inflating: data/train/10165.jpg
#   inflating: data/train/10166.jpg
#   inflating: data/train/10167.jpg
#   inflating: data/train/10168.jpg
#   inflating: data/train/10169.jpg
#   inflating: data/train/1017.jpg
#   inflating: data/train/10170.jpg
#   inflating: data/train/10171.jpg
#   inflating: data/train/10172.jpg
#   inflating: data/train/10173.jpg
#   inflating: data/train/10174.jpg
#   inflating: data/train/10175.jpg
#   inflating: data/train/10176.jpg
#   inflating: data/train/10177.jpg
#   inflating: data/train/10178.jpg
#   inflating: data/train/10179.jpg
#   inflating: data/train/1018.jpg
#   inflating: data/train/10180.jpg
#   inflating: data/train/10181.jpg
#   inflating: data/train/10182.jpg
#   inflating: data/train/10183.jpg
#   inflating: data/train/10184.jpg
#   inflating: data/train/10185.jpg
#   inflating: data/train/10186.jpg
#   inflating: data/train/10187.jpg
#   inflating: data/train/10188.jpg
#   inflating: data/train/10189.jpg
#   inflating: data/train/1019.jpg
#   inflating: data/train/10190.jpg
#   inflating: data/train/10191.jpg
#   inflating: data/train/10192.jpg
#   inflating: data/train/10193.jpg
#   inflating: data/train/10194.jpg
#   inflating: data/train/10195.jpg
#   inflating: data/train/10196.jpg
#   inflating: data/train/10197.jpg
#   inflating: data/train/10198.jpg
#   inflating: data/train/10199.jpg
#   inflating: data/train/102.jpg
#   inflating: data/train/1020.jpg
#   inflating: data/train/10200.jpg
#   inflating: data/train/10201.jpg
#   inflating: data/train/10202.jpg
#   inflating: data/train/10203.jpg
#   inflating: data/train/10204.jpg
#   inflating: data/train/10205.jpg
#   inflating: data/train/10206.jpg
#   inflating: data/train/10207.jpg
#   inflating: data/train/10208.jpg
#   inflating: data/train/10209.jpg
#   inflating: data/train/1021.jpg
#   inflating: data/train/10210.jpg
#   inflating: data/train/10211.jpg
#   inflating: data/train/10212.jpg
#   inflating: data/train/10213.jpg
#   inflating: data/train/10214.jpg
#   inflating: data/train/10215.jpg
#   inflating: data/train/10216.jpg
#   inflating: data/train/10217.jpg
#   inflating: data/train/10218.jpg
#   inflating: data/train/10219.jpg
#   inflating: data/train/1022.jpg
#   inflating: data/train/10220.jpg
#   inflating: data/train/10221.jpg
#   inflating: data/train/10222.jpg
#   inflating: data/train/10223.jpg
#   inflating: data/train/10224.jpg
#   inflating: data/train/10225.jpg
#   inflating: data/train/10226.jpg
#   inflating: data/train/10227.jpg
#   inflating: data/train/10228.jpg
#   inflating: data/train/10229.jpg
#   inflating: data/train/1023.jpg
#   inflating: data/train/10230.jpg
#   inflating: data/train/10231.jpg
#   inflating: data/train/10232.jpg
#   inflating: data/train/10233.jpg
#   inflating: data/train/10234.jpg
#   inflating: data/train/10235.jpg
#   inflating: data/train/10236.jpg
#   inflating: data/train/10237.jpg
#   inflating: data/train/10238.jpg
#   inflating: data/train/10239.jpg
#   inflating: data/train/1024.jpg
#   inflating: data/train/10240.jpg
#   inflating: data/train/10241.jpg
#   inflating: data/train/10242.jpg
#   inflating: data/train/10243.jpg
#   inflating: data/train/10244.jpg
#   inflating: data/train/10245.jpg
#   inflating: data/train/10246.jpg
#   inflating: data/train/10247.jpg
#   inflating: data/train/10248.jpg
#   inflating: data/train/10249.jpg
#   inflating: data/train/1025.jpg
#   inflating: data/train/10250.jpg
#   inflating: data/train/10251.jpg
#   inflating: data/train/10252.jpg
#   inflating: data/train/10253.jpg
#   inflating: data/train/10254.jpg
#   inflating: data/train/10255.jpg
#   inflating: data/train/10256.jpg
#   inflating: data/train/10257.jpg
#   inflating: data/train/10258.jpg
#   inflating: data/train/10259.jpg
#   inflating: data/train/1026.jpg
#   inflating: data/train/10260.jpg
#   inflating: data/train/10261.jpg
#   inflating: data/train/10262.jpg
#   inflating: data/train/10263.jpg
#   inflating: data/train/10264.jpg
#   inflating: data/train/10265.jpg
#   inflating: data/train/10266.jpg
#   inflating: data/train/10267.jpg
#   inflating: data/train/10268.jpg
#   inflating: data/train/10269.jpg
#   inflating: data/train/1027.jpg
#   inflating: data/train/10270.jpg
#   inflating: data/train/10271.jpg
#   inflating: data/train/10272.jpg
#   inflating: data/train/10273.jpg
#   inflating: data/train/10274.jpg
#   inflating: data/train/10275.jpg
#   inflating: data/train/10276.jpg
#   inflating: data/train/10277.jpg
#   inflating: data/train/10278.jpg
#   inflating: data/train/10279.jpg
#   inflating: data/train/1028.jpg
#   inflating: data/train/10280.jpg
#   inflating: data/train/10281.jpg
#   inflating: data/train/10282.jpg
#   inflating: data/train/10283.jpg
#   inflating: data/train/10284.jpg
#   inflating: data/train/10285.jpg
#   inflating: data/train/10286.jpg
#   inflating: data/train/10287.jpg
#   inflating: data/train/10288.jpg
#   inflating: data/train/10289.jpg
#   inflating: data/train/1029.jpg
#   inflating: data/train/10290.jpg
#   inflating: data/train/10291.jpg
#   inflating: data/train/10292.jpg
#   inflating: data/train/10293.jpg
#   inflating: data/train/10294.jpg
#   inflating: data/train/10295.jpg
#   inflating: data/train/10296.jpg
#   inflating: data/train/10297.jpg
#   inflating: data/train/10298.jpg
#   inflating: data/train/10299.jpg
#   inflating: data/train/103.jpg
#   inflating: data/train/1030.jpg
#   inflating: data/train/10300.jpg
#   inflating: data/train/10301.jpg
#   inflating: data/train/10302.jpg
#   inflating: data/train/10303.jpg
#   inflating: data/train/10304.jpg
#   inflating: data/train/10305.jpg
#   inflating: data/train/10306.jpg
#   inflating: data/train/10307.jpg
#   inflating: data/train/10308.jpg
#   inflating: data/train/10309.jpg
#   inflating: data/train/1031.jpg
#   inflating: data/train/10310.jpg
#   inflating: data/train/10311.jpg
#   inflating: data/train/10312.jpg
#   inflating: data/train/10313.jpg
#   inflating: data/train/10314.jpg
#   inflating: data/train/10315.jpg
#   inflating: data/train/10316.jpg
#   inflating: data/train/10317.jpg
#   inflating: data/train/10318.jpg
#   inflating: data/train/10319.jpg
#   inflating: data/train/1032.jpg
#   inflating: data/train/10320.jpg
#   inflating: data/train/10321.jpg
#   inflating: data/train/10322.jpg
#   inflating: data/train/10323.jpg
#   inflating: data/train/10324.jpg
#   inflating: data/train/10325.jpg
#   inflating: data/train/10326.jpg
#   inflating: data/train/10327.jpg
#   inflating: data/train/10328.jpg
#   inflating: data/train/10329.jpg
#   inflating: data/train/1033.jpg
#   inflating: data/train/10330.jpg
#   inflating: data/train/10331.jpg
#   inflating: data/train/10332.jpg
#   inflating: data/train/10333.jpg
#   inflating: data/train/10334.jpg
#   inflating: data/train/10335.jpg
#   inflating: data/train/10336.jpg
#   inflating: data/train/10337.jpg
#   inflating: data/train/10338.jpg
#   inflating: data/train/10339.jpg
#   inflating: data/train/1034.jpg
#   inflating: data/train/10340.jpg
#   inflating: data/train/10341.jpg
#   inflating: data/train/10342.jpg
#   inflating: data/train/10343.jpg
#   inflating: data/train/10344.jpg
#   inflating: data/train/10345.jpg
#   inflating: data/train/10346.jpg
#   inflating: data/train/10347.jpg
#   inflating: data/train/10348.jpg
#   inflating: data/train/10349.jpg
#   inflating: data/train/1035.jpg
#   inflating: data/train/10350.jpg
#   inflating: data/train/10351.jpg
#   inflating: data/train/10352.jpg
#   inflating: data/train/10353.jpg
#   inflating: data/train/10354.jpg
#   inflating: data/train/10355.jpg
#   inflating: data/train/10356.jpg
#   inflating: data/train/10357.jpg
#   inflating: data/train/10358.jpg
#   inflating: data/train/10359.jpg
#   inflating: data/train/1036.jpg
#   inflating: data/train/10360.jpg
#   inflating: data/train/10361.jpg
#   inflating: data/train/10362.jpg
#   inflating: data/train/10363.jpg
#   inflating: data/train/10364.jpg
#   inflating: data/train/10365.jpg
#   inflating: data/train/10366.jpg
#   inflating: data/train/10367.jpg
#   inflating: data/train/10368.jpg
#   inflating: data/train/10369.jpg
#   inflating: data/train/1037.jpg
#   inflating: data/train/10370.jpg
#   inflating: data/train/10371.jpg
#   inflating: data/train/10372.jpg
#   inflating: data/train/10373.jpg
#   inflating: data/train/10374.jpg
#   inflating: data/train/10375.jpg
#   inflating: data/train/10376.jpg
#   inflating: data/train/10377.jpg
#   inflating: data/train/10378.jpg
#   inflating: data/train/10379.jpg
#   inflating: data/train/1038.jpg
#   inflating: data/train/10380.jpg
#   inflating: data/train/10381.jpg
#   inflating: data/train/10382.jpg
#   inflating: data/train/10383.jpg
#   inflating: data/train/10384.jpg
#   inflating: data/train/10385.jpg
#   inflating: data/train/10386.jpg
#   inflating: data/train/10387.jpg
#   inflating: data/train/10388.jpg
#   inflating: data/train/10389.jpg
#   inflating: data/train/1039.jpg
#   inflating: data/train/10390.jpg
#   inflating: data/train/10391.jpg
#   inflating: data/train/10392.jpg
#   inflating: data/train/10393.jpg
#   inflating: data/train/10394.jpg
#   inflating: data/train/10395.jpg
#   inflating: data/train/10396.jpg
#   inflating: data/train/10397.jpg
#   inflating: data/train/10398.jpg
#   inflating: data/train/10399.jpg
#   inflating: data/train/104.jpg
#   inflating: data/train/1040.jpg
#   inflating: data/train/10400.jpg
#   inflating: data/train/10401.jpg
#   inflating: data/train/10402.jpg
#   inflating: data/train/10403.jpg
#   inflating: data/train/10404.jpg
#   inflating: data/train/10405.jpg
#   inflating: data/train/10406.jpg
#   inflating: data/train/10407.jpg
#   inflating: data/train/10408.jpg
#   inflating: data/train/10409.jpg
#   inflating: data/train/1041.jpg
#   inflating: data/train/10410.jpg
#   inflating: data/train/10411.jpg
#   inflating: data/train/10412.jpg
#   inflating: data/train/10413.jpg
#   inflating: data/train/10414.jpg
#   inflating: data/train/10415.jpg
#   inflating: data/train/10416.jpg
#   inflating: data/train/10417.jpg
#   inflating: data/train/10418.jpg
#   inflating: data/train/10419.jpg
#   inflating: data/train/1042.jpg
#   inflating: data/train/10420.jpg
#   inflating: data/train/10421.jpg
#   inflating: data/train/10422.jpg
#   inflating: data/train/10423.jpg
#   inflating: data/train/10424.jpg
#   inflating: data/train/10425.jpg
#   inflating: data/train/10426.jpg
#   inflating: data/train/10427.jpg
#   inflating: data/train/10428.jpg
#   inflating: data/train/10429.jpg
#   inflating: data/train/1043.jpg
#   inflating: data/train/10430.jpg
#   inflating: data/train/10431.jpg
#   inflating: data/train/10432.jpg
#   inflating: data/train/10433.jpg
#   inflating: data/train/10434.jpg
#   inflating: data/train/10435.jpg
#   inflating: data/train/10436.jpg
#   inflating: data/train/10437.jpg
#   inflating: data/train/10438.jpg
#   inflating: data/train/10439.jpg
#   inflating: data/train/1044.jpg
#   inflating: data/train/10440.jpg
#   inflating: data/train/10441.jpg
#   inflating: data/train/10442.jpg
#   inflating: data/train/10443.jpg
#   inflating: data/train/10444.jpg
#   inflating: data/train/10445.jpg
#   inflating: data/train/10446.jpg
#   inflating: data/train/10447.jpg
#   inflating: data/train/10448.jpg
#   inflating: data/train/10449.jpg
#   inflating: data/train/1045.jpg
#   inflating: data/train/10450.jpg
#   inflating: data/train/10451.jpg
#   inflating: data/train/10452.jpg
#   inflating: data/train/10453.jpg
#   inflating: data/train/10454.jpg
#   inflating: data/train/10455.jpg
#   inflating: data/train/10456.jpg
#   inflating: data/train/10457.jpg
#   inflating: data/train/10458.jpg
#   inflating: data/train/10459.jpg
#   inflating: data/train/1046.jpg
#   inflating: data/train/10460.jpg
#   inflating: data/train/10461.jpg
#   inflating: data/train/10462.jpg
#   inflating: data/train/10463.jpg
#   inflating: data/train/10464.jpg
#   inflating: data/train/10465.jpg
#   inflating: data/train/10466.jpg
#   inflating: data/train/10467.jpg
#   inflating: data/train/10468.jpg
#   inflating: data/train/10469.jpg
#   inflating: data/train/1047.jpg
#   inflating: data/train/10470.jpg
#   inflating: data/train/10471.jpg
#   inflating: data/train/10472.jpg
#   inflating: data/train/10473.jpg
#   inflating: data/train/10474.jpg
#   inflating: data/train/10475.jpg
#   inflating: data/train/10476.jpg
#   inflating: data/train/10477.jpg
#   inflating: data/train/10478.jpg
#   inflating: data/train/10479.jpg
#   inflating: data/train/1048.jpg
#   inflating: data/train/10480.jpg
#   inflating: data/train/10481.jpg
#   inflating: data/train/10482.jpg
#   inflating: data/train/10483.jpg
#   inflating: data/train/10484.jpg
#   inflating: data/train/10485.jpg
#   inflating: data/train/10486.jpg
#   inflating: data/train/10487.jpg
#   inflating: data/train/10488.jpg
#   inflating: data/train/10489.jpg
#   inflating: data/train/1049.jpg
#   inflating: data/train/10490.jpg
#   inflating: data/train/10491.jpg
#   inflating: data/train/10492.jpg
#   inflating: data/train/10493.jpg
#   inflating: data/train/10494.jpg
#   inflating: data/train/10495.jpg
#   inflating: data/train/10496.jpg
#   inflating: data/train/10497.jpg
#   inflating: data/train/10498.jpg
#   inflating: data/train/10499.jpg
#   inflating: data/train/105.jpg
#   inflating: data/train/1050.jpg
#   inflating: data/train/10500.jpg
#   inflating: data/train/10501.jpg
#   inflating: data/train/10502.jpg
#   inflating: data/train/10503.jpg
#   inflating: data/train/10504.jpg
#   inflating: data/train/10505.jpg
#   inflating: data/train/10506.jpg
#   inflating: data/train/10507.jpg
#   inflating: data/train/10508.jpg
#   inflating: data/train/10509.jpg
#   inflating: data/train/1051.jpg
#   inflating: data/train/10510.jpg
#   inflating: data/train/10511.jpg
#   inflating: data/train/10512.jpg
#   inflating: data/train/10513.jpg
#   inflating: data/train/10514.jpg
#   inflating: data/train/10515.jpg
#   inflating: data/train/10516.jpg
#   inflating: data/train/10517.jpg
#   inflating: data/train/10518.jpg
#   inflating: data/train/10519.jpg
#   inflating: data/train/1052.jpg
#   inflating: data/train/10520.jpg
#   inflating: data/train/10521.jpg
#   inflating: data/train/10522.jpg
#   inflating: data/train/10523.jpg
#   inflating: data/train/10524.jpg
#   inflating: data/train/10525.jpg
#   inflating: data/train/10526.jpg
#   inflating: data/train/10527.jpg
#   inflating: data/train/10528.jpg
#   inflating: data/train/10529.jpg
#   inflating: data/train/1053.jpg
#   inflating: data/train/10530.jpg
#   inflating: data/train/10531.jpg
#   inflating: data/train/10532.jpg
#   inflating: data/train/10533.jpg
#   inflating: data/train/10534.jpg
#   inflating: data/train/10535.jpg
#   inflating: data/train/10536.jpg
#   inflating: data/train/10537.jpg
#   inflating: data/train/10538.jpg
#   inflating: data/train/10539.jpg
#   inflating: data/train/1054.jpg
#   inflating: data/train/10540.jpg
#   inflating: data/train/10541.jpg
#   inflating: data/train/10542.jpg
#   inflating: data/train/10543.jpg
#   inflating: data/train/10544.jpg
#   inflating: data/train/10545.jpg
#   inflating: data/train/10546.jpg
#   inflating: data/train/10547.jpg
#   inflating: data/train/10548.jpg
#   inflating: data/train/10549.jpg
#   inflating: data/train/1055.jpg
#   inflating: data/train/10550.jpg
#   inflating: data/train/10551.jpg
#   inflating: data/train/10552.jpg
#   inflating: data/train/10553.jpg
#   inflating: data/train/10554.jpg
#   inflating: data/train/10555.jpg
#   inflating: data/train/10556.jpg
#   inflating: data/train/10557.jpg
#   inflating: data/train/10558.jpg
#   inflating: data/train/10559.jpg
#   inflating: data/train/1056.jpg
#   inflating: data/train/10560.jpg
#   inflating: data/train/10561.jpg
#   inflating: data/train/10562.jpg
#   inflating: data/train/10563.jpg
#   inflating: data/train/10564.jpg
#   inflating: data/train/10565.jpg
#   inflating: data/train/10566.jpg
#   inflating: data/train/10567.jpg
#   inflating: data/train/10568.jpg
#   inflating: data/train/10569.jpg
#   inflating: data/train/1057.jpg
#   inflating: data/train/10570.jpg
#   inflating: data/train/10571.jpg
#   inflating: data/train/10572.jpg
#   inflating: data/train/10573.jpg
#   inflating: data/train/10574.jpg
#   inflating: data/train/10575.jpg
#   inflating: data/train/10576.jpg
#   inflating: data/train/10577.jpg
#   inflating: data/train/10578.jpg
#   inflating: data/train/10579.jpg
#   inflating: data/train/1058.jpg
#   inflating: data/train/10580.jpg
#   inflating: data/train/10581.jpg
#   inflating: data/train/10582.jpg
#   inflating: data/train/10583.jpg
#   inflating: data/train/10584.jpg
#   inflating: data/train/10585.jpg
#   inflating: data/train/10586.jpg
#   inflating: data/train/10587.jpg
#   inflating: data/train/10588.jpg
#   inflating: data/train/10589.jpg
#   inflating: data/train/1059.jpg
#   inflating: data/train/10590.jpg
#   inflating: data/train/10591.jpg
#   inflating: data/train/10592.jpg
#   inflating: data/train/10593.jpg
#   inflating: data/train/10594.jpg
#   inflating: data/train/10595.jpg
#   inflating: data/train/10596.jpg
#   inflating: data/train/10597.jpg
#   inflating: data/train/10598.jpg
#   inflating: data/train/10599.jpg
#   inflating: data/train/106.jpg
#   inflating: data/train/1060.jpg
#   inflating: data/train/10600.jpg
#   inflating: data/train/10601.jpg
#   inflating: data/train/10602.jpg
#   inflating: data/train/10603.jpg
#   inflating: data/train/10604.jpg
#   inflating: data/train/10605.jpg
#   inflating: data/train/10606.jpg
#   inflating: data/train/10607.jpg
#   inflating: data/train/10608.jpg
#   inflating: data/train/10609.jpg
#   inflating: data/train/1061.jpg
#   inflating: data/train/10610.jpg
#   inflating: data/train/10611.jpg
#   inflating: data/train/10612.jpg
#   inflating: data/train/10613.jpg
#   inflating: data/train/10614.jpg
#   inflating: data/train/10615.jpg
#   inflating: data/train/10616.jpg
#   inflating: data/train/10617.jpg
#   inflating: data/train/10618.jpg
#   inflating: data/train/10619.jpg
#   inflating: data/train/1062.jpg
#   inflating: data/train/10620.jpg
#   inflating: data/train/10621.jpg
#   inflating: data/train/10622.jpg
#   inflating: data/train/10623.jpg
#   inflating: data/train/10624.jpg
#   inflating: data/train/10625.jpg
#   inflating: data/train/10626.jpg
#   inflating: data/train/10627.jpg
#   inflating: data/train/10628.jpg
#   inflating: data/train/10629.jpg
#   inflating: data/train/1063.jpg
#   inflating: data/train/10630.jpg
#   inflating: data/train/10631.jpg
#   inflating: data/train/10632.jpg
#   inflating: data/train/10633.jpg
#   inflating: data/train/10634.jpg
#   inflating: data/train/10635.jpg
#   inflating: data/train/10636.jpg
#   inflating: data/train/10637.jpg
#   inflating: data/train/10638.jpg
#   inflating: data/train/10639.jpg
#   inflating: data/train/1064.jpg
#   inflating: data/train/10640.jpg
#   inflating: data/train/10641.jpg
#   inflating: data/train/10642.jpg
#   inflating: data/train/10643.jpg
#   inflating: data/train/10644.jpg
#   inflating: data/train/10645.jpg
#   inflating: data/train/10646.jpg
#   inflating: data/train/10647.jpg
#   inflating: data/train/10648.jpg
#   inflating: data/train/10649.jpg
#   inflating: data/train/1065.jpg
#   inflating: data/train/10650.jpg
#   inflating: data/train/10651.jpg
#   inflating: data/train/10652.jpg
#   inflating: data/train/10653.jpg
#   inflating: data/train/10654.jpg
#   inflating: data/train/10655.jpg
#   inflating: data/train/10656.jpg
#   inflating: data/train/10657.jpg
#   inflating: data/train/10658.jpg
#   inflating: data/train/10659.jpg
#   inflating: data/train/1066.jpg
#   inflating: data/train/10660.jpg
#   inflating: data/train/10661.jpg
#   inflating: data/train/10662.jpg
#   inflating: data/train/10663.jpg
#   inflating: data/train/10664.jpg
#   inflating: data/train/10665.jpg
#   inflating: data/train/10666.jpg
#   inflating: data/train/10667.jpg
#   inflating: data/train/10668.jpg
#   inflating: data/train/10669.jpg
#   inflating: data/train/1067.jpg
#   inflating: data/train/10670.jpg
#   inflating: data/train/10671.jpg
#   inflating: data/train/10672.jpg
#   inflating: data/train/10673.jpg
#   inflating: data/train/10674.jpg
#   inflating: data/train/10675.jpg
#   inflating: data/train/10676.jpg
#   inflating: data/train/10677.jpg
#   inflating: data/train/10678.jpg
#   inflating: data/train/10679.jpg
#   inflating: data/train/1068.jpg
#   inflating: data/train/10680.jpg
#   inflating: data/train/10681.jpg
#   inflating: data/train/10682.jpg
#   inflating: data/train/10683.jpg
#   inflating: data/train/10684.jpg
#   inflating: data/train/10685.jpg
#   inflating: data/train/10686.jpg
#   inflating: data/train/10687.jpg
#   inflating: data/train/10688.jpg
#   inflating: data/train/10689.jpg
#   inflating: data/train/1069.jpg
#   inflating: data/train/10690.jpg
#   inflating: data/train/10691.jpg
#   inflating: data/train/10692.jpg
#   inflating: data/train/10693.jpg
#   inflating: data/train/10694.jpg
#   inflating: data/train/10695.jpg
#   inflating: data/train/10696.jpg
#   inflating: data/train/10697.jpg
#   inflating: data/train/10698.jpg
#   inflating: data/train/10699.jpg
#   inflating: data/train/107.jpg
#   inflating: data/train/1070.jpg
#   inflating: data/train/10700.jpg
#   inflating: data/train/10701.jpg
#   inflating: data/train/10702.jpg
#   inflating: data/train/10703.jpg
#   inflating: data/train/10704.jpg
#   inflating: data/train/10705.jpg
#   inflating: data/train/10706.jpg
#   inflating: data/train/10707.jpg
#   inflating: data/train/10708.jpg
#   inflating: data/train/10709.jpg
#   inflating: data/train/1071.jpg
#   inflating: data/train/10710.jpg
#   inflating: data/train/10711.jpg
#   inflating: data/train/10712.jpg
#   inflating: data/train/10713.jpg
#   inflating: data/train/10714.jpg
#   inflating: data/train/10715.jpg
#   inflating: data/train/10716.jpg
#   inflating: data/train/10717.jpg
#   inflating: data/train/10718.jpg
#   inflating: data/train/10719.jpg
#   inflating: data/train/1072.jpg
#   inflating: data/train/10720.jpg
#   inflating: data/train/10721.jpg
#   inflating: data/train/10722.jpg
#   inflating: data/train/10723.jpg
#   inflating: data/train/10724.jpg
#   inflating: data/train/10725.jpg
#   inflating: data/train/10726.jpg
#   inflating: data/train/10727.jpg
#   inflating: data/train/10728.jpg
#   inflating: data/train/10729.jpg
#   inflating: data/train/1073.jpg
#   inflating: data/train/10730.jpg
#   inflating: data/train/10731.jpg
#   inflating: data/train/10732.jpg
#   inflating: data/train/10733.jpg
#   inflating: data/train/10734.jpg
#   inflating: data/train/10735.jpg
#   inflating: data/train/10736.jpg
#   inflating: data/train/10737.jpg
#   inflating: data/train/10738.jpg
#   inflating: data/train/10739.jpg
#   inflating: data/train/1074.jpg
#   inflating: data/train/10740.jpg
#   inflating: data/train/10741.jpg
#   inflating: data/train/10742.jpg
#   inflating: data/train/10743.jpg
#   inflating: data/train/10744.jpg
#   inflating: data/train/10745.jpg
#   inflating: data/train/10746.jpg
#   inflating: data/train/10747.jpg
#   inflating: data/train/10748.jpg
#   inflating: data/train/10749.jpg
#   inflating: data/train/1075.jpg
#   inflating: data/train/10750.jpg
#   inflating: data/train/10751.jpg
#   inflating: data/train/10752.jpg
#   inflating: data/train/10753.jpg
#   inflating: data/train/10754.jpg
#   inflating: data/train/10755.jpg
#   inflating: data/train/10756.jpg
#   inflating: data/train/10757.jpg
#   inflating: data/train/10758.jpg
#   inflating: data/train/10759.jpg
#   inflating: data/train/1076.jpg
#   inflating: data/train/10760.jpg
#   inflating: data/train/10761.jpg
#   inflating: data/train/10762.jpg
#   inflating: data/train/10763.jpg
#   inflating: data/train/10764.jpg
#   inflating: data/train/10765.jpg
#   inflating: data/train/10766.jpg
#   inflating: data/train/10767.jpg
#   inflating: data/train/10768.jpg
#   inflating: data/train/10769.jpg
#   inflating: data/train/1077.jpg
#   inflating: data/train/10770.jpg
#   inflating: data/train/10771.jpg
#   inflating: data/train/10772.jpg
#   inflating: data/train/10773.jpg
#   inflating: data/train/10774.jpg
#   inflating: data/train/10775.jpg
#   inflating: data/train/10776.jpg
#   inflating: data/train/10777.jpg
#   inflating: data/train/10778.jpg
#   inflating: data/train/10779.jpg
#   inflating: data/train/1078.jpg
#   inflating: data/train/10780.jpg
#   inflating: data/train/10781.jpg
#   inflating: data/train/10782.jpg
#   inflating: data/train/10783.jpg
#   inflating: data/train/10784.jpg
#   inflating: data/train/10785.jpg
#   inflating: data/train/10786.jpg
#   inflating: data/train/10787.jpg
#   inflating: data/train/10788.jpg
#   inflating: data/train/10789.jpg
#   inflating: data/train/1079.jpg
#   inflating: data/train/10790.jpg
#   inflating: data/train/10791.jpg
#   inflating: data/train/10792.jpg
#   inflating: data/train/10793.jpg
#   inflating: data/train/10794.jpg
#   inflating: data/train/10795.jpg
#   inflating: data/train/10796.jpg
#   inflating: data/train/10797.jpg
#   inflating: data/train/10798.jpg
#   inflating: data/train/10799.jpg
#   inflating: data/train/108.jpg
#   inflating: data/train/1080.jpg
#   inflating: data/train/10800.jpg
#   inflating: data/train/10801.jpg
#   inflating: data/train/10802.jpg
#   inflating: data/train/10803.jpg
#   inflating: data/train/10804.jpg
#   inflating: data/train/10805.jpg
#   inflating: data/train/10806.jpg
#   inflating: data/train/10807.jpg
#   inflating: data/train/10808.jpg
#   inflating: data/train/10809.jpg
#   inflating: data/train/1081.jpg
#   inflating: data/train/10810.jpg
#   inflating: data/train/10811.jpg
#   inflating: data/train/10812.jpg
#   inflating: data/train/10813.jpg
#   inflating: data/train/10814.jpg
#   inflating: data/train/10815.jpg
#   inflating: data/train/10816.jpg
#   inflating: data/train/10817.jpg
#   inflating: data/train/10818.jpg
#   inflating: data/train/10819.jpg
#   inflating: data/train/1082.jpg
#   inflating: data/train/10820.jpg
#   inflating: data/train/10821.jpg
#   inflating: data/train/10822.jpg
#   inflating: data/train/10823.jpg
#   inflating: data/train/10824.jpg
#   inflating: data/train/10825.jpg
#   inflating: data/train/10826.jpg
#   inflating: data/train/10827.jpg
#   inflating: data/train/10828.jpg
#   inflating: data/train/10829.jpg
#   inflating: data/train/1083.jpg
#   inflating: data/train/10830.jpg
#   inflating: data/train/10831.jpg
#   inflating: data/train/10832.jpg
#   inflating: data/train/10833.jpg
#   inflating: data/train/10834.jpg
#   inflating: data/train/10835.jpg
#   inflating: data/train/10836.jpg
#   inflating: data/train/10837.jpg
#   inflating: data/train/10838.jpg
#   inflating: data/train/10839.jpg
#   inflating: data/train/1084.jpg
#   inflating: data/train/10840.jpg
#   inflating: data/train/10841.jpg
#   inflating: data/train/10842.jpg
#   inflating: data/train/10843.jpg
#   inflating: data/train/10844.jpg
#   inflating: data/train/10845.jpg
#   inflating: data/train/10846.jpg
#   inflating: data/train/10847.jpg
#   inflating: data/train/10848.jpg
#   inflating: data/train/10849.jpg
#   inflating: data/train/1085.jpg
#   inflating: data/train/10850.jpg
#   inflating: data/train/10851.jpg
#   inflating: data/train/10852.jpg
#   inflating: data/train/10853.jpg
#   inflating: data/train/10854.jpg
#   inflating: data/train/10855.jpg
#   inflating: data/train/10856.jpg
#   inflating: data/train/10857.jpg
#   inflating: data/train/10858.jpg
#   inflating: data/train/10859.jpg
#   inflating: data/train/1086.jpg
#   inflating: data/train/10860.jpg
#   inflating: data/train/10861.jpg
#   inflating: data/train/10862.jpg
#   inflating: data/train/10863.jpg
#   inflating: data/train/10864.jpg
#   inflating: data/train/10865.jpg
#   inflating: data/train/10866.jpg
#   inflating: data/train/10867.jpg
#   inflating: data/train/10868.jpg
#   inflating: data/train/10869.jpg
#   inflating: data/train/1087.jpg
#   inflating: data/train/10870.jpg
#   inflating: data/train/10871.jpg
#   inflating: data/train/10872.jpg
#   inflating: data/train/10873.jpg
#   inflating: data/train/10874.jpg
#   inflating: data/train/10875.jpg
#   inflating: data/train/10876.jpg
#   inflating: data/train/10877.jpg
#   inflating: data/train/10878.jpg
#   inflating: data/train/10879.jpg
#   inflating: data/train/1088.jpg
#   inflating: data/train/10880.jpg
#   inflating: data/train/10881.jpg
#   inflating: data/train/10882.jpg
#   inflating: data/train/10883.jpg
#   inflating: data/train/10884.jpg
#   inflating: data/train/10885.jpg
#   inflating: data/train/10886.jpg
#   inflating: data/train/10887.jpg
#   inflating: data/train/10888.jpg
#   inflating: data/train/10889.jpg
#   inflating: data/train/1089.jpg
#   inflating: data/train/10890.jpg
#   inflating: data/train/10891.jpg
#   inflating: data/train/10892.jpg
#   inflating: data/train/10893.jpg
#   inflating: data/train/10894.jpg
#   inflating: data/train/10895.jpg
#   inflating: data/train/10896.jpg
#   inflating: data/train/10897.jpg
#   inflating: data/train/10898.jpg
#   inflating: data/train/10899.jpg
#   inflating: data/train/109.jpg
#   inflating: data/train/1090.jpg
#   inflating: data/train/10900.jpg
#   inflating: data/train/10901.jpg
#   inflating: data/train/10902.jpg
#   inflating: data/train/10903.jpg
#   inflating: data/train/10904.jpg
#   inflating: data/train/10905.jpg
#   inflating: data/train/10906.jpg
#   inflating: data/train/10907.jpg
#   inflating: data/train/10908.jpg
#   inflating: data/train/10909.jpg
#   inflating: data/train/1091.jpg
#   inflating: data/train/10910.jpg
#   inflating: data/train/10911.jpg
#   inflating: data/train/10912.jpg
#   inflating: data/train/10913.jpg
#   inflating: data/train/10914.jpg
#   inflating: data/train/10915.jpg
#   inflating: data/train/10916.jpg
#   inflating: data/train/10917.jpg
#   inflating: data/train/10918.jpg
#   inflating: data/train/10919.jpg
#   inflating: data/train/1092.jpg
#   inflating: data/train/10920.jpg
#   inflating: data/train/10921.jpg
#   inflating: data/train/10922.jpg
#   inflating: data/train/10923.jpg
#   inflating: data/train/10924.jpg
#   inflating: data/train/10925.jpg
#   inflating: data/train/10926.jpg
#   inflating: data/train/10927.jpg
#   inflating: data/train/10928.jpg
#   inflating: data/train/10929.jpg
#   inflating: data/train/1093.jpg
#   inflating: data/train/10930.jpg
#   inflating: data/train/10931.jpg
#   inflating: data/train/10932.jpg
#   inflating: data/train/10933.jpg
#   inflating: data/train/10934.jpg
#   inflating: data/train/10935.jpg
#   inflating: data/train/10936.jpg
#   inflating: data/train/10937.jpg
#   inflating: data/train/10938.jpg
#   inflating: data/train/10939.jpg
#   inflating: data/train/1094.jpg
#   inflating: data/train/10940.jpg
#   inflating: data/train/10941.jpg
#   inflating: data/train/10942.jpg
#   inflating: data/train/10943.jpg
#   inflating: data/train/10944.jpg
#   inflating: data/train/10945.jpg
#   inflating: data/train/10946.jpg
#   inflating: data/train/10947.jpg
#   inflating: data/train/10948.jpg
#   inflating: data/train/10949.jpg
#   inflating: data/train/1095.jpg
#   inflating: data/train/10950.jpg
#   inflating: data/train/10951.jpg
#   inflating: data/train/10952.jpg
#   inflating: data/train/10953.jpg
#   inflating: data/train/10954.jpg
#   inflating: data/train/10955.jpg
#   inflating: data/train/10956.jpg
#   inflating: data/train/10957.jpg
#   inflating: data/train/10958.jpg
#   inflating: data/train/10959.jpg
#   inflating: data/train/1096.jpg
#   inflating: data/train/10960.jpg
#   inflating: data/train/10961.jpg
#   inflating: data/train/10962.jpg
#   inflating: data/train/10963.jpg
#   inflating: data/train/10964.jpg
#   inflating: data/train/10965.jpg
#   inflating: data/train/10966.jpg
#   inflating: data/train/10967.jpg
#   inflating: data/train/10968.jpg
#   inflating: data/train/10969.jpg
#   inflating: data/train/1097.jpg
#   inflating: data/train/10970.jpg
#   inflating: data/train/10971.jpg
#   inflating: data/train/10972.jpg
#   inflating: data/train/10973.jpg
#   inflating: data/train/10974.jpg
#   inflating: data/train/10975.jpg
#   inflating: data/train/10976.jpg
#   inflating: data/train/10977.jpg
#   inflating: data/train/10978.jpg
#   inflating: data/train/10979.jpg
#   inflating: data/train/1098.jpg
#   inflating: data/train/10980.jpg
#   inflating: data/train/10981.jpg
#   inflating: data/train/10982.jpg
#   inflating: data/train/10983.jpg
#   inflating: data/train/10984.jpg
#   inflating: data/train/10985.jpg
#   inflating: data/train/10986.jpg
#   inflating: data/train/10987.jpg
#   inflating: data/train/10988.jpg
#   inflating: data/train/10989.jpg
#   inflating: data/train/1099.jpg
#   inflating: data/train/10990.jpg
#   inflating: data/train/10991.jpg
#   inflating: data/train/10992.jpg
#   inflating: data/train/10993.jpg
#   inflating: data/train/10994.jpg
#   inflating: data/train/10995.jpg
#   inflating: data/train/10996.jpg
#   inflating: data/train/10997.jpg
#   inflating: data/train/10998.jpg
#   inflating: data/train/10999.jpg
#   inflating: data/train/11.jpg
#   inflating: data/train/110.jpg
#   inflating: data/train/1100.jpg
#   inflating: data/train/11000.jpg
#   inflating: data/train/11001.jpg
#   inflating: data/train/11002.jpg
#   inflating: data/train/11003.jpg
#   inflating: data/train/11004.jpg
#   inflating: data/train/11005.jpg
#   inflating: data/train/11006.jpg
#   inflating: data/train/11007.jpg
#   inflating: data/train/11008.jpg
#   inflating: data/train/11009.jpg
#   inflating: data/train/1101.jpg
#   inflating: data/train/11010.jpg
#   inflating: data/train/11011.jpg
#   inflating: data/train/11012.jpg
#   inflating: data/train/11013.jpg
#   inflating: data/train/11014.jpg
#   inflating: data/train/11015.jpg
#   inflating: data/train/11016.jpg
#   inflating: data/train/11017.jpg
#   inflating: data/train/11018.jpg
#   inflating: data/train/11019.jpg
#   inflating: data/train/1102.jpg
#   inflating: data/train/11020.jpg
#   inflating: data/train/11021.jpg
#   inflating: data/train/11022.jpg
#   inflating: data/train/11023.jpg
#   inflating: data/train/11024.jpg
#   inflating: data/train/11025.jpg
#   inflating: data/train/11026.jpg
#   inflating: data/train/11027.jpg
#   inflating: data/train/11028.jpg
#   inflating: data/train/11029.jpg
#   inflating: data/train/1103.jpg
#   inflating: data/train/11030.jpg
#   inflating: data/train/11031.jpg
#   inflating: data/train/11032.jpg
#   inflating: data/train/11033.jpg
#   inflating: data/train/11034.jpg
#   inflating: data/train/11035.jpg
#   inflating: data/train/11036.jpg
#   inflating: data/train/11037.jpg
#   inflating: data/train/11038.jpg
#   inflating: data/train/11039.jpg
#   inflating: data/train/1104.jpg
#   inflating: data/train/11040.jpg
#   inflating: data/train/11041.jpg
#   inflating: data/train/11042.jpg
#   inflating: data/train/11043.jpg
#   inflating: data/train/11044.jpg
#   inflating: data/train/11045.jpg
#   inflating: data/train/11046.jpg
#   inflating: data/train/11047.jpg
#   inflating: data/train/11048.jpg
#   inflating: data/train/11049.jpg
#   inflating: data/train/1105.jpg
#   inflating: data/train/11050.jpg
#   inflating: data/train/11051.jpg
#   inflating: data/train/11052.jpg
#   inflating: data/train/11053.jpg
#   inflating: data/train/11054.jpg
#   inflating: data/train/11055.jpg
#   inflating: data/train/11056.jpg
#   inflating: data/train/11057.jpg
#   inflating: data/train/11058.jpg
#   inflating: data/train/11059.jpg
#   inflating: data/train/1106.jpg
#   inflating: data/train/11060.jpg
#   inflating: data/train/11061.jpg
#   inflating: data/train/11062.jpg
#   inflating: data/train/11063.jpg
#   inflating: data/train/11064.jpg
#   inflating: data/train/11065.jpg
#   inflating: data/train/11066.jpg
#   inflating: data/train/11067.jpg
#   inflating: data/train/11068.jpg
#   inflating: data/train/11069.jpg
#   inflating: data/train/1107.jpg
#   inflating: data/train/11070.jpg
#   inflating: data/train/11071.jpg
#   inflating: data/train/11072.jpg
#   inflating: data/train/11073.jpg
#   inflating: data/train/11074.jpg
#   inflating: data/train/11075.jpg
#   inflating: data/train/11076.jpg
#   inflating: data/train/11077.jpg
#   inflating: data/train/11078.jpg
#   inflating: data/train/11079.jpg
#   inflating: data/train/1108.jpg
#   inflating: data/train/11080.jpg
#   inflating: data/train/11081.jpg
#   inflating: data/train/11082.jpg
#   inflating: data/train/11083.jpg
#   inflating: data/train/11084.jpg
#   inflating: data/train/11085.jpg
#   inflating: data/train/11086.jpg
#   inflating: data/train/11087.jpg
#   inflating: data/train/11088.jpg
#   inflating: data/train/11089.jpg
#   inflating: data/train/1109.jpg
#   inflating: data/train/11090.jpg
#   inflating: data/train/11091.jpg
#   inflating: data/train/11092.jpg
#   inflating: data/train/11093.jpg
#   inflating: data/train/11094.jpg
#   inflating: data/train/11095.jpg
#   inflating: data/train/11096.jpg
#   inflating: data/train/11097.jpg
#   inflating: data/train/11098.jpg
#   inflating: data/train/11099.jpg
#   inflating: data/train/111.jpg
#   inflating: data/train/1110.jpg
#   inflating: data/train/11100.jpg
#   inflating: data/train/11101.jpg
#   inflating: data/train/11102.jpg
#   inflating: data/train/11103.jpg
#   inflating: data/train/11104.jpg
#   inflating: data/train/11105.jpg
#   inflating: data/train/11106.jpg
#   inflating: data/train/11107.jpg
#   inflating: data/train/11108.jpg
#   inflating: data/train/11109.jpg
#   inflating: data/train/1111.jpg
#   inflating: data/train/11110.jpg
#   inflating: data/train/11111.jpg
#   inflating: data/train/11112.jpg
#   inflating: data/train/11113.jpg
#   inflating: data/train/11114.jpg
#   inflating: data/train/11115.jpg
#   inflating: data/train/11116.jpg
#   inflating: data/train/11117.jpg
#   inflating: data/train/11118.jpg
#   inflating: data/train/11119.jpg
#   inflating: data/train/1112.jpg
#   inflating: data/train/11120.jpg
#   inflating: data/train/11121.jpg
#   inflating: data/train/11122.jpg
#   inflating: data/train/11123.jpg
#   inflating: data/train/11124.jpg
#   inflating: data/train/11125.jpg
#   inflating: data/train/11126.jpg
#   inflating: data/train/11127.jpg
#   inflating: data/train/11128.jpg
#   inflating: data/train/11129.jpg
#   inflating: data/train/1113.jpg
# ...
#   inflating: data/train/962.jpg
#   inflating: data/train/9620.jpg
#   inflating: data/train/9621.jpg
#   inflating: data/train/9622.jpg
#   inflating: data/train/9623.jpg
#   inflating: data/train/9624.jpg
#   inflating: data/train/9625.jpg
#   inflating: data/train/9626.jpg
#   inflating: data/train/9627.jpg
#   inflating: data/train/9628.jpg
#   inflating: data/train/9629.jpg
#   inflating: data/train/963.jpg
#   inflating: data/train/9630.jpg
#   inflating: data/train/9631.jpg
#   inflating: data/train/9632.jpg
#   inflating: data/train/9633.jpg
#   inflating: data/train/9634.jpg
#   inflating: data/train/9635.jpg
#   inflating: data/train/9636.jpg
#   inflating: data/train/9637.jpg
#   inflating: data/train/9638.jpg
#   inflating: data/train/9639.jpg
#   inflating: data/train/964.jpg
#   inflating: data/train/9640.jpg
#   inflating: data/train/9641.jpg
#   inflating: data/train/9642.jpg
#   inflating: data/train/9643.jpg
#   inflating: data/train/9644.jpg
#   inflating: data/train/9645.jpg
#   inflating: data/train/9646.jpg
#   inflating: data/train/9647.jpg
#   inflating: data/train/9648.jpg
#   inflating: data/train/9649.jpg
#   inflating: data/train/965.jpg
#   inflating: data/train/9650.jpg
#   inflating: data/train/9651.jpg
#   inflating: data/train/9652.jpg
#   inflating: data/train/9653.jpg
#   inflating: data/train/9654.jpg
#   inflating: data/train/9655.jpg
#   inflating: data/train/9656.jpg
#   inflating: data/train/9657.jpg
#   inflating: data/train/9658.jpg
#   inflating: data/train/9659.jpg
#   inflating: data/train/966.jpg
#   inflating: data/train/9660.jpg
#   inflating: data/train/9661.jpg
#   inflating: data/train/9662.jpg
#   inflating: data/train/9663.jpg
#   inflating: data/train/9664.jpg
#   inflating: data/train/9665.jpg
#   inflating: data/train/9666.jpg
#   inflating: data/train/9667.jpg
#   inflating: data/train/9668.jpg
#   inflating: data/train/9669.jpg
#   inflating: data/train/967.jpg
#   inflating: data/train/9670.jpg
#   inflating: data/train/9671.jpg
#   inflating: data/train/9672.jpg
#   inflating: data/train/9673.jpg
#   inflating: data/train/9674.jpg
#   inflating: data/train/9675.jpg
#   inflating: data/train/9676.jpg
#   inflating: data/train/9677.jpg
#   inflating: data/train/9678.jpg
#   inflating: data/train/9679.jpg
#   inflating: data/train/968.jpg
#   inflating: data/train/9680.jpg
#   inflating: data/train/9681.jpg
#   inflating: data/train/9682.jpg
#   inflating: data/train/9683.jpg
#   inflating: data/train/9684.jpg
#   inflating: data/train/9685.jpg
#   inflating: data/train/9686.jpg
#   inflating: data/train/9687.jpg
#   inflating: data/train/9688.jpg
#   inflating: data/train/9689.jpg
#   inflating: data/train/969.jpg
#   inflating: data/train/9690.jpg
#   inflating: data/train/9691.jpg
#   inflating: data/train/9692.jpg
#   inflating: data/train/9693.jpg
#   inflating: data/train/9694.jpg
#   inflating: data/train/9695.jpg
#   inflating: data/train/9696.jpg
#   inflating: data/train/9697.jpg
#   inflating: data/train/9698.jpg
#   inflating: data/train/9699.jpg
#   inflating: data/train/97.jpg
#   inflating: data/train/970.jpg
#   inflating: data/train/9700.jpg
#   inflating: data/train/9701.jpg
#   inflating: data/train/9702.jpg
#   inflating: data/train/9703.jpg
#   inflating: data/train/9704.jpg
#   inflating: data/train/9705.jpg
#   inflating: data/train/9706.jpg
#   inflating: data/train/9707.jpg
#   inflating: data/train/9708.jpg
#   inflating: data/train/9709.jpg
#   inflating: data/train/971.jpg
#   inflating: data/train/9710.jpg
#   inflating: data/train/9711.jpg
#   inflating: data/train/9712.jpg
#   inflating: data/train/9713.jpg
#   inflating: data/train/9714.jpg
#   inflating: data/train/9715.jpg
#   inflating: data/train/9716.jpg
#   inflating: data/train/9717.jpg
#   inflating: data/train/9718.jpg
#   inflating: data/train/9719.jpg
#   inflating: data/train/972.jpg
#   inflating: data/train/9720.jpg
#   inflating: data/train/9721.jpg
#   inflating: data/train/9722.jpg
#   inflating: data/train/9723.jpg
#   inflating: data/train/9724.jpg
#   inflating: data/train/9725.jpg
#   inflating: data/train/9726.jpg
#   inflating: data/train/9727.jpg
#   inflating: data/train/9728.jpg
#   inflating: data/train/9729.jpg
#   inflating: data/train/973.jpg
#   inflating: data/train/9730.jpg
#   inflating: data/train/9731.jpg
#   inflating: data/train/9732.jpg
#   inflating: data/train/9733.jpg
#   inflating: data/train/9734.jpg
#   inflating: data/train/9735.jpg
#   inflating: data/train/9736.jpg
#   inflating: data/train/9737.jpg
#   inflating: data/train/9738.jpg
#   inflating: data/train/9739.jpg
#   inflating: data/train/974.jpg
#   inflating: data/train/9740.jpg
#   inflating: data/train/9741.jpg
#   inflating: data/train/9742.jpg
#   inflating: data/train/9743.jpg
#   inflating: data/train/9744.jpg
#   inflating: data/train/9745.jpg
#   inflating: data/train/9746.jpg
#   inflating: data/train/9747.jpg
#   inflating: data/train/9748.jpg
#   inflating: data/train/9749.jpg
#   inflating: data/train/975.jpg
#   inflating: data/train/9750.jpg
#   inflating: data/train/9751.jpg
#   inflating: data/train/9752.jpg
#   inflating: data/train/9753.jpg
#   inflating: data/train/9754.jpg
#   inflating: data/train/9755.jpg
#   inflating: data/train/9756.jpg
#   inflating: data/train/9757.jpg
#   inflating: data/train/9758.jpg
#   inflating: data/train/9759.jpg
#   inflating: data/train/976.jpg
#   inflating: data/train/9760.jpg
#   inflating: data/train/9761.jpg
#   inflating: data/train/9762.jpg
#   inflating: data/train/9763.jpg
#   inflating: data/train/9764.jpg
#   inflating: data/train/9765.jpg
#   inflating: data/train/9766.jpg
#   inflating: data/train/9767.jpg
#   inflating: data/train/9768.jpg
#   inflating: data/train/9769.jpg
#   inflating: data/train/977.jpg
#   inflating: data/train/9770.jpg
#   inflating: data/train/9771.jpg
#   inflating: data/train/9772.jpg
#   inflating: data/train/9773.jpg
#   inflating: data/train/9774.jpg
#   inflating: data/train/9775.jpg
#   inflating: data/train/9776.jpg
#   inflating: data/train/9777.jpg
#   inflating: data/train/9778.jpg
#   inflating: data/train/9779.jpg
#   inflating: data/train/978.jpg
#   inflating: data/train/9780.jpg
#   inflating: data/train/9781.jpg
#   inflating: data/train/9782.jpg
#   inflating: data/train/9783.jpg
#   inflating: data/train/9784.jpg
#   inflating: data/train/9785.jpg
#   inflating: data/train/9786.jpg
#   inflating: data/train/9787.jpg
#   inflating: data/train/9788.jpg
#   inflating: data/train/9789.jpg
#   inflating: data/train/979.jpg
#   inflating: data/train/9790.jpg
#   inflating: data/train/9791.jpg
#   inflating: data/train/9792.jpg
#   inflating: data/train/9793.jpg
#   inflating: data/train/9794.jpg
#   inflating: data/train/9795.jpg
#   inflating: data/train/9796.jpg
#   inflating: data/train/9797.jpg
#   inflating: data/train/9798.jpg
#   inflating: data/train/9799.jpg
#   inflating: data/train/98.jpg
#   inflating: data/train/980.jpg
#   inflating: data/train/9800.jpg
#   inflating: data/train/9801.jpg
#   inflating: data/train/9802.jpg
#   inflating: data/train/9803.jpg
#   inflating: data/train/9804.jpg
#   inflating: data/train/9805.jpg
#   inflating: data/train/9806.jpg
#   inflating: data/train/9807.jpg
#   inflating: data/train/9808.jpg
#   inflating: data/train/9809.jpg
#   inflating: data/train/981.jpg
#   inflating: data/train/9810.jpg
#   inflating: data/train/9811.jpg
#   inflating: data/train/9812.jpg
#   inflating: data/train/9813.jpg
#   inflating: data/train/9814.jpg
#   inflating: data/train/9815.jpg
#   inflating: data/train/9816.jpg
#   inflating: data/train/9817.jpg
#   inflating: data/train/9818.jpg
#   inflating: data/train/9819.jpg
#   inflating: data/train/982.jpg
#   inflating: data/train/9820.jpg
#   inflating: data/train/9821.jpg
#   inflating: data/train/9822.jpg
#   inflating: data/train/9823.jpg
#   inflating: data/train/9824.jpg
#   inflating: data/train/9825.jpg
#   inflating: data/train/9826.jpg
#   inflating: data/train/9827.jpg
#   inflating: data/train/9828.jpg
#   inflating: data/train/9829.jpg
#   inflating: data/train/983.jpg
#   inflating: data/train/9830.jpg
#   inflating: data/train/9831.jpg
#   inflating: data/train/9832.jpg
#   inflating: data/train/9833.jpg
#   inflating: data/train/9834.jpg
#   inflating: data/train/9835.jpg
#   inflating: data/train/9836.jpg
#   inflating: data/train/9837.jpg
#   inflating: data/train/9838.jpg
#   inflating: data/train/9839.jpg
#   inflating: data/train/984.jpg
#   inflating: data/train/9840.jpg
#   inflating: data/train/9841.jpg
#   inflating: data/train/9842.jpg
#   inflating: data/train/9843.jpg
#   inflating: data/train/9844.jpg
#   inflating: data/train/9845.jpg
#   inflating: data/train/9846.jpg
#   inflating: data/train/9847.jpg
#   inflating: data/train/9848.jpg
#   inflating: data/train/9849.jpg
#   inflating: data/train/985.jpg
#   inflating: data/train/9850.jpg
#   inflating: data/train/9851.jpg
#   inflating: data/train/9852.jpg
#   inflating: data/train/9853.jpg
#   inflating: data/train/9854.jpg
#   inflating: data/train/9855.jpg
#   inflating: data/train/9856.jpg
#   inflating: data/train/9857.jpg
#   inflating: data/train/9858.jpg
#   inflating: data/train/9859.jpg
#   inflating: data/train/986.jpg
#   inflating: data/train/9860.jpg
#   inflating: data/train/9861.jpg
#   inflating: data/train/9862.jpg
#   inflating: data/train/9863.jpg
#   inflating: data/train/9864.jpg
#   inflating: data/train/9865.jpg
#   inflating: data/train/9866.jpg
#   inflating: data/train/9867.jpg
#   inflating: data/train/9868.jpg
#   inflating: data/train/9869.jpg
#   inflating: data/train/987.jpg
#   inflating: data/train/9870.jpg
#   inflating: data/train/9871.jpg
#   inflating: data/train/9872.jpg
#   inflating: data/train/9873.jpg
#   inflating: data/train/9874.jpg
#   inflating: data/train/9875.jpg
#   inflating: data/train/9876.jpg
#   inflating: data/train/9877.jpg
#   inflating: data/train/9878.jpg
#   inflating: data/train/9879.jpg
#   inflating: data/train/988.jpg
#   inflating: data/train/9880.jpg
#   inflating: data/train/9881.jpg
#   inflating: data/train/9882.jpg
#   inflating: data/train/9883.jpg
#   inflating: data/train/9884.jpg
#   inflating: data/train/9885.jpg
#   inflating: data/train/9886.jpg
#   inflating: data/train/9887.jpg
#   inflating: data/train/9888.jpg
#   inflating: data/train/9889.jpg
#   inflating: data/train/989.jpg
#   inflating: data/train/9890.jpg
#   inflating: data/train/9891.jpg
#   inflating: data/train/9892.jpg
#   inflating: data/train/9893.jpg
#   inflating: data/train/9894.jpg
#   inflating: data/train/9895.jpg
#   inflating: data/train/9896.jpg
#   inflating: data/train/9897.jpg
#   inflating: data/train/9898.jpg
#   inflating: data/train/9899.jpg
#   inflating: data/train/99.jpg
#   inflating: data/train/990.jpg
#   inflating: data/train/9900.jpg
#   inflating: data/train/9901.jpg
#   inflating: data/train/9902.jpg
#   inflating: data/train/9903.jpg
#   inflating: data/train/9904.jpg
#   inflating: data/train/9905.jpg
#   inflating: data/train/9906.jpg
#   inflating: data/train/9907.jpg
#   inflating: data/train/9908.jpg
#   inflating: data/train/9909.jpg
#   inflating: data/train/991.jpg
#   inflating: data/train/9910.jpg
#   inflating: data/train/9911.jpg
#   inflating: data/train/9912.jpg
#   inflating: data/train/9913.jpg
#   inflating: data/train/9914.jpg
#   inflating: data/train/9915.jpg
#   inflating: data/train/9916.jpg
#   inflating: data/train/9917.jpg
#   inflating: data/train/9918.jpg
#   inflating: data/train/9919.jpg
#   inflating: data/train/992.jpg
#   inflating: data/train/9920.jpg
#   inflating: data/train/9921.jpg
#   inflating: data/train/9922.jpg
#   inflating: data/train/9923.jpg
#   inflating: data/train/9924.jpg
#   inflating: data/train/9925.jpg
#   inflating: data/train/9926.jpg
#   inflating: data/train/9927.jpg
#   inflating: data/train/9928.jpg
#   inflating: data/train/9929.jpg
#   inflating: data/train/993.jpg
#   inflating: data/train/9930.jpg
#   inflating: data/train/9931.jpg
#   inflating: data/train/9932.jpg
#   inflating: data/train/9933.jpg
#   inflating: data/train/9934.jpg
#   inflating: data/train/9935.jpg
#   inflating: data/train/9936.jpg
#   inflating: data/train/9937.jpg
#   inflating: data/train/9938.jpg
#   inflating: data/train/9939.jpg
#   inflating: data/train/994.jpg
#   inflating: data/train/9940.jpg
#   inflating: data/train/9941.jpg
#   inflating: data/train/9942.jpg
#   inflating: data/train/9943.jpg
#   inflating: data/train/9944.jpg
#   inflating: data/train/9945.jpg
#   inflating: data/train/9946.jpg
#   inflating: data/train/9947.jpg
#   inflating: data/train/9948.jpg
#   inflating: data/train/9949.jpg
#   inflating: data/train/995.jpg
#   inflating: data/train/9950.jpg
#   inflating: data/train/9951.jpg
#   inflating: data/train/9952.jpg
#   inflating: data/train/9953.jpg
#   inflating: data/train/9954.jpg
#   inflating: data/train/9955.jpg
#   inflating: data/train/9956.jpg
#   inflating: data/train/9957.jpg
#   inflating: data/train/9958.jpg
#   inflating: data/train/9959.jpg
#   inflating: data/train/996.jpg
#   inflating: data/train/9960.jpg
#   inflating: data/train/9961.jpg
#   inflating: data/train/9962.jpg
#   inflating: data/train/9963.jpg
#   inflating: data/train/9964.jpg
#   inflating: data/train/9965.jpg
#   inflating: data/train/9966.jpg
#   inflating: data/train/9967.jpg
#   inflating: data/train/9968.jpg
#   inflating: data/train/9969.jpg
#   inflating: data/train/997.jpg
#   inflating: data/train/9970.jpg
#   inflating: data/train/9971.jpg
#   inflating: data/train/9972.jpg
#   inflating: data/train/9973.jpg
#   inflating: data/train/9974.jpg
#   inflating: data/train/9975.jpg
#   inflating: data/train/9976.jpg
#   inflating: data/train/9977.jpg
#   inflating: data/train/9978.jpg
#   inflating: data/train/9979.jpg
#   inflating: data/train/998.jpg
#   inflating: data/train/9980.jpg
#   inflating: data/train/9981.jpg
#   inflating: data/train/9982.jpg
#   inflating: data/train/9983.jpg
#   inflating: data/train/9984.jpg
#   inflating: data/train/9985.jpg
#   inflating: data/train/9986.jpg
#   inflating: data/train/9987.jpg
#   inflating: data/train/9988.jpg
#   inflating: data/train/9989.jpg
#   inflating: data/train/999.jpg
#   inflating: data/train/9990.jpg
#   inflating: data/train/9991.jpg
#   inflating: data/train/9992.jpg
#   inflating: data/train/9993.jpg
#   inflating: data/train/9994.jpg
#   inflating: data/train/9995.jpg
#   inflating: data/train/9996.jpg
#   inflating: data/train/9997.jpg
#   inflating: data/train/9998.jpg
#   inflating: data/train/9999.jpg

# %%
print("all files unzipped. Images in train folder and labels in test.csv")
# Out:
# all files unzipped. Images in train folder and labels in test.csv

# %% [markdown]
# ### Separate the Test Files in a separate Test Folder

# %%
test_df = pd.read_csv('data/test.csv')
test_df.head()
# Out:
#   image_name
# 0      3.jpg
# 1      5.jpg
# 2      6.jpg
# 3     11.jpg
# 4     14.jpg

# %%
test_df.to_csv("out.csv", index=False,header=False) ## create the csv file without the Headers

#Just the header has been removed from the test labels for the below cell to run correctly
#test_df2 = pd.read_csv('out.csv')
#test_df2.head()
# !rsync --files-from=out.csv data/train data/test

# %%
print("Now we have separated the Test files from Train and put in Test Folder itself")
# Out:
# Now we have separated the Test files from Train and put in Test Folder itself

# %% [markdown]
# ###Setting the path for data

# %% [markdown]
# We are going to use the [Intel Image Scene](https://www.kaggle.com/nitishabharathi/scene-classification) by [Analytics Vidhya](https://datahack.analyticsvidhya.com/contest/practice-problem-intel-scene-classification-challe/) which features 6 scenes.
#
# Our model will need to learn to differentiate between these 6 distinct categories.
# We use **FASTAI-V1** model to get the results.

# %% [markdown]
# ####DATASET DESCRIPTION
# **There are 17034 images in train and 7301 images in test data.**
#
# The categories of natural scenes and their corresponding labels in the dataset are as follows -
#
#  ** 'buildings' -> 0,**
#
# **'forest' -> 1,**
#
# **'glacier' -> 2,**
#
# **'mountain' -> 3,**
#
# **'sea' -> 4, **
#
# **'street' -> 5 **
#
# There are three files provided to you, viz **train.zip, test.csv and sample_submission.csv** which have the following structure.
#
# Variable	Definition
#
# image_name	Name of the image in the dataset (ID column)
#
# label	Category of natural scene (target column)
#
# **train.zip contains the images corresponding to both train and test set along with the true labels for train set images in train.csv**

# %%
path = 'data';path
# Out:
# 'data'

# %%
path_img = 'data/train'

# %%
fnames = get_image_files(path_img)
fnames[:5]
# Out:
# [PosixPath('data/train/11268.jpg'),
#  PosixPath('data/train/21500.jpg'),
#  PosixPath('data/train/16973.jpg'),
#  PosixPath('data/train/19996.jpg'),
#  PosixPath('data/train/22797.jpg')]

# %%
from IPython.display import Image 
Image(filename='data/train/13664.jpg')

# %%
from IPython.display import Image 
Image(filename='data/train/11432.jpg')

# %%
os.listdir('data/')
# Out:
# ['test.csv', 'train', 'test']

# %% [markdown]
# ###Loading and Understanding the Data
# The first thing we do when we approach a problem is to take a look at the data. We _always_ need to understand very well what the problem is and what the data looks like before we can figure out how to solve it. Taking a look at the data, means **understanding how the data directories are structured**, what the **labels** are and what some **sample images** look like.
#
# The main difference between the handling of image classification datasets is the way labels are stored. In this particular dataset, **6 labels** are stored based on the csv files.
#
# Fortunately, the fastai library has a handy function made exactly for this.
#
# [Image data from CSV / DataFrame](https://docs.fast.ai/vision.data.html#ImageDataBunch.from_csv).

# %% [markdown]
# ##Loading Labels [From_CSV](https://github.com/fastai/fastai/blob/master/fastai/vision/data.py#L131)
#
# from_csv[source]
#
# from_csv(`path`:PathOrStr, `folder`:PathOrStr=`'.'`, `sep`=`None`, `csv_labels`:PathOrStr=`'labels.csv'`, `valid_pct`:float=`0.2`, `fn_col`:int=`0`, `label_col`:int=`1`, `suffix`:str=`''`, `header`:Union[int, str, NoneType]=`'infer'`, `kwargs`:Any) → ImageDataBunch
#
# Create from a csv file in path/csv_labels.
#
# **data = ImageDataBunch.from_csv(path, ds_tfms=tfms, size=24);**

# %% [markdown]
# **File Structure**
#
# path\
#
#     labels.csv -> label for training images
#     test.csv -> list of test images without labels
#
#     train\
#       training images
#     test\
#        testing images
#
#  train.csv contains correct labels of **17034 images** in train
#
#  test.csv contains list of **7301 images** in train folder itself but without labels.

# %%
tfms = get_transforms()
data = ImageDataBunch.from_csv(path_img, ds_tfms=tfms, size=300)
#data = ImageDataBunch.from_csv(path, train='train','../labels.csv', valid_pct=0.2, ds_tfms=tfms, size=224,classes=[str(i) for i in range(6)])

# %%
label_df = pd.read_csv('data/train/labels.csv')
label_df.head()
# Out:
#   image_name  label
# 0      0.jpg      0
# 1      1.jpg      4
# 2      2.jpg      5
# 3      4.jpg      0
# 4      7.jpg      4

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# [0, 1, 2, 3, 4, 5]
# (6, 6)

# %%
data.show_batch(rows=3, figsize=(12,9))

# %% [markdown]
# # Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. It will be explained later in the course and you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us use larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network will require more GPU memory.

# %%
#For Metrics to have Top 3 results
from fastai import *
from sklearn import metrics as skm

# %%
learn = create_cnn(data, models.resnet50, metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.torch/models/resnet50-19c8e357.pth
# 100%|██████████| 102502400/102502400 [00:04<00:00, 23625188.90it/s]

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='progress-bar-interrupted' max='212', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       Interrupted
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %% [markdown]
# ##Train and save the model checkpoint

# %%
#Run this when training
learn.fit_one_cycle(5) ## best way to fit as of 2018
print("learning complete")
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='5', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       20.00% [1/5 07:09<28:38]
#     </div>
#
# <table style='width:300px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.352410</th>
#     <th>0.216003</th>
#     <th>0.918086</th>
#   </tr>
# </table>
#
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='212', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.60% [14/212 00:27<06:24 0.3293]
#     </div>

# %%
print("we save after 1st weights are learned")
learn.save('stage-1-550')

# %% [markdown]
# Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))

# %%
learn.save('stage-2-9495')
#learn.load('stage-2-9495')

print("we save after 2nd weights are learned")

# %%
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# If it doesn't, you can always go back to your previous model.

# %%
learn.save('stage-3-9527')
#learn.load('stage-3-9527')

print("we save after unfreezing 3rd weights are learned")

# %%
print("weights loaded")
#Load the pre-trained model weights
#!mv stage-3-9527.pth data/train/models/stage-3-9527.pth
#!mv stage-2-550.pth data/train/models/stage-2-550.pth
learn.load('stage-3-9527')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# The categories of natural scenes and their corresponding labels in the dataset are as follows -
#
# **'buildings' -> 0,
# 'forest' -> 1,
# 'glacier' -> 2,
# 'mountain' -> 3,
# 'sea' -> 4,
# 'street' -> 5**

# %% [markdown]
# ## New Section

# %% [markdown]
# **interp.plot_top_losses(9, figsize=(15,11)) # Prediction/ Actual/ Loss/ Probability**

# %%
interp.plot_top_losses(9, figsize=(15,11)) # Prediction/ Actual/ Loss/ Probability
'''
The categories of natural scenes and their corresponding labels in the dataset are as follows -
'buildings' -> 0, 'forest' -> 1, 'glacier' -> 2, 'mountain' -> 3, 'sea' -> 4, 'street' -> 5'''

# %%
interp.most_confused()

# %%
interp.plot_confusion_matrix(figsize=(10,10), dpi=60)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
#
#
# ---

# %% [markdown]
# ## Add the Test Folder

# %%
# now replace the validation dataset entry with the test dataset as a new validation dataset: 
# everything is exactly the same, except replacing `split_by_pct` w/ `split_by_folder` 
# (or perhaps you were already using the latter, so simply switch to valid='test')
data_test = (ImageItemList.from_csv(path_img,csv_name='labels.csv')
        .split_by_folder(train='train', valid='../test')
        .label_from_csv()
        .transform(tfms)
        .databunch()
        .normalize()
       ) 
learn.data = data_test
learn.validate()

# %%
data = ImageDataBunch.from_csv(path_img, ds_tfms=tfms, size=300)

# %% [markdown]
# ###Start the Prediction for the Test Dataset based on test csv

# %%
#test_files = os.listdir('data/test')
#test_df = pd.read_csv(f'{path}test.csv')
#print("test files are") 
#test_files
#test_file_name = pd.DataFrame(test_files)
print(test_file_name.nunique())

# %%
#demo = []
  img = learn.data.test_ds[0][0]
  a = learn.predict(img)
  b = list(a)[2]
  print(a)
  c = pd.DataFrame([[i, b[i]] for i in range(len(b))])
  c.columns = ["class","probability"]
  #print(c)
  d = c.sort_values("probability", ascending = False)
  #demo.append(d[:3])
  #d = sorted(c, reverse = True)
  print(d[:3])

#??learn.predict

# %%
preds,_ = learn.get_preds(DatasetType.Test);

# %%
pred,y = learn.TTA(DatasetType.Test);

# %%
# Predict into the test set
learn.get_preds(DatasetType.Test)
test_output = learn.get_preds(is_test=True)
log_probs, y = test_output

# %%
DatasetType.Test[0]

# %%
test_ids = list(sorted({fname.split('_')[0] for fname in os.listdir(path/'test')}))

data.test_ds.x

test.
#pred_labels = [' '.join(list([str(i) for i in np.nonzero(row>0.2)[0]])) for row in np.array(preds)];pred_labels
#df = pd.DataFrame({'Id':test_ids,'Predicted':pred_labels})
#df.to_csv(path/'protein_predictions_datablocks.csv', header=True, index=False)

# %%
preds.info()

# %%
predsnp = np.array(preds)
predsdf = pd.DataFrame(predsnp)

# %%
predsdf

# %%
predsdf.to_csv("preds.csv")
